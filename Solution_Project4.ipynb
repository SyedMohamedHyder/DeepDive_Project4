# %%
import itertools
import csv

# %%
def read_file(filename):
    with open(filename, 'r') as file:
        yield from file

# %%
lines = read_file('employment.csv')

# %%
next(lines)
# Out:
# 'employer,department,employee_id,ssn\n'

# %%
with open('personal_info.csv', 'r') as file:
    for line in itertools.islice(file, 5):
        print(line, end='')
# Out:
# ssn,first_name,last_name,gender,language
# 100-53-9824,Sebastiano,Tester,Male,Icelandic
# 101-71-4702,Cayla,MacDonagh,Female,Lao
# 101-84-0356,Nomi,Lipprose,Female,Yiddish
# 104-22-0928,Justinian,Kunzelmann,Male,Dhivehi

# %%
with open('vehicles.csv', 'r') as file:
    for line in itertools.islice(file, 5):
        print(line, end='')
# Out:
# ssn,vehicle_make,vehicle_model,model_year
# 100-53-9824,Oldsmobile,Bravada,1993
# 101-71-4702,Ford,Mustang,1997
# 101-84-0356,GMC,Yukon,2005
# 104-22-0928,Oldsmobile,Intrigue,2000

# %%
with open('employment.csv', 'r') as file:
    for line in itertools.islice(file, 15):
        print(line, end='')
# Out:
# employer,department,employee_id,ssn
# Stiedemann-Bailey,Research and Development,29-0890771,100-53-9824
# Nicolas and Sons,Sales,41-6841359,101-71-4702
# Connelly Group,Research and Development,98-7952860,101-84-0356
# Upton LLC,Marketing,56-9817552,104-22-0928
# Zemlak-Olson,Business Development,46-2886707,104-84-7144
# "Kohler, Bradtke and Davis",Support,80-0975518,105-27-5541
# "Roberts, Torphy and Dach",Human Resources,77-4895332,105-85-7486
# Lind-Jast,Marketing,79-6418731,105-91-5022
# Bashirian-Lueilwitz,Engineering,44-3328799,105-91-7777
# "Windler, Marks and Haley",Services,54-6271885,106-35-1938
# Leffler-Hahn,Accounting,31-5735282,106-36-3293
# Lueilwitz LLC,Marketing,33-9146042,110-84-3641
# Davis Inc,Accounting,39-0400385,111-35-1034
# Kunze LLC,Research and Development,78-2612900,114-06-6912

# %%
with open('update_status.csv', 'r') as file:
    for line in itertools.islice(file, 5):
        print(line, end='')
# Out:
# ssn,last_updated,created
# 100-53-9824,2017-10-07T00:14:42Z,2016-01-24T21:19:30Z
# 101-71-4702,2017-01-23T11:23:17Z,2016-01-27T04:32:57Z
# 101-84-0356,2017-10-04T11:21:30Z,2016-09-21T23:04:07Z
# 104-22-0928,2017-03-28T12:38:29Z,2016-04-15T11:37:17Z

# %%
from datetime import datetime
from collections import namedtuple

# %%
def parse_data(value):
    data_parser ={
        
        'ssn' : lambda number : int(number.replace('-','')),
        'model_year' : int,
        'employee_id' : lambda number : int(number.replace('-','')),
        'last_updated' : lambda date : datetime.strptime(date, '%Y-%m-%dT%H:%M:%SZ'),
        'created' : lambda date : datetime.strptime(date, '%Y-%m-%dT%H:%M:%SZ')
        
    }
    return (data_parser.get(datatype, str)(data) for data, datatype in value)

# %%
def file_to_iter(filename):
    with open(filename, 'r') as file:
        reader = csv.reader(file, delimiter=',', quotechar='"')
        headers = next(reader)
        name = filename.replace('.csv','').title()
        Data = namedtuple(name , headers)
        for line in reader:
            data = parse_data(zip(line, headers))
            yield Data(*data)

# %%
personal_info_iter = file_to_iter('personal_info.csv')

# %%
vehicles_iter = file_to_iter('vehicles.csv')

# %%
for line in itertools.islice(vehicles_iter, 5):
    print(line)
# Out:
# Vehicles(ssn=100539824, vehicle_make='Oldsmobile', vehicle_model='Bravada', model_year=1993)
# Vehicles(ssn=101714702, vehicle_make='Ford', vehicle_model='Mustang', model_year=1997)
# Vehicles(ssn=101840356, vehicle_make='GMC', vehicle_model='Yukon', model_year=2005)
# Vehicles(ssn=104220928, vehicle_make='Oldsmobile', vehicle_model='Intrigue', model_year=2000)
# Vehicles(ssn=104847144, vehicle_make='Ford', vehicle_model='Crown Victoria', model_year=2008)

# %%
updated_status_iter = file_to_iter('update_status.csv')

# %%
for line in itertools.islice(updated_status_iter, 15):
    print(line)
# Out:
# Update_Status(ssn=100539824, last_updated=datetime.datetime(2017, 10, 7, 0, 14, 42), created=datetime.datetime(2016, 1, 24, 21, 19, 30))
# Update_Status(ssn=101714702, last_updated=datetime.datetime(2017, 1, 23, 11, 23, 17), created=datetime.datetime(2016, 1, 27, 4, 32, 57))
# Update_Status(ssn=101840356, last_updated=datetime.datetime(2017, 10, 4, 11, 21, 30), created=datetime.datetime(2016, 9, 21, 23, 4, 7))
# Update_Status(ssn=104220928, last_updated=datetime.datetime(2017, 3, 28, 12, 38, 29), created=datetime.datetime(2016, 4, 15, 11, 37, 17))
# Update_Status(ssn=104847144, last_updated=datetime.datetime(2018, 2, 19, 1, 34, 33), created=datetime.datetime(2016, 3, 15, 14, 7, 57))
# Update_Status(ssn=105275541, last_updated=datetime.datetime(2017, 7, 24, 8, 58, 52), created=datetime.datetime(2016, 7, 23, 17, 58, 35))
# Update_Status(ssn=105857486, last_updated=datetime.datetime(2018, 2, 14, 11, 32, 39), created=datetime.datetime(2016, 12, 15, 5, 46, 43))
# Update_Status(ssn=105915022, last_updated=datetime.datetime(2018, 3, 24, 14, 29, 33), created=datetime.datetime(2016, 3, 24, 3, 43, 3))
# Update_Status(ssn=105917777, last_updated=datetime.datetime(2017, 5, 11, 1, 48, 32), created=datetime.datetime(2016, 5, 31, 0, 38, 13))
# Update_Status(ssn=106351938, last_updated=datetime.datetime(2017, 10, 21, 1, 7, 28), created=datetime.datetime(2016, 9, 8, 4, 2, 12))
# Update_Status(ssn=106363293, last_updated=datetime.datetime(2017, 3, 18, 18, 24, 17), created=datetime.datetime(2016, 5, 16, 21, 21, 36))
# Update_Status(ssn=110843641, last_updated=datetime.datetime(2017, 9, 4, 19, 2, 3), created=datetime.datetime(2016, 9, 12, 22, 50, 5))
# Update_Status(ssn=111351034, last_updated=datetime.datetime(2017, 3, 18, 14, 51, 4), created=datetime.datetime(2016, 8, 21, 7, 36, 17))
# Update_Status(ssn=114066912, last_updated=datetime.datetime(2018, 2, 5, 20, 48, 34), created=datetime.datetime(2016, 7, 15, 21, 58, 3))
# Update_Status(ssn=114660984, last_updated=datetime.datetime(2017, 6, 16, 17, 41, 33), created=datetime.datetime(2016, 5, 28, 20, 31, 25))

# %%
for line in itertools.islice(personal_info_iter, 15):
    print(line)
# Out:
# Personal_Info(ssn=100539824, first_name='Sebastiano', last_name='Tester', gender='Male', language='Icelandic')
# Personal_Info(ssn=101714702, first_name='Cayla', last_name='MacDonagh', gender='Female', language='Lao')
# Personal_Info(ssn=101840356, first_name='Nomi', last_name='Lipprose', gender='Female', language='Yiddish')
# Personal_Info(ssn=104220928, first_name='Justinian', last_name='Kunzelmann', gender='Male', language='Dhivehi')
# Personal_Info(ssn=104847144, first_name='Claudianus', last_name='Brixey', gender='Male', language='Afrikaans')
# Personal_Info(ssn=105275541, first_name='Federico', last_name='Aggett', gender='Male', language='Chinese')
# Personal_Info(ssn=105857486, first_name='Angelina', last_name='McAvey', gender='Female', language='Punjabi')
# Personal_Info(ssn=105915022, first_name='Moselle', last_name='Apfel', gender='Female', language='Latvian')
# Personal_Info(ssn=105917777, first_name='Audi', last_name='Roach', gender='Female', language='Estonian')
# Personal_Info(ssn=106351938, first_name='Mackenzie', last_name='Nussey', gender='Male', language='Swedish')
# Personal_Info(ssn=106363293, first_name='Martino', last_name='Tregoning', gender='Male', language='Tok Pisin')
# Personal_Info(ssn=110843641, first_name='Amberly', last_name='Huws', gender='Female', language='Papiamento')
# Personal_Info(ssn=111351034, first_name='Giacopo', last_name='Timperley', gender='Male', language='Gagauz')
# Personal_Info(ssn=114066912, first_name='Jule', last_name='Velte', gender='Male', language='Dutch')
# Personal_Info(ssn=114660984, first_name='Casandra', last_name='Juares', gender='Female', language='Lithuanian')

# %%
employment_iter = file_to_iter('employment.csv')

# %%
for line in itertools.islice(employment_iter, 15):
    print(line)
# Out:
# Employment(employer='Stiedemann-Bailey', department='Research and Development', employee_id=290890771, ssn=100539824)
# Employment(employer='Nicolas and Sons', department='Sales', employee_id=416841359, ssn=101714702)
# Employment(employer='Connelly Group', department='Research and Development', employee_id=987952860, ssn=101840356)
# Employment(employer='Upton LLC', department='Marketing', employee_id=569817552, ssn=104220928)
# Employment(employer='Zemlak-Olson', department='Business Development', employee_id=462886707, ssn=104847144)
# Employment(employer='Kohler, Bradtke and Davis', department='Support', employee_id=800975518, ssn=105275541)
# Employment(employer='Roberts, Torphy and Dach', department='Human Resources', employee_id=774895332, ssn=105857486)
# Employment(employer='Lind-Jast', department='Marketing', employee_id=796418731, ssn=105915022)
# Employment(employer='Bashirian-Lueilwitz', department='Engineering', employee_id=443328799, ssn=105917777)
# Employment(employer='Windler, Marks and Haley', department='Services', employee_id=546271885, ssn=106351938)
# Employment(employer='Leffler-Hahn', department='Accounting', employee_id=315735282, ssn=106363293)
# Employment(employer='Lueilwitz LLC', department='Marketing', employee_id=339146042, ssn=110843641)
# Employment(employer='Davis Inc', department='Accounting', employee_id=390400385, ssn=111351034)
# Employment(employer='Kunze LLC', department='Research and Development', employee_id=782612900, ssn=114066912)
# Employment(employer='Mayert, Rice and Schmitt', department='Product Management', employee_id=858596488, ssn=114660984)

# %% [markdown]
# # Goal 1

# %%
def parse_data(value):
    data_parser ={
        
        'ssn' : lambda number : int(number.replace('-','')),
        'model_year' : int,
        'employee_id' : lambda number : int(number.replace('-','')),
        'last_updated' : lambda date : datetime.strptime(date, '%Y-%m-%dT%H:%M:%SZ'),
        'created' : lambda date : datetime.strptime(date, '%Y-%m-%dT%H:%M:%SZ')
        
    }
    return (data_parser.get(datatype, str)(data) for data, datatype in value)

def file_to_iter(filename):
    with open(filename, 'r') as file:
        reader = csv.reader(file, delimiter=',', quotechar='"')
        name = filename.replace('.csv','').title()
        headers = next(reader)
        Data_tuple = namedtuple(name , headers)
        for line in reader:
            data = parse_data(zip(line, headers))
            yield Data_tuple(*data)

# %%
personal_info_iter = file_to_iter('personal_info.csv')
vehicles_iter = file_to_iter('vehicles.csv')
employment_iter = file_to_iter('employment.csv')
updated_status_iter = file_to_iter('update_status.csv')

# %%
length = 0
for data in personal_info_iter:
    length += 1
print(length)
# Out:
# 1000

# %%
length = 0
for data in vehicles_iter:
    length += 1
print(length)
# Out:
# 1000

# %%
length = 0
for data in employment_iter:
    length += 1
print(length)
# Out:
# 1000

# %%
length = 0
for data in updated_status_iter:
    length += 1
print(length)
# Out:
# 1000

# %%
personal_info_iter = file_to_iter('personal_info.csv')
vehicles_iter = file_to_iter('vehicles.csv')
employment_iter = file_to_iter('employment.csv')
updated_status_iter = file_to_iter('update_status.csv')

# %%
for data in personal_info_iter:
    print(data)
# Out:
# Personal_Info(ssn=100539824, first_name='Sebastiano', last_name='Tester', gender='Male', language='Icelandic')
# Personal_Info(ssn=101714702, first_name='Cayla', last_name='MacDonagh', gender='Female', language='Lao')
# Personal_Info(ssn=101840356, first_name='Nomi', last_name='Lipprose', gender='Female', language='Yiddish')
# Personal_Info(ssn=104220928, first_name='Justinian', last_name='Kunzelmann', gender='Male', language='Dhivehi')
# Personal_Info(ssn=104847144, first_name='Claudianus', last_name='Brixey', gender='Male', language='Afrikaans')
# Personal_Info(ssn=105275541, first_name='Federico', last_name='Aggett', gender='Male', language='Chinese')
# Personal_Info(ssn=105857486, first_name='Angelina', last_name='McAvey', gender='Female', language='Punjabi')
# Personal_Info(ssn=105915022, first_name='Moselle', last_name='Apfel', gender='Female', language='Latvian')
# Personal_Info(ssn=105917777, first_name='Audi', last_name='Roach', gender='Female', language='Estonian')
# Personal_Info(ssn=106351938, first_name='Mackenzie', last_name='Nussey', gender='Male', language='Swedish')
# Personal_Info(ssn=106363293, first_name='Martino', last_name='Tregoning', gender='Male', language='Tok Pisin')
# Personal_Info(ssn=110843641, first_name='Amberly', last_name='Huws', gender='Female', language='Papiamento')
# Personal_Info(ssn=111351034, first_name='Giacopo', last_name='Timperley', gender='Male', language='Gagauz')
# Personal_Info(ssn=114066912, first_name='Jule', last_name='Velte', gender='Male', language='Dutch')
# Personal_Info(ssn=114660984, first_name='Casandra', last_name='Juares', gender='Female', language='Lithuanian')
# Personal_Info(ssn=114748701, first_name='Levey', last_name='Baradel', gender='Male', language='Icelandic')
# Personal_Info(ssn=116107235, first_name='Chiquita', last_name='Danbi', gender='Female', language='Dari')
# Personal_Info(ssn=116774915, first_name='Herold', last_name='Fearon', gender='Male', language='Italian')
# Personal_Info(ssn=117396617, first_name='Auroora', last_name='Yong', gender='Female', language='Swahili')
# Personal_Info(ssn=117779748, first_name='Lucien', last_name='Smalman', gender='Male', language='Hebrew')
# Personal_Info(ssn=117786202, first_name='Dareen', last_name='Jiggins', gender='Female', language='Polish')
# Personal_Info(ssn=118210357, first_name='Laina', last_name='Bayly', gender='Female', language='Bulgarian')
# Personal_Info(ssn=118957100, first_name='Alexi', last_name='Leglise', gender='Female', language='Lithuanian')
# Personal_Info(ssn=119078817, first_name='Blondie', last_name='Powderham', gender='Female', language='Croatian')
# Personal_Info(ssn=120335535, first_name='Eugen', last_name='Shark', gender='Male', language='Dhivehi')
# Personal_Info(ssn=120984054, first_name='Lorry', last_name='Hitter', gender='Male', language='Kazakh')
# Personal_Info(ssn=121983948, first_name='Sal', last_name='Le Lievre', gender='Male', language='Croatian')
# Personal_Info(ssn=123053229, first_name='Spenser', last_name='Shucksmith', gender='Male', language='Bosnian')
# Personal_Info(ssn=123622832, first_name='Kare', last_name='Barhams', gender='Female', language='Tajik')
# Personal_Info(ssn=123883381, first_name='Christiane', last_name='Hynes', gender='Female', language='Danish')
# Personal_Info(ssn=125079434, first_name='Florella', last_name='Mathevon', gender='Female', language='Armenian')
# Personal_Info(ssn=127492473, first_name='Quinta', last_name='Rippingall', gender='Female', language='Haitian Creole')
# Personal_Info(ssn=127528001, first_name='Wilona', last_name='Noirel', gender='Female', language='Aymara')
# Personal_Info(ssn=127684232, first_name='Tresa', last_name='Verheyden', gender='Female', language='Icelandic')
# Personal_Info(ssn=127933548, first_name='Mellicent', last_name='Ingham', gender='Female', language='Lao')
# Personal_Info(ssn=128424599, first_name='Neddy', last_name="O'Griffin", gender='Male', language='Croatian')
# Personal_Info(ssn=128530369, first_name='Chucho', last_name='Rikel', gender='Male', language='Croatian')
# Personal_Info(ssn=128537952, first_name='Tobie', last_name='Newhouse', gender='Male', language='Luxembourgish')
# Personal_Info(ssn=128566040, first_name='Jinny', last_name='Stebbings', gender='Female', language='Armenian')
# Personal_Info(ssn=128604388, first_name='Norton', last_name='Shailer', gender='Male', language='Czech')
# Personal_Info(ssn=129670291, first_name='Danella', last_name='Linacre', gender='Female', language='Dzongkha')
# Personal_Info(ssn=131814310, first_name='Jemie', last_name='Manilo', gender='Female', language='Finnish')
# Personal_Info(ssn=132263507, first_name='Shalom', last_name='Arendsen', gender='Male', language='Hindi')
# Personal_Info(ssn=134050120, first_name='Simone', last_name='Cruickshanks', gender='Female', language='Filipino')
# Personal_Info(ssn=135869625, first_name='Tilly', last_name='Meir', gender='Female', language='Gagauz')
# Personal_Info(ssn=137131889, first_name='Tedman', last_name="O'Donnelly", gender='Male', language='Bislama')
# Personal_Info(ssn=138654579, first_name='Davidson', last_name='Gregoraci', gender='Male', language='Luxembourgish')
# Personal_Info(ssn=138671198, first_name='Pam', last_name='Tofful', gender='Female', language='Bislama')
# Personal_Info(ssn=138885288, first_name='Joletta', last_name='Babcock', gender='Female', language='Burmese')
# Personal_Info(ssn=139048189, first_name='Stirling', last_name='Creak', gender='Male', language='Italian')
# Personal_Info(ssn=139945865, first_name='Donalt', last_name='Plewes', gender='Male', language='Haitian Creole')
# Personal_Info(ssn=139996417, first_name='Susanetta', last_name='Nazaret', gender='Female', language='Punjabi')
# Personal_Info(ssn=140339727, first_name='Price', last_name='Butterwick', gender='Male', language='Belarusian')
# Personal_Info(ssn=140588263, first_name='Tim', last_name='Bergin', gender='Female', language='Maori')
# Personal_Info(ssn=141150543, first_name='Candy', last_name='Murtagh', gender='Female', language='Montenegrin')
# Personal_Info(ssn=141889721, first_name='Cyrille', last_name='Capponer', gender='Male', language='Tswana')
# Personal_Info(ssn=142774616, first_name='Barron', last_name='Victoria', gender='Male', language='Assamese')
# Personal_Info(ssn=142873416, first_name='Margaux', last_name='Wintringham', gender='Female', language='Tajik')
# Personal_Info(ssn=143174714, first_name='Hallie', last_name='Jeggo', gender='Female', language='Greek')
# Personal_Info(ssn=145108454, first_name='Donny', last_name='Laba', gender='Male', language='Japanese')
# Personal_Info(ssn=145355124, first_name='Leon', last_name='Boyson', gender='Male', language='Dhivehi')
# Personal_Info(ssn=145783985, first_name='Baron', last_name='Cocci', gender='Male', language='Mongolian')
# Personal_Info(ssn=146813446, first_name='Korry', last_name='Billham', gender='Female', language='Hebrew')
# Personal_Info(ssn=147331463, first_name='Bendicty', last_name='Gentry', gender='Male', language='Papiamento')
# Personal_Info(ssn=147478577, first_name='Janessa', last_name='Growy', gender='Female', language='Gujarati')
# Personal_Info(ssn=147633462, first_name='Aime', last_name='Di Antonio', gender='Female', language='Tok Pisin')
# Personal_Info(ssn=148607519, first_name='Jordan', last_name='Readwood', gender='Female', language='Khmer')
# Personal_Info(ssn=149187272, first_name='Andrey', last_name='Bettley', gender='Male', language='Papiamento')
# Personal_Info(ssn=149456482, first_name='Wheeler', last_name='Harbottle', gender='Male', language='Georgian')
# Personal_Info(ssn=150646357, first_name='Helenka', last_name='Summerell', gender='Female', language='Bosnian')
# Personal_Info(ssn=150893343, first_name='Bram', last_name='Beetlestone', gender='Male', language='Dzongkha')
# Personal_Info(ssn=151543946, first_name='Piggy', last_name='Fishly', gender='Male', language='Nepali')
# Personal_Info(ssn=151700641, first_name='Urbain', last_name='Balint', gender='Male', language='Malagasy')
# Personal_Info(ssn=151781397, first_name='Portia', last_name='Belshaw', gender='Female', language='Sotho')
# Personal_Info(ssn=152713526, first_name='Mel', last_name='Atkirk', gender='Female', language='Swedish')
# Personal_Info(ssn=153671309, first_name='Annelise', last_name='Yushin', gender='Female', language='French')
# Personal_Info(ssn=154177912, first_name='Ainslee', last_name='Branche', gender='Female', language='Hindi')
# Personal_Info(ssn=156187547, first_name='Trey', last_name='Payne', gender='Male', language='West Frisian')
# Personal_Info(ssn=156916848, first_name='Carol', last_name='Cromar', gender='Female', language='Amharic')
# Personal_Info(ssn=157179982, first_name='Ardyce', last_name='Kuhnel', gender='Female', language='Danish')
# Personal_Info(ssn=157387090, first_name='Johannes', last_name='Bugge', gender='Male', language='Afrikaans')
# Personal_Info(ssn=157515269, first_name='Melisse', last_name='Petkov', gender='Female', language='Punjabi')
# Personal_Info(ssn=161369710, first_name='Melina', last_name='MacDavitt', gender='Female', language='Polish')
# Personal_Info(ssn=161534778, first_name='Kiri', last_name='Ciccone', gender='Female', language='Kyrgyz')
# Personal_Info(ssn=163688070, first_name='Vassily', last_name='MacCarlich', gender='Male', language='Filipino')
# Personal_Info(ssn=163981022, first_name='Babbette', last_name='Crystal', gender='Female', language='Lithuanian')
# Personal_Info(ssn=164119849, first_name='Clemence', last_name='Aujean', gender='Female', language='Albanian')
# Personal_Info(ssn=166104488, first_name='Lester', last_name='Keyson', gender='Male', language='Bislama')
# Personal_Info(ssn=167392377, first_name='Reyna', last_name='Ullyatt', gender='Female', language='Portuguese')
# Personal_Info(ssn=168025324, first_name='Dane', last_name='Cornick', gender='Male', language='Tajik')
# Personal_Info(ssn=168198754, first_name='Teddie', last_name='Ingliss', gender='Male', language='Norwegian')
# Personal_Info(ssn=168810838, first_name='Toby', last_name='Pond-Jones', gender='Female', language='Aymara')
# Personal_Info(ssn=168896661, first_name='Vergil', last_name='Cecere', gender='Male', language='Tetum')
# Personal_Info(ssn=170653388, first_name='Salvidor', last_name='Larcher', gender='Male', language='Burmese')
# Personal_Info(ssn=171277781, first_name='Phillida', last_name='Cleeve', gender='Female', language='Lao')
# Personal_Info(ssn=172237739, first_name='Everett', last_name='Turneaux', gender='Male', language='Kyrgyz')
# Personal_Info(ssn=172774263, first_name='Alex', last_name='Udie', gender='Male', language='French')
# Personal_Info(ssn=172897546, first_name='Trude', last_name='Gillson', gender='Female', language='Norwegian')
# Personal_Info(ssn=173997372, first_name='Hedwiga', last_name='Gee', gender='Female', language='Danish')
# Personal_Info(ssn=174132047, first_name='Rey', last_name='Dallywater', gender='Female', language='Zulu')
# Personal_Info(ssn=174353812, first_name='Sayer', last_name='Astling', gender='Male', language='Kyrgyz')
# Personal_Info(ssn=174519992, first_name='Drucie', last_name='Travers', gender='Female', language='Swati')
# Personal_Info(ssn=174872537, first_name='Benton', last_name='Nolte', gender='Male', language='Persian')
# Personal_Info(ssn=176821359, first_name='Corny', last_name='Rothera', gender='Female', language='Thai')
# Personal_Info(ssn=176995851, first_name='Olivero', last_name='Janse', gender='Male', language='Moldovan')
# Personal_Info(ssn=179882790, first_name='Errick', last_name='Charsley', gender='Male', language='Japanese')
# Personal_Info(ssn=181074434, first_name='Ferdinande', last_name='Probet', gender='Female', language='Catalan')
# Personal_Info(ssn=181288337, first_name='Fan', last_name='Hillyatt', gender='Female', language='Moldovan')
# Personal_Info(ssn=181886077, first_name='Ebba', last_name='Wozencroft', gender='Female', language='German')
# Personal_Info(ssn=182155082, first_name='Lavinie', last_name='Niess', gender='Female', language='Swahili')
# Personal_Info(ssn=182814541, first_name='Sunny', last_name='Ferrarini', gender='Male', language='Swedish')
# Personal_Info(ssn=183105024, first_name='Curran', last_name='Squires', gender='Male', language='Romanian')
# Personal_Info(ssn=184606243, first_name='Fern', last_name='Demogeot', gender='Female', language='Tok Pisin')
# Personal_Info(ssn=184841003, first_name='Bary', last_name='Buzin', gender='Male', language='Aymara')
# Personal_Info(ssn=184923560, first_name='Kore', last_name='Eastes', gender='Female', language='Fijian')
# Personal_Info(ssn=184945241, first_name='Manfred', last_name='McCrillis', gender='Male', language='Swati')
# Personal_Info(ssn=185500434, first_name='Alexa', last_name='Emblin', gender='Female', language='Quechua')
# Personal_Info(ssn=185849868, first_name='Shandy', last_name='Ilyin', gender='Female', language='Northern Sotho')
# Personal_Info(ssn=186657773, first_name='Hazlett', last_name='Arney', gender='Male', language='Marathi')
# Personal_Info(ssn=188209317, first_name='Clifford', last_name='Sedgemore', gender='Male', language='Thai')
# Personal_Info(ssn=188404336, first_name='Belita', last_name='Camolli', gender='Female', language='Telugu')
# Personal_Info(ssn=189265696, first_name='Arnold', last_name='Pepis', gender='Male', language='Tok Pisin')
# Personal_Info(ssn=189491458, first_name='Vernen', last_name='Ivanyushkin', gender='Male', language='Quechua')
# Personal_Info(ssn=190056987, first_name='Gorden', last_name='Clemonts', gender='Male', language='West Frisian')
# Personal_Info(ssn=190534517, first_name='Hadlee', last_name='Rohan', gender='Male', language='Swahili')
# Personal_Info(ssn=191153194, first_name='Calhoun', last_name='Mugford', gender='Male', language='Thai')
# Personal_Info(ssn=192540695, first_name='Trev', last_name='Ruppeli', gender='Male', language='Maori')
# Personal_Info(ssn=192673201, first_name='Edvard', last_name='Cattel', gender='Male', language='Hebrew')
# Personal_Info(ssn=194765816, first_name='Jacquelynn', last_name='Shurey', gender='Female', language='Amharic')
# Personal_Info(ssn=195235731, first_name='Talyah', last_name='Canny', gender='Female', language='Portuguese')
# Personal_Info(ssn=196693796, first_name='Marijo', last_name='Tester', gender='Female', language='Oriya')
# Personal_Info(ssn=198706443, first_name='Judah', last_name='Duggan', gender='Male', language='Macedonian')
# Personal_Info(ssn=199450804, first_name='Consolata', last_name='Pigram', gender='Female', language='Guarana')
# Personal_Info(ssn=199544639, first_name='Ellene', last_name='Dowrey', gender='Female', language='Nepali')
# Personal_Info(ssn=200817151, first_name='Merilyn', last_name='Tink', gender='Female', language='Bengali')
# Personal_Info(ssn=201531249, first_name='Jammal', last_name='Dohmer', gender='Male', language='Danish')
# Personal_Info(ssn=202841146, first_name='Dore', last_name='Woodrup', gender='Male', language='Afrikaans')
# Personal_Info(ssn=203357648, first_name='Budd', last_name='Artiss', gender='Male', language='Norwegian')
# Personal_Info(ssn=205697375, first_name='Cacilia', last_name='Kneesha', gender='Female', language='Indonesian')
# Personal_Info(ssn=205872423, first_name='Oralla', last_name='Kearle', gender='Female', language='Zulu')
# Personal_Info(ssn=206286674, first_name='Con', last_name='Mansbridge', gender='Male', language='Haitian Creole')
# Personal_Info(ssn=206838848, first_name='Ardyth', last_name='Arger', gender='Female', language='Gagauz')
# Personal_Info(ssn=208742166, first_name='Tiebold', last_name='Gherarducci', gender='Male', language='Croatian')
# Personal_Info(ssn=208805879, first_name='Rockie', last_name='Fryd', gender='Male', language='Korean')
# Personal_Info(ssn=209508146, first_name='Kenna', last_name='Meryett', gender='Female', language='Czech')
# Personal_Info(ssn=209584708, first_name='Stephanus', last_name='Creboe', gender='Male', language='Latvian')
# Personal_Info(ssn=210914729, first_name='Tamarra', last_name='Minchella', gender='Female', language='Greek')
# Personal_Info(ssn=211041734, first_name='Jeana', last_name='Girardeau', gender='Female', language='Dzongkha')
# Personal_Info(ssn=211135247, first_name='Wes', last_name='Weinberg', gender='Male', language='French')
# Personal_Info(ssn=211155182, first_name='Gene', last_name='Bassilashvili', gender='Female', language='Swedish')
# Personal_Info(ssn=211196826, first_name='Noni', last_name='Meynell', gender='Female', language='Portuguese')
# Personal_Info(ssn=212400215, first_name='Giffie', last_name='Strauss', gender='Male', language='Azeri')
# Personal_Info(ssn=212411496, first_name='Agnese', last_name='Lawes', gender='Female', language='Tamil')
# Personal_Info(ssn=213281395, first_name='Catlaina', last_name='Patullo', gender='Female', language='Bengali')
# Personal_Info(ssn=214291189, first_name='Chandler', last_name='Gonsalvo', gender='Male', language='Haitian Creole')
# Personal_Info(ssn=214968581, first_name='Earlie', last_name='de Nore', gender='Male', language='Georgian')
# Personal_Info(ssn=214997584, first_name='Barny', last_name='Witherden', gender='Male', language='Czech')
# Personal_Info(ssn=216893812, first_name='Florian', last_name='Jaze', gender='Male', language='Croatian')
# Personal_Info(ssn=216973104, first_name='Elvira', last_name='McDougal', gender='Female', language='Bislama')
# Personal_Info(ssn=217713922, first_name='Hayes', last_name='Vallentin', gender='Male', language='Bengali')
# Personal_Info(ssn=217815416, first_name='Gusta', last_name='Cruise', gender='Female', language='Tsonga')
# Personal_Info(ssn=218144448, first_name='Keary', last_name='Druhan', gender='Male', language='Dutch')
# Personal_Info(ssn=218259873, first_name='Westbrooke', last_name='Succamore', gender='Male', language='Fijian')
# Personal_Info(ssn=218311615, first_name='Trenton', last_name='Eggerton', gender='Male', language='Dari')
# Personal_Info(ssn=218497300, first_name='Justinn', last_name='Sherebrooke', gender='Female', language='English')
# Personal_Info(ssn=220160476, first_name='Baxy', last_name='Brothwood', gender='Male', language='Kyrgyz')
# Personal_Info(ssn=220380208, first_name='Jess', last_name='Fulun', gender='Female', language='Gagauz')
# Personal_Info(ssn=222398571, first_name='Fidelia', last_name='Domonkos', gender='Female', language='Fijian')
# Personal_Info(ssn=223679203, first_name='Markus', last_name='Radband', gender='Male', language='Bosnian')
# Personal_Info(ssn=223980846, first_name='Josy', last_name='Hadwick', gender='Female', language='Papiamento')
# Personal_Info(ssn=224123436, first_name='Alister', last_name='Eakle', gender='Male', language='Estonian')
# Personal_Info(ssn=224309267, first_name='Flori', last_name='Bagnal', gender='Female', language='Swedish')
# Personal_Info(ssn=224546919, first_name='Kelly', last_name='Shipman', gender='Male', language='Icelandic')
# Personal_Info(ssn=224842271, first_name='Weider', last_name='Carlisle', gender='Male', language='Swedish')
# Personal_Info(ssn=224990668, first_name='Brandy', last_name='Steed', gender='Male', language='Croatian')
# Personal_Info(ssn=225085789, first_name='Tamra', last_name='Becken', gender='Female', language='Telugu')
# Personal_Info(ssn=225642735, first_name='Graig', last_name='Rasher', gender='Male', language='Maltese')
# Personal_Info(ssn=226764452, first_name='Van', last_name='Gervaise', gender='Male', language='Greek')
# Personal_Info(ssn=227727247, first_name='Mauricio', last_name='Gush', gender='Male', language='Tajik')
# Personal_Info(ssn=228167922, first_name='Tabby', last_name='Chitty', gender='Male', language='Spanish')
# Personal_Info(ssn=228552042, first_name='Jaquith', last_name='Durtnel', gender='Female', language='Czech')
# Personal_Info(ssn=228905077, first_name='Jonathon', last_name='Klugel', gender='Male', language='Hindi')
# Personal_Info(ssn=229449909, first_name='Barnabas', last_name='Heppenspall', gender='Male', language='Icelandic')
# Personal_Info(ssn=230091794, first_name='Xerxes', last_name='Mathivon', gender='Male', language='Danish')
# Personal_Info(ssn=230480684, first_name='Clay', last_name='Peaurt', gender='Male', language='Dhivehi')
# Personal_Info(ssn=230991485, first_name='Markus', last_name='Revill', gender='Male', language='Moldovan')
# Personal_Info(ssn=231669264, first_name='Gisele', last_name='Castelow', gender='Female', language='Hiri Motu')
# Personal_Info(ssn=232185397, first_name='Clare', last_name='McGairl', gender='Female', language='Bengali')
# Personal_Info(ssn=233272377, first_name='Arlyne', last_name='Stenning', gender='Female', language='Dari')
# Personal_Info(ssn=235103518, first_name='Winfield', last_name='Purvis', gender='Male', language='Estonian')
# Personal_Info(ssn=236318333, first_name='Wendeline', last_name='Millins', gender='Female', language='Kashmiri')
# Personal_Info(ssn=236372567, first_name='Ariel', last_name='Murrigan', gender='Female', language='West Frisian')
# Personal_Info(ssn=237486737, first_name='Eal', last_name='Ducastel', gender='Male', language='Indonesian')
# Personal_Info(ssn=237807039, first_name='Ardyce', last_name='Hunn', gender='Female', language='Maltese')
# Personal_Info(ssn=238138034, first_name='Estrellita', last_name='Heavy', gender='Female', language='Azeri')
# Personal_Info(ssn=238399999, first_name='Pauly', last_name='Griffin', gender='Female', language='Georgian')
# Personal_Info(ssn=239099133, first_name='Tom', last_name='Roggeman', gender='Male', language='Sotho')
# Personal_Info(ssn=239374122, first_name='Jodee', last_name='Elsdon', gender='Female', language='Guarana')
# Personal_Info(ssn=240088805, first_name='Gates', last_name='McGiffin', gender='Female', language='Finnish')
# Personal_Info(ssn=240328915, first_name='Cathee', last_name='Tarbard', gender='Female', language='Papiamento')
# Personal_Info(ssn=240676258, first_name='Kalina', last_name='Lloyds', gender='Female', language='Hindi')
# Personal_Info(ssn=242229624, first_name='Felice', last_name='Surr', gender='Male', language='Afrikaans')
# Personal_Info(ssn=243379496, first_name='Verine', last_name='Etchells', gender='Female', language='Burmese')
# Personal_Info(ssn=243444611, first_name='Shani', last_name="O'Tierney", gender='Female', language='Aymara')
# Personal_Info(ssn=244342210, first_name='Lek', last_name='Heino', gender='Male', language='New Zealand Sign Language')
# Personal_Info(ssn=244527593, first_name='Erda', last_name='Paulusch', gender='Female', language='Gujarati')
# Personal_Info(ssn=244793004, first_name='Renault', last_name='Stollard', gender='Male', language='Amharic')
# Personal_Info(ssn=244810671, first_name='Viviyan', last_name='Udell', gender='Female', language='Moldovan')
# Personal_Info(ssn=245605880, first_name='Oby', last_name='Hauxby', gender='Male', language='French')
# Personal_Info(ssn=245774110, first_name='Alasdair', last_name='McAndrew', gender='Male', language='Czech')
# Personal_Info(ssn=247089326, first_name='Minni', last_name='Scurman', gender='Female', language='Kannada')
# Personal_Info(ssn=247865288, first_name='Lilly', last_name='Holby', gender='Female', language='Bosnian')
# Personal_Info(ssn=248079757, first_name='Sean', last_name='Ham', gender='Male', language='Luxembourgish')
# Personal_Info(ssn=248230150, first_name='Welbie', last_name='Gilley', gender='Male', language='Korean')
# Personal_Info(ssn=249195514, first_name='Yehudi', last_name='Pharoah', gender='Male', language='Latvian')
# Personal_Info(ssn=253618401, first_name='Genny', last_name='Juara', gender='Female', language='Tswana')
# Personal_Info(ssn=254106071, first_name='Dwight', last_name='Eastcourt', gender='Male', language='Oriya')
# Personal_Info(ssn=254929669, first_name='Tom', last_name='Larking', gender='Male', language='Icelandic')
# Personal_Info(ssn=255810958, first_name='Darryl', last_name='Sparkes', gender='Female', language='Estonian')
# Personal_Info(ssn=256547507, first_name='Angus', last_name='Cullip', gender='Male', language='Spanish')
# Personal_Info(ssn=256570666, first_name='Rip', last_name='Grube', gender='Male', language='Ndebele')
# Personal_Info(ssn=257126834, first_name='Derward', last_name='Paladini', gender='Male', language='Thai')
# Personal_Info(ssn=257598603, first_name='Cyrillus', last_name='Sanchiz', gender='Male', language='Romanian')
# Personal_Info(ssn=257773669, first_name='Ynez', last_name='Hain', gender='Female', language='Kazakh')
# Personal_Info(ssn=258226416, first_name='Veriee', last_name='Klein', gender='Female', language='Northern Sotho')
# Personal_Info(ssn=259385920, first_name='Jethro', last_name='Rustidge', gender='Male', language='Fijian')
# Personal_Info(ssn=261149490, first_name='Lorry', last_name='Boshere', gender='Male', language='Oriya')
# Personal_Info(ssn=262092144, first_name='Leigh', last_name='Paxforde', gender='Male', language='Portuguese')
# Personal_Info(ssn=262467573, first_name='Lorene', last_name='Vagg', gender='Female', language='Punjabi')
# Personal_Info(ssn=262554066, first_name='Kaitlynn', last_name='Bleazard', gender='Female', language='Estonian')
# Personal_Info(ssn=262667030, first_name='Gray', last_name='Bissatt', gender='Female', language='Khmer')
# Personal_Info(ssn=264393910, first_name='Elysia', last_name='Favell', gender='Female', language='Hindi')
# Personal_Info(ssn=266869980, first_name='Rita', last_name='Leving', gender='Female', language='Latvian')
# Personal_Info(ssn=267756383, first_name='Ardath', last_name='Pitts', gender='Female', language='Romanian')
# Personal_Info(ssn=269012640, first_name='Russell', last_name='Dabner', gender='Male', language='Danish')
# Personal_Info(ssn=271040134, first_name='Eadith', last_name='Jerg', gender='Female', language='Gagauz')
# Personal_Info(ssn=271819938, first_name='James', last_name='Robbins', gender='Male', language='Bengali')
# Personal_Info(ssn=271933051, first_name='Augustin', last_name='Agiolfinger', gender='Male', language='Latvian')
# Personal_Info(ssn=272507309, first_name='Sig', last_name='Ather', gender='Male', language='Catalan')
# Personal_Info(ssn=272817979, first_name='Sherlocke', last_name='Giddings', gender='Male', language='Georgian')
# Personal_Info(ssn=273498218, first_name='Haze', last_name='Starkings', gender='Male', language='Portuguese')
# Personal_Info(ssn=274503806, first_name='Shurlocke', last_name='Aron', gender='Male', language='Punjabi')
# Personal_Info(ssn=274769883, first_name='Fawn', last_name='MacNamara', gender='Female', language='Bengali')
# Personal_Info(ssn=276052973, first_name='Cly', last_name='Yerlett', gender='Male', language='Kazakh')
# Personal_Info(ssn=278555842, first_name='Korie', last_name='Di Pietro', gender='Female', language='German')
# Personal_Info(ssn=278644853, first_name='Diane-marie', last_name='Broggini', gender='Female', language='Tsonga')
# Personal_Info(ssn=279127167, first_name='Elbertina', last_name='Alders', gender='Female', language='Amharic')
# Personal_Info(ssn=279405540, first_name='Montague', last_name='Knowler', gender='Male', language='Chinese')
# Personal_Info(ssn=279495682, first_name='Kleon', last_name='Tembridge', gender='Male', language='Gagauz')
# Personal_Info(ssn=280537447, first_name='Suzette', last_name='Prahl', gender='Female', language='Romanian')
# Personal_Info(ssn=280984410, first_name='Ealasaid', last_name='Devon', gender='Female', language='Tok Pisin')
# Personal_Info(ssn=281233458, first_name='Bettina', last_name='Danilov', gender='Female', language='Sotho')
# Personal_Info(ssn=282839206, first_name='Jackie', last_name='McPhater', gender='Male', language='Gagauz')
# Personal_Info(ssn=283046835, first_name='Tobey', last_name='Joule', gender='Female', language='Dzongkha')
# Personal_Info(ssn=286264004, first_name='Augustus', last_name='Doodson', gender='Male', language='Romanian')
# Personal_Info(ssn=287579688, first_name='Joachim', last_name='Moncreiff', gender='Male', language='Catalan')
# Personal_Info(ssn=287662660, first_name='Larissa', last_name='Airy', gender='Female', language='Bislama')
# Personal_Info(ssn=288547233, first_name='Hedy', last_name='Eaklee', gender='Female', language='English')
# Personal_Info(ssn=288876462, first_name='Stanislaus', last_name='Haylor', gender='Male', language='Kannada')
# Personal_Info(ssn=289039882, first_name='Giusto', last_name='Baszniak', gender='Male', language='Yiddish')
# Personal_Info(ssn=289098686, first_name='Heath', last_name='Stallan', gender='Male', language='Malayalam')
# Personal_Info(ssn=290257300, first_name='Bowie', last_name='Bancroft', gender='Male', language='Thai')
# Personal_Info(ssn=290824968, first_name='Ingram', last_name='Kincade', gender='Male', language='Moldovan')
# Personal_Info(ssn=293543694, first_name='Theodora', last_name='Geddes', gender='Female', language='Maori')
# Personal_Info(ssn=294279936, first_name='Cari', last_name='Bradane', gender='Female', language='Japanese')
# Personal_Info(ssn=294531911, first_name='Ginelle', last_name='Jaquet', gender='Female', language='Persian')
# Personal_Info(ssn=295637693, first_name='Fonzie', last_name='Fattorini', gender='Male', language='Estonian')
# Personal_Info(ssn=296327910, first_name='Harlene', last_name='Morrill', gender='Female', language='Swati')
# Personal_Info(ssn=296880097, first_name='Herculie', last_name='Branthwaite', gender='Male', language='Hungarian')
# Personal_Info(ssn=296904908, first_name='Holt', last_name='Angel', gender='Male', language='Tamil')
# Personal_Info(ssn=297631154, first_name='Maribelle', last_name='Gowanson', gender='Female', language='Montenegrin')
# Personal_Info(ssn=298063497, first_name='Moshe', last_name='Thomassin', gender='Male', language='Polish')
# Personal_Info(ssn=298699168, first_name='Shea', last_name='Canon', gender='Male', language='Finnish')
# Personal_Info(ssn=298706018, first_name='Minny', last_name='Van der Baaren', gender='Female', language='Afrikaans')
# Personal_Info(ssn=298797640, first_name='Mycah', last_name='Hillam', gender='Male', language='Swahili')
# Personal_Info(ssn=299036911, first_name='Janela', last_name='Ferrone', gender='Female', language='Gagauz')
# Personal_Info(ssn=299380483, first_name='Robb', last_name='Posner', gender='Male', language='Italian')
# Personal_Info(ssn=299771060, first_name='Bellina', last_name='Galbreth', gender='Female', language='Norwegian')
# Personal_Info(ssn=300593610, first_name='Tam', last_name='Howles', gender='Male', language='Pashto')
# Personal_Info(ssn=300768770, first_name='Danielle', last_name='Rowth', gender='Female', language='Italian')
# Personal_Info(ssn=300807209, first_name='Gabbie', last_name='Burney', gender='Female', language='Dutch')
# Personal_Info(ssn=301264306, first_name='Emmye', last_name='Whelpdale', gender='Female', language='Tajik')
# Personal_Info(ssn=301510522, first_name='Kenneth', last_name='Methley', gender='Male', language='Papiamento')
# Personal_Info(ssn=302644858, first_name='Hakeem', last_name='Zelley', gender='Male', language='Afrikaans')
# Personal_Info(ssn=304484312, first_name='Edeline', last_name='Van de Vlies', gender='Female', language='Montenegrin')
# Personal_Info(ssn=305071498, first_name='Ruddy', last_name="O'Crotty", gender='Male', language='Spanish')
# Personal_Info(ssn=306232423, first_name='Ree', last_name='Meader', gender='Female', language='Polish')
# Personal_Info(ssn=306862930, first_name='Kassie', last_name='Neaverson', gender='Female', language='Luxembourgish')
# Personal_Info(ssn=308580964, first_name='Talbert', last_name='Osipov', gender='Male', language='Tetum')
# Personal_Info(ssn=309040364, first_name='Dov', last_name='Speight', gender='Male', language='Tajik')
# Personal_Info(ssn=309388085, first_name='Nell', last_name='Scrigmour', gender='Female', language='Persian')
# Personal_Info(ssn=310602027, first_name='Zacherie', last_name='Parken', gender='Male', language='Albanian')
# Personal_Info(ssn=311469296, first_name='Alic', last_name='Pabel', gender='Male', language='Fijian')
# Personal_Info(ssn=312387084, first_name='Ezri', last_name='Paolicchi', gender='Male', language='Malagasy')
# Personal_Info(ssn=312593476, first_name='Sadye', last_name='Beloe', gender='Female', language='Icelandic')
# Personal_Info(ssn=312773647, first_name='Hussein', last_name='Blything', gender='Male', language='Hebrew')
# Personal_Info(ssn=313027822, first_name='Spence', last_name='Climer', gender='Male', language='Maori')
# Personal_Info(ssn=313527312, first_name='Farrand', last_name='MacKenzie', gender='Female', language='French')
# Personal_Info(ssn=315125664, first_name='Vere', last_name='Morlon', gender='Female', language='German')
# Personal_Info(ssn=315262241, first_name='Cammy', last_name='Harland', gender='Female', language='Bulgarian')
# Personal_Info(ssn=315449671, first_name='Ximenez', last_name='Maghull', gender='Male', language='Macedonian')
# Personal_Info(ssn=315785587, first_name='Helsa', last_name='Lumber', gender='Female', language='Tok Pisin')
# Personal_Info(ssn=317281600, first_name='Rodrick', last_name='Abrahams', gender='Male', language='Assamese')
# Personal_Info(ssn=317432055, first_name='Jocelyn', last_name='Gildroy', gender='Female', language='Punjabi')
# Personal_Info(ssn=318585314, first_name='Stephan', last_name='Peatt', gender='Male', language='New Zealand Sign Language')
# Personal_Info(ssn=319430465, first_name='Boothe', last_name='Vanin', gender='Male', language='West Frisian')
# Personal_Info(ssn=320901419, first_name='Em', last_name='Darwood', gender='Male', language='Icelandic')
# Personal_Info(ssn=320979147, first_name='Roch', last_name='Wahlberg', gender='Female', language='Thai')
# Personal_Info(ssn=323286705, first_name='Christiano', last_name='Stoffler', gender='Male', language='Kyrgyz')
# Personal_Info(ssn=323338689, first_name='Dulcinea', last_name='Lundberg', gender='Female', language='Dutch')
# Personal_Info(ssn=324395230, first_name='Alexandrina', last_name='Dahlbom', gender='Female', language='Moldovan')
# Personal_Info(ssn=324738895, first_name='Walliw', last_name='Alstead', gender='Female', language='Guarana')
# Personal_Info(ssn=324756098, first_name='Rafael', last_name='Robinett', gender='Male', language='Portuguese')
# Personal_Info(ssn=326649957, first_name='Jorgan', last_name='Renowden', gender='Male', language='Swati')
# Personal_Info(ssn=327520546, first_name='Carlota', last_name='Hovey', gender='Female', language='English')
# Personal_Info(ssn=327887554, first_name='Malynda', last_name='Kingerby', gender='Female', language='Swahili')
# Personal_Info(ssn=330993055, first_name='Marinna', last_name='Dally', gender='Female', language='Azeri')
# Personal_Info(ssn=332836591, first_name='Forrester', last_name='Cullabine', gender='Male', language='Dzongkha')
# Personal_Info(ssn=333525097, first_name='Florentia', last_name='Espinazo', gender='Female', language='Tetum')
# Personal_Info(ssn=333955025, first_name='Rebeca', last_name='Walesa', gender='Female', language='Zulu')
# Personal_Info(ssn=335351520, first_name='Ervin', last_name='Hugues', gender='Male', language='Armenian')
# Personal_Info(ssn=336482579, first_name='Renee', last_name='Crank', gender='Female', language='Armenian')
# Personal_Info(ssn=339278046, first_name='Julita', last_name='Jouhan', gender='Female', language='Bosnian')
# Personal_Info(ssn=339712687, first_name='Marlie', last_name='Corpe', gender='Female', language='Persian')
# Personal_Info(ssn=341106840, first_name='Cyrille', last_name='Critchlow', gender='Male', language='Portuguese')
# Personal_Info(ssn=342059057, first_name='Beatrix', last_name='Relton', gender='Female', language='Latvian')
# Personal_Info(ssn=342550538, first_name='Hilliary', last_name='Suddards', gender='Female', language='Dzongkha')
# Personal_Info(ssn=342909333, first_name='Geri', last_name='Yesinov', gender='Male', language='Norwegian')
# Personal_Info(ssn=343208407, first_name='Bradford', last_name='Niemiec', gender='Male', language='Chinese')
# Personal_Info(ssn=343813179, first_name='Reinhard', last_name='Bortolutti', gender='Male', language='Kannada')
# Personal_Info(ssn=345742160, first_name='Camile', last_name='Pengelly', gender='Female', language='Lao')
# Personal_Info(ssn=347093254, first_name='Dulciana', last_name='Hexum', gender='Female', language='Lao')
# Personal_Info(ssn=347648652, first_name='Dusty', last_name='Morat', gender='Female', language='Japanese')
# Personal_Info(ssn=348734312, first_name='Elberta', last_name='Howden', gender='Female', language='Khmer')
# Personal_Info(ssn=348743224, first_name='Dorthy', last_name='Abreheart', gender='Female', language='Bosnian')
# Personal_Info(ssn=349538864, first_name='Muffin', last_name='Lord', gender='Female', language='Georgian')
# Personal_Info(ssn=349677502, first_name='Ari', last_name='Yitzhakov', gender='Male', language='Zulu')
# Personal_Info(ssn=350209593, first_name='Eldridge', last_name='Crispin', gender='Male', language='Dutch')
# Personal_Info(ssn=350804646, first_name='Harp', last_name='Du Plantier', gender='Male', language='Dutch')
# Personal_Info(ssn=351732802, first_name='Cybill', last_name='Parnham', gender='Female', language='Latvian')
# Personal_Info(ssn=355219711, first_name='Daryn', last_name='Battin', gender='Female', language='Georgian')
# Personal_Info(ssn=355529767, first_name='Kacy', last_name='Offen', gender='Female', language='Kurdish')
# Personal_Info(ssn=355967706, first_name='Lauritz', last_name='Lucock', gender='Male', language='Mongolian')
# Personal_Info(ssn=356399199, first_name='Arney', last_name='Polglaze', gender='Male', language='Marathi')
# Personal_Info(ssn=357376094, first_name='Chrisse', last_name='Kirton', gender='Male', language='Latvian')
# Personal_Info(ssn=358847049, first_name='Emalee', last_name='McCleary', gender='Female', language='Thai')
# Personal_Info(ssn=360696230, first_name='Grannie', last_name='Champ', gender='Male', language='Belarusian')
# Personal_Info(ssn=361061530, first_name='Luis', last_name='Ashborne', gender='Male', language='Mongolian')
# Personal_Info(ssn=361427068, first_name='Ashia', last_name='Ferran', gender='Female', language='West Frisian')
# Personal_Info(ssn=361494597, first_name='Adan', last_name='Janssen', gender='Male', language='Swedish')
# Personal_Info(ssn=361835004, first_name='Wilona', last_name='Sink', gender='Female', language='Sotho')
# Personal_Info(ssn=362098563, first_name='Carri', last_name='Peterffy', gender='Female', language='Icelandic')
# Personal_Info(ssn=362127902, first_name='Weber', last_name='Legrand', gender='Male', language='Swahili')
# Personal_Info(ssn=364250166, first_name='Arnuad', last_name='Planque', gender='Male', language='Hindi')
# Personal_Info(ssn=364652174, first_name='Bernarr', last_name='Wollard', gender='Male', language='Irish Gaelic')
# Personal_Info(ssn=366610607, first_name='Bethena', last_name='Joicey', gender='Female', language='Haitian Creole')
# Personal_Info(ssn=367228998, first_name='Blake', last_name='Mustin', gender='Female', language='Kyrgyz')
# Personal_Info(ssn=367624426, first_name='Sigismondo', last_name='Lerohan', gender='Male', language='Georgian')
# Personal_Info(ssn=370016977, first_name='Hugues', last_name='Jeffryes', gender='Male', language='Georgian')
# Personal_Info(ssn=370245876, first_name='Sergei', last_name='Risby', gender='Male', language='Bulgarian')
# Personal_Info(ssn=370726509, first_name='Wrennie', last_name='McCrorie', gender='Female', language='Papiamento')
# Personal_Info(ssn=371285892, first_name='Malia', last_name='Hanse', gender='Female', language='Tsonga')
# Personal_Info(ssn=371440582, first_name='Clemmy', last_name='Cogzell', gender='Male', language='Estonian')
# Personal_Info(ssn=371623727, first_name='Cymbre', last_name='Chinnock', gender='Female', language='Dutch')
# Personal_Info(ssn=371889249, first_name='Nealon', last_name='Oxtaby', gender='Male', language='German')
# Personal_Info(ssn=372447487, first_name='Jolyn', last_name='Bertome', gender='Female', language='Catalan')
# Personal_Info(ssn=372627057, first_name='Eleanora', last_name='Vazquez', gender='Female', language='Gujarati')
# Personal_Info(ssn=373672734, first_name='Ileana', last_name='Luty', gender='Female', language='Italian')
# Personal_Info(ssn=374470262, first_name='Bank', last_name='Evitts', gender='Male', language='Aymara')
# Personal_Info(ssn=378080805, first_name='Carroll', last_name='Harty', gender='Female', language='Swedish')
# Personal_Info(ssn=378602472, first_name='Eddie', last_name='Howieson', gender='Female', language='Albanian')
# Personal_Info(ssn=378660449, first_name='Kelby', last_name='Wincer', gender='Male', language='Pashto')
# Personal_Info(ssn=378790193, first_name='Kenny', last_name='Josefsen', gender='Male', language='Danish')
# Personal_Info(ssn=378886805, first_name='Vittoria', last_name='Oldroyd', gender='Female', language='Moldovan')
# Personal_Info(ssn=379078748, first_name='Dyanna', last_name='Noto', gender='Female', language='Polish')
# Personal_Info(ssn=380339730, first_name='Katinka', last_name='Piet', gender='Female', language='Malay')
# Personal_Info(ssn=380353854, first_name='Cathleen', last_name='Sizland', gender='Female', language='Bislama')
# Personal_Info(ssn=383184058, first_name='Frederigo', last_name='Cooksey', gender='Male', language='Indonesian')
# Personal_Info(ssn=384306793, first_name='Kipp', last_name='Burnyate', gender='Male', language='English')
# Personal_Info(ssn=384942772, first_name='Ramsay', last_name='Dolbey', gender='Male', language='Tok Pisin')
# Personal_Info(ssn=385301777, first_name='Aubrey', last_name='Wetherill', gender='Female', language='Tswana')
# Personal_Info(ssn=385347828, first_name='Dori', last_name='Quogan', gender='Female', language='Afrikaans')
# Personal_Info(ssn=385980431, first_name='Kassi', last_name='Rashleigh', gender='Female', language='Tswana')
# Personal_Info(ssn=386157960, first_name='Steffie', last_name='Tedahl', gender='Female', language='Punjabi')
# Personal_Info(ssn=386344088, first_name='Adamo', last_name='Wogden', gender='Male', language='Arabic')
# Personal_Info(ssn=386689884, first_name='Francis', last_name='Foch', gender='Male', language='Dzongkha')
# Personal_Info(ssn=386973523, first_name='Siusan', last_name='Durkin', gender='Female', language='Kurdish')
# Personal_Info(ssn=389310910, first_name='Mac', last_name='Westrey', gender='Male', language='Armenian')
# Personal_Info(ssn=389511424, first_name='Isadore', last_name='Orbine', gender='Male', language='Pashto')
# Personal_Info(ssn=389848254, first_name='Chiquita', last_name='Jolliman', gender='Female', language='Marathi')
# Personal_Info(ssn=390743062, first_name='Cara', last_name='Ingree', gender='Female', language='Indonesian')
# Personal_Info(ssn=391149280, first_name='Faun', last_name='Chillistone', gender='Female', language='Montenegrin')
# Personal_Info(ssn=391474578, first_name='Fiann', last_name='Fellman', gender='Female', language='Assamese')
# Personal_Info(ssn=391732830, first_name='Padget', last_name='Manthorpe', gender='Male', language='Marathi')
# Personal_Info(ssn=393226585, first_name='Reinold', last_name='Ellif', gender='Male', language='Nepali')
# Personal_Info(ssn=396511559, first_name='Natasha', last_name='Dafter', gender='Female', language='Maori')
# Personal_Info(ssn=397165372, first_name='Alonzo', last_name='Mc Mechan', gender='Male', language='Polish')
# Personal_Info(ssn=397298349, first_name='Madelle', last_name='Mapledorum', gender='Female', language='Tok Pisin')
# Personal_Info(ssn=397878282, first_name='Kyrstin', last_name='Waldock', gender='Female', language='Belarusian')
# Personal_Info(ssn=399312815, first_name='Durward', last_name='Giamitti', gender='Male', language='Tok Pisin')
# Personal_Info(ssn=399638810, first_name='Bobbee', last_name='Postians', gender='Female', language='Papiamento')
# Personal_Info(ssn=399816133, first_name='Viv', last_name='Borsay', gender='Female', language='Chinese')
# Personal_Info(ssn=400218654, first_name='Travus', last_name='Miranda', gender='Male', language='Kannada')
# Personal_Info(ssn=400776007, first_name='Dannie', last_name='Shurmer', gender='Male', language='Tajik')
# Personal_Info(ssn=402613479, first_name='Mariele', last_name='Meyrick', gender='Female', language='Telugu')
# Personal_Info(ssn=402652055, first_name='Martie', last_name='Crawshaw', gender='Male', language='Marathi')
# Personal_Info(ssn=402885570, first_name='Torry', last_name='Bossons', gender='Male', language='Chinese')
# Personal_Info(ssn=403651535, first_name='Cathy', last_name='Gabe', gender='Female', language='Hiri Motu')
# Personal_Info(ssn=404574023, first_name='Pattin', last_name='Jarmain', gender='Male', language='Hindi')
# Personal_Info(ssn=405251422, first_name='Raquel', last_name='Dukelow', gender='Female', language='Gujarati')
# Personal_Info(ssn=406155123, first_name='Janot', last_name='Pulhoster', gender='Female', language='Dari')
# Personal_Info(ssn=406244867, first_name='Renaud', last_name='Fleetwood', gender='Male', language='Papiamento')
# Personal_Info(ssn=406490634, first_name='Lolita', last_name='Dailey', gender='Female', language='Czech')
# Personal_Info(ssn=407300910, first_name='Gerhard', last_name='Crielly', gender='Male', language='Bislama')
# Personal_Info(ssn=407807367, first_name='Sigismundo', last_name='Pothbury', gender='Male', language='Latvian')
# Personal_Info(ssn=407996159, first_name='Flynn', last_name='Jirasek', gender='Male', language='Afrikaans')
# Personal_Info(ssn=408837943, first_name='Wallie', last_name='Klosterman', gender='Male', language='Hungarian')
# Personal_Info(ssn=408983291, first_name='Karia', last_name='Riquet', gender='Female', language='Italian')
# Personal_Info(ssn=409582034, first_name='Fiann', last_name='Corsar', gender='Female', language='Swahili')
# Personal_Info(ssn=409908946, first_name='Doralia', last_name='Proughten', gender='Female', language='Estonian')
# Personal_Info(ssn=410384237, first_name='Gibbie', last_name='Seamer', gender='Male', language='Tok Pisin')
# Personal_Info(ssn=410765092, first_name='Spencer', last_name='Dallon', gender='Male', language='Swati')
# Personal_Info(ssn=411214276, first_name='Mari', last_name='Livick', gender='Female', language='Pashto')
# Personal_Info(ssn=411434217, first_name='Cull', last_name='Noddle', gender='Male', language='Spanish')
# Personal_Info(ssn=411794655, first_name='Caterina', last_name='Coey', gender='Female', language='French')
# Personal_Info(ssn=412509133, first_name='Dianemarie', last_name='Withey', gender='Female', language='Czech')
# Personal_Info(ssn=412590452, first_name='Seamus', last_name='Petrusch', gender='Male', language='Spanish')
# Personal_Info(ssn=412598022, first_name='Brenna', last_name='Follin', gender='Female', language='Gagauz')
# Personal_Info(ssn=412798951, first_name='Giorgi', last_name='Sisnett', gender='Male', language='Tamil')
# Personal_Info(ssn=413143928, first_name='Shaine', last_name='Liebrecht', gender='Male', language='Sotho')
# Personal_Info(ssn=413565613, first_name='Anjanette', last_name='Carnock', gender='Female', language='Nepali')
# Personal_Info(ssn=415420898, first_name='Karlik', last_name='Adlam', gender='Male', language='Mongolian')
# Personal_Info(ssn=415742251, first_name='Pattin', last_name='Greson', gender='Male', language='Italian')
# Personal_Info(ssn=416377763, first_name='Emelia', last_name='Hancell', gender='Female', language='German')
# Personal_Info(ssn=416383607, first_name='Jerry', last_name='Christin', gender='Male', language='Hebrew')
# Personal_Info(ssn=416806367, first_name='Myrna', last_name='Christoffe', gender='Female', language='Tok Pisin')
# Personal_Info(ssn=416870469, first_name='Dannel', last_name='Whyffen', gender='Male', language='Estonian')
# Personal_Info(ssn=418721888, first_name='Roddy', last_name='Worman', gender='Male', language='Bosnian')
# Personal_Info(ssn=418996659, first_name='Grenville', last_name='Gulliver', gender='Male', language='Ndebele')
# Personal_Info(ssn=420467789, first_name='Steffie', last_name='Britto', gender='Female', language='New Zealand Sign Language')
# Personal_Info(ssn=420523813, first_name='Arnaldo', last_name='Balsdone', gender='Male', language='Zulu')
# Personal_Info(ssn=421012511, first_name='Mikaela', last_name='Andrivot', gender='Female', language='English')
# Personal_Info(ssn=421139794, first_name='Minne', last_name='Measey', gender='Female', language='Danish')
# Personal_Info(ssn=421203448, first_name='Alie', last_name='Gerauld', gender='Female', language='Khmer')
# Personal_Info(ssn=421887316, first_name='Cherie', last_name='Yeudall', gender='Female', language='Dutch')
# Personal_Info(ssn=422674000, first_name='Corby', last_name='Boyington', gender='Male', language='Sotho')
# Personal_Info(ssn=423621820, first_name='Ruddy', last_name='Ingerson', gender='Male', language='Maori')
# ...
# Personal_Info(ssn=775099949, first_name='Orlando', last_name='Gresley', gender='Male', language='Danish')
# Personal_Info(ssn=777051491, first_name='Devora', last_name='Ashbridge', gender='Female', language='Somali')
# Personal_Info(ssn=777682978, first_name='Mignon', last_name='Skottle', gender='Female', language='Northern Sotho')
# Personal_Info(ssn=777944586, first_name='Siward', last_name='Blues', gender='Male', language='Thai')
# Personal_Info(ssn=778748262, first_name='Sonia', last_name='Grishakin', gender='Female', language='Bulgarian')
# Personal_Info(ssn=779591449, first_name='Gertrude', last_name='Ledamun', gender='Female', language='Hungarian')
# Personal_Info(ssn=780698282, first_name='Sibeal', last_name='Dawney', gender='Female', language='Czech')
# Personal_Info(ssn=781882076, first_name='Gelya', last_name='Stell', gender='Female', language='Czech')
# Personal_Info(ssn=782469660, first_name='Malina', last_name='Julyan', gender='Female', language='Burmese')
# Personal_Info(ssn=782606848, first_name='Jehu', last_name='Scholig', gender='Male', language='Polish')
# Personal_Info(ssn=783229258, first_name='Modestine', last_name='Cuttings', gender='Female', language='Assamese')
# Personal_Info(ssn=784880730, first_name='Baxie', last_name='Judd', gender='Male', language='Maltese')
# Personal_Info(ssn=785145978, first_name='Trista', last_name='Watkinson', gender='Female', language='Moldovan')
# Personal_Info(ssn=786563561, first_name='Wait', last_name='Boyda', gender='Male', language='Norwegian')
# Personal_Info(ssn=786636223, first_name='Adham', last_name='Toope', gender='Male', language='Belarusian')
# Personal_Info(ssn=787059008, first_name='Ricki', last_name='Jurges', gender='Female', language='Arabic')
# Personal_Info(ssn=787095697, first_name='Chelsea', last_name='Pashby', gender='Female', language='Northern Sotho')
# Personal_Info(ssn=787107877, first_name='Torrence', last_name='Tapping', gender='Male', language='Hiri Motu')
# Personal_Info(ssn=788152625, first_name='Drusilla', last_name='Bannester', gender='Female', language='Gujarati')
# Personal_Info(ssn=789701821, first_name='Denni', last_name='De Biasio', gender='Female', language='Azeri')
# Personal_Info(ssn=790041283, first_name='Christyna', last_name='Morrissey', gender='Female', language='Quechua')
# Personal_Info(ssn=792718046, first_name='Carly', last_name='Hazley', gender='Female', language='Guarana')
# Personal_Info(ssn=794243802, first_name='Esther', last_name='Sayton', gender='Female', language='Somali')
# Personal_Info(ssn=795566486, first_name='Stevena', last_name='Vatcher', gender='Female', language='Gagauz')
# Personal_Info(ssn=795775263, first_name='Burty', last_name='Frosdick', gender='Male', language='Marathi')
# Personal_Info(ssn=797052289, first_name='Fanchon', last_name='Petrushanko', gender='Female', language='Finnish')
# Personal_Info(ssn=797259814, first_name='Aleksandr', last_name='Swalwell', gender='Male', language='Pashto')
# Personal_Info(ssn=797652382, first_name='Marianne', last_name='Huccaby', gender='Female', language='Swedish')
# Personal_Info(ssn=797877992, first_name='Lonna', last_name='Plumridge', gender='Female', language='Armenian')
# Personal_Info(ssn=798341082, first_name='Henka', last_name='Synder', gender='Female', language='Italian')
# Personal_Info(ssn=798655644, first_name='Irita', last_name='Heady', gender='Female', language='Montenegrin')
# Personal_Info(ssn=800069721, first_name='Carter', last_name='Waldron', gender='Male', language='Estonian')
# Personal_Info(ssn=801088313, first_name='Aida', last_name='Whitemarsh', gender='Female', language='Chinese')
# Personal_Info(ssn=801926460, first_name='Levi', last_name='Downgate', gender='Male', language='Belarusian')
# Personal_Info(ssn=801992773, first_name='Justinian', last_name='Carlesso', gender='Male', language='Japanese')
# Personal_Info(ssn=804460617, first_name='Geneva', last_name='Crinion', gender='Female', language='Hungarian')
# Personal_Info(ssn=807135922, first_name='Vivi', last_name='Edinboro', gender='Female', language='Sotho')
# Personal_Info(ssn=807246202, first_name='Lanette', last_name='Elvins', gender='Female', language='Hiri Motu')
# Personal_Info(ssn=807256136, first_name='Sammy', last_name='Linnard', gender='Female', language='Dutch')
# Personal_Info(ssn=807358936, first_name='Georgi', last_name='Widd', gender='Male', language='Afrikaans')
# Personal_Info(ssn=807508539, first_name='Jaquith', last_name='Erdes', gender='Female', language='Dhivehi')
# Personal_Info(ssn=807605615, first_name='Michale', last_name='Druery', gender='Male', language='Dhivehi')
# Personal_Info(ssn=808558658, first_name='Ursulina', last_name='Kunze', gender='Female', language='Chinese')
# Personal_Info(ssn=808802542, first_name='Gustaf', last_name='Hullot', gender='Male', language='Persian')
# Personal_Info(ssn=811652750, first_name='Minetta', last_name='Dusting', gender='Female', language='Spanish')
# Personal_Info(ssn=812119403, first_name='Carmina', last_name='Turnell', gender='Female', language='West Frisian')
# Personal_Info(ssn=813424142, first_name='Killy', last_name='Threadgould', gender='Male', language='Polish')
# Personal_Info(ssn=813475215, first_name='Willi', last_name='Collet', gender='Male', language='Gujarati')
# Personal_Info(ssn=815830300, first_name='Romeo', last_name='Rayworth', gender='Male', language='Thai')
# Personal_Info(ssn=816313858, first_name='Elvera', last_name='Walmsley', gender='Female', language='Montenegrin')
# Personal_Info(ssn=816474782, first_name='Wilmer', last_name='Maides', gender='Male', language='Aymara')
# Personal_Info(ssn=816902049, first_name='Berry', last_name='Delagnes', gender='Female', language='Bengali')
# Personal_Info(ssn=817041950, first_name='Fletcher', last_name='McGrouther', gender='Male', language='Albanian')
# Personal_Info(ssn=817257437, first_name='Randall', last_name='Fibbitts', gender='Male', language='Yiddish')
# Personal_Info(ssn=817808930, first_name='Lib', last_name='Skein', gender='Female', language='Arabic')
# Personal_Info(ssn=818610770, first_name='Stanly', last_name='Casseldine', gender='Male', language='Belarusian')
# Personal_Info(ssn=819525886, first_name='Paulette', last_name='McAree', gender='Female', language='Arabic')
# Personal_Info(ssn=819641414, first_name='Malynda', last_name='Hundall', gender='Female', language='Filipino')
# Personal_Info(ssn=820961105, first_name='Andy', last_name='Sayce', gender='Female', language='Pashto')
# Personal_Info(ssn=822059037, first_name='Meggi', last_name='Mapes', gender='Female', language='Moldovan')
# Personal_Info(ssn=822304861, first_name='Phyllis', last_name='Cronk', gender='Female', language='Fijian')
# Personal_Info(ssn=823270762, first_name='Marten', last_name='McCord', gender='Male', language='Indonesian')
# Personal_Info(ssn=823755753, first_name='Thibaut', last_name='Van Schafflaer', gender='Male', language='Chinese')
# Personal_Info(ssn=824894169, first_name='Tamqrah', last_name='Goroni', gender='Female', language='Swedish')
# Personal_Info(ssn=826978029, first_name='Llewellyn', last_name='Shimwell', gender='Male', language='Belarusian')
# Personal_Info(ssn=827624599, first_name='Phyllys', last_name='Akast', gender='Female', language='Armenian')
# Personal_Info(ssn=830231573, first_name='Carine', last_name='Abramin', gender='Female', language='Bislama')
# Personal_Info(ssn=831443286, first_name='Leesa', last_name='Finci', gender='Female', language='Nepali')
# Personal_Info(ssn=833011428, first_name='Ashlan', last_name='Zannotti', gender='Female', language='Finnish')
# Personal_Info(ssn=835543785, first_name='Nathaniel', last_name='Wegman', gender='Male', language='Azeri')
# Personal_Info(ssn=836401837, first_name='Brocky', last_name='Kewzick', gender='Male', language='Armenian')
# Personal_Info(ssn=836993309, first_name='Cobby', last_name='Mutter', gender='Male', language='Georgian')
# Personal_Info(ssn=837765619, first_name='Alleyn', last_name='Parade', gender='Male', language='Croatian')
# Personal_Info(ssn=838691351, first_name='Alwin', last_name='Hazzard', gender='Male', language='Kannada')
# Personal_Info(ssn=840417929, first_name='Sherlock', last_name='Pinshon', gender='Male', language='Khmer')
# Personal_Info(ssn=841648517, first_name='Hugues', last_name='Kenealy', gender='Male', language='Korean')
# Personal_Info(ssn=842907557, first_name='Brit', last_name='Weall', gender='Female', language='West Frisian')
# Personal_Info(ssn=844154668, first_name='Eleonora', last_name='Delete', gender='Female', language='Hiri Motu')
# Personal_Info(ssn=844507305, first_name='Merralee', last_name='Orae', gender='Female', language='Macedonian')
# Personal_Info(ssn=846071407, first_name='Tobias', last_name='Blakelock', gender='Male', language='German')
# Personal_Info(ssn=846099851, first_name='Shani', last_name='Penrose', gender='Female', language='New Zealand Sign Language')
# Personal_Info(ssn=846599961, first_name='Saleem', last_name='Osmant', gender='Male', language='Croatian')
# Personal_Info(ssn=847344817, first_name='Orazio', last_name='Coners', gender='Male', language='Yiddish')
# Personal_Info(ssn=847617656, first_name='Brit', last_name='Lodovichi', gender='Male', language='Bislama')
# Personal_Info(ssn=848583386, first_name='Julianne', last_name='Lygo', gender='Female', language='Japanese')
# Personal_Info(ssn=848742886, first_name='Helyn', last_name='Witheford', gender='Female', language='Bislama')
# Personal_Info(ssn=848768808, first_name='Durward', last_name='Nuscha', gender='Male', language='Nepali')
# Personal_Info(ssn=849311551, first_name='Lisabeth', last_name='Mattessen', gender='Female', language='German')
# Personal_Info(ssn=849646624, first_name='Hallie', last_name='Proschke', gender='Female', language='Fijian')
# Personal_Info(ssn=849982973, first_name='Hurley', last_name='Newart', gender='Male', language='Hindi')
# Personal_Info(ssn=851942162, first_name='Rodi', last_name='Mulrenan', gender='Female', language='Catalan')
# Personal_Info(ssn=852157707, first_name='Mario', last_name='Lelande', gender='Male', language='Nepali')
# Personal_Info(ssn=853118953, first_name='Brice', last_name='Kyd', gender='Male', language='Dari')
# Personal_Info(ssn=853473648, first_name='Olag', last_name='Belhome', gender='Male', language='Maltese')
# Personal_Info(ssn=854687635, first_name='Eyde', last_name='McCunn', gender='Female', language='Moldovan')
# Personal_Info(ssn=854712983, first_name='Rikki', last_name='Loveland', gender='Male', language='Dutch')
# Personal_Info(ssn=854795334, first_name='Bevan', last_name='Kolczynski', gender='Male', language='Swahili')
# Personal_Info(ssn=856183980, first_name='Neale', last_name='Sesser', gender='Male', language='Maltese')
# Personal_Info(ssn=856279112, first_name='Virgilio', last_name='Kirrage', gender='Male', language='Pashto')
# Personal_Info(ssn=856674080, first_name='Aggy', last_name='Cobley', gender='Female', language='Dhivehi')
# Personal_Info(ssn=857375902, first_name='Jenni', last_name='Swinyard', gender='Female', language='Hindi')
# Personal_Info(ssn=858037735, first_name='Allayne', last_name='Wardingley', gender='Male', language='Kazakh')
# Personal_Info(ssn=858279190, first_name='Yuri', last_name='Sixsmith', gender='Male', language='Norwegian')
# Personal_Info(ssn=860670256, first_name='Bendicty', last_name='Lindgren', gender='Male', language='Tajik')
# Personal_Info(ssn=860892570, first_name='Otto', last_name='Burgwin', gender='Male', language='Finnish')
# Personal_Info(ssn=861506716, first_name='Norina', last_name='Yerbury', gender='Female', language='Indonesian')
# Personal_Info(ssn=862200653, first_name='Wilfrid', last_name='Kid', gender='Male', language='Swedish')
# Personal_Info(ssn=864229364, first_name='Lyell', last_name='Petrollo', gender='Male', language='Latvian')
# Personal_Info(ssn=864917489, first_name='Guthrie', last_name='Pilsworth', gender='Male', language='Bislama')
# Personal_Info(ssn=866181440, first_name='Zachary', last_name='Branchflower', gender='Male', language='Papiamento')
# Personal_Info(ssn=866530625, first_name='Francene', last_name='Ehlerding', gender='Female', language='Latvian')
# Personal_Info(ssn=867116007, first_name='Kennett', last_name='Barhims', gender='Male', language='Malayalam')
# Personal_Info(ssn=867136844, first_name='Clo', last_name='Skacel', gender='Female', language='Armenian')
# Personal_Info(ssn=867882360, first_name='Gasper', last_name='Dohrmann', gender='Male', language='Dzongkha')
# Personal_Info(ssn=868321805, first_name='Joanna', last_name='Raycroft', gender='Female', language='Bosnian')
# Personal_Info(ssn=870126609, first_name='Jourdain', last_name='Comino', gender='Male', language='Guarana')
# Personal_Info(ssn=870931121, first_name='Elisha', last_name='Wonham', gender='Male', language='Hebrew')
# Personal_Info(ssn=871993191, first_name='Susann', last_name='Walrond', gender='Female', language='Amharic')
# Personal_Info(ssn=872189267, first_name='Roddy', last_name='Honeywood', gender='Male', language='Maltese')
# Personal_Info(ssn=872491288, first_name='Salaidh', last_name='Barthod', gender='Female', language='Finnish')
# Personal_Info(ssn=873364733, first_name='Locke', last_name='Staries', gender='Male', language='Moldovan')
# Personal_Info(ssn=875189454, first_name='Eustace', last_name='Kinnear', gender='Male', language='Hiri Motu')
# Personal_Info(ssn=875750495, first_name='Frasquito', last_name='Lammas', gender='Male', language='Polish')
# Personal_Info(ssn=878128265, first_name='Nance', last_name='Doble', gender='Female', language='Dhivehi')
# Personal_Info(ssn=880224449, first_name='Zebadiah', last_name='Halliburton', gender='Male', language='Azeri')
# Personal_Info(ssn=881195974, first_name='Lodovico', last_name='Gabby', gender='Male', language='Northern Sotho')
# Personal_Info(ssn=881887308, first_name='Maitilde', last_name='Davis', gender='Female', language='Tsonga')
# Personal_Info(ssn=881957180, first_name='Homerus', last_name='Lamar', gender='Male', language='Macedonian')
# Personal_Info(ssn=882495290, first_name='Tamarah', last_name='Stenson', gender='Female', language='Armenian')
# Personal_Info(ssn=884611852, first_name='Wylie', last_name='Glennon', gender='Male', language='Romanian')
# Personal_Info(ssn=887417878, first_name='Bruce', last_name='Danieli', gender='Male', language='Tamil')
# Personal_Info(ssn=887839002, first_name='Mab', last_name='Bozworth', gender='Female', language='Tok Pisin')
# Personal_Info(ssn=888507008, first_name='Mayor', last_name='Gouley', gender='Male', language='Dzongkha')
# Personal_Info(ssn=888537684, first_name='Lanny', last_name='Perfect', gender='Male', language='Estonian')
# Personal_Info(ssn=888824928, first_name='Billye', last_name='Legat', gender='Female', language='Icelandic')
# Personal_Info(ssn=890289962, first_name='Kingston', last_name='Spitell', gender='Male', language='Quechua')
# Personal_Info(ssn=893120901, first_name='Dicky', last_name='Rohlfing', gender='Male', language='Oriya')
# Personal_Info(ssn=893177318, first_name='Nani', last_name='Bonelle', gender='Female', language='Kyrgyz')
# Personal_Info(ssn=894810628, first_name='Ree', last_name='Mordue', gender='Female', language='Tswana')
# Personal_Info(ssn=895261658, first_name='Nance', last_name='Danzelman', gender='Female', language='Icelandic')
# Personal_Info(ssn=895265515, first_name='Frank', last_name='Mason', gender='Male', language='Northern Sotho')
# Personal_Info(ssn=897767070, first_name='Glynnis', last_name='Tillerton', gender='Female', language='Nepali')
# Personal_Info(ssn=898033165, first_name='Sela', last_name='Vaillant', gender='Female', language='Arabic')
# Personal_Info(ssn=898868860, first_name='Hershel', last_name='Few', gender='Male', language='Gagauz')
# Personal_Info(ssn=899091766, first_name='Joe', last_name='Myderscough', gender='Male', language='Filipino')
# Personal_Info(ssn=899397179, first_name='Rani', last_name='Naisbitt', gender='Female', language='Greek')
# Personal_Info(ssn=899397378, first_name='Lindsay', last_name='Colledge', gender='Female', language='Croatian')
# Personal_Info(ssn=899476116, first_name='Tiphanie', last_name='Kevlin', gender='Female', language='Tetum')

# %%
for data in vehicles_iter:
    print(data)
# Out:
# Vehicles(ssn=100539824, vehicle_make='Oldsmobile', vehicle_model='Bravada', model_year=1993)
# Vehicles(ssn=101714702, vehicle_make='Ford', vehicle_model='Mustang', model_year=1997)
# Vehicles(ssn=101840356, vehicle_make='GMC', vehicle_model='Yukon', model_year=2005)
# Vehicles(ssn=104220928, vehicle_make='Oldsmobile', vehicle_model='Intrigue', model_year=2000)
# Vehicles(ssn=104847144, vehicle_make='Ford', vehicle_model='Crown Victoria', model_year=2008)
# Vehicles(ssn=105275541, vehicle_make='Ford', vehicle_model='Mustang', model_year=2001)
# Vehicles(ssn=105857486, vehicle_make='Chrysler', vehicle_model='300', model_year=2008)
# Vehicles(ssn=105915022, vehicle_make='Isuzu', vehicle_model='Hombre Space', model_year=2000)
# Vehicles(ssn=105917777, vehicle_make='Chevrolet', vehicle_model='Silverado 3500', model_year=2004)
# Vehicles(ssn=106351938, vehicle_make='GMC', vehicle_model='Sonoma Club', model_year=1992)
# Vehicles(ssn=106363293, vehicle_make='Volkswagen', vehicle_model='Touareg', model_year=2008)
# Vehicles(ssn=110843641, vehicle_make='Ford', vehicle_model='Mustang', model_year=1990)
# Vehicles(ssn=111351034, vehicle_make='Ford', vehicle_model='Fiesta', model_year=2001)
# Vehicles(ssn=114066912, vehicle_make='Aston Martin', vehicle_model='DBS', model_year=2011)
# Vehicles(ssn=114660984, vehicle_make='Chevrolet', vehicle_model='Camaro', model_year=1998)
# Vehicles(ssn=114748701, vehicle_make='Mercedes-Benz', vehicle_model='CL65 AMG', model_year=2009)
# Vehicles(ssn=116107235, vehicle_make='Bugatti', vehicle_model='Veyron', model_year=2009)
# Vehicles(ssn=116774915, vehicle_make='Buick', vehicle_model='Rainier', model_year=2004)
# Vehicles(ssn=117396617, vehicle_make='Scion', vehicle_model='tC', model_year=2008)
# Vehicles(ssn=117779748, vehicle_make='Audi', vehicle_model='S6', model_year=2009)
# Vehicles(ssn=117786202, vehicle_make='Rolls-Royce', vehicle_model='Phantom', model_year=2007)
# Vehicles(ssn=118210357, vehicle_make='GMC', vehicle_model='3500 Club Coupe', model_year=1992)
# Vehicles(ssn=118957100, vehicle_make='Plymouth', vehicle_model='Laser', model_year=1993)
# Vehicles(ssn=119078817, vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2005)
# Vehicles(ssn=120335535, vehicle_make='Isuzu', vehicle_model='Trooper', model_year=1997)
# Vehicles(ssn=120984054, vehicle_make='Acura', vehicle_model='RL', model_year=2003)
# Vehicles(ssn=121983948, vehicle_make='Pontiac', vehicle_model='Montana', model_year=2002)
# Vehicles(ssn=123053229, vehicle_make='Jaguar', vehicle_model='X-Type', model_year=2003)
# Vehicles(ssn=123622832, vehicle_make='Cadillac', vehicle_model='Catera', model_year=1999)
# Vehicles(ssn=123883381, vehicle_make='Ford', vehicle_model='Mustang', model_year=1989)
# Vehicles(ssn=125079434, vehicle_make='Lexus', vehicle_model='RX', model_year=2010)
# Vehicles(ssn=127492473, vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2004)
# Vehicles(ssn=127528001, vehicle_make='Porsche', vehicle_model='Cayenne', model_year=2008)
# Vehicles(ssn=127684232, vehicle_make='Scion', vehicle_model='xB', model_year=2004)
# Vehicles(ssn=127933548, vehicle_make='Jeep', vehicle_model='Grand Cherokee', model_year=2007)
# Vehicles(ssn=128424599, vehicle_make='Chevrolet', vehicle_model='Avalanche 1500', model_year=2006)
# Vehicles(ssn=128530369, vehicle_make='Audi', vehicle_model='A4', model_year=2010)
# Vehicles(ssn=128537952, vehicle_make='Dodge', vehicle_model='Neon', model_year=1995)
# Vehicles(ssn=128566040, vehicle_make='BMW', vehicle_model='M', model_year=2001)
# Vehicles(ssn=128604388, vehicle_make='Buick', vehicle_model='Skyhawk', model_year=1988)
# Vehicles(ssn=129670291, vehicle_make='Lotus', vehicle_model='Esprit', model_year=1993)
# Vehicles(ssn=131814310, vehicle_make='Land Rover', vehicle_model='Range Rover Sport', model_year=2012)
# Vehicles(ssn=132263507, vehicle_make='Dodge', vehicle_model='Ramcharger', model_year=1992)
# Vehicles(ssn=134050120, vehicle_make='BMW', vehicle_model='M5', model_year=2006)
# Vehicles(ssn=135869625, vehicle_make='Toyota', vehicle_model='Tundra', model_year=2004)
# Vehicles(ssn=137131889, vehicle_make='Infiniti', vehicle_model='G', model_year=2005)
# Vehicles(ssn=138654579, vehicle_make='Oldsmobile', vehicle_model='Achieva', model_year=1992)
# Vehicles(ssn=138671198, vehicle_make='Lexus', vehicle_model='RX', model_year=2003)
# Vehicles(ssn=138885288, vehicle_make='Mercury', vehicle_model='Monterey', model_year=2004)
# Vehicles(ssn=139048189, vehicle_make='Ford', vehicle_model='Escort', model_year=1997)
# Vehicles(ssn=139945865, vehicle_make='Volkswagen', vehicle_model='Cabriolet', model_year=1990)
# Vehicles(ssn=139996417, vehicle_make='Volvo', vehicle_model='V70', model_year=2002)
# Vehicles(ssn=140339727, vehicle_make='Mitsubishi', vehicle_model='Lancer', model_year=2003)
# Vehicles(ssn=140588263, vehicle_make='Volvo', vehicle_model='XC90', model_year=2009)
# Vehicles(ssn=141150543, vehicle_make='Toyota', vehicle_model='Corolla', model_year=2000)
# Vehicles(ssn=141889721, vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2011)
# Vehicles(ssn=142774616, vehicle_make='Chevrolet', vehicle_model='Prizm', model_year=1999)
# Vehicles(ssn=142873416, vehicle_make='Ford', vehicle_model='Thunderbird', model_year=2005)
# Vehicles(ssn=143174714, vehicle_make='Nissan', vehicle_model='Frontier', model_year=1999)
# Vehicles(ssn=145108454, vehicle_make='GMC', vehicle_model='Savana 1500', model_year=1999)
# Vehicles(ssn=145355124, vehicle_make='GMC', vehicle_model='Savana 1500', model_year=1999)
# Vehicles(ssn=145783985, vehicle_make='Mercedes-Benz', vehicle_model='E-Class', model_year=1993)
# Vehicles(ssn=146813446, vehicle_make='Ford', vehicle_model='Thunderbird', model_year=1988)
# Vehicles(ssn=147331463, vehicle_make='GMC', vehicle_model='Vandura G1500', model_year=1995)
# Vehicles(ssn=147478577, vehicle_make='Mitsubishi', vehicle_model='GTO', model_year=1996)
# Vehicles(ssn=147633462, vehicle_make='Ford', vehicle_model='Explorer', model_year=2005)
# Vehicles(ssn=148607519, vehicle_make='Mitsubishi', vehicle_model='RVR', model_year=1992)
# Vehicles(ssn=149187272, vehicle_make='Mercedes-Benz', vehicle_model='500SEL', model_year=1992)
# Vehicles(ssn=149456482, vehicle_make='GMC', vehicle_model='3500 Club Coupe', model_year=1995)
# Vehicles(ssn=150646357, vehicle_make='Cadillac', vehicle_model='Escalade', model_year=2000)
# Vehicles(ssn=150893343, vehicle_make='Plymouth', vehicle_model='Laser', model_year=1993)
# Vehicles(ssn=151543946, vehicle_make='Ford', vehicle_model='Probe', model_year=1996)
# Vehicles(ssn=151700641, vehicle_make='Ford', vehicle_model='F250', model_year=1999)
# Vehicles(ssn=151781397, vehicle_make='BMW', vehicle_model='M5', model_year=2000)
# Vehicles(ssn=152713526, vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2001)
# Vehicles(ssn=153671309, vehicle_make='Ford', vehicle_model='Taurus', model_year=1998)
# Vehicles(ssn=154177912, vehicle_make='Nissan', vehicle_model='Armada', model_year=2005)
# Vehicles(ssn=156187547, vehicle_make='Subaru', vehicle_model='Legacy', model_year=2011)
# Vehicles(ssn=156916848, vehicle_make='Acura', vehicle_model='TL', model_year=2005)
# Vehicles(ssn=157179982, vehicle_make='Audi', vehicle_model='Q7', model_year=2007)
# Vehicles(ssn=157387090, vehicle_make='Dodge', vehicle_model='Dakota Club', model_year=2005)
# Vehicles(ssn=157515269, vehicle_make='BMW', vehicle_model='Z3', model_year=1996)
# Vehicles(ssn=161369710, vehicle_make='Mercedes-Benz', vehicle_model='SLK-Class', model_year=1999)
# Vehicles(ssn=161534778, vehicle_make='Ford', vehicle_model='Mustang', model_year=1995)
# Vehicles(ssn=163688070, vehicle_make='Lincoln', vehicle_model='Continental', model_year=1998)
# Vehicles(ssn=163981022, vehicle_make='Honda', vehicle_model='Civic', model_year=2012)
# Vehicles(ssn=164119849, vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=2001)
# Vehicles(ssn=166104488, vehicle_make='Cadillac', vehicle_model='DTS', model_year=2008)
# Vehicles(ssn=167392377, vehicle_make='GMC', vehicle_model='3500', model_year=1998)
# Vehicles(ssn=168025324, vehicle_make='Volkswagen', vehicle_model='Fox', model_year=1989)
# Vehicles(ssn=168198754, vehicle_make='Toyota', vehicle_model='MR2', model_year=1993)
# Vehicles(ssn=168810838, vehicle_make='Mazda', vehicle_model='Mazda5', model_year=2012)
# Vehicles(ssn=168896661, vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1964)
# Vehicles(ssn=170653388, vehicle_make='Dodge', vehicle_model='Caravan', model_year=2010)
# Vehicles(ssn=171277781, vehicle_make='Ford', vehicle_model='Mustang', model_year=1985)
# Vehicles(ssn=172237739, vehicle_make='Mazda', vehicle_model='Mazdaspeed 3', model_year=2011)
# Vehicles(ssn=172774263, vehicle_make='Volvo', vehicle_model='S60', model_year=2002)
# Vehicles(ssn=172897546, vehicle_make='Mercury', vehicle_model='Cougar', model_year=1969)
# Vehicles(ssn=173997372, vehicle_make='Kia', vehicle_model='Sephia', model_year=1997)
# Vehicles(ssn=174132047, vehicle_make='Mitsubishi', vehicle_model='L300', model_year=1988)
# Vehicles(ssn=174353812, vehicle_make='Ford', vehicle_model='Thunderbird', model_year=1972)
# Vehicles(ssn=174519992, vehicle_make='Chevrolet', vehicle_model='Beretta', model_year=1994)
# Vehicles(ssn=174872537, vehicle_make='Ford', vehicle_model='Taurus', model_year=1991)
# Vehicles(ssn=176821359, vehicle_make='Toyota', vehicle_model='Celica', model_year=1995)
# Vehicles(ssn=176995851, vehicle_make='Jeep', vehicle_model='Commander', model_year=2007)
# Vehicles(ssn=179882790, vehicle_make='Chevrolet', vehicle_model='Malibu', model_year=2013)
# Vehicles(ssn=181074434, vehicle_make='Chevrolet', vehicle_model='Impala SS', model_year=1995)
# Vehicles(ssn=181288337, vehicle_make='GMC', vehicle_model='Canyon', model_year=2004)
# Vehicles(ssn=181886077, vehicle_make='Suzuki', vehicle_model='XL-7', model_year=2008)
# Vehicles(ssn=182155082, vehicle_make='Mercedes-Benz', vehicle_model='S-Class', model_year=1988)
# Vehicles(ssn=182814541, vehicle_make='Jeep', vehicle_model='Grand Cherokee', model_year=1997)
# Vehicles(ssn=183105024, vehicle_make='Maserati', vehicle_model='Spyder', model_year=1991)
# Vehicles(ssn=184606243, vehicle_make='Ford', vehicle_model='Mustang', model_year=1998)
# Vehicles(ssn=184841003, vehicle_make='Mercury', vehicle_model='Mystique', model_year=1997)
# Vehicles(ssn=184923560, vehicle_make='Scion', vehicle_model='xD', model_year=2011)
# Vehicles(ssn=184945241, vehicle_make='Audi', vehicle_model='90', model_year=1991)
# Vehicles(ssn=185500434, vehicle_make='Suzuki', vehicle_model='X-90', model_year=1998)
# Vehicles(ssn=185849868, vehicle_make='Mercury', vehicle_model='Sable', model_year=2001)
# Vehicles(ssn=186657773, vehicle_make='Mitsubishi', vehicle_model='Precis', model_year=1990)
# Vehicles(ssn=188209317, vehicle_make='Chevrolet', vehicle_model='Avalanche 2500', model_year=2003)
# Vehicles(ssn=188404336, vehicle_make='Mercedes-Benz', vehicle_model='E-Class', model_year=1985)
# Vehicles(ssn=189265696, vehicle_make='BMW', vehicle_model='8 Series', model_year=1995)
# Vehicles(ssn=189491458, vehicle_make='Volkswagen', vehicle_model='Touareg', model_year=2008)
# Vehicles(ssn=190056987, vehicle_make='Subaru', vehicle_model='Legacy', model_year=1990)
# Vehicles(ssn=190534517, vehicle_make='Hyundai', vehicle_model='Sonata', model_year=1993)
# Vehicles(ssn=191153194, vehicle_make='Mercury', vehicle_model='Grand Marquis', model_year=2009)
# Vehicles(ssn=192540695, vehicle_make='Volvo', vehicle_model='C70', model_year=1998)
# Vehicles(ssn=192673201, vehicle_make='Mitsubishi', vehicle_model='Galant', model_year=1999)
# Vehicles(ssn=194765816, vehicle_make='Dodge', vehicle_model='Dakota', model_year=2001)
# Vehicles(ssn=195235731, vehicle_make='Saturn', vehicle_model='Outlook', model_year=2007)
# Vehicles(ssn=196693796, vehicle_make='Subaru', vehicle_model='Legacy', model_year=2007)
# Vehicles(ssn=198706443, vehicle_make='Infiniti', vehicle_model='QX', model_year=2005)
# Vehicles(ssn=199450804, vehicle_make='Suzuki', vehicle_model='XL-7', model_year=2003)
# Vehicles(ssn=199544639, vehicle_make='Mercury', vehicle_model='Mountaineer', model_year=2006)
# Vehicles(ssn=200817151, vehicle_make='Mitsubishi', vehicle_model='Tredia', model_year=1985)
# Vehicles(ssn=201531249, vehicle_make='Acura', vehicle_model='NSX', model_year=1996)
# Vehicles(ssn=202841146, vehicle_make='Chrysler', vehicle_model='LHS', model_year=2000)
# Vehicles(ssn=203357648, vehicle_make='Volvo', vehicle_model='960', model_year=1992)
# Vehicles(ssn=205697375, vehicle_make='Subaru', vehicle_model='Outback', model_year=2011)
# Vehicles(ssn=205872423, vehicle_make='Chevrolet', vehicle_model='Express 2500', model_year=1999)
# Vehicles(ssn=206286674, vehicle_make='Mitsubishi', vehicle_model='Chariot', model_year=1994)
# Vehicles(ssn=206838848, vehicle_make='Volvo', vehicle_model='S60', model_year=2011)
# Vehicles(ssn=208742166, vehicle_make='Lexus', vehicle_model='LX', model_year=1999)
# Vehicles(ssn=208805879, vehicle_make='Mercury', vehicle_model='Mountaineer', model_year=2009)
# Vehicles(ssn=209508146, vehicle_make='Chevrolet', vehicle_model='Sportvan G20', model_year=1992)
# Vehicles(ssn=209584708, vehicle_make='Buick', vehicle_model='LaCrosse', model_year=2009)
# Vehicles(ssn=210914729, vehicle_make='Acura', vehicle_model='Integra', model_year=1997)
# Vehicles(ssn=211041734, vehicle_make='Ford', vehicle_model='E-Series', model_year=2011)
# Vehicles(ssn=211135247, vehicle_make='Mercedes-Benz', vehicle_model='SLR McLaren', model_year=2005)
# Vehicles(ssn=211155182, vehicle_make='Chrysler', vehicle_model='Town & Country', model_year=2010)
# Vehicles(ssn=211196826, vehicle_make='Ford', vehicle_model='Econoline E150', model_year=1996)
# Vehicles(ssn=212400215, vehicle_make='Dodge', vehicle_model='Shadow', model_year=1993)
# Vehicles(ssn=212411496, vehicle_make='Volkswagen', vehicle_model='Eurovan', model_year=1995)
# Vehicles(ssn=213281395, vehicle_make='Ford', vehicle_model='Mustang', model_year=2002)
# Vehicles(ssn=214291189, vehicle_make='Kia', vehicle_model='Sedona', model_year=2011)
# Vehicles(ssn=214968581, vehicle_make='Kia', vehicle_model='Borrego', model_year=2009)
# Vehicles(ssn=214997584, vehicle_make='Saturn', vehicle_model='Outlook', model_year=2010)
# Vehicles(ssn=216893812, vehicle_make='Maybach', vehicle_model='Landaulet', model_year=2012)
# Vehicles(ssn=216973104, vehicle_make='Bentley', vehicle_model='Continental Super', model_year=2012)
# Vehicles(ssn=217713922, vehicle_make='Volkswagen', vehicle_model='Corrado', model_year=1990)
# Vehicles(ssn=217815416, vehicle_make='Ford', vehicle_model='Mustang', model_year=2005)
# Vehicles(ssn=218144448, vehicle_make='Mitsubishi', vehicle_model='GTO', model_year=1999)
# Vehicles(ssn=218259873, vehicle_make='Honda', vehicle_model='Prelude', model_year=1997)
# Vehicles(ssn=218311615, vehicle_make='Mitsubishi', vehicle_model='3000GT', model_year=1996)
# Vehicles(ssn=218497300, vehicle_make='Plymouth', vehicle_model='Neon', model_year=1995)
# Vehicles(ssn=220160476, vehicle_make='Lexus', vehicle_model='LX', model_year=2011)
# Vehicles(ssn=220380208, vehicle_make='Ford', vehicle_model='Lightning', model_year=1994)
# Vehicles(ssn=222398571, vehicle_make='Lexus', vehicle_model='LX', model_year=2005)
# Vehicles(ssn=223679203, vehicle_make='Chevrolet', vehicle_model='Impala', model_year=2002)
# Vehicles(ssn=223980846, vehicle_make='Nissan', vehicle_model='GT-R', model_year=2012)
# Vehicles(ssn=224123436, vehicle_make='Kia', vehicle_model='Sportage', model_year=1998)
# Vehicles(ssn=224309267, vehicle_make='Chevrolet', vehicle_model='Avalanche', model_year=2009)
# Vehicles(ssn=224546919, vehicle_make='Mercedes-Benz', vehicle_model='SL-Class', model_year=1990)
# Vehicles(ssn=224842271, vehicle_make='Jeep', vehicle_model='Liberty', model_year=2005)
# Vehicles(ssn=224990668, vehicle_make='Acura', vehicle_model='TL', model_year=2008)
# Vehicles(ssn=225085789, vehicle_make='Mitsubishi', vehicle_model='Expo', model_year=1995)
# Vehicles(ssn=225642735, vehicle_make='Mercedes-Benz', vehicle_model='CLK-Class', model_year=2004)
# Vehicles(ssn=226764452, vehicle_make='Mazda', vehicle_model='B-Series Plus', model_year=1992)
# Vehicles(ssn=227727247, vehicle_make='Mitsubishi', vehicle_model='Lancer', model_year=2006)
# Vehicles(ssn=228167922, vehicle_make='Kia', vehicle_model='Sportage', model_year=2001)
# Vehicles(ssn=228552042, vehicle_make='Ford', vehicle_model='Mustang', model_year=1993)
# Vehicles(ssn=228905077, vehicle_make='GMC', vehicle_model='Yukon', model_year=2009)
# Vehicles(ssn=229449909, vehicle_make='Toyota', vehicle_model='MR2', model_year=2002)
# Vehicles(ssn=230091794, vehicle_make='Nissan', vehicle_model='Xterra', model_year=2004)
# Vehicles(ssn=230480684, vehicle_make='Pontiac', vehicle_model='Sunfire', model_year=1999)
# Vehicles(ssn=230991485, vehicle_make='Volkswagen', vehicle_model='CC', model_year=2009)
# Vehicles(ssn=231669264, vehicle_make='GMC', vehicle_model='Sonoma Club Coupe', model_year=1994)
# Vehicles(ssn=232185397, vehicle_make='Suzuki', vehicle_model='Samurai', model_year=1995)
# Vehicles(ssn=233272377, vehicle_make='Pontiac', vehicle_model='Firebird', model_year=1986)
# Vehicles(ssn=235103518, vehicle_make='Buick', vehicle_model='Skylark', model_year=1992)
# Vehicles(ssn=236318333, vehicle_make='Mazda', vehicle_model='B-Series', model_year=1997)
# Vehicles(ssn=236372567, vehicle_make='GMC', vehicle_model='3500', model_year=1992)
# Vehicles(ssn=237486737, vehicle_make='Maserati', vehicle_model='GranSport', model_year=2006)
# Vehicles(ssn=237807039, vehicle_make='Mazda', vehicle_model='MPV', model_year=1992)
# Vehicles(ssn=238138034, vehicle_make='Suzuki', vehicle_model='Swift', model_year=1994)
# Vehicles(ssn=238399999, vehicle_make='Mazda', vehicle_model='Familia', model_year=1990)
# Vehicles(ssn=239099133, vehicle_make='Chevrolet', vehicle_model='TrailBlazer', model_year=2004)
# Vehicles(ssn=239374122, vehicle_make='Chevrolet', vehicle_model='Silverado 1500', model_year=2002)
# Vehicles(ssn=240088805, vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1988)
# Vehicles(ssn=240328915, vehicle_make='Chrysler', vehicle_model='Crossfire', model_year=2006)
# Vehicles(ssn=240676258, vehicle_make='Aston Martin', vehicle_model='V8 Vantage', model_year=2008)
# Vehicles(ssn=242229624, vehicle_make='Nissan', vehicle_model='350Z', model_year=2003)
# Vehicles(ssn=243379496, vehicle_make='Mitsubishi', vehicle_model='Lancer', model_year=2003)
# Vehicles(ssn=243444611, vehicle_make='Mercedes-Benz', vehicle_model='S-Class', model_year=1987)
# Vehicles(ssn=244342210, vehicle_make='Mercury', vehicle_model='Villager', model_year=2002)
# Vehicles(ssn=244527593, vehicle_make='Lexus', vehicle_model='SC', model_year=1992)
# Vehicles(ssn=244793004, vehicle_make='Scion', vehicle_model='xB', model_year=2004)
# Vehicles(ssn=244810671, vehicle_make='Dodge', vehicle_model='Caravan', model_year=1997)
# Vehicles(ssn=245605880, vehicle_make='Dodge', vehicle_model='Dakota Club', model_year=1995)
# Vehicles(ssn=245774110, vehicle_make='Ford', vehicle_model='Escape', model_year=2012)
# Vehicles(ssn=247089326, vehicle_make='Ford', vehicle_model='E250', model_year=2008)
# Vehicles(ssn=247865288, vehicle_make='Audi', vehicle_model='Q5', model_year=2010)
# Vehicles(ssn=248079757, vehicle_make='Toyota', vehicle_model='Camry', model_year=1992)
# Vehicles(ssn=248230150, vehicle_make='BMW', vehicle_model='645', model_year=2005)
# Vehicles(ssn=249195514, vehicle_make='GMC', vehicle_model='Savana 1500', model_year=2008)
# Vehicles(ssn=253618401, vehicle_make='Chrysler', vehicle_model='Voyager', model_year=2000)
# Vehicles(ssn=254106071, vehicle_make='Toyota', vehicle_model='Tacoma Xtra', model_year=1996)
# Vehicles(ssn=254929669, vehicle_make='Mercedes-Benz', vehicle_model='300SD', model_year=1993)
# Vehicles(ssn=255810958, vehicle_make='Plymouth', vehicle_model='Colt', model_year=1992)
# Vehicles(ssn=256547507, vehicle_make='Chevrolet', vehicle_model='Express 3500', model_year=2005)
# Vehicles(ssn=256570666, vehicle_make='Honda', vehicle_model='S2000', model_year=2001)
# Vehicles(ssn=257126834, vehicle_make='Hyundai', vehicle_model='Sonata', model_year=2010)
# Vehicles(ssn=257598603, vehicle_make='Mitsubishi', vehicle_model='Lancer', model_year=2002)
# Vehicles(ssn=257773669, vehicle_make='Jeep', vehicle_model='Wrangler', model_year=1993)
# Vehicles(ssn=258226416, vehicle_make='Mercury', vehicle_model='Monterey', model_year=2007)
# Vehicles(ssn=259385920, vehicle_make='Plymouth', vehicle_model='Acclaim', model_year=1993)
# Vehicles(ssn=261149490, vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2006)
# Vehicles(ssn=262092144, vehicle_make='Bentley', vehicle_model='Continental GTC', model_year=2008)
# Vehicles(ssn=262467573, vehicle_make='Kia', vehicle_model='Sportage', model_year=2008)
# Vehicles(ssn=262554066, vehicle_make='Buick', vehicle_model='Regal', model_year=2002)
# Vehicles(ssn=262667030, vehicle_make='Toyota', vehicle_model='T100 Xtra', model_year=1998)
# Vehicles(ssn=264393910, vehicle_make='Mercedes-Benz', vehicle_model='600SL', model_year=1993)
# Vehicles(ssn=266869980, vehicle_make='Suzuki', vehicle_model='Reno', model_year=2006)
# Vehicles(ssn=267756383, vehicle_make='Ford', vehicle_model='Courier', model_year=1989)
# Vehicles(ssn=269012640, vehicle_make='Dodge', vehicle_model='Ram 1500', model_year=2001)
# Vehicles(ssn=271040134, vehicle_make='Ford', vehicle_model='Bronco', model_year=1995)
# Vehicles(ssn=271819938, vehicle_make='Aston Martin', vehicle_model='V8 Vantage', model_year=2008)
# Vehicles(ssn=271933051, vehicle_make='Lexus', vehicle_model='IS-F', model_year=2012)
# Vehicles(ssn=272507309, vehicle_make='Chrysler', vehicle_model='PT Cruiser', model_year=2003)
# Vehicles(ssn=272817979, vehicle_make='BMW', vehicle_model='325', model_year=2005)
# Vehicles(ssn=273498218, vehicle_make='Mitsubishi', vehicle_model='Eclipse', model_year=2003)
# Vehicles(ssn=274503806, vehicle_make='Subaru', vehicle_model='Forester', model_year=2005)
# Vehicles(ssn=274769883, vehicle_make='Chevrolet', vehicle_model='Impala', model_year=1995)
# Vehicles(ssn=276052973, vehicle_make='Acura', vehicle_model='RDX', model_year=2010)
# Vehicles(ssn=278555842, vehicle_make='Toyota', vehicle_model='Highlander', model_year=2002)
# Vehicles(ssn=278644853, vehicle_make='Suzuki', vehicle_model='SX4', model_year=2010)
# Vehicles(ssn=279127167, vehicle_make='Mercedes-Benz', vehicle_model='400SE', model_year=1992)
# Vehicles(ssn=279405540, vehicle_make='Isuzu', vehicle_model='Stylus', model_year=1993)
# Vehicles(ssn=279495682, vehicle_make='Saab', vehicle_model='3-Sep', model_year=2012)
# Vehicles(ssn=280537447, vehicle_make='Chrysler', vehicle_model='Concorde', model_year=1994)
# Vehicles(ssn=280984410, vehicle_make='Lexus', vehicle_model='SC', model_year=2000)
# Vehicles(ssn=281233458, vehicle_make='Infiniti', vehicle_model='M', model_year=2010)
# Vehicles(ssn=282839206, vehicle_make='Toyota', vehicle_model='4Runner', model_year=1997)
# Vehicles(ssn=283046835, vehicle_make='Buick', vehicle_model='LeSabre', model_year=2001)
# Vehicles(ssn=286264004, vehicle_make='Pontiac', vehicle_model='LeMans', model_year=1968)
# Vehicles(ssn=287579688, vehicle_make='Mitsubishi', vehicle_model='L300', model_year=1987)
# Vehicles(ssn=287662660, vehicle_make='Volvo', vehicle_model='V50', model_year=2010)
# Vehicles(ssn=288547233, vehicle_make='BMW', vehicle_model='5 Series', model_year=2008)
# Vehicles(ssn=288876462, vehicle_make='Dodge', vehicle_model='Stratus', model_year=2004)
# Vehicles(ssn=289039882, vehicle_make='Lincoln', vehicle_model='Town Car', model_year=2001)
# Vehicles(ssn=289098686, vehicle_make='Ford', vehicle_model='Explorer', model_year=1991)
# Vehicles(ssn=290257300, vehicle_make='Mazda', vehicle_model='929', model_year=1991)
# Vehicles(ssn=290824968, vehicle_make='Ford', vehicle_model='Club Wagon', model_year=1995)
# Vehicles(ssn=293543694, vehicle_make='Lexus', vehicle_model='SC', model_year=1996)
# Vehicles(ssn=294279936, vehicle_make='Mercedes-Benz', vehicle_model='SL-Class', model_year=1985)
# Vehicles(ssn=294531911, vehicle_make='Volvo', vehicle_model='XC60', model_year=2012)
# Vehicles(ssn=295637693, vehicle_make='Mazda', vehicle_model='Miata MX-5', model_year=2010)
# Vehicles(ssn=296327910, vehicle_make='GMC', vehicle_model='Yukon XL 2500', model_year=2009)
# Vehicles(ssn=296880097, vehicle_make='Chrysler', vehicle_model='Cirrus', model_year=1999)
# Vehicles(ssn=296904908, vehicle_make='Jensen', vehicle_model='Interceptor', model_year=1967)
# Vehicles(ssn=297631154, vehicle_make='Toyota', vehicle_model='Camry', model_year=2001)
# Vehicles(ssn=298063497, vehicle_make='Nissan', vehicle_model='Altima', model_year=2012)
# Vehicles(ssn=298699168, vehicle_make='Mercedes-Benz', vehicle_model='GL-Class', model_year=2007)
# Vehicles(ssn=298706018, vehicle_make='Acura', vehicle_model='NSX', model_year=1997)
# Vehicles(ssn=298797640, vehicle_make='Ford', vehicle_model='EXP', model_year=1988)
# Vehicles(ssn=299036911, vehicle_make='Dodge', vehicle_model='Viper RT/10', model_year=1994)
# Vehicles(ssn=299380483, vehicle_make='GMC', vehicle_model='Savana 1500', model_year=2005)
# Vehicles(ssn=299771060, vehicle_make='Infiniti', vehicle_model='QX', model_year=1999)
# Vehicles(ssn=300593610, vehicle_make='Saturn', vehicle_model='S-Series', model_year=2000)
# Vehicles(ssn=300768770, vehicle_make='Bentley', vehicle_model='Arnage', model_year=2009)
# Vehicles(ssn=300807209, vehicle_make='Mercedes-Benz', vehicle_model='C-Class', model_year=2009)
# Vehicles(ssn=301264306, vehicle_make='Mercury', vehicle_model='Sable', model_year=2002)
# Vehicles(ssn=301510522, vehicle_make='Smart', vehicle_model='Fortwo', model_year=2010)
# Vehicles(ssn=302644858, vehicle_make='Mercedes-Benz', vehicle_model='S-Class', model_year=2001)
# Vehicles(ssn=304484312, vehicle_make='Audi', vehicle_model='Allroad', model_year=2005)
# Vehicles(ssn=305071498, vehicle_make='Mercedes-Benz', vehicle_model='G-Class', model_year=2006)
# Vehicles(ssn=306232423, vehicle_make='Mazda', vehicle_model='929', model_year=1993)
# Vehicles(ssn=306862930, vehicle_make='GMC', vehicle_model='Sierra Denali', model_year=2006)
# Vehicles(ssn=308580964, vehicle_make='Buick', vehicle_model='Coachbuilder', model_year=1995)
# Vehicles(ssn=309040364, vehicle_make='Toyota', vehicle_model='Tacoma', model_year=2011)
# Vehicles(ssn=309388085, vehicle_make='Mitsubishi', vehicle_model='3000GT', model_year=1999)
# Vehicles(ssn=310602027, vehicle_make='GMC', vehicle_model='Savana', model_year=2012)
# Vehicles(ssn=311469296, vehicle_make='BMW', vehicle_model='525', model_year=2004)
# Vehicles(ssn=312387084, vehicle_make='Ford', vehicle_model='Expedition EL', model_year=2012)
# Vehicles(ssn=312593476, vehicle_make='Lotus', vehicle_model='Esprit', model_year=2000)
# Vehicles(ssn=312773647, vehicle_make='Saab', vehicle_model='900', model_year=1992)
# Vehicles(ssn=313027822, vehicle_make='Dodge', vehicle_model='Ram Wagon B150', model_year=1992)
# Vehicles(ssn=313527312, vehicle_make='Ford', vehicle_model='Taurus', model_year=2013)
# Vehicles(ssn=315125664, vehicle_make='Buick', vehicle_model='Riviera', model_year=1993)
# Vehicles(ssn=315262241, vehicle_make='Chevrolet', vehicle_model='Silverado 2500', model_year=1999)
# Vehicles(ssn=315449671, vehicle_make='BMW', vehicle_model='X6 M', model_year=2011)
# Vehicles(ssn=315785587, vehicle_make='Audi', vehicle_model='5000S', model_year=1984)
# Vehicles(ssn=317281600, vehicle_make='Saab', vehicle_model='3-Sep', model_year=2009)
# Vehicles(ssn=317432055, vehicle_make='Mitsubishi', vehicle_model='Mirage', model_year=1984)
# Vehicles(ssn=318585314, vehicle_make='Jaguar', vehicle_model='S-Type', model_year=2002)
# Vehicles(ssn=319430465, vehicle_make='Pontiac', vehicle_model='Trans Sport', model_year=1999)
# Vehicles(ssn=320901419, vehicle_make='Cadillac', vehicle_model='DeVille', model_year=1996)
# Vehicles(ssn=320979147, vehicle_make='Ford', vehicle_model='F-Series Super Duty', model_year=2007)
# Vehicles(ssn=323286705, vehicle_make='Lincoln', vehicle_model='Mark VII', model_year=1984)
# Vehicles(ssn=323338689, vehicle_make='Nissan', vehicle_model='Versa', model_year=2008)
# Vehicles(ssn=324395230, vehicle_make='Honda', vehicle_model='Prelude', model_year=1997)
# Vehicles(ssn=324738895, vehicle_make='Porsche', vehicle_model='968', model_year=1992)
# Vehicles(ssn=324756098, vehicle_make='Mitsubishi', vehicle_model='Mirage', model_year=1986)
# Vehicles(ssn=326649957, vehicle_make='Audi', vehicle_model='RS4', model_year=2008)
# Vehicles(ssn=327520546, vehicle_make='Land Rover', vehicle_model='Range Rover Sport', model_year=2008)
# Vehicles(ssn=327887554, vehicle_make='Toyota', vehicle_model='Corolla', model_year=1994)
# Vehicles(ssn=330993055, vehicle_make='Mitsubishi', vehicle_model='Montero', model_year=2001)
# Vehicles(ssn=332836591, vehicle_make='Mitsubishi', vehicle_model='Chariot', model_year=1991)
# Vehicles(ssn=333525097, vehicle_make='Lotus', vehicle_model='Esprit', model_year=1999)
# Vehicles(ssn=333955025, vehicle_make='Chevrolet', vehicle_model='Monte Carlo', model_year=2002)
# Vehicles(ssn=335351520, vehicle_make='Lincoln', vehicle_model='Town Car', model_year=1984)
# Vehicles(ssn=336482579, vehicle_make='Land Rover', vehicle_model='Freelander', model_year=2001)
# Vehicles(ssn=339278046, vehicle_make='Chevrolet', vehicle_model='Camaro', model_year=1998)
# Vehicles(ssn=339712687, vehicle_make='Mitsubishi', vehicle_model='Raider', model_year=2007)
# Vehicles(ssn=341106840, vehicle_make='Porsche', vehicle_model='911', model_year=1992)
# Vehicles(ssn=342059057, vehicle_make='Lamborghini', vehicle_model='Gallardo', model_year=2003)
# Vehicles(ssn=342550538, vehicle_make='GMC', vehicle_model='Sierra', model_year=2012)
# Vehicles(ssn=342909333, vehicle_make='Ford', vehicle_model='Mustang', model_year=2001)
# Vehicles(ssn=343208407, vehicle_make='Mazda', vehicle_model='MPV', model_year=2003)
# Vehicles(ssn=343813179, vehicle_make='Honda', vehicle_model='Passport', model_year=1994)
# Vehicles(ssn=345742160, vehicle_make='Audi', vehicle_model='S8', model_year=2002)
# Vehicles(ssn=347093254, vehicle_make='Jeep', vehicle_model='Wrangler', model_year=1997)
# Vehicles(ssn=347648652, vehicle_make='Chevrolet', vehicle_model='Metro', model_year=2001)
# Vehicles(ssn=348734312, vehicle_make='Eagle', vehicle_model='Vision', model_year=1994)
# Vehicles(ssn=348743224, vehicle_make='BMW', vehicle_model='X6 M', model_year=2012)
# Vehicles(ssn=349538864, vehicle_make='Ford', vehicle_model='Focus', model_year=2000)
# Vehicles(ssn=349677502, vehicle_make='Volkswagen', vehicle_model='Golf', model_year=1990)
# Vehicles(ssn=350209593, vehicle_make='Toyota', vehicle_model='Echo', model_year=2002)
# Vehicles(ssn=350804646, vehicle_make='Chevrolet', vehicle_model='Aveo', model_year=2008)
# Vehicles(ssn=351732802, vehicle_make='Volkswagen', vehicle_model='Jetta', model_year=2001)
# Vehicles(ssn=355219711, vehicle_make='Ford', vehicle_model='Festiva', model_year=1992)
# Vehicles(ssn=355529767, vehicle_make='Nissan', vehicle_model='Sentra', model_year=2008)
# Vehicles(ssn=355967706, vehicle_make='Audi', vehicle_model='100', model_year=1992)
# Vehicles(ssn=356399199, vehicle_make='Land Rover', vehicle_model='Range Rover', model_year=2006)
# Vehicles(ssn=357376094, vehicle_make='Chevrolet', vehicle_model='2500', model_year=1992)
# Vehicles(ssn=358847049, vehicle_make='Dodge', vehicle_model='Dakota Club', model_year=2007)
# Vehicles(ssn=360696230, vehicle_make='Mitsubishi', vehicle_model='Pajero', model_year=1985)
# Vehicles(ssn=361061530, vehicle_make='Plymouth', vehicle_model='Laser', model_year=1992)
# Vehicles(ssn=361427068, vehicle_make='Ford', vehicle_model='Club Wagon', model_year=1996)
# Vehicles(ssn=361494597, vehicle_make='Ford', vehicle_model='F-Series', model_year=1993)
# Vehicles(ssn=361835004, vehicle_make='Audi', vehicle_model='S4', model_year=2013)
# Vehicles(ssn=362098563, vehicle_make='Toyota', vehicle_model='Paseo', model_year=1995)
# Vehicles(ssn=362127902, vehicle_make='Mitsubishi', vehicle_model='Diamante', model_year=1994)
# Vehicles(ssn=364250166, vehicle_make='GMC', vehicle_model='Yukon XL 1500', model_year=2004)
# Vehicles(ssn=364652174, vehicle_make='Cadillac', vehicle_model='Escalade EXT', model_year=2007)
# Vehicles(ssn=366610607, vehicle_make='Ford', vehicle_model='F350', model_year=2007)
# Vehicles(ssn=367228998, vehicle_make='Chevrolet', vehicle_model='Express 2500', model_year=1997)
# Vehicles(ssn=367624426, vehicle_make='Saab', vehicle_model='900', model_year=1999)
# Vehicles(ssn=370016977, vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=2002)
# Vehicles(ssn=370245876, vehicle_make='Honda', vehicle_model='Civic', model_year=2005)
# Vehicles(ssn=370726509, vehicle_make='Saab', vehicle_model='900', model_year=1991)
# Vehicles(ssn=371285892, vehicle_make='Chevrolet', vehicle_model='Corvair', model_year=1960)
# Vehicles(ssn=371440582, vehicle_make='Mercedes-Benz', vehicle_model='C-Class', model_year=1994)
# Vehicles(ssn=371623727, vehicle_make='Acura', vehicle_model='NSX', model_year=2004)
# Vehicles(ssn=371889249, vehicle_make='Mitsubishi', vehicle_model='Diamante', model_year=2001)
# Vehicles(ssn=372447487, vehicle_make='Buick', vehicle_model='Riviera', model_year=1991)
# Vehicles(ssn=372627057, vehicle_make='Mercedes-Benz', vehicle_model='S-Class', model_year=1990)
# Vehicles(ssn=373672734, vehicle_make='Isuzu', vehicle_model='Hombre Space', model_year=1997)
# Vehicles(ssn=374470262, vehicle_make='GMC', vehicle_model='Rally Wagon 1500', model_year=1992)
# Vehicles(ssn=378080805, vehicle_make='Volvo', vehicle_model='S40', model_year=2010)
# Vehicles(ssn=378602472, vehicle_make='Dodge', vehicle_model='Ram 2500', model_year=2000)
# Vehicles(ssn=378660449, vehicle_make='Dodge', vehicle_model='Daytona', model_year=1984)
# Vehicles(ssn=378790193, vehicle_make='Chevrolet', vehicle_model='Avalanche 1500', model_year=2004)
# Vehicles(ssn=378886805, vehicle_make='Ford', vehicle_model='Festiva', model_year=1992)
# Vehicles(ssn=379078748, vehicle_make='Honda', vehicle_model='Accord', model_year=2011)
# Vehicles(ssn=380339730, vehicle_make='Jaguar', vehicle_model='X-Type', model_year=2003)
# Vehicles(ssn=380353854, vehicle_make='Honda', vehicle_model='Passport', model_year=1994)
# Vehicles(ssn=383184058, vehicle_make='Audi', vehicle_model='Cabriolet', model_year=1994)
# Vehicles(ssn=384306793, vehicle_make='Suzuki', vehicle_model='Grand Vitara', model_year=2012)
# Vehicles(ssn=384942772, vehicle_make='Porsche', vehicle_model='Cayman', model_year=2008)
# Vehicles(ssn=385301777, vehicle_make='Volvo', vehicle_model='S80', model_year=2009)
# Vehicles(ssn=385347828, vehicle_make='Lexus', vehicle_model='GS', model_year=2010)
# Vehicles(ssn=385980431, vehicle_make='Rolls-Royce', vehicle_model='Phantom', model_year=2011)
# Vehicles(ssn=386157960, vehicle_make='Subaru', vehicle_model='Brat', model_year=1987)
# Vehicles(ssn=386344088, vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=2005)
# Vehicles(ssn=386689884, vehicle_make='Subaru', vehicle_model='Tribeca', model_year=2012)
# Vehicles(ssn=386973523, vehicle_make='Aston Martin', vehicle_model='V8 Vantage S', model_year=2011)
# Vehicles(ssn=389310910, vehicle_make='Chevrolet', vehicle_model='Express 2500', model_year=2008)
# Vehicles(ssn=389511424, vehicle_make='BMW', vehicle_model='M5', model_year=2000)
# Vehicles(ssn=389848254, vehicle_make='Honda', vehicle_model='S2000', model_year=2006)
# Vehicles(ssn=390743062, vehicle_make='Audi', vehicle_model='TT', model_year=2002)
# Vehicles(ssn=391149280, vehicle_make='Hyundai', vehicle_model='Genesis', model_year=2010)
# Vehicles(ssn=391474578, vehicle_make='Dodge', vehicle_model='Ram 1500', model_year=1997)
# Vehicles(ssn=391732830, vehicle_make='Subaru', vehicle_model='Outback', model_year=2004)
# Vehicles(ssn=393226585, vehicle_make='Panoz', vehicle_model='Esperante', model_year=2008)
# Vehicles(ssn=396511559, vehicle_make='Infiniti', vehicle_model='Q', model_year=1993)
# Vehicles(ssn=397165372, vehicle_make='Chevrolet', vehicle_model='Lumina', model_year=1995)
# Vehicles(ssn=397298349, vehicle_make='Hyundai', vehicle_model='Elantra', model_year=1995)
# Vehicles(ssn=397878282, vehicle_make='Chevrolet', vehicle_model='Blazer', model_year=1998)
# Vehicles(ssn=399312815, vehicle_make='Chevrolet', vehicle_model='Cavalier', model_year=1996)
# Vehicles(ssn=399638810, vehicle_make='Acura', vehicle_model='Integra', model_year=1992)
# Vehicles(ssn=399816133, vehicle_make='Cadillac', vehicle_model='Allante', model_year=1992)
# Vehicles(ssn=400218654, vehicle_make='Ford', vehicle_model='Escort', model_year=2002)
# Vehicles(ssn=400776007, vehicle_make='GMC', vehicle_model='Savana 2500', model_year=2001)
# Vehicles(ssn=402613479, vehicle_make='Oldsmobile', vehicle_model='Alero', model_year=2000)
# Vehicles(ssn=402652055, vehicle_make='Saab', vehicle_model='3-Sep', model_year=2001)
# Vehicles(ssn=402885570, vehicle_make='Acura', vehicle_model='RSX', model_year=2002)
# Vehicles(ssn=403651535, vehicle_make='Mitsubishi', vehicle_model='Eclipse', model_year=1992)
# Vehicles(ssn=404574023, vehicle_make='Mazda', vehicle_model='Mazda3', model_year=2011)
# Vehicles(ssn=405251422, vehicle_make='BMW', vehicle_model='5 Series', model_year=2006)
# Vehicles(ssn=406155123, vehicle_make='Dodge', vehicle_model='Caravan', model_year=2000)
# Vehicles(ssn=406244867, vehicle_make='Audi', vehicle_model='Allroad', model_year=2004)
# Vehicles(ssn=406490634, vehicle_make='Toyota', vehicle_model='Corolla', model_year=2003)
# Vehicles(ssn=407300910, vehicle_make='Audi', vehicle_model='Coupe GT', model_year=1985)
# Vehicles(ssn=407807367, vehicle_make='Audi', vehicle_model='5000S', model_year=1986)
# Vehicles(ssn=407996159, vehicle_make='Chevrolet', vehicle_model='Sportvan G20', model_year=1993)
# Vehicles(ssn=408837943, vehicle_make='Mitsubishi', vehicle_model='Eclipse', model_year=2005)
# Vehicles(ssn=408983291, vehicle_make='Geo', vehicle_model='Metro', model_year=1992)
# Vehicles(ssn=409582034, vehicle_make='Audi', vehicle_model='A4', model_year=2001)
# Vehicles(ssn=409908946, vehicle_make='Toyota', vehicle_model='Paseo', model_year=1994)
# Vehicles(ssn=410384237, vehicle_make='Saab', vehicle_model='5-Sep', model_year=2009)
# Vehicles(ssn=410765092, vehicle_make='Dodge', vehicle_model='Avenger', model_year=2008)
# Vehicles(ssn=411214276, vehicle_make='Kia', vehicle_model='Sephia', model_year=1997)
# Vehicles(ssn=411434217, vehicle_make='Buick', vehicle_model='Century', model_year=1986)
# Vehicles(ssn=411794655, vehicle_make='Toyota', vehicle_model='Sienna', model_year=2003)
# Vehicles(ssn=412509133, vehicle_make='Lamborghini', vehicle_model='Gallardo', model_year=2003)
# Vehicles(ssn=412590452, vehicle_make='Honda', vehicle_model='Prelude', model_year=1985)
# Vehicles(ssn=412598022, vehicle_make='Lexus', vehicle_model='ES', model_year=1997)
# Vehicles(ssn=412798951, vehicle_make='Volkswagen', vehicle_model='Golf', model_year=2011)
# Vehicles(ssn=413143928, vehicle_make='Ford', vehicle_model='Aerostar', model_year=1996)
# Vehicles(ssn=413565613, vehicle_make='Dodge', vehicle_model='D150', model_year=1993)
# Vehicles(ssn=415420898, vehicle_make='Ford', vehicle_model='Fiesta', model_year=2001)
# Vehicles(ssn=415742251, vehicle_make='Ford', vehicle_model='Mustang', model_year=1964)
# Vehicles(ssn=416377763, vehicle_make='Mercedes-Benz', vehicle_model='SL-Class', model_year=1992)
# Vehicles(ssn=416383607, vehicle_make='BMW', vehicle_model='3 Series', model_year=1997)
# Vehicles(ssn=416806367, vehicle_make='Lexus', vehicle_model='LX', model_year=2008)
# Vehicles(ssn=416870469, vehicle_make='Ford', vehicle_model='Windstar', model_year=1999)
# Vehicles(ssn=418721888, vehicle_make='Mitsubishi', vehicle_model='Pajero', model_year=1996)
# Vehicles(ssn=418996659, vehicle_make='Mitsubishi', vehicle_model='Lancer Evolution', model_year=2008)
# Vehicles(ssn=420467789, vehicle_make='Chevrolet', vehicle_model='Express 2500', model_year=2005)
# Vehicles(ssn=420523813, vehicle_make='Buick', vehicle_model='LaCrosse', model_year=2006)
# Vehicles(ssn=421012511, vehicle_make='Ford', vehicle_model='F350', model_year=2012)
# Vehicles(ssn=421139794, vehicle_make='Mitsubishi', vehicle_model='Eclipse', model_year=1996)
# Vehicles(ssn=421203448, vehicle_make='Ford', vehicle_model='Crown Victoria', model_year=1998)
# Vehicles(ssn=421887316, vehicle_make='Toyota', vehicle_model='Xtra', model_year=1993)
# Vehicles(ssn=422674000, vehicle_make='Acura', vehicle_model='MDX', model_year=2008)
# Vehicles(ssn=423621820, vehicle_make='Mitsubishi', vehicle_model='GTO', model_year=1992)
# Vehicles(ssn=423884721, vehicle_make='Toyota', vehicle_model='Yaris', model_year=2008)
# Vehicles(ssn=424229138, vehicle_make='Oldsmobile', vehicle_model='Silhouette', model_year=2000)
# Vehicles(ssn=424910692, vehicle_make='Ford', vehicle_model='Escape', model_year=2008)
# Vehicles(ssn=424920863, vehicle_make='Suzuki', vehicle_model='Sidekick', model_year=1996)
# Vehicles(ssn=426098331, vehicle_make='Mercedes-Benz', vehicle_model='S-Class', model_year=1985)
# Vehicles(ssn=426334523, vehicle_make='Chrysler', vehicle_model='Town & Country', model_year=2001)
# Vehicles(ssn=426523410, vehicle_make='Toyota', vehicle_model='FJ Cruiser', model_year=2009)
# Vehicles(ssn=426615374, vehicle_make='GMC', vehicle_model='Sierra Hybrid', model_year=2006)
# Vehicles(ssn=427124625, vehicle_make='Mercury', vehicle_model='Cougar', model_year=1989)
# Vehicles(ssn=427360095, vehicle_make='Audi', vehicle_model='S5', model_year=2010)
# Vehicles(ssn=427966355, vehicle_make='Maserati', vehicle_model='Spyder', model_year=2002)
# Vehicles(ssn=428192946, vehicle_make='Ford', vehicle_model='Taurus', model_year=2012)
# Vehicles(ssn=428790781, vehicle_make='Ford', vehicle_model='Taurus', model_year=1993)
# Vehicles(ssn=429437811, vehicle_make='Lexus', vehicle_model='GX', model_year=2005)
# Vehicles(ssn=430276236, vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2008)
# Vehicles(ssn=430278349, vehicle_make='Porsche', vehicle_model='944', model_year=1991)
# Vehicles(ssn=432258923, vehicle_make='Lincoln', vehicle_model='MKX', model_year=2008)
# Vehicles(ssn=433087855, vehicle_make='Pontiac', vehicle_model='Torrent', model_year=2009)
# Vehicles(ssn=434412365, vehicle_make='Ford', vehicle_model='F-Series', model_year=1987)
# Vehicles(ssn=435340115, vehicle_make='Volkswagen', vehicle_model='Passat', model_year=2000)
# Vehicles(ssn=438800430, vehicle_make='Ford', vehicle_model='Explorer', model_year=2009)
# Vehicles(ssn=438821280, vehicle_make='Cadillac', vehicle_model='XLR', model_year=2009)
# Vehicles(ssn=440604889, vehicle_make='Honda', vehicle_model='Ridgeline', model_year=2011)
# Vehicles(ssn=441191376, vehicle_make='Plymouth', vehicle_model='Grand Voyager', model_year=1999)
# Vehicles(ssn=442151994, vehicle_make='Volkswagen', vehicle_model='Golf III', model_year=1994)
# Vehicles(ssn=444013823, vehicle_make='GMC', vehicle_model='Yukon', model_year=2012)
# Vehicles(ssn=445490727, vehicle_make='Nissan', vehicle_model='Frontier', model_year=1999)
# Vehicles(ssn=445623843, vehicle_make='Hummer', vehicle_model='H1', model_year=1994)
# Vehicles(ssn=446161946, vehicle_make='Jaguar', vehicle_model='XJ Series', model_year=2002)
# Vehicles(ssn=446731646, vehicle_make='Buick', vehicle_model='Regal', model_year=1996)
# Vehicles(ssn=447055935, vehicle_make='Rolls-Royce', vehicle_model='Phantom', model_year=2009)
# Vehicles(ssn=449387421, vehicle_make='Buick', vehicle_model='Century', model_year=2004)
# Vehicles(ssn=450041023, vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1978)
# Vehicles(ssn=450363771, vehicle_make='Ford', vehicle_model='Mustang', model_year=1997)
# Vehicles(ssn=450364561, vehicle_make='BMW', vehicle_model='X6', model_year=2009)
# Vehicles(ssn=450455021, vehicle_make='Dodge', vehicle_model='Avenger', model_year=2011)
# Vehicles(ssn=450567231, vehicle_make='Ford', vehicle_model='Freestyle', model_year=2005)
# Vehicles(ssn=450962075, vehicle_make='Lamborghini', vehicle_model='Diablo', model_year=1999)
# Vehicles(ssn=451345996, vehicle_make='Volkswagen', vehicle_model='Routan', model_year=2011)
# Vehicles(ssn=451528000, vehicle_make='Ford', vehicle_model='Club Wagon', model_year=1997)
# Vehicles(ssn=452269999, vehicle_make='Subaru', vehicle_model='Legacy', model_year=1998)
# Vehicles(ssn=453990644, vehicle_make='GMC', vehicle_model='Acadia', model_year=2008)
# Vehicles(ssn=454364371, vehicle_make='Toyota', vehicle_model='T100 Xtra', model_year=1997)
# Vehicles(ssn=455674513, vehicle_make='Mercedes-Benz', vehicle_model='SLK-Class', model_year=2000)
# Vehicles(ssn=455743521, vehicle_make='Ford', vehicle_model='Mustang', model_year=2001)
# Vehicles(ssn=455836194, vehicle_make='Chevrolet', vehicle_model='Impala', model_year=2005)
# Vehicles(ssn=457553869, vehicle_make='Mitsubishi', vehicle_model='Pajero', model_year=2003)
# Vehicles(ssn=457577890, vehicle_make='Pontiac', vehicle_model='Grand Am', model_year=2002)
# Vehicles(ssn=457976863, vehicle_make='Lincoln', vehicle_model='Continental', model_year=1984)
# Vehicles(ssn=458970499, vehicle_make='Mitsubishi', vehicle_model='Endeavor', model_year=2011)
# Vehicles(ssn=459297955, vehicle_make='Infiniti', vehicle_model='G', model_year=2007)
# Vehicles(ssn=460650321, vehicle_make='Subaru', vehicle_model='Impreza', model_year=2006)
# Vehicles(ssn=461842780, vehicle_make='GMC', vehicle_model='Sonoma', model_year=1993)
# Vehicles(ssn=461888139, vehicle_make='GMC', vehicle_model='Jimmy', model_year=1997)
# Vehicles(ssn=464211055, vehicle_make='Subaru', vehicle_model='Impreza', model_year=1998)
# Vehicles(ssn=464847886, vehicle_make='Cadillac', vehicle_model='Escalade EXT', model_year=2008)
# Vehicles(ssn=465960362, vehicle_make='Chevrolet', vehicle_model='Cruze', model_year=2012)
# Vehicles(ssn=468886064, vehicle_make='Suzuki', vehicle_model='Equator', model_year=2012)
# Vehicles(ssn=469080077, vehicle_make='Mercury', vehicle_model='Mountaineer', model_year=2000)
# Vehicles(ssn=469961488, vehicle_make='Chevrolet', vehicle_model='Silverado 1500', model_year=2008)
# Vehicles(ssn=470345693, vehicle_make='Geo', vehicle_model='Metro', model_year=1992)
# Vehicles(ssn=470947669, vehicle_make='Chevrolet', vehicle_model='Express 1500', model_year=2002)
# Vehicles(ssn=471281745, vehicle_make='Mazda', vehicle_model='RX-7', model_year=1990)
# Vehicles(ssn=472230389, vehicle_make='Mazda', vehicle_model='Mazda5', model_year=2010)
# Vehicles(ssn=473657769, vehicle_make='Land Rover', vehicle_model='Range Rover', model_year=2006)
# Vehicles(ssn=474567332, vehicle_make='Plymouth', vehicle_model='Voyager', model_year=1995)
# Vehicles(ssn=474951775, vehicle_make='Ford', vehicle_model='Explorer Sport', model_year=2003)
# Vehicles(ssn=475155394, vehicle_make='Honda', vehicle_model='Accord', model_year=2008)
# Vehicles(ssn=475241840, vehicle_make='Chevrolet', vehicle_model='HHR', model_year=2008)
# Vehicles(ssn=475475055, vehicle_make='Maserati', vehicle_model='Biturbo', model_year=1984)
# Vehicles(ssn=476270948, vehicle_make='Dodge', vehicle_model='Intrepid', model_year=2001)
# Vehicles(ssn=476688276, vehicle_make='Porsche', vehicle_model='928', model_year=1994)
# Vehicles(ssn=477300077, vehicle_make='Chevrolet', vehicle_model='G-Series G20', model_year=1995)
# Vehicles(ssn=478148720, vehicle_make='GMC', vehicle_model='1500 Club Coupe', model_year=1999)
# Vehicles(ssn=479498804, vehicle_make='Smart', vehicle_model='Fortwo', model_year=2008)
# Vehicles(ssn=480534039, vehicle_make='Chevrolet', vehicle_model='Express 3500', model_year=2010)
# Vehicles(ssn=481100098, vehicle_make='Subaru', vehicle_model='XT', model_year=1985)
# Vehicles(ssn=481873503, vehicle_make='Pontiac', vehicle_model='Grand Prix', model_year=1994)
# Vehicles(ssn=482887624, vehicle_make='Hyundai', vehicle_model='Sonata', model_year=2010)
# Vehicles(ssn=484069645, vehicle_make='Mercury', vehicle_model='Tracer', model_year=1991)
# Vehicles(ssn=484369255, vehicle_make='Ford', vehicle_model='Aerostar', model_year=1987)
# Vehicles(ssn=484755799, vehicle_make='BMW', vehicle_model='M3', model_year=2005)
# Vehicles(ssn=485390911, vehicle_make='Volvo', vehicle_model='S40', model_year=2003)
# Vehicles(ssn=485798123, vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1995)
# Vehicles(ssn=486871145, vehicle_make='Chevrolet', vehicle_model='Beretta', model_year=1993)
# Vehicles(ssn=488022147, vehicle_make='GMC', vehicle_model='Acadia', model_year=2007)
# Vehicles(ssn=488127780, vehicle_make='Jaguar', vehicle_model='XJ', model_year=2010)
# Vehicles(ssn=489574785, vehicle_make='Volkswagen', vehicle_model='New Beetle', model_year=1999)
# Vehicles(ssn=491368648, vehicle_make='Audi', vehicle_model='4000s', model_year=1986)
# Vehicles(ssn=491383802, vehicle_make='Mazda', vehicle_model='Mazda5', model_year=2006)
# ...
# Vehicles(ssn=744872990, vehicle_make='Dodge', vehicle_model='Caravan', model_year=2003)
# Vehicles(ssn=745191777, vehicle_make='GMC', vehicle_model='Savana 1500', model_year=2005)
# Vehicles(ssn=746551405, vehicle_make='Volvo', vehicle_model='S80', model_year=2008)
# Vehicles(ssn=747128456, vehicle_make='Lexus', vehicle_model='HS', model_year=2011)
# Vehicles(ssn=749858879, vehicle_make='Mercedes-Benz', vehicle_model='M-Class', model_year=2002)
# Vehicles(ssn=753940630, vehicle_make='Ford', vehicle_model='Aerostar', model_year=1992)
# Vehicles(ssn=753985796, vehicle_make='Volvo', vehicle_model='S40', model_year=2011)
# Vehicles(ssn=754289729, vehicle_make='Mercedes-Benz', vehicle_model='190E', model_year=1992)
# Vehicles(ssn=754494659, vehicle_make='Oldsmobile', vehicle_model='Ciera', model_year=1995)
# Vehicles(ssn=755084000, vehicle_make='Acura', vehicle_model='CL', model_year=1999)
# Vehicles(ssn=756402283, vehicle_make='Ford', vehicle_model='Crown Victoria', model_year=1995)
# Vehicles(ssn=758205576, vehicle_make='Ford', vehicle_model='Escape', model_year=2008)
# Vehicles(ssn=761012227, vehicle_make='Dodge', vehicle_model='Grand Caravan', model_year=2000)
# Vehicles(ssn=761645650, vehicle_make='Mazda', vehicle_model='Millenia', model_year=1998)
# Vehicles(ssn=762438029, vehicle_make='Lincoln', vehicle_model='Navigator', model_year=2001)
# Vehicles(ssn=763091587, vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1995)
# Vehicles(ssn=764932248, vehicle_make='Chevrolet', vehicle_model='Monte Carlo', model_year=2004)
# Vehicles(ssn=765358117, vehicle_make='Nissan', vehicle_model='Pathfinder', model_year=1992)
# Vehicles(ssn=765455973, vehicle_make='Hyundai', vehicle_model='Accent', model_year=1998)
# Vehicles(ssn=765879144, vehicle_make='Audi', vehicle_model='A4', model_year=2001)
# Vehicles(ssn=767054859, vehicle_make='Chevrolet', vehicle_model='Silverado 3500', model_year=2007)
# Vehicles(ssn=767556767, vehicle_make='Mercedes-Benz', vehicle_model='600SEC', model_year=1993)
# Vehicles(ssn=768545764, vehicle_make='Mercury', vehicle_model='Grand Marquis', model_year=1997)
# Vehicles(ssn=768748540, vehicle_make='Mercedes-Benz', vehicle_model='600SEC', model_year=1993)
# Vehicles(ssn=770618252, vehicle_make='Bentley', vehicle_model='Arnage', model_year=2008)
# Vehicles(ssn=771206900, vehicle_make='Mazda', vehicle_model='Mazda6', model_year=2007)
# Vehicles(ssn=771710505, vehicle_make='Ford', vehicle_model='Festiva', model_year=1989)
# Vehicles(ssn=773219639, vehicle_make='Mitsubishi', vehicle_model='Starion', model_year=1984)
# Vehicles(ssn=773537438, vehicle_make='Volvo', vehicle_model='V40', model_year=2001)
# Vehicles(ssn=773821734, vehicle_make='Porsche', vehicle_model='Boxster', model_year=1999)
# Vehicles(ssn=774085376, vehicle_make='Jeep', vehicle_model='Commander', model_year=2006)
# Vehicles(ssn=775099949, vehicle_make='Ford', vehicle_model='Tempo', model_year=1987)
# Vehicles(ssn=777051491, vehicle_make='Pontiac', vehicle_model='Firefly', model_year=1989)
# Vehicles(ssn=777682978, vehicle_make='Austin', vehicle_model='Mini', model_year=1959)
# Vehicles(ssn=777944586, vehicle_make='Oldsmobile', vehicle_model='Ciera', model_year=1996)
# Vehicles(ssn=778748262, vehicle_make='Chevrolet', vehicle_model='Sportvan G30', model_year=1993)
# Vehicles(ssn=779591449, vehicle_make='Mitsubishi', vehicle_model='Mighty Max', model_year=1992)
# Vehicles(ssn=780698282, vehicle_make='Pontiac', vehicle_model='Firebird', model_year=1991)
# Vehicles(ssn=781882076, vehicle_make='Toyota', vehicle_model='Yaris', model_year=2009)
# Vehicles(ssn=782469660, vehicle_make='Subaru', vehicle_model='Outback', model_year=2000)
# Vehicles(ssn=782606848, vehicle_make='Chevrolet', vehicle_model='Blazer', model_year=2005)
# Vehicles(ssn=783229258, vehicle_make='Buick', vehicle_model='Skylark', model_year=1990)
# Vehicles(ssn=784880730, vehicle_make='Pontiac', vehicle_model='Firebird', model_year=2000)
# Vehicles(ssn=785145978, vehicle_make='Kia', vehicle_model='Carens', model_year=2008)
# Vehicles(ssn=786563561, vehicle_make='Ford', vehicle_model='Tempo', model_year=1986)
# Vehicles(ssn=786636223, vehicle_make='Hyundai', vehicle_model='Accent', model_year=2008)
# Vehicles(ssn=787059008, vehicle_make='GMC', vehicle_model='Savana 1500', model_year=1997)
# Vehicles(ssn=787095697, vehicle_make='Lexus', vehicle_model='GS', model_year=1993)
# Vehicles(ssn=787107877, vehicle_make='Buick', vehicle_model='Coachbuilder', model_year=1991)
# Vehicles(ssn=788152625, vehicle_make='Suzuki', vehicle_model='SJ', model_year=1992)
# Vehicles(ssn=789701821, vehicle_make='Saab', vehicle_model='5-Sep', model_year=2004)
# Vehicles(ssn=790041283, vehicle_make='Mercury', vehicle_model='Mountaineer', model_year=1998)
# Vehicles(ssn=792718046, vehicle_make='Infiniti', vehicle_model='Q', model_year=2002)
# Vehicles(ssn=794243802, vehicle_make='Land Rover', vehicle_model='Discovery', model_year=2000)
# Vehicles(ssn=795566486, vehicle_make='Chrysler', vehicle_model='300', model_year=2008)
# Vehicles(ssn=795775263, vehicle_make='Ford', vehicle_model='E150', model_year=2010)
# Vehicles(ssn=797052289, vehicle_make='Dodge', vehicle_model='Journey', model_year=2010)
# Vehicles(ssn=797259814, vehicle_make='Lexus', vehicle_model='HS', model_year=2012)
# Vehicles(ssn=797652382, vehicle_make='Volkswagen', vehicle_model='Scirocco', model_year=1985)
# Vehicles(ssn=797877992, vehicle_make='Volkswagen', vehicle_model='Scirocco', model_year=1985)
# Vehicles(ssn=798341082, vehicle_make='Lotus', vehicle_model='Esprit', model_year=1987)
# Vehicles(ssn=798655644, vehicle_make='Lexus', vehicle_model='ES', model_year=1993)
# Vehicles(ssn=800069721, vehicle_make='Toyota', vehicle_model='Highlander', model_year=2003)
# Vehicles(ssn=801088313, vehicle_make='Suzuki', vehicle_model='Grand Vitara', model_year=2006)
# Vehicles(ssn=801926460, vehicle_make='Toyota', vehicle_model='Sienna', model_year=1999)
# Vehicles(ssn=801992773, vehicle_make='Ford', vehicle_model='E-Series', model_year=1986)
# Vehicles(ssn=804460617, vehicle_make='GMC', vehicle_model='Sierra 2500', model_year=2011)
# Vehicles(ssn=807135922, vehicle_make='Cadillac', vehicle_model='Seville', model_year=2001)
# Vehicles(ssn=807246202, vehicle_make='Hyundai', vehicle_model='Accent', model_year=2000)
# Vehicles(ssn=807256136, vehicle_make='Oldsmobile', vehicle_model='Toronado', model_year=1966)
# Vehicles(ssn=807358936, vehicle_make='Dodge', vehicle_model='Ram 1500', model_year=2005)
# Vehicles(ssn=807508539, vehicle_make='Pontiac', vehicle_model='Montana', model_year=2005)
# Vehicles(ssn=807605615, vehicle_make='Dodge', vehicle_model='Viper', model_year=2000)
# Vehicles(ssn=808558658, vehicle_make='Buick', vehicle_model='Coachbuilder', model_year=1994)
# Vehicles(ssn=808802542, vehicle_make='Dodge', vehicle_model='Ram', model_year=2009)
# Vehicles(ssn=811652750, vehicle_make='Oldsmobile', vehicle_model='Cutlass', model_year=1998)
# Vehicles(ssn=812119403, vehicle_make='Pontiac', vehicle_model='Turbo Firefly', model_year=1990)
# Vehicles(ssn=813424142, vehicle_make='Isuzu', vehicle_model='Rodeo Sport', model_year=2002)
# Vehicles(ssn=813475215, vehicle_make='Lamborghini', vehicle_model='Diablo', model_year=1994)
# Vehicles(ssn=815830300, vehicle_make='GMC', vehicle_model='3500', model_year=1994)
# Vehicles(ssn=816313858, vehicle_make='Chevrolet', vehicle_model='Silverado 3500', model_year=2004)
# Vehicles(ssn=816474782, vehicle_make='Cadillac', vehicle_model='Fleetwood', model_year=1996)
# Vehicles(ssn=816902049, vehicle_make='Dodge', vehicle_model='Durango', model_year=2012)
# Vehicles(ssn=817041950, vehicle_make='Audi', vehicle_model='A4', model_year=2003)
# Vehicles(ssn=817257437, vehicle_make='Dodge', vehicle_model='Sprinter', model_year=2009)
# Vehicles(ssn=817808930, vehicle_make='Subaru', vehicle_model='Legacy', model_year=2002)
# Vehicles(ssn=818610770, vehicle_make='Jaguar', vehicle_model='X-Type', model_year=2002)
# Vehicles(ssn=819525886, vehicle_make='Infiniti', vehicle_model='I', model_year=2003)
# Vehicles(ssn=819641414, vehicle_make='Lincoln', vehicle_model='Aviator', model_year=2004)
# Vehicles(ssn=820961105, vehicle_make='Isuzu', vehicle_model='Hombre', model_year=1998)
# Vehicles(ssn=822059037, vehicle_make='Acura', vehicle_model='MDX', model_year=2001)
# Vehicles(ssn=822304861, vehicle_make='Honda', vehicle_model='Element', model_year=2010)
# Vehicles(ssn=823270762, vehicle_make='Aston Martin', vehicle_model='DB9', model_year=2011)
# Vehicles(ssn=823755753, vehicle_make='GMC', vehicle_model='1500', model_year=1997)
# Vehicles(ssn=824894169, vehicle_make='Mercedes-Benz', vehicle_model='G-Class', model_year=2006)
# Vehicles(ssn=826978029, vehicle_make='Dodge', vehicle_model='Viper', model_year=2003)
# Vehicles(ssn=827624599, vehicle_make='Mazda', vehicle_model='Miata MX-5', model_year=2002)
# Vehicles(ssn=830231573, vehicle_make='Land Rover', vehicle_model='Defender', model_year=1994)
# Vehicles(ssn=831443286, vehicle_make='Mitsubishi', vehicle_model='Mirage', model_year=2000)
# Vehicles(ssn=833011428, vehicle_make='Kia', vehicle_model='Sephia', model_year=1995)
# Vehicles(ssn=835543785, vehicle_make='Dodge', vehicle_model='Sprinter', model_year=2006)
# Vehicles(ssn=836401837, vehicle_make='Mercedes-Benz', vehicle_model='R-Class', model_year=2006)
# Vehicles(ssn=836993309, vehicle_make='Honda', vehicle_model='Fit', model_year=2012)
# Vehicles(ssn=837765619, vehicle_make='Aptera', vehicle_model='Type-1h', model_year=2010)
# Vehicles(ssn=838691351, vehicle_make='Mitsubishi', vehicle_model='Outlander Sport', model_year=2011)
# Vehicles(ssn=840417929, vehicle_make='Mazda', vehicle_model='Miata MX-5', model_year=1996)
# Vehicles(ssn=841648517, vehicle_make='Volkswagen', vehicle_model='Passat', model_year=1996)
# Vehicles(ssn=842907557, vehicle_make='Pontiac', vehicle_model='Grand Am', model_year=1985)
# Vehicles(ssn=844154668, vehicle_make='GMC', vehicle_model='Vandura 3500', model_year=1993)
# Vehicles(ssn=844507305, vehicle_make='Mitsubishi', vehicle_model='Montero', model_year=2001)
# Vehicles(ssn=846071407, vehicle_make='Eagle', vehicle_model='Vision', model_year=1997)
# Vehicles(ssn=846099851, vehicle_make='Subaru', vehicle_model='Legacy', model_year=2002)
# Vehicles(ssn=846599961, vehicle_make='Volkswagen', vehicle_model='Jetta', model_year=1999)
# Vehicles(ssn=847344817, vehicle_make='Nissan', vehicle_model='350Z', model_year=2003)
# Vehicles(ssn=847617656, vehicle_make='Mitsubishi', vehicle_model='Galant', model_year=1996)
# Vehicles(ssn=848583386, vehicle_make='Toyota', vehicle_model='RAV4', model_year=2007)
# Vehicles(ssn=848742886, vehicle_make='Hyundai', vehicle_model='Accent', model_year=2011)
# Vehicles(ssn=848768808, vehicle_make='Toyota', vehicle_model='Celica', model_year=1998)
# Vehicles(ssn=849311551, vehicle_make='Ford', vehicle_model='Crown Victoria', model_year=2011)
# Vehicles(ssn=849646624, vehicle_make='Panoz', vehicle_model='Esperante', model_year=2006)
# Vehicles(ssn=849982973, vehicle_make='Mazda', vehicle_model='B-Series', model_year=1993)
# Vehicles(ssn=851942162, vehicle_make='Chevrolet', vehicle_model='Cobalt', model_year=2010)
# Vehicles(ssn=852157707, vehicle_make='Mazda', vehicle_model='MX-5', model_year=2010)
# Vehicles(ssn=853118953, vehicle_make='Pontiac', vehicle_model='Fiero', model_year=1987)
# Vehicles(ssn=853473648, vehicle_make='Infiniti', vehicle_model='I', model_year=2003)
# Vehicles(ssn=854687635, vehicle_make='Pontiac', vehicle_model='Grand Prix', model_year=1991)
# Vehicles(ssn=854712983, vehicle_make='Subaru', vehicle_model='SVX', model_year=1993)
# Vehicles(ssn=854795334, vehicle_make='Jeep', vehicle_model='Cherokee', model_year=1996)
# Vehicles(ssn=856183980, vehicle_make='Toyota', vehicle_model='MR2', model_year=1992)
# Vehicles(ssn=856279112, vehicle_make='BMW', vehicle_model='3 Series', model_year=2011)
# Vehicles(ssn=856674080, vehicle_make='Dodge', vehicle_model='Grand Caravan', model_year=2007)
# Vehicles(ssn=857375902, vehicle_make='Lotus', vehicle_model='Esprit', model_year=1996)
# Vehicles(ssn=858037735, vehicle_make='Porsche', vehicle_model='944', model_year=1984)
# Vehicles(ssn=858279190, vehicle_make='Suzuki', vehicle_model='Swift', model_year=1997)
# Vehicles(ssn=860670256, vehicle_make='Toyota', vehicle_model='Tacoma', model_year=2001)
# Vehicles(ssn=860892570, vehicle_make='Dodge', vehicle_model='Dakota', model_year=2007)
# Vehicles(ssn=861506716, vehicle_make='BMW', vehicle_model='M5', model_year=2007)
# Vehicles(ssn=862200653, vehicle_make='Mazda', vehicle_model='B-Series', model_year=2002)
# Vehicles(ssn=864229364, vehicle_make='Acura', vehicle_model='ZDX', model_year=2011)
# Vehicles(ssn=864917489, vehicle_make='Pontiac', vehicle_model='Grand Am', model_year=2004)
# Vehicles(ssn=866181440, vehicle_make='Volvo', vehicle_model='S60', model_year=2002)
# Vehicles(ssn=866530625, vehicle_make='Chevrolet', vehicle_model='Blazer', model_year=1997)
# Vehicles(ssn=867116007, vehicle_make='Volvo', vehicle_model='S80', model_year=2001)
# Vehicles(ssn=867136844, vehicle_make='Land Rover', vehicle_model='Range Rover', model_year=1986)
# Vehicles(ssn=867882360, vehicle_make='Ford', vehicle_model='F-Series', model_year=1987)
# Vehicles(ssn=868321805, vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2007)
# Vehicles(ssn=870126609, vehicle_make='Mercedes-Benz', vehicle_model='W201', model_year=1991)
# Vehicles(ssn=870931121, vehicle_make='Mitsubishi', vehicle_model='Pajero', model_year=1998)
# Vehicles(ssn=871993191, vehicle_make='Toyota', vehicle_model='Sienna', model_year=2000)
# Vehicles(ssn=872189267, vehicle_make='Audi', vehicle_model='A4', model_year=2010)
# Vehicles(ssn=872491288, vehicle_make='Acura', vehicle_model='Integra', model_year=1997)
# Vehicles(ssn=873364733, vehicle_make='Austin', vehicle_model='Mini Cooper', model_year=1964)
# Vehicles(ssn=875189454, vehicle_make='Mitsubishi', vehicle_model='Diamante', model_year=1993)
# Vehicles(ssn=875750495, vehicle_make='Hyundai', vehicle_model='Tiburon', model_year=2000)
# Vehicles(ssn=878128265, vehicle_make='Chrysler', vehicle_model='Concorde', model_year=1998)
# Vehicles(ssn=880224449, vehicle_make='Toyota', vehicle_model='Camry', model_year=2008)
# Vehicles(ssn=881195974, vehicle_make='Infiniti', vehicle_model='G', model_year=2004)
# Vehicles(ssn=881887308, vehicle_make='Subaru', vehicle_model='SVX', model_year=1994)
# Vehicles(ssn=881957180, vehicle_make='BMW', vehicle_model='M6', model_year=2009)
# Vehicles(ssn=882495290, vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2011)
# Vehicles(ssn=884611852, vehicle_make='Plymouth', vehicle_model='Neon', model_year=1996)
# Vehicles(ssn=887417878, vehicle_make='Lexus', vehicle_model='GS', model_year=2013)
# Vehicles(ssn=887839002, vehicle_make='Audi', vehicle_model='S6', model_year=2011)
# Vehicles(ssn=888507008, vehicle_make='Nissan', vehicle_model='Armada', model_year=2008)
# Vehicles(ssn=888537684, vehicle_make='Volkswagen', vehicle_model='Jetta', model_year=1991)
# Vehicles(ssn=888824928, vehicle_make='Volvo', vehicle_model='S60', model_year=2005)
# Vehicles(ssn=890289962, vehicle_make='GMC', vehicle_model='Savana 1500', model_year=2000)
# Vehicles(ssn=893120901, vehicle_make='Lotus', vehicle_model='Esprit', model_year=1991)
# Vehicles(ssn=893177318, vehicle_make='Chevrolet', vehicle_model='Lumina', model_year=1995)
# Vehicles(ssn=894810628, vehicle_make='Kia', vehicle_model='Sedona', model_year=2012)
# Vehicles(ssn=895261658, vehicle_make='Toyota', vehicle_model='Land Cruiser', model_year=2003)
# Vehicles(ssn=895265515, vehicle_make='Acura', vehicle_model='TL', model_year=1999)
# Vehicles(ssn=897767070, vehicle_make='BMW', vehicle_model='X3', model_year=2011)
# Vehicles(ssn=898033165, vehicle_make='Toyota', vehicle_model='Xtra', model_year=1994)
# Vehicles(ssn=898868860, vehicle_make='Lotus', vehicle_model='Esprit', model_year=2003)
# Vehicles(ssn=899091766, vehicle_make='Toyota', vehicle_model='Camry', model_year=2012)
# Vehicles(ssn=899397179, vehicle_make='Infiniti', vehicle_model='FX', model_year=2006)
# Vehicles(ssn=899397378, vehicle_make='Toyota', vehicle_model='Land Cruiser', model_year=1999)
# Vehicles(ssn=899476116, vehicle_make='Volkswagen', vehicle_model='Phaeton', model_year=2005)

# %%
for data in employment_iter:
    print(data)
# Out:
# Employment(employer='Stiedemann-Bailey', department='Research and Development', employee_id=290890771, ssn=100539824)
# Employment(employer='Nicolas and Sons', department='Sales', employee_id=416841359, ssn=101714702)
# Employment(employer='Connelly Group', department='Research and Development', employee_id=987952860, ssn=101840356)
# Employment(employer='Upton LLC', department='Marketing', employee_id=569817552, ssn=104220928)
# Employment(employer='Zemlak-Olson', department='Business Development', employee_id=462886707, ssn=104847144)
# Employment(employer='Kohler, Bradtke and Davis', department='Support', employee_id=800975518, ssn=105275541)
# Employment(employer='Roberts, Torphy and Dach', department='Human Resources', employee_id=774895332, ssn=105857486)
# Employment(employer='Lind-Jast', department='Marketing', employee_id=796418731, ssn=105915022)
# Employment(employer='Bashirian-Lueilwitz', department='Engineering', employee_id=443328799, ssn=105917777)
# Employment(employer='Windler, Marks and Haley', department='Services', employee_id=546271885, ssn=106351938)
# Employment(employer='Leffler-Hahn', department='Accounting', employee_id=315735282, ssn=106363293)
# Employment(employer='Lueilwitz LLC', department='Marketing', employee_id=339146042, ssn=110843641)
# Employment(employer='Davis Inc', department='Accounting', employee_id=390400385, ssn=111351034)
# Employment(employer='Kunze LLC', department='Research and Development', employee_id=782612900, ssn=114066912)
# Employment(employer='Mayert, Rice and Schmitt', department='Product Management', employee_id=858596488, ssn=114660984)
# Employment(employer='Pouros LLC', department='Legal', employee_id=142589283, ssn=114748701)
# Employment(employer='Pfannerstill Group', department='Research and Development', employee_id=431532437, ssn=116107235)
# Employment(employer='Ryan Group', department='Sales', employee_id=88274517, ssn=116774915)
# Employment(employer='Ritchie-Pagac', department='Business Development', employee_id=380095184, ssn=117396617)
# Employment(employer='Schmeler and Sons', department='Research and Development', employee_id=623275199, ssn=117779748)
# Employment(employer='Kerluke-Dibbert', department='Services', employee_id=905121197, ssn=117786202)
# Employment(employer='Hane-Klocko', department='Human Resources', employee_id=272946273, ssn=118210357)
# Employment(employer='Ernser LLC', department='Services', employee_id=76466085, ssn=118957100)
# Employment(employer='Terry LLC', department='Accounting', employee_id=704864087, ssn=119078817)
# Employment(employer='Rolfson, Price and Crooks', department='Business Development', employee_id=770255816, ssn=120335535)
# Employment(employer='Romaguera, Welch and Haley', department='Engineering', employee_id=146523887, ssn=120984054)
# Employment(employer='Paucek, Huels and Bauch', department='Accounting', employee_id=211452824, ssn=121983948)
# Employment(employer='Hayes-Trantow', department='Support', employee_id=72855255, ssn=123053229)
# Employment(employer='Cruickshank, Legros and Keebler', department='Research and Development', employee_id=571590433, ssn=123622832)
# Employment(employer='Mueller-Rath', department='Human Resources', employee_id=58069298, ssn=123883381)
# Employment(employer='Schumm, Schumm and Reichert', department='Engineering', employee_id=733839744, ssn=125079434)
# Employment(employer='Tromp-Leffler', department='Support', employee_id=26267170, ssn=127492473)
# Employment(employer='Wolf LLC', department='Engineering', employee_id=538370994, ssn=127528001)
# Employment(employer='Kulas-Corwin', department='Sales', employee_id=780632027, ssn=127684232)
# Employment(employer='MacGyver, Wiegand and Grant', department='Product Management', employee_id=774182531, ssn=127933548)
# Employment(employer="Kertzmann-O'Hara", department='Sales', employee_id=448015165, ssn=128424599)
# Employment(employer='Vandervort, Bernier and Morissette', department='Human Resources', employee_id=144998615, ssn=128530369)
# Employment(employer='King-Donnelly', department='Training', employee_id=820573004, ssn=128537952)
# Employment(employer='Harris Inc', department='Support', employee_id=537535536, ssn=128566040)
# Employment(employer='Heidenreich, Bergnaum and Smith', department='Training', employee_id=47204163, ssn=128604388)
# Employment(employer='Altenwerth-Heidenreich', department='Research and Development', employee_id=583628686, ssn=129670291)
# Employment(employer='Gibson and Sons', department='Sales', employee_id=578173633, ssn=131814310)
# Employment(employer='Rodriguez LLC', department='Legal', employee_id=657310166, ssn=132263507)
# Employment(employer='Donnelly-Crooks', department='Human Resources', employee_id=222943669, ssn=134050120)
# Employment(employer='Hyatt LLC', department='Training', employee_id=969647102, ssn=135869625)
# Employment(employer='Schuster Group', department='Research and Development', employee_id=724728604, ssn=137131889)
# Employment(employer='Homenick-Beer', department='Product Management', employee_id=19334133, ssn=138654579)
# Employment(employer='VonRueden-Torphy', department='Business Development', employee_id=106636122, ssn=138671198)
# Employment(employer='Mohr, Harvey and Mitchell', department='Legal', employee_id=647550101, ssn=138885288)
# Employment(employer='Keeling-Schroeder', department='Engineering', employee_id=822479019, ssn=139048189)
# Employment(employer='Gusikowski-Block', department='Legal', employee_id=411454732, ssn=139945865)
# Employment(employer='Pollich-Heathcote', department='Product Management', employee_id=122844710, ssn=139996417)
# Employment(employer='Bogisich Inc', department='Human Resources', employee_id=347172919, ssn=140339727)
# Employment(employer='Gutkowski Inc', department='Engineering', employee_id=834836768, ssn=140588263)
# Employment(employer='Greenholt LLC', department='Sales', employee_id=845391800, ssn=141150543)
# Employment(employer='Hartmann Inc', department='Support', employee_id=267276512, ssn=141889721)
# Employment(employer='Zboncak-Gulgowski', department='Marketing', employee_id=50368584, ssn=142774616)
# Employment(employer='Altenwerth-Emard', department='Marketing', employee_id=305847411, ssn=142873416)
# Employment(employer='Cronin Inc', department='Business Development', employee_id=83106397, ssn=143174714)
# Employment(employer='Murray, Wolff and Little', department='Business Development', employee_id=293578815, ssn=145108454)
# Employment(employer='Dibbert LLC', department='Support', employee_id=99620598, ssn=145355124)
# Employment(employer='Tromp Inc', department='Research and Development', employee_id=63360383, ssn=145783985)
# Employment(employer='Kub, Koch and Ratke', department='Marketing', employee_id=727830449, ssn=146813446)
# Employment(employer='Greenholt-Gusikowski', department='Engineering', employee_id=166006875, ssn=147331463)
# Employment(employer='Tremblay, Jacobs and Swift', department='Training', employee_id=461648855, ssn=147478577)
# Employment(employer='Bashirian-Moen', department='Training', employee_id=519115041, ssn=147633462)
# Employment(employer='Hudson-Gerhold', department='Human Resources', employee_id=622244500, ssn=148607519)
# Employment(employer='Balistreri Inc', department='Sales', employee_id=928183627, ssn=149187272)
# Employment(employer='Eichmann, Quigley and Macejkovic', department='Business Development', employee_id=488059597, ssn=149456482)
# Employment(employer='Bosco-Kunde', department='Services', employee_id=551726090, ssn=150646357)
# Employment(employer='Ratke-Raynor', department='Legal', employee_id=606687797, ssn=150893343)
# Employment(employer='Bergstrom-Boyle', department='Marketing', employee_id=723121170, ssn=151543946)
# Employment(employer='McLaughlin-Rohan', department='Legal', employee_id=471922172, ssn=151700641)
# Employment(employer='Schinner, Swaniawski and Carter', department='Human Resources', employee_id=933103060, ssn=151781397)
# Employment(employer='Little, Hagenes and McKenzie', department='Training', employee_id=759906937, ssn=152713526)
# Employment(employer='Gerlach, Bahringer and Rutherford', department='Accounting', employee_id=955604381, ssn=153671309)
# Employment(employer='Gorczany LLC', department='Training', employee_id=628983936, ssn=154177912)
# Employment(employer='Little, Powlowski and Witting', department='Business Development', employee_id=424459617, ssn=156187547)
# Employment(employer='King LLC', department='Research and Development', employee_id=394026042, ssn=156916848)
# Employment(employer='Konopelski-Vandervort', department='Legal', employee_id=878332368, ssn=157179982)
# Employment(employer='Reichel Group', department='Training', employee_id=105605387, ssn=157387090)
# Employment(employer='Gerhold-Marquardt', department='Research and Development', employee_id=256013938, ssn=157515269)
# Employment(employer='Greenholt-Hermiston', department='Business Development', employee_id=669841280, ssn=161369710)
# Employment(employer='Oberbrunner, Donnelly and Gibson', department='Human Resources', employee_id=832548521, ssn=161534778)
# Employment(employer='Roberts Group', department='Product Management', employee_id=76620387, ssn=163688070)
# Employment(employer='Olson-Lynch', department='Business Development', employee_id=507113609, ssn=163981022)
# Employment(employer='Quitzon, Rempel and Hane', department='Business Development', employee_id=34767523, ssn=164119849)
# Employment(employer='Carroll, Konopelski and Wunsch', department='Research and Development', employee_id=434797129, ssn=166104488)
# Employment(employer='Howell LLC', department='Business Development', employee_id=702399476, ssn=167392377)
# Employment(employer='Johnson Inc', department='Services', employee_id=347741883, ssn=168025324)
# Employment(employer='Corwin and Sons', department='Legal', employee_id=158160997, ssn=168198754)
# Employment(employer='Zemlak LLC', department='Research and Development', employee_id=868667896, ssn=168810838)
# Employment(employer='Toy-Jakubowski', department='Engineering', employee_id=178085199, ssn=168896661)
# Employment(employer='Murphy, Windler and Bartoletti', department='Legal', employee_id=26976472, ssn=170653388)
# Employment(employer='Batz Inc', department='Support', employee_id=492738721, ssn=171277781)
# Employment(employer='Jast and Sons', department='Services', employee_id=386141294, ssn=172237739)
# Employment(employer='Roberts LLC', department='Research and Development', employee_id=912028080, ssn=172774263)
# Employment(employer='Schultz, Price and Walsh', department='Business Development', employee_id=696328477, ssn=172897546)
# Employment(employer='Zulauf, Hudson and Wisozk', department='Research and Development', employee_id=391896194, ssn=173997372)
# Employment(employer='Bode-Zulauf', department='Marketing', employee_id=420021775, ssn=174132047)
# Employment(employer='Windler Group', department='Legal', employee_id=162190623, ssn=174353812)
# Employment(employer='Jast-Quitzon', department='Human Resources', employee_id=675707294, ssn=174519992)
# Employment(employer='Green-Waelchi', department='Engineering', employee_id=297065788, ssn=174872537)
# Employment(employer='Brown Group', department='Accounting', employee_id=910435820, ssn=176821359)
# Employment(employer='MacGyver-Hartmann', department='Accounting', employee_id=774207310, ssn=176995851)
# Employment(employer='McGlynn LLC', department='Support', employee_id=354393230, ssn=179882790)
# Employment(employer='Little, Herzog and Mertz', department='Legal', employee_id=459164509, ssn=181074434)
# Employment(employer='Kertzmann-Reichel', department='Research and Development', employee_id=670581933, ssn=181288337)
# Employment(employer='Douglas, Funk and Schowalter', department='Services', employee_id=772512148, ssn=181886077)
# Employment(employer='Bayer-Kunze', department='Support', employee_id=866996270, ssn=182155082)
# Employment(employer='Kiehn, Hansen and Will', department='Support', employee_id=948005696, ssn=182814541)
# Employment(employer='Kling-Howe', department='Research and Development', employee_id=717470887, ssn=183105024)
# Employment(employer='Quitzon-Morissette', department='Product Management', employee_id=815434446, ssn=184606243)
# Employment(employer='Bergstrom-Daniel', department='Marketing', employee_id=317381298, ssn=184841003)
# Employment(employer='Johnston, Leuschke and Stracke', department='Support', employee_id=969321837, ssn=184923560)
# Employment(employer='Lubowitz-Franecki', department='Product Management', employee_id=685287750, ssn=184945241)
# Employment(employer='Nienow-Metz', department='Legal', employee_id=885601438, ssn=185500434)
# Employment(employer='Quitzon, Stiedemann and Breitenberg', department='Services', employee_id=761399493, ssn=185849868)
# Employment(employer='Turner-Connelly', department='Research and Development', employee_id=921687621, ssn=186657773)
# Employment(employer='Kling, Prosacco and Wisoky', department='Accounting', employee_id=770491080, ssn=188209317)
# Employment(employer="Von, O'Kon and Runolfsdottir", department='Research and Development', employee_id=346414700, ssn=188404336)
# Employment(employer='McLaughlin-Botsford', department='Business Development', employee_id=602450272, ssn=189265696)
# Employment(employer='Mann-Stehr', department='Sales', employee_id=829383132, ssn=189491458)
# Employment(employer='Smitham-Blick', department='Engineering', employee_id=73918459, ssn=190056987)
# Employment(employer='Reilly and Sons', department='Product Management', employee_id=2155545, ssn=190534517)
# Employment(employer='Keeling, Hansen and Mertz', department='Training', employee_id=863420084, ssn=191153194)
# Employment(employer='Mante Inc', department='Business Development', employee_id=398018810, ssn=192540695)
# Employment(employer='Nicolas Group', department='Support', employee_id=752636577, ssn=192673201)
# Employment(employer='Sauer, Mann and Kling', department='Accounting', employee_id=893029716, ssn=194765816)
# Employment(employer='Hodkiewicz, Rau and Ryan', department='Marketing', employee_id=292776451, ssn=195235731)
# Employment(employer='Prosacco LLC', department='Business Development', employee_id=536059808, ssn=196693796)
# Employment(employer='Mante, Roberts and Miller', department='Research and Development', employee_id=981318396, ssn=198706443)
# Employment(employer='Farrell and Sons', department='Product Management', employee_id=853648779, ssn=199450804)
# Employment(employer='Heathcote-Torp', department='Product Management', employee_id=772681193, ssn=199544639)
# Employment(employer='Hilpert, Kassulke and Gutkowski', department='Research and Development', employee_id=26484055, ssn=200817151)
# Employment(employer="Will, Lemke and O'Hara", department='Marketing', employee_id=687719884, ssn=201531249)
# Employment(employer='Schuppe-Dickinson', department='Services', employee_id=478932065, ssn=202841146)
# Employment(employer='Kling-Graham', department='Marketing', employee_id=84055205, ssn=203357648)
# Employment(employer='MacGyver, Armstrong and Murray', department='Research and Development', employee_id=688311842, ssn=205697375)
# Employment(employer='Goodwin-Oberbrunner', department='Accounting', employee_id=70291024, ssn=205872423)
# Employment(employer='Russel-Terry', department='Engineering', employee_id=700439540, ssn=206286674)
# Employment(employer='Hickle, Beatty and McCullough', department='Business Development', employee_id=957755368, ssn=206838848)
# Employment(employer='Feeney Group', department='Product Management', employee_id=848299490, ssn=208742166)
# Employment(employer='Volkman-King', department='Training', employee_id=295040096, ssn=208805879)
# Employment(employer='Senger, Fay and Schuppe', department='Marketing', employee_id=59734435, ssn=209508146)
# Employment(employer='Lesch, Hartmann and Leffler', department='Engineering', employee_id=326936796, ssn=209584708)
# Employment(employer='Weber, Reynolds and Brakus', department='Training', employee_id=260100410, ssn=210914729)
# Employment(employer='Renner LLC', department='Services', employee_id=296760360, ssn=211041734)
# Employment(employer='Lind and Sons', department='Services', employee_id=934909831, ssn=211135247)
# Employment(employer='Sawayn, Marvin and Rempel', department='Research and Development', employee_id=746068283, ssn=211155182)
# Employment(employer='Feil, Wunsch and Cassin', department='Human Resources', employee_id=453457627, ssn=211196826)
# Employment(employer='Trantow Inc', department='Services', employee_id=965222028, ssn=212400215)
# Employment(employer='Hills-Luettgen', department='Engineering', employee_id=496662355, ssn=212411496)
# Employment(employer='Larson and Sons', department='Sales', employee_id=183961077, ssn=213281395)
# Employment(employer='Sipes LLC', department='Business Development', employee_id=135040342, ssn=214291189)
# Employment(employer='Aufderhar, Trantow and Goodwin', department='Marketing', employee_id=708647485, ssn=214968581)
# Employment(employer='Emmerich, Emmerich and Mertz', department='Business Development', employee_id=139720741, ssn=214997584)
# Employment(employer='Quitzon Inc', department='Human Resources', employee_id=970142691, ssn=216893812)
# Employment(employer='Skiles, Reichel and Romaguera', department='Engineering', employee_id=398820670, ssn=216973104)
# Employment(employer='Nienow-Hegmann', department='Training', employee_id=816888800, ssn=217713922)
# Employment(employer='Gislason-Padberg', department='Sales', employee_id=208472919, ssn=217815416)
# Employment(employer='Cormier, Weimann and Erdman', department='Accounting', employee_id=728208288, ssn=218144448)
# Employment(employer='Mraz, Stokes and MacGyver', department='Legal', employee_id=406893978, ssn=218259873)
# Employment(employer='Stokes-Hayes', department='Marketing', employee_id=501906989, ssn=218311615)
# Employment(employer='Johns, Corkery and Feeney', department='Services', employee_id=227439070, ssn=218497300)
# Employment(employer='Hirthe, Doyle and Harvey', department='Training', employee_id=131135326, ssn=220160476)
# Employment(employer='Brekke, Grady and Ruecker', department='Human Resources', employee_id=662984352, ssn=220380208)
# Employment(employer='Bernier, Ruecker and Carroll', department='Services', employee_id=690108218, ssn=222398571)
# Employment(employer='Langosh, Blick and Bechtelar', department='Product Management', employee_id=556679606, ssn=223679203)
# Employment(employer='Luettgen, Marks and Rosenbaum', department='Human Resources', employee_id=463461516, ssn=223980846)
# Employment(employer='Smith-Bergstrom', department='Sales', employee_id=118895205, ssn=224123436)
# Employment(employer='Jacobson-Kuhn', department='Human Resources', employee_id=335097675, ssn=224309267)
# Employment(employer='Ziemann-Lowe', department='Sales', employee_id=730391148, ssn=224546919)
# Employment(employer='Pollich, Hodkiewicz and Kris', department='Research and Development', employee_id=344050792, ssn=224842271)
# Employment(employer='Deckow Group', department='Engineering', employee_id=492911011, ssn=224990668)
# Employment(employer='Greenholt, Sawayn and Gusikowski', department='Business Development', employee_id=980311958, ssn=225085789)
# Employment(employer='Feeney, Champlin and Predovic', department='Sales', employee_id=688708911, ssn=225642735)
# Employment(employer='Blanda LLC', department='Business Development', employee_id=922526945, ssn=226764452)
# Employment(employer='Veum Group', department='Marketing', employee_id=318987623, ssn=227727247)
# Employment(employer='Dare Inc', department='Business Development', employee_id=273116134, ssn=228167922)
# Employment(employer='Batz-Bahringer', department='Research and Development', employee_id=741907423, ssn=228552042)
# Employment(employer='Johns LLC', department='Sales', employee_id=204360965, ssn=228905077)
# Employment(employer='Kling, Keeling and Cormier', department='Human Resources', employee_id=408081800, ssn=229449909)
# Employment(employer="O'Keefe-Keeling", department='Training', employee_id=400839938, ssn=230091794)
# Employment(employer='Fahey Group', department='Product Management', employee_id=822230506, ssn=230480684)
# Employment(employer='Hodkiewicz-Murray', department='Marketing', employee_id=990856844, ssn=230991485)
# Employment(employer='Dare, Kuhn and Pfannerstill', department='Marketing', employee_id=683132488, ssn=231669264)
# Employment(employer="Schumm-O'Conner", department='Legal', employee_id=24952668, ssn=232185397)
# Employment(employer='Donnelly, Abernathy and Blanda', department='Marketing', employee_id=380287814, ssn=233272377)
# Employment(employer='Grant-Aufderhar', department='Engineering', employee_id=638402825, ssn=235103518)
# Employment(employer='Zboncak and Sons', department='Product Management', employee_id=853010287, ssn=236318333)
# Employment(employer='Tremblay LLC', department='Research and Development', employee_id=456122996, ssn=236372567)
# Employment(employer='Kuhlman Group', department='Accounting', employee_id=853357304, ssn=237486737)
# Employment(employer='Schmeler Inc', department='Research and Development', employee_id=751537754, ssn=237807039)
# Employment(employer="Reichel-O'Hara", department='Research and Development', employee_id=963899752, ssn=238138034)
# Employment(employer='Beatty, Mohr and Wolff', department='Support', employee_id=466432775, ssn=238399999)
# Employment(employer='Conroy LLC', department='Legal', employee_id=450095737, ssn=239099133)
# Employment(employer='Kassulke-Cruickshank', department='Support', employee_id=338042555, ssn=239374122)
# Employment(employer='Mraz, Veum and Farrell', department='Product Management', employee_id=306285659, ssn=240088805)
# Employment(employer="O'Keefe-Cruickshank", department='Research and Development', employee_id=341983927, ssn=240328915)
# Employment(employer='Donnelly-Reichel', department='Sales', employee_id=516219405, ssn=240676258)
# Employment(employer='Koch Inc', department='Marketing', employee_id=556904797, ssn=242229624)
# Employment(employer='Ferry, Schaden and Lowe', department='Product Management', employee_id=949140863, ssn=243379496)
# Employment(employer='Carroll and Sons', department='Marketing', employee_id=960367474, ssn=243444611)
# Employment(employer='Ortiz, King and Kovacek', department='Engineering', employee_id=775215930, ssn=244342210)
# Employment(employer='Kuhic Group', department='Business Development', employee_id=86244265, ssn=244527593)
# Employment(employer='Altenwerth, Feest and Hammes', department='Legal', employee_id=185795578, ssn=244793004)
# Employment(employer='Howell-Wunsch', department='Legal', employee_id=917637157, ssn=244810671)
# Employment(employer='Christiansen, Conroy and Hettinger', department='Research and Development', employee_id=965661085, ssn=245605880)
# Employment(employer='Barton-Raynor', department='Legal', employee_id=864272610, ssn=245774110)
# Employment(employer='McClure and Sons', department='Human Resources', employee_id=801737009, ssn=247089326)
# Employment(employer='Flatley, Braun and Wiegand', department='Product Management', employee_id=838221727, ssn=247865288)
# Employment(employer='Davis Group', department='Accounting', employee_id=828582303, ssn=248079757)
# Employment(employer='Jones Group', department='Legal', employee_id=8209244, ssn=248230150)
# Employment(employer='Pagac and Sons', department='Training', employee_id=452560161, ssn=249195514)
# Employment(employer='Halvorson-Parisian', department='Support', employee_id=162500138, ssn=253618401)
# Employment(employer='Botsford, Lockman and Schiller', department='Engineering', employee_id=854893521, ssn=254106071)
# Employment(employer='Armstrong, Halvorson and Lemke', department='Services', employee_id=250791940, ssn=254929669)
# Employment(employer='Aufderhar, Quigley and Wiza', department='Research and Development', employee_id=879571848, ssn=255810958)
# Employment(employer='Purdy Group', department='Business Development', employee_id=857663270, ssn=256547507)
# Employment(employer='Bauch, Monahan and Hagenes', department='Sales', employee_id=449784881, ssn=256570666)
# Employment(employer='Tremblay, Mraz and Hamill', department='Business Development', employee_id=984265000, ssn=257126834)
# Employment(employer='Macejkovic, Johnson and Hane', department='Accounting', employee_id=792599258, ssn=257598603)
# Employment(employer='Schimmel, Kling and Lueilwitz', department='Services', employee_id=731055129, ssn=257773669)
# Employment(employer='Kub Inc', department='Support', employee_id=342321361, ssn=258226416)
# Employment(employer='Hauck Inc', department='Accounting', employee_id=192907576, ssn=259385920)
# Employment(employer='Boyle, Rutherford and Parisian', department='Legal', employee_id=368081521, ssn=261149490)
# Employment(employer='Carroll, Treutel and Kub', department='Research and Development', employee_id=839766179, ssn=262092144)
# Employment(employer='Mitchell, Robel and Yost', department='Research and Development', employee_id=444519112, ssn=262467573)
# Employment(employer='Schultz, West and Cummings', department='Research and Development', employee_id=818904444, ssn=262554066)
# Employment(employer='Jacobson LLC', department='Research and Development', employee_id=834988535, ssn=262667030)
# Employment(employer='Halvorson and Sons', department='Services', employee_id=930006221, ssn=264393910)
# Employment(employer='Kiehn Inc', department='Training', employee_id=428834969, ssn=266869980)
# Employment(employer='Gottlieb, Gleichner and Kihn', department='Services', employee_id=421073885, ssn=267756383)
# Employment(employer='Volkman, Zulauf and Hickle', department='Engineering', employee_id=377828624, ssn=269012640)
# Employment(employer='Wilderman-Larkin', department='Business Development', employee_id=86806443, ssn=271040134)
# Employment(employer='Feeney Inc', department='Sales', employee_id=949045161, ssn=271819938)
# Employment(employer='Marks-McKenzie', department='Engineering', employee_id=62333892, ssn=271933051)
# Employment(employer='Zieme-Yundt', department='Human Resources', employee_id=634840862, ssn=272507309)
# Employment(employer='Heidenreich, Leffler and Zboncak', department='Marketing', employee_id=392936486, ssn=272817979)
# Employment(employer='Rutherford, Sporer and Schuster', department='Engineering', employee_id=450663762, ssn=273498218)
# Employment(employer='Schuster, Dach and Huel', department='Business Development', employee_id=537845226, ssn=274503806)
# Employment(employer='Kassulke Group', department='Human Resources', employee_id=864085293, ssn=274769883)
# Employment(employer='Conroy Inc', department='Engineering', employee_id=788420673, ssn=276052973)
# Employment(employer='Pfannerstill-Rowe', department='Sales', employee_id=50913038, ssn=278555842)
# Employment(employer='Dickinson-Watsica', department='Support', employee_id=759021921, ssn=278644853)
# Employment(employer='Gutkowski Group', department='Accounting', employee_id=328927113, ssn=279127167)
# Employment(employer='Kutch, Koch and Emmerich', department='Business Development', employee_id=94660484, ssn=279405540)
# Employment(employer='Hudson Inc', department='Product Management', employee_id=978540521, ssn=279495682)
# Employment(employer='Moen, Veum and McLaughlin', department='Accounting', employee_id=120401993, ssn=280537447)
# Employment(employer='Ferry Group', department='Support', employee_id=491709312, ssn=280984410)
# Employment(employer='Cruickshank Inc', department='Legal', employee_id=913900799, ssn=281233458)
# Employment(employer='Ward Inc', department='Support', employee_id=118557773, ssn=282839206)
# Employment(employer='Abbott, Bahringer and Goyette', department='Marketing', employee_id=415601892, ssn=283046835)
# Employment(employer='Lind, Runolfsdottir and Bailey', department='Legal', employee_id=146813788, ssn=286264004)
# Employment(employer='Fahey-Klein', department='Human Resources', employee_id=711209998, ssn=287579688)
# Employment(employer='Collier Inc', department='Research and Development', employee_id=815101189, ssn=287662660)
# Employment(employer='Beatty and Sons', department='Sales', employee_id=719137028, ssn=288547233)
# Employment(employer='Jacobs-Christiansen', department='Engineering', employee_id=446939532, ssn=288876462)
# Employment(employer='DuBuque-Krajcik', department='Legal', employee_id=993967417, ssn=289039882)
# Employment(employer='Funk-Tremblay', department='Training', employee_id=84068275, ssn=289098686)
# Employment(employer='Weissnat Group', department='Legal', employee_id=48151489, ssn=290257300)
# Employment(employer='Gutmann-Cruickshank', department='Engineering', employee_id=298276855, ssn=290824968)
# Employment(employer='Howe-Robel', department='Services', employee_id=456137557, ssn=293543694)
# Employment(employer='Spencer and Sons', department='Marketing', employee_id=570353432, ssn=294279936)
# Employment(employer='Little, Veum and Sauer', department='Legal', employee_id=457118863, ssn=294531911)
# Employment(employer='Heidenreich Group', department='Accounting', employee_id=791848443, ssn=295637693)
# Employment(employer='Collier-Wisozk', department='Legal', employee_id=403440604, ssn=296327910)
# Employment(employer='Ebert-Bahringer', department='Business Development', employee_id=888295986, ssn=296880097)
# Employment(employer='Mayert-Volkman', department='Research and Development', employee_id=117283397, ssn=296904908)
# Employment(employer='Stark-Wolff', department='Product Management', employee_id=656789812, ssn=297631154)
# Employment(employer='Johns-Maggio', department='Services', employee_id=409534160, ssn=298063497)
# Employment(employer='Hilpert Inc', department='Support', employee_id=728266702, ssn=298699168)
# Employment(employer='Sporer, Haley and Cartwright', department='Legal', employee_id=728129260, ssn=298706018)
# Employment(employer='Brown Inc', department='Accounting', employee_id=688035288, ssn=298797640)
# Employment(employer='Kilback Group', department='Services', employee_id=25391126, ssn=299036911)
# Employment(employer='Streich Group', department='Product Management', employee_id=259880164, ssn=299380483)
# Employment(employer='Kozey Group', department='Sales', employee_id=273066253, ssn=299771060)
# Employment(employer='Lebsack-Gerlach', department='Human Resources', employee_id=482553583, ssn=300593610)
# Employment(employer='McClure-Gerhold', department='Business Development', employee_id=19218158, ssn=300768770)
# Employment(employer='Ankunding, Larson and Leannon', department='Legal', employee_id=8103537, ssn=300807209)
# Employment(employer='Muller, Blanda and Quigley', department='Sales', employee_id=876217832, ssn=301264306)
# Employment(employer='White-Fahey', department='Sales', employee_id=302737861, ssn=301510522)
# Employment(employer='Cartwright, Schowalter and Barton', department='Marketing', employee_id=155191499, ssn=302644858)
# Employment(employer='Stamm-Reichert', department='Engineering', employee_id=254364794, ssn=304484312)
# Employment(employer='Howe Inc', department='Legal', employee_id=118989188, ssn=305071498)
# Employment(employer='Kuhic, Veum and Swift', department='Product Management', employee_id=626620097, ssn=306232423)
# Employment(employer='Considine-Schaefer', department='Human Resources', employee_id=588894681, ssn=306862930)
# Employment(employer='Hilpert Group', department='Accounting', employee_id=84226273, ssn=308580964)
# Employment(employer='Heidenreich Inc', department='Product Management', employee_id=851333821, ssn=309040364)
# Employment(employer='Aufderhar, Metz and Bashirian', department='Business Development', employee_id=682399289, ssn=309388085)
# Employment(employer='Mayert-Pagac', department='Marketing', employee_id=841179190, ssn=310602027)
# Employment(employer='Huels Group', department='Training', employee_id=411636448, ssn=311469296)
# Employment(employer='Donnelly-Roberts', department='Training', employee_id=605025688, ssn=312387084)
# Employment(employer='Rolfson, Dietrich and Hyatt', department='Business Development', employee_id=648324745, ssn=312593476)
# Employment(employer='Dibbert-Koepp', department='Marketing', employee_id=322009977, ssn=312773647)
# Employment(employer='Stamm-Boehm', department='Business Development', employee_id=741724903, ssn=313027822)
# Employment(employer='Torp LLC', department='Training', employee_id=194509043, ssn=313527312)
# Employment(employer='Wiegand-Bernhard', department='Business Development', employee_id=575620609, ssn=315125664)
# Employment(employer='Predovic, Renner and Hansen', department='Research and Development', employee_id=161755710, ssn=315262241)
# Employment(employer='Hettinger-Halvorson', department='Research and Development', employee_id=848346426, ssn=315449671)
# Employment(employer='Wehner-Parker', department='Product Management', employee_id=35512362, ssn=315785587)
# Employment(employer='Moen, Turcotte and Stracke', department='Marketing', employee_id=758473260, ssn=317281600)
# Employment(employer='Dickens LLC', department='Product Management', employee_id=109248587, ssn=317432055)
# Employment(employer='Tremblay, Adams and Schroeder', department='Human Resources', employee_id=220577935, ssn=318585314)
# Employment(employer='Howell-Little', department='Legal', employee_id=73979239, ssn=319430465)
# Employment(employer='Smitham-Herman', department='Sales', employee_id=641439160, ssn=320901419)
# Employment(employer='Deckow, Hudson and Koch', department='Research and Development', employee_id=458944543, ssn=320979147)
# Employment(employer='Paucek, Sipes and Pagac', department='Training', employee_id=523969729, ssn=323286705)
# Employment(employer='Will Inc', department='Product Management', employee_id=700007392, ssn=323338689)
# Employment(employer='Kovacek, Effertz and Rodriguez', department='Accounting', employee_id=543498156, ssn=324395230)
# Employment(employer='Bergnaum and Sons', department='Engineering', employee_id=234135932, ssn=324738895)
# Employment(employer='Rosenbaum-Bogisich', department='Human Resources', employee_id=618722569, ssn=324756098)
# Employment(employer='Heathcote, Gerhold and Kuhlman', department='Services', employee_id=607003804, ssn=326649957)
# Employment(employer='Boyle-Gleichner', department='Legal', employee_id=459409049, ssn=327520546)
# Employment(employer='Lowe, Tromp and Orn', department='Product Management', employee_id=955467981, ssn=327887554)
# Employment(employer='Schimmel and Sons', department='Sales', employee_id=756111866, ssn=330993055)
# Employment(employer='Hoppe-Dickens', department='Sales', employee_id=724063548, ssn=332836591)
# Employment(employer='Nienow Inc', department='Product Management', employee_id=773574938, ssn=333525097)
# Employment(employer='Beahan-Little', department='Sales', employee_id=701386102, ssn=333955025)
# Employment(employer='Berge-Schimmel', department='Business Development', employee_id=277571787, ssn=335351520)
# Employment(employer='Thiel Group', department='Support', employee_id=276837894, ssn=336482579)
# Employment(employer='Kessler-Simonis', department='Research and Development', employee_id=156371973, ssn=339278046)
# Employment(employer='Homenick, Mitchell and Mills', department='Engineering', employee_id=442643547, ssn=339712687)
# Employment(employer='Block, Doyle and Waelchi', department='Product Management', employee_id=659497375, ssn=341106840)
# Employment(employer='Lind, Auer and Waelchi', department='Research and Development', employee_id=594510364, ssn=342059057)
# Employment(employer='Pouros-Kohler', department='Legal', employee_id=760199175, ssn=342550538)
# Employment(employer='Okuneva and Sons', department='Sales', employee_id=974377037, ssn=342909333)
# Employment(employer='Parker, Wehner and Oberbrunner', department='Support', employee_id=120866614, ssn=343208407)
# Employment(employer='King Inc', department='Support', employee_id=70669669, ssn=343813179)
# Employment(employer='Jaskolski, Batz and Rempel', department='Marketing', employee_id=829497860, ssn=345742160)
# Employment(employer='Bahringer, Pacocha and Ritchie', department='Engineering', employee_id=927514376, ssn=347093254)
# Employment(employer='Prosacco-Herzog', department='Sales', employee_id=386538811, ssn=347648652)
# Employment(employer='Sanford-Rohan', department='Engineering', employee_id=892980268, ssn=348734312)
# Employment(employer='Ledner and Sons', department='Engineering', employee_id=887250304, ssn=348743224)
# Employment(employer='Labadie, Lockman and Kozey', department='Support', employee_id=732905417, ssn=349538864)
# Employment(employer='Lynch, Schowalter and Ferry', department='Support', employee_id=240076267, ssn=349677502)
# Employment(employer='Mann Inc', department='Services', employee_id=91183256, ssn=350209593)
# Employment(employer='West and Sons', department='Product Management', employee_id=77836538, ssn=350804646)
# Employment(employer='Goodwin, Luettgen and Harvey', department='Human Resources', employee_id=914775280, ssn=351732802)
# Employment(employer='Jacobson and Sons', department='Legal', employee_id=527624074, ssn=355219711)
# Employment(employer='Wilderman Inc', department='Legal', employee_id=72741705, ssn=355529767)
# Employment(employer='Kiehn Inc', department='Product Management', employee_id=256512671, ssn=355967706)
# Employment(employer='Mohr-Padberg', department='Marketing', employee_id=94337320, ssn=356399199)
# Employment(employer='Bergnaum, Funk and Huel', department='Legal', employee_id=95871313, ssn=357376094)
# Employment(employer='Kuhn LLC', department='Research and Development', employee_id=127386844, ssn=358847049)
# Employment(employer='Kutch, Walker and Christiansen', department='Support', employee_id=426530979, ssn=360696230)
# Employment(employer='Ledner, Weimann and Bernhard', department='Accounting', employee_id=796369486, ssn=361061530)
# Employment(employer="Altenwerth, Jacobson and O'Keefe", department='Training', employee_id=768687759, ssn=361427068)
# Employment(employer="D'Amore Inc", department='Sales', employee_id=971951142, ssn=361494597)
# Employment(employer="D'Amore LLC", department='Services', employee_id=613591939, ssn=361835004)
# Employment(employer='Kautzer and Sons', department='Research and Development', employee_id=560050837, ssn=362098563)
# Employment(employer='Mertz Inc', department='Services', employee_id=266200024, ssn=362127902)
# Employment(employer='Veum and Sons', department='Engineering', employee_id=782982514, ssn=364250166)
# Employment(employer='Schuppe-Flatley', department='Business Development', employee_id=326644811, ssn=364652174)
# Employment(employer="Brakus-D'Amore", department='Human Resources', employee_id=670234629, ssn=366610607)
# Employment(employer='Dickinson-Wiegand', department='Accounting', employee_id=439661529, ssn=367228998)
# Employment(employer="O'Kon, Eichmann and Block", department='Research and Development', employee_id=226937844, ssn=367624426)
# Employment(employer='Stark-White', department='Support', employee_id=619710930, ssn=370016977)
# Employment(employer='Hackett and Sons', department='Product Management', employee_id=992141062, ssn=370245876)
# Employment(employer='Padberg, Walter and Barton', department='Product Management', employee_id=221713376, ssn=370726509)
# Employment(employer='Adams-Ledner', department='Services', employee_id=405208891, ssn=371285892)
# Employment(employer='Gislason and Sons', department='Legal', employee_id=924254610, ssn=371440582)
# Employment(employer='Gleichner Group', department='Research and Development', employee_id=527507546, ssn=371623727)
# Employment(employer='Stiedemann LLC', department='Services', employee_id=306730450, ssn=371889249)
# Employment(employer='Fahey, Fahey and Gleason', department='Product Management', employee_id=28347934, ssn=372447487)
# Employment(employer='Tremblay LLC', department='Accounting', employee_id=923893782, ssn=372627057)
# Employment(employer='Brekke-Rippin', department='Services', employee_id=16025412, ssn=373672734)
# Employment(employer='Murazik and Sons', department='Services', employee_id=912150669, ssn=374470262)
# Employment(employer='Reynolds, Stroman and Pagac', department='Marketing', employee_id=810595624, ssn=378080805)
# Employment(employer='Baumbach Group', department='Human Resources', employee_id=937798424, ssn=378602472)
# Employment(employer='Reynolds-Mosciski', department='Support', employee_id=967261958, ssn=378660449)
# Employment(employer='Carter, Padberg and Stiedemann', department='Support', employee_id=447764644, ssn=378790193)
# Employment(employer='Franecki-Wisozk', department='Marketing', employee_id=404637900, ssn=378886805)
# Employment(employer='Dach-Torp', department='Product Management', employee_id=591247068, ssn=379078748)
# Employment(employer='McDermott Inc', department='Research and Development', employee_id=907715733, ssn=380339730)
# Employment(employer='Larkin, Bode and Moen', department='Services', employee_id=721163753, ssn=380353854)
# Employment(employer='Kuphal-Dicki', department='Product Management', employee_id=470586610, ssn=383184058)
# Employment(employer='Metz, Reynolds and Jerde', department='Sales', employee_id=280030219, ssn=384306793)
# Employment(employer='Erdman-Davis', department='Sales', employee_id=180647578, ssn=384942772)
# Employment(employer='Monahan, Weber and Reynolds', department='Sales', employee_id=593207276, ssn=385301777)
# Employment(employer='Hamill Group', department='Business Development', employee_id=348338291, ssn=385347828)
# Employment(employer='Upton, Boehm and Kemmer', department='Product Management', employee_id=828364397, ssn=385980431)
# Employment(employer='Turcotte, Shields and Hand', department='Marketing', employee_id=967302690, ssn=386157960)
# Employment(employer='Runolfsson, Grimes and Batz', department='Human Resources', employee_id=218425795, ssn=386344088)
# Employment(employer='Jakubowski, Padberg and Mohr', department='Training', employee_id=466921210, ssn=386689884)
# Employment(employer='Durgan LLC', department='Business Development', employee_id=758054834, ssn=386973523)
# Employment(employer='Welch-Hamill', department='Engineering', employee_id=226182445, ssn=389310910)
# Employment(employer='Jacobi, Durgan and Moen', department='Human Resources', employee_id=474459434, ssn=389511424)
# Employment(employer='Little, Johns and Kuphal', department='Human Resources', employee_id=585489644, ssn=389848254)
# Employment(employer='Bechtelar-McCullough', department='Sales', employee_id=11786654, ssn=390743062)
# Employment(employer='Friesen, Goyette and Satterfield', department='Research and Development', employee_id=161384768, ssn=391149280)
# Employment(employer='Rath-Hessel', department='Human Resources', employee_id=868277225, ssn=391474578)
# Employment(employer='Ritchie-Cassin', department='Training', employee_id=672306452, ssn=391732830)
# Employment(employer='Klocko-Frami', department='Sales', employee_id=350739294, ssn=393226585)
# Employment(employer='Bogan, Stamm and Donnelly', department='Legal', employee_id=362545788, ssn=396511559)
# Employment(employer='Miller-Harvey', department='Human Resources', employee_id=3867844, ssn=397165372)
# Employment(employer='Okuneva-Lehner', department='Sales', employee_id=464308357, ssn=397298349)
# Employment(employer='Jones Inc', department='Sales', employee_id=482299282, ssn=397878282)
# Employment(employer='Klocko, Stiedemann and Collier', department='Support', employee_id=937234405, ssn=399312815)
# Employment(employer='Mills, Barton and Lakin', department='Product Management', employee_id=741474493, ssn=399638810)
# Employment(employer='Kihn Group', department='Legal', employee_id=571893655, ssn=399816133)
# Employment(employer='Crist Inc', department='Engineering', employee_id=98581339, ssn=400218654)
# Employment(employer='McCullough-Durgan', department='Research and Development', employee_id=9482594, ssn=400776007)
# Employment(employer='Rau, Frami and Friesen', department='Product Management', employee_id=982176332, ssn=402613479)
# Employment(employer='MacGyver-Kihn', department='Marketing', employee_id=703011031, ssn=402652055)
# Employment(employer='Stanton Inc', department='Human Resources', employee_id=656066334, ssn=402885570)
# Employment(employer='Kirlin, Welch and Braun', department='Accounting', employee_id=810591716, ssn=403651535)
# Employment(employer='Thiel, Ankunding and Medhurst', department='Training', employee_id=437580921, ssn=404574023)
# Employment(employer='Keebler Group', department='Product Management', employee_id=576192942, ssn=405251422)
# Employment(employer='Wilkinson, Lind and Ziemann', department='Research and Development', employee_id=475274344, ssn=406155123)
# Employment(employer='Senger-Breitenberg', department='Marketing', employee_id=863769423, ssn=406244867)
# Employment(employer='Bashirian Group', department='Legal', employee_id=674961160, ssn=406490634)
# Employment(employer="Kozey, O'Reilly and Nicolas", department='Accounting', employee_id=14265007, ssn=407300910)
# Employment(employer='Langosh Inc', department='Human Resources', employee_id=729016938, ssn=407807367)
# Employment(employer='McClure, Erdman and Schumm', department='Product Management', employee_id=481683026, ssn=407996159)
# Employment(employer="O'Conner, Ratke and Cormier", department='Product Management', employee_id=677795930, ssn=408837943)
# Employment(employer='Gibson LLC', department='Training', employee_id=758998272, ssn=408983291)
# Employment(employer='Wilkinson Group', department='Accounting', employee_id=248239174, ssn=409582034)
# Employment(employer='Yost and Sons', department='Sales', employee_id=77718175, ssn=409908946)
# Employment(employer='Murazik LLC', department='Engineering', employee_id=766254682, ssn=410384237)
# Employment(employer='West-Auer', department='Business Development', employee_id=302738860, ssn=410765092)
# Employment(employer='Schmidt, Torp and Schultz', department='Training', employee_id=716519002, ssn=411214276)
# Employment(employer='Senger, Schuppe and Mueller', department='Marketing', employee_id=270379629, ssn=411434217)
# Employment(employer='Gleason LLC', department='Product Management', employee_id=79043060, ssn=411794655)
# Employment(employer="O'Connell-Stiedemann", department='Engineering', employee_id=44499468, ssn=412509133)
# Employment(employer='VonRueden, Zboncak and Erdman', department='Legal', employee_id=624306075, ssn=412590452)
# Employment(employer='Dooley, Wehner and Mohr', department='Legal', employee_id=570199872, ssn=412598022)
# Employment(employer='Hilll, Hickle and Koelpin', department='Services', employee_id=513888263, ssn=412798951)
# Employment(employer='Treutel, Jerde and Bayer', department='Training', employee_id=938500147, ssn=413143928)
# Employment(employer='Marks, Wilkinson and Kub', department='Services', employee_id=871098264, ssn=413565613)
# Employment(employer="Rempel-O'Connell", department='Sales', employee_id=569638561, ssn=415420898)
# Employment(employer='Streich, Batz and Carter', department='Sales', employee_id=540581511, ssn=415742251)
# Employment(employer='Metz-Wolf', department='Business Development', employee_id=728305549, ssn=416377763)
# Employment(employer='Hartmann-Torphy', department='Training', employee_id=937537715, ssn=416383607)
# Employment(employer='Ryan-Schulist', department='Business Development', employee_id=382848171, ssn=416806367)
# Employment(employer='Kertzmann Inc', department='Services', employee_id=20973225, ssn=416870469)
# Employment(employer='Heidenreich-Schmitt', department='Training', employee_id=914798424, ssn=418721888)
# Employment(employer="O'Keefe Group", department='Product Management', employee_id=703957124, ssn=418996659)
# Employment(employer='Schroeder LLC', department='Engineering', employee_id=657085477, ssn=420467789)
# Employment(employer='Osinski, Tillman and Rowe', department='Business Development', employee_id=405829646, ssn=420523813)
# Employment(employer='Wyman and Sons', department='Support', employee_id=274093007, ssn=421012511)
# Employment(employer='Kunde Group', department='Engineering', employee_id=804320276, ssn=421139794)
# Employment(employer='Orn, Willms and Torp', department='Support', employee_id=252477756, ssn=421203448)
# Employment(employer='Sanford, Becker and Nienow', department='Product Management', employee_id=239748703, ssn=421887316)
# Employment(employer='Halvorson, Hammes and Jerde', department='Training', employee_id=946937073, ssn=422674000)
# Employment(employer='Cole-Reinger', department='Accounting', employee_id=641589266, ssn=423621820)
# Employment(employer='Cruickshank-Collins', department='Support', employee_id=196964711, ssn=423884721)
# ...
# Employment(employer='Boyer, Mueller and Boyer', department='Engineering', employee_id=199999045, ssn=773537438)
# Employment(employer='Hickle-Herman', department='Accounting', employee_id=915888473, ssn=773821734)
# Employment(employer='Wisozk, Daniel and Becker', department='Research and Development', employee_id=46398608, ssn=774085376)
# Employment(employer='Gottlieb Inc', department='Research and Development', employee_id=999505516, ssn=775099949)
# Employment(employer='Hartmann-Schaden', department='Accounting', employee_id=382823318, ssn=777051491)
# Employment(employer='Will, Crist and Jakubowski', department='Marketing', employee_id=224425487, ssn=777682978)
# Employment(employer='Mohr-Tromp', department='Services', employee_id=223680088, ssn=777944586)
# Employment(employer='Anderson, Dickinson and Toy', department='Marketing', employee_id=468501105, ssn=778748262)
# Employment(employer='Emmerich, Auer and Howe', department='Accounting', employee_id=411699228, ssn=779591449)
# Employment(employer='Kihn, Veum and Rippin', department='Product Management', employee_id=71206591, ssn=780698282)
# Employment(employer='Gulgowski, Carroll and Sauer', department='Training', employee_id=276046833, ssn=781882076)
# Employment(employer='Little-Veum', department='Engineering', employee_id=708373631, ssn=782469660)
# Employment(employer='Murray, Boyle and Bashirian', department='Sales', employee_id=835303621, ssn=782606848)
# Employment(employer='Funk, Boyer and Littel', department='Legal', employee_id=952744801, ssn=783229258)
# Employment(employer='Fisher-Collier', department='Marketing', employee_id=583884885, ssn=784880730)
# Employment(employer='Mohr-Schinner', department='Legal', employee_id=814856450, ssn=785145978)
# Employment(employer='Cruickshank-Bechtelar', department='Research and Development', employee_id=98549621, ssn=786563561)
# Employment(employer='Pagac, Howell and Sipes', department='Human Resources', employee_id=107064521, ssn=786636223)
# Employment(employer='Funk Inc', department='Accounting', employee_id=603943212, ssn=787059008)
# Employment(employer='Armstrong-VonRueden', department='Support', employee_id=645533135, ssn=787095697)
# Employment(employer='Collins, Blick and Rippin', department='Marketing', employee_id=91706408, ssn=787107877)
# Employment(employer='Hermann, Hintz and Turner', department='Marketing', employee_id=909925003, ssn=788152625)
# Employment(employer='Hayes-Rutherford', department='Product Management', employee_id=947076951, ssn=789701821)
# Employment(employer='Frami-Cruickshank', department='Sales', employee_id=563838122, ssn=790041283)
# Employment(employer='Rempel-Weissnat', department='Business Development', employee_id=20335898, ssn=792718046)
# Employment(employer='Schoen-Reinger', department='Legal', employee_id=769226609, ssn=794243802)
# Employment(employer='Rau-Schmidt', department='Legal', employee_id=398891615, ssn=795566486)
# Employment(employer='Brakus, Towne and Connelly', department='Support', employee_id=982184361, ssn=795775263)
# Employment(employer='Jerde-Nitzsche', department='Engineering', employee_id=765567281, ssn=797052289)
# Employment(employer='Reinger Group', department='Marketing', employee_id=439515382, ssn=797259814)
# Employment(employer='Walker-Lemke', department='Research and Development', employee_id=520032929, ssn=797652382)
# Employment(employer='Becker, Ferry and Kulas', department='Human Resources', employee_id=830034047, ssn=797877992)
# Employment(employer='Hartmann Group', department='Services', employee_id=928673485, ssn=798341082)
# Employment(employer='Jacobi, Reilly and Walsh', department='Legal', employee_id=384551321, ssn=798655644)
# Employment(employer='Schuppe LLC', department='Training', employee_id=95823092, ssn=800069721)
# Employment(employer='Schuppe-King', department='Product Management', employee_id=624397047, ssn=801088313)
# Employment(employer='Lesch LLC', department='Support', employee_id=669572760, ssn=801926460)
# Employment(employer='Glover-Corwin', department='Marketing', employee_id=94622650, ssn=801992773)
# Employment(employer='Nitzsche, Kilback and Abernathy', department='Services', employee_id=792655397, ssn=804460617)
# Employment(employer="Kihn, D'Amore and Volkman", department='Business Development', employee_id=659491878, ssn=807135922)
# Employment(employer='King Inc', department='Marketing', employee_id=284538440, ssn=807246202)
# Employment(employer='Dooley, Bogisich and Eichmann', department='Support', employee_id=210846325, ssn=807256136)
# Employment(employer='Schneider-Effertz', department='Product Management', employee_id=534269406, ssn=807358936)
# Employment(employer='Cormier-Quigley', department='Sales', employee_id=454824943, ssn=807508539)
# Employment(employer='Mayert, Mueller and Stamm', department='Sales', employee_id=235127432, ssn=807605615)
# Employment(employer='Mosciski-Marquardt', department='Product Management', employee_id=372182084, ssn=808558658)
# Employment(employer='Cronin, Reilly and Wilderman', department='Legal', employee_id=38800554, ssn=808802542)
# Employment(employer='Howell LLC', department='Marketing', employee_id=843613670, ssn=811652750)
# Employment(employer='Nienow, Gaylord and Hartmann', department='Services', employee_id=412452184, ssn=812119403)
# Employment(employer='Rolfson and Sons', department='Engineering', employee_id=438040427, ssn=813424142)
# Employment(employer='Schultz LLC', department='Product Management', employee_id=582106819, ssn=813475215)
# Employment(employer='Dach, Donnelly and Walter', department='Support', employee_id=839676607, ssn=815830300)
# Employment(employer='Hilll Inc', department='Product Management', employee_id=133299629, ssn=816313858)
# Employment(employer='Rice-Upton', department='Support', employee_id=295433714, ssn=816474782)
# Employment(employer='Waelchi-MacGyver', department='Training', employee_id=173761486, ssn=816902049)
# Employment(employer='Russel, Gottlieb and Satterfield', department='Support', employee_id=534636208, ssn=817041950)
# Employment(employer='Kilback Group', department='Training', employee_id=438990, ssn=817257437)
# Employment(employer='Rath-Ryan', department='Marketing', employee_id=311949756, ssn=817808930)
# Employment(employer='Kovacek, Effertz and Kihn', department='Business Development', employee_id=490909555, ssn=818610770)
# Employment(employer='Wunsch-Walsh', department='Marketing', employee_id=588512115, ssn=819525886)
# Employment(employer='Reichel and Sons', department='Human Resources', employee_id=151566614, ssn=819641414)
# Employment(employer='Watsica-Ziemann', department='Research and Development', employee_id=877414041, ssn=820961105)
# Employment(employer='Crona, Bogan and Beatty', department='Business Development', employee_id=3394171, ssn=822059037)
# Employment(employer='Halvorson, Hirthe and Quitzon', department='Marketing', employee_id=678224406, ssn=822304861)
# Employment(employer='Kemmer, Rolfson and Marquardt', department='Sales', employee_id=607054525, ssn=823270762)
# Employment(employer='Sipes-Zulauf', department='Training', employee_id=971660502, ssn=823755753)
# Employment(employer='Marquardt Group', department='Human Resources', employee_id=301833919, ssn=824894169)
# Employment(employer='Leffler-Rodriguez', department='Accounting', employee_id=532045990, ssn=826978029)
# Employment(employer='Marquardt, Wehner and Heathcote', department='Legal', employee_id=8910869, ssn=827624599)
# Employment(employer='Mayer Inc', department='Legal', employee_id=686332753, ssn=830231573)
# Employment(employer='Bashirian, Beer and Bailey', department='Engineering', employee_id=383479804, ssn=831443286)
# Employment(employer='Kozey-Jast', department='Legal', employee_id=563616909, ssn=833011428)
# Employment(employer='Johnson Group', department='Sales', employee_id=673262618, ssn=835543785)
# Employment(employer='Smitham, Rutherford and Jerde', department='Research and Development', employee_id=905771245, ssn=836401837)
# Employment(employer='Moore-Funk', department='Research and Development', employee_id=49339587, ssn=836993309)
# Employment(employer='Bauch LLC', department='Services', employee_id=876743338, ssn=837765619)
# Employment(employer='Hermann and Sons', department='Training', employee_id=608507863, ssn=838691351)
# Employment(employer='Lowe Inc', department='Research and Development', employee_id=164102117, ssn=840417929)
# Employment(employer='Walsh and Sons', department='Legal', employee_id=434857392, ssn=841648517)
# Employment(employer='Langworth-Friesen', department='Support', employee_id=381404046, ssn=842907557)
# Employment(employer='Rohan-Nicolas', department='Support', employee_id=753856459, ssn=844154668)
# Employment(employer='Beer-Kihn', department='Support', employee_id=515485483, ssn=844507305)
# Employment(employer='Lesch LLC', department='Marketing', employee_id=653499297, ssn=846071407)
# Employment(employer='Boehm, Goldner and Wisozk', department='Sales', employee_id=299226065, ssn=846099851)
# Employment(employer='Rolfson and Sons', department='Product Management', employee_id=598318028, ssn=846599961)
# Employment(employer='Schmidt, Schaden and Pfeffer', department='Training', employee_id=397754939, ssn=847344817)
# Employment(employer='Dibbert LLC', department='Support', employee_id=37617020, ssn=847617656)
# Employment(employer='Jerde-Batz', department='Product Management', employee_id=140272415, ssn=848583386)
# Employment(employer='Macejkovic and Sons', department='Support', employee_id=520638791, ssn=848742886)
# Employment(employer='Robel, Luettgen and Moore', department='Legal', employee_id=857186677, ssn=848768808)
# Employment(employer='Yundt, Wehner and Brown', department='Legal', employee_id=550777439, ssn=849311551)
# Employment(employer='Blanda, Marks and Metz', department='Training', employee_id=810398914, ssn=849646624)
# Employment(employer='Flatley-Huel', department='Sales', employee_id=590940865, ssn=849982973)
# Employment(employer='Collier, Botsford and Ruecker', department='Engineering', employee_id=185849664, ssn=851942162)
# Employment(employer='Conn Group', department='Training', employee_id=97105416, ssn=852157707)
# Employment(employer='Moen Inc', department='Sales', employee_id=981092646, ssn=853118953)
# Employment(employer='Barrows Inc', department='Product Management', employee_id=63741043, ssn=853473648)
# Employment(employer='Thiel-Murray', department='Support', employee_id=962035605, ssn=854687635)
# Employment(employer='Blanda-Ferry', department='Product Management', employee_id=749087432, ssn=854712983)
# Employment(employer='Dietrich Inc', department='Business Development', employee_id=791998214, ssn=854795334)
# Employment(employer='Baumbach, Jenkins and Russel', department='Product Management', employee_id=394882068, ssn=856183980)
# Employment(employer='Lakin and Sons', department='Accounting', employee_id=414723930, ssn=856279112)
# Employment(employer='Kassulke, Ritchie and Braun', department='Accounting', employee_id=61382466, ssn=856674080)
# Employment(employer='Swaniawski Group', department='Services', employee_id=442276418, ssn=857375902)
# Employment(employer='Stark-Pouros', department='Training', employee_id=537456817, ssn=858037735)
# Employment(employer='Goodwin Inc', department='Marketing', employee_id=732880950, ssn=858279190)
# Employment(employer='Williamson-Lemke', department='Accounting', employee_id=809563373, ssn=860670256)
# Employment(employer='Reinger Inc', department='Engineering', employee_id=802005731, ssn=860892570)
# Employment(employer='Stokes Inc', department='Training', employee_id=126635955, ssn=861506716)
# Employment(employer='Dicki, Green and White', department='Services', employee_id=871017676, ssn=862200653)
# Employment(employer='Thiel, Parker and Hilpert', department='Marketing', employee_id=202324966, ssn=864229364)
# Employment(employer='Heidenreich, Stehr and Huel', department='Sales', employee_id=891713880, ssn=864917489)
# Employment(employer='Bartoletti Inc', department='Support', employee_id=777239839, ssn=866181440)
# Employment(employer='Douglas-Breitenberg', department='Business Development', employee_id=636285198, ssn=866530625)
# Employment(employer='Nitzsche-Walker', department='Engineering', employee_id=505681388, ssn=867116007)
# Employment(employer='Crist, Leuschke and Grimes', department='Legal', employee_id=98398802, ssn=867136844)
# Employment(employer='Emard Inc', department='Business Development', employee_id=492589434, ssn=867882360)
# Employment(employer='Abshire Inc', department='Research and Development', employee_id=558987515, ssn=868321805)
# Employment(employer='Thompson, Parker and Moen', department='Research and Development', employee_id=461484106, ssn=870126609)
# Employment(employer='Morissette, Rowe and Muller', department='Engineering', employee_id=739912953, ssn=870931121)
# Employment(employer='Lueilwitz, Stokes and Kassulke', department='Marketing', employee_id=161937114, ssn=871993191)
# Employment(employer='Glover, Jacobs and Heidenreich', department='Sales', employee_id=721577952, ssn=872189267)
# Employment(employer='Cummings-Mertz', department='Sales', employee_id=782291834, ssn=872491288)
# Employment(employer='Wilderman-Grimes', department='Engineering', employee_id=396055619, ssn=873364733)
# Employment(employer='Schultz-Medhurst', department='Support', employee_id=566050344, ssn=875189454)
# Employment(employer='Wunsch-Gleason', department='Services', employee_id=283015726, ssn=875750495)
# Employment(employer='Witting, Schuster and Barton', department='Research and Development', employee_id=544161357, ssn=878128265)
# Employment(employer='Harber-Legros', department='Training', employee_id=599280036, ssn=880224449)
# Employment(employer='Daugherty, Gislason and Kreiger', department='Training', employee_id=255973403, ssn=881195974)
# Employment(employer="O'Connell, Raynor and Veum", department='Sales', employee_id=160843654, ssn=881887308)
# Employment(employer='Schumm Inc', department='Services', employee_id=188360445, ssn=881957180)
# Employment(employer='Zulauf Inc', department='Accounting', employee_id=467067366, ssn=882495290)
# Employment(employer='Stanton, Price and Wehner', department='Services', employee_id=165769119, ssn=884611852)
# Employment(employer='Ziemann, Denesik and Casper', department='Research and Development', employee_id=716097002, ssn=887417878)
# Employment(employer='Terry and Sons', department='Research and Development', employee_id=69390159, ssn=887839002)
# Employment(employer='Herzog, Stehr and Quitzon', department='Engineering', employee_id=385385705, ssn=888507008)
# Employment(employer='Collier, Hilll and Hagenes', department='Training', employee_id=156651242, ssn=888537684)
# Employment(employer='Reynolds, Nicolas and Morar', department='Engineering', employee_id=483998718, ssn=888824928)
# Employment(employer='Heller, Kihn and Bartoletti', department='Research and Development', employee_id=569393666, ssn=890289962)
# Employment(employer='Christiansen LLC', department='Sales', employee_id=661175841, ssn=893120901)
# Employment(employer='Orn Inc', department='Human Resources', employee_id=384356300, ssn=893177318)
# Employment(employer='Flatley, Senger and Bernier', department='Services', employee_id=722633200, ssn=894810628)
# Employment(employer='Hilll, Kunze and Beer', department='Human Resources', employee_id=904168298, ssn=895261658)
# Employment(employer='Franecki LLC', department='Services', employee_id=637802530, ssn=895265515)
# Employment(employer='Reilly-Jakubowski', department='Marketing', employee_id=776363112, ssn=897767070)
# Employment(employer='Bins-Gerhold', department='Sales', employee_id=899965641, ssn=898033165)
# Employment(employer='Olson-Johnson', department='Support', employee_id=367761827, ssn=898868860)
# Employment(employer='Cronin LLC', department='Services', employee_id=838730953, ssn=899091766)
# Employment(employer='Little-Hansen', department='Business Development', employee_id=458154226, ssn=899397179)
# Employment(employer="Christiansen, Ondricka and O'Connell", department='Marketing', employee_id=327034344, ssn=899397378)
# Employment(employer='Bednar LLC', department='Support', employee_id=166342889, ssn=899476116)

# %%
for data in updated_status_iter:
    print(data)
# Out:
# Update_Status(ssn=100539824, last_updated=datetime.datetime(2017, 10, 7, 0, 14, 42), created=datetime.datetime(2016, 1, 24, 21, 19, 30))
# Update_Status(ssn=101714702, last_updated=datetime.datetime(2017, 1, 23, 11, 23, 17), created=datetime.datetime(2016, 1, 27, 4, 32, 57))
# Update_Status(ssn=101840356, last_updated=datetime.datetime(2017, 10, 4, 11, 21, 30), created=datetime.datetime(2016, 9, 21, 23, 4, 7))
# Update_Status(ssn=104220928, last_updated=datetime.datetime(2017, 3, 28, 12, 38, 29), created=datetime.datetime(2016, 4, 15, 11, 37, 17))
# Update_Status(ssn=104847144, last_updated=datetime.datetime(2018, 2, 19, 1, 34, 33), created=datetime.datetime(2016, 3, 15, 14, 7, 57))
# Update_Status(ssn=105275541, last_updated=datetime.datetime(2017, 7, 24, 8, 58, 52), created=datetime.datetime(2016, 7, 23, 17, 58, 35))
# Update_Status(ssn=105857486, last_updated=datetime.datetime(2018, 2, 14, 11, 32, 39), created=datetime.datetime(2016, 12, 15, 5, 46, 43))
# Update_Status(ssn=105915022, last_updated=datetime.datetime(2018, 3, 24, 14, 29, 33), created=datetime.datetime(2016, 3, 24, 3, 43, 3))
# Update_Status(ssn=105917777, last_updated=datetime.datetime(2017, 5, 11, 1, 48, 32), created=datetime.datetime(2016, 5, 31, 0, 38, 13))
# Update_Status(ssn=106351938, last_updated=datetime.datetime(2017, 10, 21, 1, 7, 28), created=datetime.datetime(2016, 9, 8, 4, 2, 12))
# Update_Status(ssn=106363293, last_updated=datetime.datetime(2017, 3, 18, 18, 24, 17), created=datetime.datetime(2016, 5, 16, 21, 21, 36))
# Update_Status(ssn=110843641, last_updated=datetime.datetime(2017, 9, 4, 19, 2, 3), created=datetime.datetime(2016, 9, 12, 22, 50, 5))
# Update_Status(ssn=111351034, last_updated=datetime.datetime(2017, 3, 18, 14, 51, 4), created=datetime.datetime(2016, 8, 21, 7, 36, 17))
# Update_Status(ssn=114066912, last_updated=datetime.datetime(2018, 2, 5, 20, 48, 34), created=datetime.datetime(2016, 7, 15, 21, 58, 3))
# Update_Status(ssn=114660984, last_updated=datetime.datetime(2017, 6, 16, 17, 41, 33), created=datetime.datetime(2016, 5, 28, 20, 31, 25))
# Update_Status(ssn=114748701, last_updated=datetime.datetime(2017, 10, 30, 23, 54, 38), created=datetime.datetime(2016, 6, 4, 5, 18, 3))
# Update_Status(ssn=116107235, last_updated=datetime.datetime(2017, 3, 10, 0, 31, 43), created=datetime.datetime(2016, 10, 17, 2, 11, 26))
# Update_Status(ssn=116774915, last_updated=datetime.datetime(2017, 11, 21, 14, 25, 11), created=datetime.datetime(2016, 7, 3, 3, 55, 39))
# Update_Status(ssn=117396617, last_updated=datetime.datetime(2017, 9, 1, 11, 58, 21), created=datetime.datetime(2016, 12, 1, 10, 11, 17))
# Update_Status(ssn=117779748, last_updated=datetime.datetime(2017, 2, 18, 23, 9, 25), created=datetime.datetime(2016, 2, 2, 15, 41, 42))
# Update_Status(ssn=117786202, last_updated=datetime.datetime(2017, 11, 2, 2, 26, 10), created=datetime.datetime(2016, 4, 18, 0, 25, 1))
# Update_Status(ssn=118210357, last_updated=datetime.datetime(2017, 12, 13, 9, 36, 48), created=datetime.datetime(2016, 10, 24, 3, 40, 22))
# Update_Status(ssn=118957100, last_updated=datetime.datetime(2017, 4, 25, 7, 54, 46), created=datetime.datetime(2016, 1, 29, 12, 5, 28))
# Update_Status(ssn=119078817, last_updated=datetime.datetime(2017, 12, 24, 15, 31, 5), created=datetime.datetime(2016, 12, 6, 14, 16, 59))
# Update_Status(ssn=120335535, last_updated=datetime.datetime(2017, 11, 11, 8, 53, 11), created=datetime.datetime(2016, 7, 10, 20, 49))
# Update_Status(ssn=120984054, last_updated=datetime.datetime(2017, 12, 1, 17, 30, 55), created=datetime.datetime(2016, 7, 23, 15, 52, 53))
# Update_Status(ssn=121983948, last_updated=datetime.datetime(2017, 8, 23, 16, 0, 57), created=datetime.datetime(2016, 6, 26, 23, 46, 48))
# Update_Status(ssn=123053229, last_updated=datetime.datetime(2017, 8, 16, 12, 8, 6), created=datetime.datetime(2016, 10, 23, 13, 32, 13))
# Update_Status(ssn=123622832, last_updated=datetime.datetime(2017, 9, 11, 0, 2, 44), created=datetime.datetime(2016, 10, 22, 16, 14, 5))
# Update_Status(ssn=123883381, last_updated=datetime.datetime(2017, 2, 21, 16, 37, 38), created=datetime.datetime(2016, 1, 30, 23, 42, 36))
# Update_Status(ssn=125079434, last_updated=datetime.datetime(2017, 2, 7, 14, 36, 31), created=datetime.datetime(2016, 7, 8, 17, 46, 23))
# Update_Status(ssn=127492473, last_updated=datetime.datetime(2017, 8, 31, 10, 3, 3), created=datetime.datetime(2016, 8, 29, 18, 48, 40))
# Update_Status(ssn=127528001, last_updated=datetime.datetime(2017, 1, 12, 9, 42, 31), created=datetime.datetime(2016, 10, 9, 1, 14, 36))
# Update_Status(ssn=127684232, last_updated=datetime.datetime(2017, 3, 20, 6, 5, 42), created=datetime.datetime(2016, 8, 19, 16, 32, 21))
# Update_Status(ssn=127933548, last_updated=datetime.datetime(2017, 9, 10, 6, 24, 19), created=datetime.datetime(2016, 7, 23, 1, 30, 3))
# Update_Status(ssn=128424599, last_updated=datetime.datetime(2017, 1, 29, 20, 31, 15), created=datetime.datetime(2016, 7, 13, 9, 52, 36))
# Update_Status(ssn=128530369, last_updated=datetime.datetime(2017, 8, 10, 21, 18), created=datetime.datetime(2016, 12, 19, 21, 37, 6))
# Update_Status(ssn=128537952, last_updated=datetime.datetime(2017, 8, 31, 16, 42, 23), created=datetime.datetime(2016, 7, 29, 3, 46, 26))
# Update_Status(ssn=128566040, last_updated=datetime.datetime(2017, 8, 13, 2, 47, 15), created=datetime.datetime(2016, 3, 21, 8, 59, 56))
# Update_Status(ssn=128604388, last_updated=datetime.datetime(2017, 1, 3, 20, 33, 45), created=datetime.datetime(2016, 3, 18, 11, 18, 14))
# Update_Status(ssn=129670291, last_updated=datetime.datetime(2017, 2, 11, 10, 18, 21), created=datetime.datetime(2016, 12, 12, 5, 1, 34))
# Update_Status(ssn=131814310, last_updated=datetime.datetime(2018, 3, 21, 12, 2, 31), created=datetime.datetime(2016, 2, 3, 23, 26, 27))
# Update_Status(ssn=132263507, last_updated=datetime.datetime(2017, 1, 19, 7, 33, 37), created=datetime.datetime(2016, 5, 20, 1, 41, 54))
# Update_Status(ssn=134050120, last_updated=datetime.datetime(2017, 1, 29, 11, 53, 22), created=datetime.datetime(2016, 8, 3, 4, 54, 40))
# Update_Status(ssn=135869625, last_updated=datetime.datetime(2017, 12, 22, 4, 4, 28), created=datetime.datetime(2016, 2, 28, 23, 53, 17))
# Update_Status(ssn=137131889, last_updated=datetime.datetime(2017, 12, 24, 9, 44, 10), created=datetime.datetime(2016, 3, 1, 19, 9, 29))
# Update_Status(ssn=138654579, last_updated=datetime.datetime(2017, 4, 17, 16, 30, 2), created=datetime.datetime(2016, 12, 17, 7, 7, 47))
# Update_Status(ssn=138671198, last_updated=datetime.datetime(2018, 3, 4, 8, 14, 31), created=datetime.datetime(2016, 9, 24, 1, 52, 46))
# Update_Status(ssn=138885288, last_updated=datetime.datetime(2017, 2, 24, 15, 47, 36), created=datetime.datetime(2016, 1, 4, 9, 37, 53))
# Update_Status(ssn=139048189, last_updated=datetime.datetime(2017, 2, 16, 21, 23, 10), created=datetime.datetime(2016, 5, 24, 4, 10, 50))
# Update_Status(ssn=139945865, last_updated=datetime.datetime(2017, 8, 19, 16, 22, 52), created=datetime.datetime(2016, 9, 10, 21, 9, 28))
# Update_Status(ssn=139996417, last_updated=datetime.datetime(2018, 1, 17, 17, 51, 12), created=datetime.datetime(2016, 12, 21, 14, 14, 20))
# Update_Status(ssn=140339727, last_updated=datetime.datetime(2017, 9, 21, 23, 4, 48), created=datetime.datetime(2016, 1, 27, 9, 2, 26))
# Update_Status(ssn=140588263, last_updated=datetime.datetime(2017, 11, 12, 21, 41, 50), created=datetime.datetime(2016, 12, 14, 20, 27, 22))
# Update_Status(ssn=141150543, last_updated=datetime.datetime(2017, 9, 27, 10, 29, 9), created=datetime.datetime(2016, 7, 17, 22, 40, 37))
# Update_Status(ssn=141889721, last_updated=datetime.datetime(2018, 1, 24, 20, 0, 4), created=datetime.datetime(2016, 12, 20, 0, 43, 43))
# Update_Status(ssn=142774616, last_updated=datetime.datetime(2017, 7, 16, 15, 12, 37), created=datetime.datetime(2016, 7, 30, 13, 28, 38))
# Update_Status(ssn=142873416, last_updated=datetime.datetime(2017, 5, 3, 14, 26, 58), created=datetime.datetime(2016, 12, 26, 21, 18, 54))
# Update_Status(ssn=143174714, last_updated=datetime.datetime(2017, 7, 21, 18, 54, 47), created=datetime.datetime(2016, 2, 9, 6, 10, 21))
# Update_Status(ssn=145108454, last_updated=datetime.datetime(2017, 1, 18, 6, 37, 31), created=datetime.datetime(2016, 4, 25, 21, 45))
# Update_Status(ssn=145355124, last_updated=datetime.datetime(2018, 2, 20, 12, 47, 43), created=datetime.datetime(2016, 10, 3, 5, 18, 6))
# Update_Status(ssn=145783985, last_updated=datetime.datetime(2017, 6, 10, 6, 21, 46), created=datetime.datetime(2016, 9, 23, 15, 35, 52))
# Update_Status(ssn=146813446, last_updated=datetime.datetime(2017, 1, 18, 8, 40, 14), created=datetime.datetime(2016, 9, 1, 8, 59, 50))
# Update_Status(ssn=147331463, last_updated=datetime.datetime(2018, 2, 9, 4, 41, 58), created=datetime.datetime(2016, 5, 31, 23, 38, 59))
# Update_Status(ssn=147478577, last_updated=datetime.datetime(2017, 4, 2, 18, 37, 59), created=datetime.datetime(2016, 12, 11, 3, 5, 36))
# Update_Status(ssn=147633462, last_updated=datetime.datetime(2018, 2, 2, 13, 16, 51), created=datetime.datetime(2016, 7, 17, 4, 28, 52))
# Update_Status(ssn=148607519, last_updated=datetime.datetime(2017, 1, 22, 22, 15, 37), created=datetime.datetime(2016, 4, 29, 8, 42, 29))
# Update_Status(ssn=149187272, last_updated=datetime.datetime(2017, 8, 31, 2, 41, 41), created=datetime.datetime(2016, 10, 21, 12, 17, 57))
# Update_Status(ssn=149456482, last_updated=datetime.datetime(2017, 9, 2, 5, 13, 32), created=datetime.datetime(2016, 2, 23, 16, 20, 59))
# Update_Status(ssn=150646357, last_updated=datetime.datetime(2018, 2, 14, 23, 35, 53), created=datetime.datetime(2016, 1, 28, 3, 19, 50))
# Update_Status(ssn=150893343, last_updated=datetime.datetime(2017, 6, 4, 1, 39, 16), created=datetime.datetime(2016, 4, 23, 14, 7, 49))
# Update_Status(ssn=151543946, last_updated=datetime.datetime(2018, 2, 8, 11, 16, 12), created=datetime.datetime(2016, 10, 19, 8, 22, 59))
# Update_Status(ssn=151700641, last_updated=datetime.datetime(2017, 2, 13, 21, 31, 15), created=datetime.datetime(2016, 4, 28, 8, 28, 43))
# Update_Status(ssn=151781397, last_updated=datetime.datetime(2017, 7, 8, 4, 22, 30), created=datetime.datetime(2016, 6, 11, 0, 28, 10))
# Update_Status(ssn=152713526, last_updated=datetime.datetime(2018, 2, 25, 4, 17, 50), created=datetime.datetime(2016, 10, 8, 19, 49, 4))
# Update_Status(ssn=153671309, last_updated=datetime.datetime(2017, 8, 16, 12, 3, 37), created=datetime.datetime(2016, 12, 22, 19, 37, 39))
# Update_Status(ssn=154177912, last_updated=datetime.datetime(2017, 4, 19, 22, 8, 24), created=datetime.datetime(2016, 1, 29, 12, 43, 45))
# Update_Status(ssn=156187547, last_updated=datetime.datetime(2017, 9, 10, 22, 58, 31), created=datetime.datetime(2016, 10, 20, 19, 49, 24))
# Update_Status(ssn=156916848, last_updated=datetime.datetime(2017, 8, 30, 22, 29, 10), created=datetime.datetime(2016, 5, 7, 6, 45, 32))
# Update_Status(ssn=157179982, last_updated=datetime.datetime(2017, 4, 17, 9, 11, 49), created=datetime.datetime(2016, 3, 17, 0, 22, 29))
# Update_Status(ssn=157387090, last_updated=datetime.datetime(2017, 3, 24, 8, 58, 33), created=datetime.datetime(2016, 9, 15, 16, 11, 12))
# Update_Status(ssn=157515269, last_updated=datetime.datetime(2017, 11, 4, 20, 16, 50), created=datetime.datetime(2016, 6, 17, 10, 3, 2))
# Update_Status(ssn=161369710, last_updated=datetime.datetime(2017, 7, 3, 6, 26, 41), created=datetime.datetime(2016, 6, 9, 5, 30, 33))
# Update_Status(ssn=161534778, last_updated=datetime.datetime(2017, 12, 3, 11, 9, 18), created=datetime.datetime(2016, 12, 9, 18, 37, 55))
# Update_Status(ssn=163688070, last_updated=datetime.datetime(2017, 9, 6, 16, 56, 6), created=datetime.datetime(2016, 10, 23, 1, 47, 51))
# Update_Status(ssn=163981022, last_updated=datetime.datetime(2017, 3, 26, 4, 2, 28), created=datetime.datetime(2016, 3, 22, 11, 24, 33))
# Update_Status(ssn=164119849, last_updated=datetime.datetime(2017, 6, 24, 10, 17, 58), created=datetime.datetime(2016, 4, 20, 11, 9, 5))
# Update_Status(ssn=166104488, last_updated=datetime.datetime(2017, 8, 14, 16, 48, 43), created=datetime.datetime(2016, 7, 2, 8, 33, 48))
# Update_Status(ssn=167392377, last_updated=datetime.datetime(2017, 10, 31, 22, 27, 7), created=datetime.datetime(2016, 2, 3, 10, 32, 1))
# Update_Status(ssn=168025324, last_updated=datetime.datetime(2018, 1, 4, 21, 50, 39), created=datetime.datetime(2016, 1, 29, 15, 31, 40))
# Update_Status(ssn=168198754, last_updated=datetime.datetime(2017, 6, 10, 3, 48, 51), created=datetime.datetime(2016, 9, 27, 15, 4, 24))
# Update_Status(ssn=168810838, last_updated=datetime.datetime(2017, 2, 11, 14, 12, 16), created=datetime.datetime(2016, 9, 19, 20, 5, 7))
# Update_Status(ssn=168896661, last_updated=datetime.datetime(2017, 7, 17, 2, 59, 15), created=datetime.datetime(2016, 4, 30, 9, 17, 39))
# Update_Status(ssn=170653388, last_updated=datetime.datetime(2017, 3, 5, 0, 46, 26), created=datetime.datetime(2016, 6, 15, 5, 37, 27))
# Update_Status(ssn=171277781, last_updated=datetime.datetime(2017, 3, 5, 9, 35, 8), created=datetime.datetime(2016, 9, 23, 3, 10, 37))
# Update_Status(ssn=172237739, last_updated=datetime.datetime(2018, 3, 2, 23, 30, 36), created=datetime.datetime(2016, 5, 12, 16, 1, 48))
# Update_Status(ssn=172774263, last_updated=datetime.datetime(2017, 10, 11, 13, 32, 41), created=datetime.datetime(2016, 9, 10, 9, 18, 50))
# Update_Status(ssn=172897546, last_updated=datetime.datetime(2017, 1, 25, 2, 11, 6), created=datetime.datetime(2016, 7, 24, 12, 57, 57))
# Update_Status(ssn=173997372, last_updated=datetime.datetime(2018, 3, 3, 15, 18, 26), created=datetime.datetime(2016, 10, 26, 15, 24, 37))
# Update_Status(ssn=174132047, last_updated=datetime.datetime(2017, 1, 28, 14, 24, 40), created=datetime.datetime(2016, 1, 12, 16, 53, 59))
# Update_Status(ssn=174353812, last_updated=datetime.datetime(2017, 1, 25, 11, 34, 25), created=datetime.datetime(2016, 5, 14, 4, 55, 35))
# Update_Status(ssn=174519992, last_updated=datetime.datetime(2017, 3, 3, 19, 42, 18), created=datetime.datetime(2016, 5, 17, 23, 32, 25))
# Update_Status(ssn=174872537, last_updated=datetime.datetime(2017, 9, 30, 14, 38, 36), created=datetime.datetime(2016, 8, 1, 11, 19, 25))
# Update_Status(ssn=176821359, last_updated=datetime.datetime(2017, 1, 14, 13, 36, 1), created=datetime.datetime(2016, 11, 29, 19, 3, 42))
# Update_Status(ssn=176995851, last_updated=datetime.datetime(2017, 4, 1, 20, 14, 53), created=datetime.datetime(2016, 12, 3, 15, 8, 4))
# Update_Status(ssn=179882790, last_updated=datetime.datetime(2017, 3, 23, 1, 30, 12), created=datetime.datetime(2016, 3, 6, 13, 15, 20))
# Update_Status(ssn=181074434, last_updated=datetime.datetime(2017, 10, 7, 7, 52, 10), created=datetime.datetime(2016, 11, 11, 20, 19, 19))
# Update_Status(ssn=181288337, last_updated=datetime.datetime(2017, 11, 30, 23, 28), created=datetime.datetime(2016, 4, 27, 20, 53, 49))
# Update_Status(ssn=181886077, last_updated=datetime.datetime(2017, 8, 16, 21, 35, 50), created=datetime.datetime(2016, 9, 15, 10, 22, 56))
# Update_Status(ssn=182155082, last_updated=datetime.datetime(2017, 10, 2, 6, 22, 27), created=datetime.datetime(2016, 10, 16, 12, 16, 53))
# Update_Status(ssn=182814541, last_updated=datetime.datetime(2017, 7, 5, 10, 19, 41), created=datetime.datetime(2016, 7, 23, 3, 16, 13))
# Update_Status(ssn=183105024, last_updated=datetime.datetime(2017, 11, 3, 0, 36, 20), created=datetime.datetime(2016, 9, 8, 5, 10, 46))
# Update_Status(ssn=184606243, last_updated=datetime.datetime(2018, 2, 26, 15, 42, 50), created=datetime.datetime(2016, 6, 16, 15, 17, 46))
# Update_Status(ssn=184841003, last_updated=datetime.datetime(2017, 10, 15, 21, 11, 17), created=datetime.datetime(2016, 11, 17, 18, 52, 56))
# Update_Status(ssn=184923560, last_updated=datetime.datetime(2017, 2, 16, 4, 37, 8), created=datetime.datetime(2016, 7, 26, 19, 25, 30))
# Update_Status(ssn=184945241, last_updated=datetime.datetime(2017, 3, 28, 16, 56, 35), created=datetime.datetime(2016, 6, 3, 5, 38, 20))
# Update_Status(ssn=185500434, last_updated=datetime.datetime(2017, 2, 19, 15, 12, 50), created=datetime.datetime(2016, 10, 24, 14, 3, 4))
# Update_Status(ssn=185849868, last_updated=datetime.datetime(2017, 7, 1, 13, 56, 28), created=datetime.datetime(2016, 8, 8, 8, 4, 45))
# Update_Status(ssn=186657773, last_updated=datetime.datetime(2017, 6, 9, 12, 34, 32), created=datetime.datetime(2016, 9, 17, 22, 55, 15))
# Update_Status(ssn=188209317, last_updated=datetime.datetime(2017, 12, 26, 5, 29, 23), created=datetime.datetime(2016, 6, 5, 4, 26, 52))
# Update_Status(ssn=188404336, last_updated=datetime.datetime(2017, 12, 27, 3, 41, 46), created=datetime.datetime(2016, 6, 30, 2, 48, 10))
# Update_Status(ssn=189265696, last_updated=datetime.datetime(2017, 8, 8, 19, 29, 59), created=datetime.datetime(2016, 9, 9, 19, 38, 18))
# Update_Status(ssn=189491458, last_updated=datetime.datetime(2017, 2, 12, 16, 15, 44), created=datetime.datetime(2016, 6, 21, 4, 10, 57))
# Update_Status(ssn=190056987, last_updated=datetime.datetime(2017, 6, 6, 20, 51, 23), created=datetime.datetime(2016, 2, 17, 12, 0, 16))
# Update_Status(ssn=190534517, last_updated=datetime.datetime(2018, 2, 12, 20, 26, 30), created=datetime.datetime(2016, 4, 15, 16, 42, 18))
# Update_Status(ssn=191153194, last_updated=datetime.datetime(2017, 7, 27, 9, 14, 42), created=datetime.datetime(2016, 5, 23, 13, 52, 39))
# Update_Status(ssn=192540695, last_updated=datetime.datetime(2017, 3, 18, 6, 5, 59), created=datetime.datetime(2016, 11, 16, 1, 58, 55))
# Update_Status(ssn=192673201, last_updated=datetime.datetime(2017, 1, 19, 20, 59, 49), created=datetime.datetime(2016, 6, 13, 1, 23, 53))
# Update_Status(ssn=194765816, last_updated=datetime.datetime(2017, 1, 16, 18, 22, 53), created=datetime.datetime(2016, 5, 26, 16, 11, 14))
# Update_Status(ssn=195235731, last_updated=datetime.datetime(2017, 5, 22, 16, 24, 23), created=datetime.datetime(2016, 10, 23, 11, 15, 3))
# Update_Status(ssn=196693796, last_updated=datetime.datetime(2017, 1, 23, 2, 41, 20), created=datetime.datetime(2016, 8, 1, 21, 34, 6))
# Update_Status(ssn=198706443, last_updated=datetime.datetime(2017, 2, 13, 7, 16, 31), created=datetime.datetime(2016, 1, 22, 5, 10, 14))
# Update_Status(ssn=199450804, last_updated=datetime.datetime(2017, 6, 23, 12, 59, 20), created=datetime.datetime(2016, 11, 7, 0, 25, 12))
# Update_Status(ssn=199544639, last_updated=datetime.datetime(2018, 2, 23, 10, 14, 54), created=datetime.datetime(2016, 4, 5, 5, 11, 13))
# Update_Status(ssn=200817151, last_updated=datetime.datetime(2017, 11, 19, 13, 58, 42), created=datetime.datetime(2016, 7, 31, 19, 2, 12))
# Update_Status(ssn=201531249, last_updated=datetime.datetime(2017, 11, 25, 14, 19, 29), created=datetime.datetime(2016, 10, 7, 18, 42, 12))
# Update_Status(ssn=202841146, last_updated=datetime.datetime(2017, 4, 1, 22, 1, 53), created=datetime.datetime(2016, 7, 21, 8, 10, 25))
# Update_Status(ssn=203357648, last_updated=datetime.datetime(2017, 12, 1, 14, 42, 14), created=datetime.datetime(2016, 8, 2, 14, 24, 12))
# Update_Status(ssn=205697375, last_updated=datetime.datetime(2018, 2, 27, 13, 25, 24), created=datetime.datetime(2016, 5, 19, 12, 10, 37))
# Update_Status(ssn=205872423, last_updated=datetime.datetime(2018, 1, 1, 8, 17, 27), created=datetime.datetime(2016, 2, 16, 23, 45, 38))
# Update_Status(ssn=206286674, last_updated=datetime.datetime(2017, 10, 14, 6, 32, 53), created=datetime.datetime(2016, 8, 1, 8, 2, 52))
# Update_Status(ssn=206838848, last_updated=datetime.datetime(2017, 11, 8, 14, 57, 17), created=datetime.datetime(2016, 4, 11, 17, 40, 42))
# Update_Status(ssn=208742166, last_updated=datetime.datetime(2017, 1, 24, 9, 46, 24), created=datetime.datetime(2016, 2, 28, 8, 58, 53))
# Update_Status(ssn=208805879, last_updated=datetime.datetime(2017, 10, 16, 21, 39, 4), created=datetime.datetime(2016, 3, 31, 17, 4, 29))
# Update_Status(ssn=209508146, last_updated=datetime.datetime(2018, 3, 13, 17, 52, 16), created=datetime.datetime(2016, 4, 10, 7, 14, 25))
# Update_Status(ssn=209584708, last_updated=datetime.datetime(2018, 2, 8, 21, 22, 2), created=datetime.datetime(2016, 6, 17, 9, 21, 14))
# Update_Status(ssn=210914729, last_updated=datetime.datetime(2017, 7, 11, 8, 17, 40), created=datetime.datetime(2016, 12, 4, 0, 41, 8))
# Update_Status(ssn=211041734, last_updated=datetime.datetime(2018, 3, 11, 20, 29, 12), created=datetime.datetime(2016, 8, 30, 15, 59, 14))
# Update_Status(ssn=211135247, last_updated=datetime.datetime(2018, 2, 22, 16, 37, 12), created=datetime.datetime(2016, 12, 20, 3, 14, 56))
# Update_Status(ssn=211155182, last_updated=datetime.datetime(2017, 4, 15, 16, 17, 42), created=datetime.datetime(2016, 3, 17, 19, 14, 56))
# Update_Status(ssn=211196826, last_updated=datetime.datetime(2018, 2, 12, 4, 33, 14), created=datetime.datetime(2016, 8, 25, 22, 0, 15))
# Update_Status(ssn=212400215, last_updated=datetime.datetime(2017, 2, 1, 18, 11, 47), created=datetime.datetime(2016, 1, 6, 22, 31, 22))
# Update_Status(ssn=212411496, last_updated=datetime.datetime(2017, 7, 7, 20, 29, 9), created=datetime.datetime(2016, 10, 27, 12, 47, 10))
# Update_Status(ssn=213281395, last_updated=datetime.datetime(2017, 6, 4, 4, 51, 16), created=datetime.datetime(2016, 6, 11, 0, 6, 58))
# Update_Status(ssn=214291189, last_updated=datetime.datetime(2018, 2, 16, 8, 10, 36), created=datetime.datetime(2016, 6, 2, 0, 48, 2))
# Update_Status(ssn=214968581, last_updated=datetime.datetime(2017, 4, 30, 7, 25, 59), created=datetime.datetime(2016, 8, 18, 0, 21, 7))
# Update_Status(ssn=214997584, last_updated=datetime.datetime(2018, 2, 22, 11, 32, 50), created=datetime.datetime(2016, 7, 14, 3, 30, 15))
# Update_Status(ssn=216893812, last_updated=datetime.datetime(2018, 3, 11, 20, 2, 23), created=datetime.datetime(2016, 7, 28, 7, 3, 44))
# Update_Status(ssn=216973104, last_updated=datetime.datetime(2017, 2, 10, 18, 28, 9), created=datetime.datetime(2016, 9, 6, 8, 20, 10))
# Update_Status(ssn=217713922, last_updated=datetime.datetime(2017, 11, 11, 19, 44, 46), created=datetime.datetime(2016, 3, 4, 12, 33, 51))
# Update_Status(ssn=217815416, last_updated=datetime.datetime(2017, 12, 27, 18, 15, 59), created=datetime.datetime(2016, 11, 20, 2, 39, 48))
# Update_Status(ssn=218144448, last_updated=datetime.datetime(2017, 7, 22, 9, 16, 18), created=datetime.datetime(2016, 6, 29, 6, 28, 37))
# Update_Status(ssn=218259873, last_updated=datetime.datetime(2017, 5, 11, 20, 22, 10), created=datetime.datetime(2016, 3, 11, 12, 58, 1))
# Update_Status(ssn=218311615, last_updated=datetime.datetime(2017, 8, 3, 8, 57, 27), created=datetime.datetime(2016, 5, 14, 20, 4, 1))
# Update_Status(ssn=218497300, last_updated=datetime.datetime(2017, 12, 22, 19, 46, 19), created=datetime.datetime(2016, 9, 17, 5, 14, 16))
# Update_Status(ssn=220160476, last_updated=datetime.datetime(2017, 3, 9, 16, 48, 29), created=datetime.datetime(2016, 7, 4, 6, 40, 49))
# Update_Status(ssn=220380208, last_updated=datetime.datetime(2017, 11, 10, 15, 6, 25), created=datetime.datetime(2016, 10, 28, 19, 34, 21))
# Update_Status(ssn=222398571, last_updated=datetime.datetime(2017, 2, 3, 23, 45, 13), created=datetime.datetime(2016, 10, 4, 0, 52, 58))
# Update_Status(ssn=223679203, last_updated=datetime.datetime(2017, 8, 4, 12, 57, 4), created=datetime.datetime(2016, 12, 2, 13, 29, 54))
# Update_Status(ssn=223980846, last_updated=datetime.datetime(2017, 3, 29, 16, 7, 6), created=datetime.datetime(2016, 6, 29, 2, 47, 31))
# Update_Status(ssn=224123436, last_updated=datetime.datetime(2018, 1, 9, 23, 34, 10), created=datetime.datetime(2016, 10, 6, 12, 21, 57))
# Update_Status(ssn=224309267, last_updated=datetime.datetime(2017, 12, 17, 11, 57, 56), created=datetime.datetime(2016, 11, 13, 20, 27, 10))
# Update_Status(ssn=224546919, last_updated=datetime.datetime(2017, 2, 11, 17, 13, 36), created=datetime.datetime(2016, 1, 30, 9, 3, 19))
# Update_Status(ssn=224842271, last_updated=datetime.datetime(2018, 1, 23, 21, 14, 49), created=datetime.datetime(2016, 6, 14, 13, 25, 45))
# Update_Status(ssn=224990668, last_updated=datetime.datetime(2017, 4, 1, 17, 51, 23), created=datetime.datetime(2016, 1, 3, 6, 43, 7))
# Update_Status(ssn=225085789, last_updated=datetime.datetime(2017, 8, 5, 11, 29, 59), created=datetime.datetime(2016, 4, 1, 16, 56, 12))
# Update_Status(ssn=225642735, last_updated=datetime.datetime(2017, 12, 24, 21, 44, 27), created=datetime.datetime(2016, 7, 16, 23, 1, 13))
# Update_Status(ssn=226764452, last_updated=datetime.datetime(2017, 7, 8, 12, 13, 2), created=datetime.datetime(2016, 3, 18, 0, 10, 46))
# Update_Status(ssn=227727247, last_updated=datetime.datetime(2017, 12, 4, 7, 32, 34), created=datetime.datetime(2016, 8, 3, 15, 37, 18))
# Update_Status(ssn=228167922, last_updated=datetime.datetime(2017, 8, 7, 2, 28, 53), created=datetime.datetime(2016, 10, 8, 19, 36, 43))
# Update_Status(ssn=228552042, last_updated=datetime.datetime(2017, 1, 17, 20, 5, 40), created=datetime.datetime(2016, 3, 8, 17, 42, 55))
# Update_Status(ssn=228905077, last_updated=datetime.datetime(2018, 2, 26, 10, 52, 3), created=datetime.datetime(2016, 5, 6, 9, 54, 1))
# Update_Status(ssn=229449909, last_updated=datetime.datetime(2017, 6, 21, 5, 51, 8), created=datetime.datetime(2016, 12, 29, 8, 27, 3))
# Update_Status(ssn=230091794, last_updated=datetime.datetime(2018, 1, 27, 21, 49, 27), created=datetime.datetime(2016, 10, 22, 14, 54, 5))
# Update_Status(ssn=230480684, last_updated=datetime.datetime(2018, 3, 26, 6, 15, 57), created=datetime.datetime(2016, 12, 29, 6, 0, 3))
# Update_Status(ssn=230991485, last_updated=datetime.datetime(2017, 8, 10, 19, 34, 42), created=datetime.datetime(2016, 9, 19, 22, 26, 22))
# Update_Status(ssn=231669264, last_updated=datetime.datetime(2017, 4, 7, 22, 50, 50), created=datetime.datetime(2016, 6, 1, 8, 10, 38))
# Update_Status(ssn=232185397, last_updated=datetime.datetime(2017, 9, 23, 2, 16, 56), created=datetime.datetime(2016, 2, 20, 4, 33, 2))
# Update_Status(ssn=233272377, last_updated=datetime.datetime(2018, 1, 31, 9, 38, 49), created=datetime.datetime(2016, 2, 13, 21, 32, 41))
# Update_Status(ssn=235103518, last_updated=datetime.datetime(2017, 8, 8, 16, 14, 22), created=datetime.datetime(2016, 8, 9, 12, 36, 49))
# Update_Status(ssn=236318333, last_updated=datetime.datetime(2017, 1, 3, 13, 2, 1), created=datetime.datetime(2016, 1, 16, 12, 51, 28))
# Update_Status(ssn=236372567, last_updated=datetime.datetime(2017, 9, 1, 17, 59, 5), created=datetime.datetime(2016, 3, 1, 16, 19, 30))
# Update_Status(ssn=237486737, last_updated=datetime.datetime(2017, 1, 22, 14, 20, 20), created=datetime.datetime(2016, 10, 19, 13, 28, 28))
# Update_Status(ssn=237807039, last_updated=datetime.datetime(2017, 6, 20, 5, 20, 53), created=datetime.datetime(2016, 9, 5, 21, 2, 3))
# Update_Status(ssn=238138034, last_updated=datetime.datetime(2017, 5, 9, 1, 16, 29), created=datetime.datetime(2016, 2, 17, 14, 44, 51))
# Update_Status(ssn=238399999, last_updated=datetime.datetime(2017, 12, 17, 18, 36, 23), created=datetime.datetime(2016, 10, 20, 4, 17, 23))
# Update_Status(ssn=239099133, last_updated=datetime.datetime(2018, 1, 28, 2, 19, 9), created=datetime.datetime(2016, 8, 4, 10, 29, 19))
# Update_Status(ssn=239374122, last_updated=datetime.datetime(2017, 9, 20, 20, 47, 44), created=datetime.datetime(2016, 3, 5, 9, 16, 37))
# Update_Status(ssn=240088805, last_updated=datetime.datetime(2017, 2, 10, 12, 14, 31), created=datetime.datetime(2016, 8, 15, 20, 52, 10))
# Update_Status(ssn=240328915, last_updated=datetime.datetime(2017, 4, 18, 14, 30, 22), created=datetime.datetime(2016, 2, 25, 19, 4, 17))
# Update_Status(ssn=240676258, last_updated=datetime.datetime(2017, 10, 17, 17, 8, 33), created=datetime.datetime(2016, 5, 24, 9, 11, 51))
# Update_Status(ssn=242229624, last_updated=datetime.datetime(2017, 3, 31, 4, 48, 46), created=datetime.datetime(2016, 11, 15, 23, 9, 12))
# Update_Status(ssn=243379496, last_updated=datetime.datetime(2017, 5, 5, 6, 46, 9), created=datetime.datetime(2016, 9, 27, 0, 48, 56))
# Update_Status(ssn=243444611, last_updated=datetime.datetime(2017, 8, 28, 4, 20, 56), created=datetime.datetime(2016, 7, 29, 20, 21, 30))
# Update_Status(ssn=244342210, last_updated=datetime.datetime(2017, 12, 30, 9, 16, 58), created=datetime.datetime(2016, 11, 12, 19, 43, 59))
# Update_Status(ssn=244527593, last_updated=datetime.datetime(2017, 12, 19, 22, 53, 28), created=datetime.datetime(2016, 9, 24, 23, 2, 28))
# Update_Status(ssn=244793004, last_updated=datetime.datetime(2017, 9, 8, 9, 13, 42), created=datetime.datetime(2016, 8, 17, 18, 53, 29))
# Update_Status(ssn=244810671, last_updated=datetime.datetime(2017, 6, 23, 11, 56, 59), created=datetime.datetime(2016, 9, 8, 8, 33, 21))
# Update_Status(ssn=245605880, last_updated=datetime.datetime(2017, 4, 5, 20, 44, 3), created=datetime.datetime(2016, 2, 6, 3, 16, 59))
# Update_Status(ssn=245774110, last_updated=datetime.datetime(2017, 3, 6, 5, 50, 56), created=datetime.datetime(2016, 8, 22, 4, 57, 23))
# Update_Status(ssn=247089326, last_updated=datetime.datetime(2017, 10, 20, 3, 18, 53), created=datetime.datetime(2016, 9, 15, 4, 25, 48))
# Update_Status(ssn=247865288, last_updated=datetime.datetime(2017, 8, 7, 13, 12, 28), created=datetime.datetime(2016, 1, 13, 5, 54, 25))
# Update_Status(ssn=248079757, last_updated=datetime.datetime(2018, 2, 25, 14, 10, 22), created=datetime.datetime(2016, 1, 25, 22, 14, 58))
# Update_Status(ssn=248230150, last_updated=datetime.datetime(2017, 3, 6, 2, 7, 51), created=datetime.datetime(2016, 8, 27, 12, 22, 11))
# Update_Status(ssn=249195514, last_updated=datetime.datetime(2017, 11, 18, 7, 3, 15), created=datetime.datetime(2016, 7, 23, 19, 17, 37))
# Update_Status(ssn=253618401, last_updated=datetime.datetime(2018, 1, 22, 4, 2, 1), created=datetime.datetime(2016, 10, 2, 2, 18, 55))
# Update_Status(ssn=254106071, last_updated=datetime.datetime(2017, 7, 27, 8, 15, 23), created=datetime.datetime(2016, 4, 1, 23, 46, 56))
# Update_Status(ssn=254929669, last_updated=datetime.datetime(2017, 6, 27, 8, 31, 24), created=datetime.datetime(2016, 4, 8, 21, 14, 39))
# Update_Status(ssn=255810958, last_updated=datetime.datetime(2017, 1, 14, 1, 34, 12), created=datetime.datetime(2016, 9, 9, 15, 46, 19))
# Update_Status(ssn=256547507, last_updated=datetime.datetime(2017, 3, 6, 4, 47, 24), created=datetime.datetime(2016, 4, 5, 12, 48, 34))
# Update_Status(ssn=256570666, last_updated=datetime.datetime(2017, 10, 8, 2, 5, 59), created=datetime.datetime(2016, 9, 30, 19, 42, 52))
# Update_Status(ssn=257126834, last_updated=datetime.datetime(2018, 3, 27, 21, 18, 39), created=datetime.datetime(2016, 11, 24, 9, 46, 5))
# Update_Status(ssn=257598603, last_updated=datetime.datetime(2017, 4, 12, 7, 13, 58), created=datetime.datetime(2016, 6, 7, 14, 41, 15))
# Update_Status(ssn=257773669, last_updated=datetime.datetime(2017, 7, 29, 13, 33, 21), created=datetime.datetime(2016, 11, 30, 14, 43, 14))
# Update_Status(ssn=258226416, last_updated=datetime.datetime(2017, 4, 28, 1, 14, 30), created=datetime.datetime(2016, 5, 7, 18, 26, 17))
# Update_Status(ssn=259385920, last_updated=datetime.datetime(2017, 7, 23, 21, 2, 37), created=datetime.datetime(2016, 10, 4, 9, 8, 54))
# Update_Status(ssn=261149490, last_updated=datetime.datetime(2017, 1, 26, 12, 19, 19), created=datetime.datetime(2016, 4, 23, 9, 0, 56))
# Update_Status(ssn=262092144, last_updated=datetime.datetime(2018, 1, 7, 8, 54, 1), created=datetime.datetime(2016, 7, 26, 12, 0, 47))
# Update_Status(ssn=262467573, last_updated=datetime.datetime(2017, 11, 3, 2, 47, 17), created=datetime.datetime(2016, 8, 22, 17, 8, 16))
# Update_Status(ssn=262554066, last_updated=datetime.datetime(2017, 6, 3, 10, 15, 39), created=datetime.datetime(2016, 12, 20, 9, 49, 37))
# Update_Status(ssn=262667030, last_updated=datetime.datetime(2018, 1, 23, 23, 44, 35), created=datetime.datetime(2016, 3, 22, 3, 8, 3))
# Update_Status(ssn=264393910, last_updated=datetime.datetime(2017, 10, 5, 3, 39, 11), created=datetime.datetime(2016, 8, 12, 8, 53, 33))
# Update_Status(ssn=266869980, last_updated=datetime.datetime(2018, 2, 19, 20, 34, 9), created=datetime.datetime(2016, 7, 7, 5, 6, 40))
# Update_Status(ssn=267756383, last_updated=datetime.datetime(2017, 1, 18, 3, 2, 58), created=datetime.datetime(2016, 5, 12, 18, 5, 24))
# Update_Status(ssn=269012640, last_updated=datetime.datetime(2017, 11, 23, 14, 20, 56), created=datetime.datetime(2016, 9, 9, 8, 12, 54))
# Update_Status(ssn=271040134, last_updated=datetime.datetime(2017, 5, 14, 7, 18, 59), created=datetime.datetime(2016, 8, 2, 17, 22, 46))
# Update_Status(ssn=271819938, last_updated=datetime.datetime(2017, 1, 29, 1, 31, 37), created=datetime.datetime(2016, 8, 16, 6, 47, 48))
# Update_Status(ssn=271933051, last_updated=datetime.datetime(2017, 2, 18, 16, 44, 2), created=datetime.datetime(2016, 6, 8, 11, 36, 44))
# Update_Status(ssn=272507309, last_updated=datetime.datetime(2017, 3, 20, 5, 38, 57), created=datetime.datetime(2016, 2, 24, 17, 32, 46))
# Update_Status(ssn=272817979, last_updated=datetime.datetime(2018, 1, 14, 21, 6, 5), created=datetime.datetime(2016, 6, 4, 3, 9, 24))
# Update_Status(ssn=273498218, last_updated=datetime.datetime(2017, 9, 9, 5, 26, 20), created=datetime.datetime(2016, 9, 27, 0, 5, 15))
# Update_Status(ssn=274503806, last_updated=datetime.datetime(2017, 5, 13, 5, 8, 51), created=datetime.datetime(2016, 6, 3, 3, 7, 43))
# Update_Status(ssn=274769883, last_updated=datetime.datetime(2017, 10, 9, 4, 11, 3), created=datetime.datetime(2016, 12, 22, 11, 44, 48))
# Update_Status(ssn=276052973, last_updated=datetime.datetime(2017, 11, 3, 5, 30, 21), created=datetime.datetime(2016, 3, 21, 11, 51, 10))
# Update_Status(ssn=278555842, last_updated=datetime.datetime(2018, 1, 2, 5, 17, 17), created=datetime.datetime(2016, 5, 1, 8, 36, 52))
# Update_Status(ssn=278644853, last_updated=datetime.datetime(2017, 12, 17, 20, 59, 8), created=datetime.datetime(2016, 7, 10, 13, 32, 27))
# Update_Status(ssn=279127167, last_updated=datetime.datetime(2017, 3, 17, 17, 36, 17), created=datetime.datetime(2016, 8, 6, 1, 23, 43))
# Update_Status(ssn=279405540, last_updated=datetime.datetime(2017, 8, 25, 15, 27, 27), created=datetime.datetime(2016, 7, 27, 23, 55, 42))
# Update_Status(ssn=279495682, last_updated=datetime.datetime(2017, 11, 27, 7, 44, 58), created=datetime.datetime(2016, 11, 9, 19, 42, 41))
# Update_Status(ssn=280537447, last_updated=datetime.datetime(2017, 5, 12, 7, 46, 5), created=datetime.datetime(2016, 2, 16, 0, 15, 21))
# Update_Status(ssn=280984410, last_updated=datetime.datetime(2017, 8, 10, 14, 59, 8), created=datetime.datetime(2016, 10, 11, 7, 49, 19))
# Update_Status(ssn=281233458, last_updated=datetime.datetime(2017, 6, 21, 9, 17, 37), created=datetime.datetime(2016, 2, 18, 5, 27))
# Update_Status(ssn=282839206, last_updated=datetime.datetime(2017, 11, 30, 2, 29, 14), created=datetime.datetime(2016, 10, 11, 1, 11, 32))
# Update_Status(ssn=283046835, last_updated=datetime.datetime(2017, 5, 29, 2, 43, 42), created=datetime.datetime(2016, 5, 17, 15, 7, 44))
# Update_Status(ssn=286264004, last_updated=datetime.datetime(2017, 7, 6, 13, 34, 13), created=datetime.datetime(2016, 7, 15, 11, 24, 21))
# Update_Status(ssn=287579688, last_updated=datetime.datetime(2017, 3, 25, 16, 51, 30), created=datetime.datetime(2016, 4, 4, 10, 16, 41))
# Update_Status(ssn=287662660, last_updated=datetime.datetime(2018, 1, 8, 5, 9, 53), created=datetime.datetime(2016, 1, 3, 15, 12, 3))
# Update_Status(ssn=288547233, last_updated=datetime.datetime(2017, 4, 9, 3, 49, 3), created=datetime.datetime(2016, 1, 13, 21, 17, 3))
# Update_Status(ssn=288876462, last_updated=datetime.datetime(2017, 4, 28, 5, 43, 4), created=datetime.datetime(2016, 6, 11, 6, 48, 8))
# Update_Status(ssn=289039882, last_updated=datetime.datetime(2017, 6, 29, 11, 35, 32), created=datetime.datetime(2016, 4, 30, 10, 2, 41))
# Update_Status(ssn=289098686, last_updated=datetime.datetime(2017, 9, 15, 1, 56, 26), created=datetime.datetime(2016, 5, 18, 1, 46, 32))
# Update_Status(ssn=290257300, last_updated=datetime.datetime(2017, 4, 13, 6, 2, 34), created=datetime.datetime(2016, 11, 25, 16, 46, 39))
# Update_Status(ssn=290824968, last_updated=datetime.datetime(2017, 7, 3, 20, 17, 20), created=datetime.datetime(2016, 3, 11, 4, 18, 51))
# Update_Status(ssn=293543694, last_updated=datetime.datetime(2017, 7, 10, 11, 18, 54), created=datetime.datetime(2016, 8, 18, 20, 59, 31))
# Update_Status(ssn=294279936, last_updated=datetime.datetime(2018, 2, 7, 23, 28, 14), created=datetime.datetime(2016, 9, 14, 4, 10, 51))
# Update_Status(ssn=294531911, last_updated=datetime.datetime(2018, 3, 8, 15, 24, 15), created=datetime.datetime(2016, 7, 22, 21, 42, 17))
# Update_Status(ssn=295637693, last_updated=datetime.datetime(2017, 2, 28, 11, 27, 31), created=datetime.datetime(2016, 1, 7, 4, 36, 56))
# Update_Status(ssn=296327910, last_updated=datetime.datetime(2017, 5, 8, 14, 27, 35), created=datetime.datetime(2016, 11, 18, 18, 55, 41))
# Update_Status(ssn=296880097, last_updated=datetime.datetime(2017, 6, 28, 19, 41, 12), created=datetime.datetime(2016, 1, 1, 23, 18, 36))
# Update_Status(ssn=296904908, last_updated=datetime.datetime(2017, 5, 8, 13, 53, 40), created=datetime.datetime(2016, 4, 12, 0, 23, 9))
# Update_Status(ssn=297631154, last_updated=datetime.datetime(2018, 1, 18, 23, 20, 37), created=datetime.datetime(2016, 3, 3, 14, 10, 1))
# Update_Status(ssn=298063497, last_updated=datetime.datetime(2017, 10, 24, 4, 25, 1), created=datetime.datetime(2016, 11, 6, 17, 11, 40))
# Update_Status(ssn=298699168, last_updated=datetime.datetime(2017, 10, 11, 23, 18, 49), created=datetime.datetime(2016, 10, 30, 0, 58, 22))
# Update_Status(ssn=298706018, last_updated=datetime.datetime(2018, 2, 12, 10, 5, 39), created=datetime.datetime(2016, 3, 28, 9, 53, 54))
# Update_Status(ssn=298797640, last_updated=datetime.datetime(2017, 11, 27, 0, 8, 54), created=datetime.datetime(2016, 11, 8, 8, 9, 5))
# Update_Status(ssn=299036911, last_updated=datetime.datetime(2017, 1, 19, 3, 33, 50), created=datetime.datetime(2016, 3, 7, 15, 33, 32))
# Update_Status(ssn=299380483, last_updated=datetime.datetime(2017, 9, 20, 16, 34, 47), created=datetime.datetime(2016, 6, 1, 9, 6, 19))
# Update_Status(ssn=299771060, last_updated=datetime.datetime(2017, 3, 13, 1, 59, 12), created=datetime.datetime(2016, 11, 1, 3, 27, 51))
# Update_Status(ssn=300593610, last_updated=datetime.datetime(2017, 8, 21, 10, 1, 31), created=datetime.datetime(2016, 6, 23, 4, 44, 22))
# Update_Status(ssn=300768770, last_updated=datetime.datetime(2017, 8, 21, 0, 3, 14), created=datetime.datetime(2016, 3, 13, 15, 45, 7))
# Update_Status(ssn=300807209, last_updated=datetime.datetime(2017, 11, 13, 1, 58, 56), created=datetime.datetime(2016, 11, 8, 3, 17, 4))
# Update_Status(ssn=301264306, last_updated=datetime.datetime(2017, 6, 20, 20, 49, 12), created=datetime.datetime(2016, 1, 25, 11, 1, 19))
# Update_Status(ssn=301510522, last_updated=datetime.datetime(2017, 7, 3, 16, 20, 32), created=datetime.datetime(2016, 7, 28, 2, 33, 50))
# Update_Status(ssn=302644858, last_updated=datetime.datetime(2018, 2, 22, 14, 59, 17), created=datetime.datetime(2016, 5, 4, 18, 49, 4))
# Update_Status(ssn=304484312, last_updated=datetime.datetime(2017, 6, 8, 17, 56, 34), created=datetime.datetime(2016, 7, 23, 15, 40, 8))
# Update_Status(ssn=305071498, last_updated=datetime.datetime(2017, 6, 18, 5, 38, 20), created=datetime.datetime(2016, 1, 31, 18, 6, 58))
# Update_Status(ssn=306232423, last_updated=datetime.datetime(2018, 2, 11, 1, 37, 8), created=datetime.datetime(2016, 9, 12, 2, 41, 26))
# Update_Status(ssn=306862930, last_updated=datetime.datetime(2017, 5, 10, 18, 3, 52), created=datetime.datetime(2016, 9, 15, 15, 20, 35))
# Update_Status(ssn=308580964, last_updated=datetime.datetime(2017, 6, 13, 11, 53, 43), created=datetime.datetime(2016, 9, 29, 22, 38, 39))
# Update_Status(ssn=309040364, last_updated=datetime.datetime(2018, 3, 23, 0, 53, 44), created=datetime.datetime(2016, 1, 18, 3, 37, 59))
# Update_Status(ssn=309388085, last_updated=datetime.datetime(2017, 10, 15, 2, 43, 14), created=datetime.datetime(2016, 5, 12, 11, 34, 16))
# Update_Status(ssn=310602027, last_updated=datetime.datetime(2018, 3, 20, 12, 53, 17), created=datetime.datetime(2016, 10, 25, 3, 4, 20))
# Update_Status(ssn=311469296, last_updated=datetime.datetime(2018, 2, 18, 15, 38, 24), created=datetime.datetime(2016, 8, 6, 19, 3, 48))
# Update_Status(ssn=312387084, last_updated=datetime.datetime(2017, 8, 7, 14, 33, 15), created=datetime.datetime(2016, 12, 1, 17, 51, 41))
# Update_Status(ssn=312593476, last_updated=datetime.datetime(2017, 6, 5, 16, 36, 40), created=datetime.datetime(2016, 6, 11, 17, 37, 47))
# Update_Status(ssn=312773647, last_updated=datetime.datetime(2017, 4, 30, 2, 56, 29), created=datetime.datetime(2016, 1, 13, 20, 57, 51))
# Update_Status(ssn=313027822, last_updated=datetime.datetime(2017, 10, 7, 16, 22, 13), created=datetime.datetime(2016, 12, 9, 3, 16, 22))
# Update_Status(ssn=313527312, last_updated=datetime.datetime(2017, 11, 27, 22, 37, 28), created=datetime.datetime(2016, 6, 9, 16, 42, 48))
# Update_Status(ssn=315125664, last_updated=datetime.datetime(2017, 6, 11, 18, 3, 12), created=datetime.datetime(2016, 5, 19, 13, 58, 32))
# Update_Status(ssn=315262241, last_updated=datetime.datetime(2017, 11, 27, 8, 16, 19), created=datetime.datetime(2016, 5, 27, 6, 53, 31))
# Update_Status(ssn=315449671, last_updated=datetime.datetime(2018, 3, 12, 23, 39, 35), created=datetime.datetime(2016, 10, 19, 9, 51, 9))
# Update_Status(ssn=315785587, last_updated=datetime.datetime(2017, 8, 20, 18, 9, 2), created=datetime.datetime(2016, 1, 17, 12, 12, 42))
# Update_Status(ssn=317281600, last_updated=datetime.datetime(2017, 12, 19, 2, 20, 21), created=datetime.datetime(2016, 10, 6, 3, 35, 19))
# Update_Status(ssn=317432055, last_updated=datetime.datetime(2017, 12, 26, 16, 31, 21), created=datetime.datetime(2016, 9, 18, 19, 55, 52))
# Update_Status(ssn=318585314, last_updated=datetime.datetime(2017, 3, 19, 17, 31, 18), created=datetime.datetime(2016, 11, 27, 19, 18, 57))
# Update_Status(ssn=319430465, last_updated=datetime.datetime(2018, 3, 8, 8, 22, 23), created=datetime.datetime(2016, 10, 30, 0, 3, 54))
# Update_Status(ssn=320901419, last_updated=datetime.datetime(2017, 8, 1, 15, 3, 18), created=datetime.datetime(2016, 5, 21, 16, 46, 58))
# Update_Status(ssn=320979147, last_updated=datetime.datetime(2017, 11, 27, 2, 56, 43), created=datetime.datetime(2016, 12, 30, 2, 58, 10))
# Update_Status(ssn=323286705, last_updated=datetime.datetime(2017, 7, 6, 8, 58, 57), created=datetime.datetime(2016, 9, 23, 12, 24, 33))
# Update_Status(ssn=323338689, last_updated=datetime.datetime(2018, 2, 6, 11, 18, 46), created=datetime.datetime(2016, 1, 30, 6, 55, 54))
# Update_Status(ssn=324395230, last_updated=datetime.datetime(2017, 12, 12, 18, 34, 16), created=datetime.datetime(2016, 8, 10, 15, 8, 1))
# Update_Status(ssn=324738895, last_updated=datetime.datetime(2018, 1, 31, 14, 40, 37), created=datetime.datetime(2016, 1, 31, 4, 8, 41))
# Update_Status(ssn=324756098, last_updated=datetime.datetime(2017, 3, 22, 10, 39, 27), created=datetime.datetime(2016, 11, 29, 5, 9, 44))
# Update_Status(ssn=326649957, last_updated=datetime.datetime(2017, 1, 28, 20, 25, 31), created=datetime.datetime(2016, 5, 21, 4, 5, 26))
# Update_Status(ssn=327520546, last_updated=datetime.datetime(2017, 11, 9, 16, 0, 25), created=datetime.datetime(2016, 6, 13, 20, 55, 47))
# Update_Status(ssn=327887554, last_updated=datetime.datetime(2017, 11, 24, 22, 24, 17), created=datetime.datetime(2016, 10, 12, 9, 25, 25))
# Update_Status(ssn=330993055, last_updated=datetime.datetime(2017, 3, 15, 2, 8, 35), created=datetime.datetime(2016, 6, 13, 6, 58, 21))
# Update_Status(ssn=332836591, last_updated=datetime.datetime(2017, 6, 1, 21, 27, 2), created=datetime.datetime(2016, 6, 26, 19, 28, 44))
# Update_Status(ssn=333525097, last_updated=datetime.datetime(2017, 8, 7, 15, 22, 28), created=datetime.datetime(2016, 10, 17, 19, 38, 37))
# Update_Status(ssn=333955025, last_updated=datetime.datetime(2017, 8, 28, 15, 13, 59), created=datetime.datetime(2016, 5, 25, 23, 33, 3))
# Update_Status(ssn=335351520, last_updated=datetime.datetime(2017, 1, 29, 15, 44, 57), created=datetime.datetime(2016, 11, 26, 7, 21, 10))
# Update_Status(ssn=336482579, last_updated=datetime.datetime(2018, 3, 2, 16, 26, 48), created=datetime.datetime(2016, 4, 28, 19, 21, 15))
# Update_Status(ssn=339278046, last_updated=datetime.datetime(2017, 12, 12, 18, 26, 28), created=datetime.datetime(2016, 4, 9, 3, 13, 49))
# Update_Status(ssn=339712687, last_updated=datetime.datetime(2017, 10, 22, 21, 42, 38), created=datetime.datetime(2016, 12, 18, 12, 54, 8))
# Update_Status(ssn=341106840, last_updated=datetime.datetime(2017, 3, 6, 16, 50, 4), created=datetime.datetime(2016, 6, 4, 11, 29, 46))
# Update_Status(ssn=342059057, last_updated=datetime.datetime(2017, 3, 23, 6, 34, 5), created=datetime.datetime(2016, 7, 19, 5, 33, 42))
# Update_Status(ssn=342550538, last_updated=datetime.datetime(2017, 8, 30, 11, 9, 11), created=datetime.datetime(2016, 1, 1, 10, 27, 44))
# Update_Status(ssn=342909333, last_updated=datetime.datetime(2017, 12, 2, 9, 54, 57), created=datetime.datetime(2016, 6, 17, 11, 46, 24))
# Update_Status(ssn=343208407, last_updated=datetime.datetime(2017, 12, 20, 4, 35, 7), created=datetime.datetime(2016, 5, 11, 2, 2, 53))
# Update_Status(ssn=343813179, last_updated=datetime.datetime(2017, 10, 17, 18, 21, 38), created=datetime.datetime(2016, 3, 6, 17, 25, 34))
# Update_Status(ssn=345742160, last_updated=datetime.datetime(2018, 2, 4, 4, 8, 54), created=datetime.datetime(2016, 7, 13, 23, 35, 12))
# Update_Status(ssn=347093254, last_updated=datetime.datetime(2017, 6, 30, 0, 52, 15), created=datetime.datetime(2016, 8, 15, 10, 51, 18))
# Update_Status(ssn=347648652, last_updated=datetime.datetime(2017, 5, 23, 11, 28, 5), created=datetime.datetime(2016, 12, 30, 3, 51, 10))
# Update_Status(ssn=348734312, last_updated=datetime.datetime(2017, 9, 13, 10, 31, 30), created=datetime.datetime(2016, 12, 14, 21, 16, 27))
# Update_Status(ssn=348743224, last_updated=datetime.datetime(2018, 2, 4, 18, 12, 54), created=datetime.datetime(2016, 5, 11, 22, 14, 46))
# Update_Status(ssn=349538864, last_updated=datetime.datetime(2017, 12, 27, 21, 15, 3), created=datetime.datetime(2016, 1, 28, 10, 14, 46))
# Update_Status(ssn=349677502, last_updated=datetime.datetime(2018, 2, 16, 4, 12, 54), created=datetime.datetime(2016, 1, 12, 23, 12, 17))
# Update_Status(ssn=350209593, last_updated=datetime.datetime(2018, 2, 10, 22, 55, 27), created=datetime.datetime(2016, 4, 12, 21, 1, 21))
# Update_Status(ssn=350804646, last_updated=datetime.datetime(2017, 8, 23, 16, 52, 47), created=datetime.datetime(2016, 5, 28, 8, 33, 21))
# Update_Status(ssn=351732802, last_updated=datetime.datetime(2017, 8, 11, 7, 49, 34), created=datetime.datetime(2016, 9, 3, 2, 20, 26))
# Update_Status(ssn=355219711, last_updated=datetime.datetime(2017, 11, 1, 23, 0, 15), created=datetime.datetime(2016, 4, 22, 13, 52, 40))
# Update_Status(ssn=355529767, last_updated=datetime.datetime(2018, 3, 20, 23, 3, 28), created=datetime.datetime(2016, 9, 25, 21, 5, 36))
# Update_Status(ssn=355967706, last_updated=datetime.datetime(2017, 10, 25, 11, 22, 28), created=datetime.datetime(2016, 3, 5, 8, 16, 19))
# Update_Status(ssn=356399199, last_updated=datetime.datetime(2017, 12, 4, 23, 53, 17), created=datetime.datetime(2016, 1, 28, 6, 55, 58))
# Update_Status(ssn=357376094, last_updated=datetime.datetime(2018, 2, 13, 5, 16, 10), created=datetime.datetime(2016, 4, 26, 4, 10, 52))
# Update_Status(ssn=358847049, last_updated=datetime.datetime(2017, 2, 9, 7, 24, 45), created=datetime.datetime(2016, 2, 21, 0, 13, 44))
# Update_Status(ssn=360696230, last_updated=datetime.datetime(2017, 5, 27, 8, 53, 14), created=datetime.datetime(2016, 12, 14, 18, 1, 16))
# Update_Status(ssn=361061530, last_updated=datetime.datetime(2017, 5, 6, 15, 5, 47), created=datetime.datetime(2016, 1, 21, 23, 6, 3))
# Update_Status(ssn=361427068, last_updated=datetime.datetime(2018, 2, 4, 13, 38, 12), created=datetime.datetime(2016, 9, 7, 15, 20, 13))
# Update_Status(ssn=361494597, last_updated=datetime.datetime(2017, 11, 22, 9, 17, 58), created=datetime.datetime(2016, 12, 20, 11, 29, 30))
# Update_Status(ssn=361835004, last_updated=datetime.datetime(2017, 8, 11, 21, 27, 23), created=datetime.datetime(2016, 12, 24, 3, 19, 11))
# ...
# Update_Status(ssn=800069721, last_updated=datetime.datetime(2017, 6, 15, 11, 45, 18), created=datetime.datetime(2016, 10, 6, 4, 19, 10))
# Update_Status(ssn=801088313, last_updated=datetime.datetime(2017, 6, 6, 18, 4, 7), created=datetime.datetime(2016, 2, 17, 16, 51, 58))
# Update_Status(ssn=801926460, last_updated=datetime.datetime(2017, 5, 30, 19, 12, 17), created=datetime.datetime(2016, 11, 3, 7, 17, 1))
# Update_Status(ssn=801992773, last_updated=datetime.datetime(2017, 8, 21, 10, 25, 47), created=datetime.datetime(2016, 7, 26, 8, 24, 12))
# Update_Status(ssn=804460617, last_updated=datetime.datetime(2017, 6, 9, 18, 37, 10), created=datetime.datetime(2016, 11, 6, 6, 36, 15))
# Update_Status(ssn=807135922, last_updated=datetime.datetime(2017, 3, 12, 16, 29, 50), created=datetime.datetime(2016, 6, 17, 23, 4, 5))
# Update_Status(ssn=807246202, last_updated=datetime.datetime(2017, 12, 22, 4, 19, 35), created=datetime.datetime(2016, 2, 20, 3, 53, 16))
# Update_Status(ssn=807256136, last_updated=datetime.datetime(2017, 7, 10, 21, 58, 9), created=datetime.datetime(2016, 6, 30, 11, 32, 14))
# Update_Status(ssn=807358936, last_updated=datetime.datetime(2017, 3, 10, 8, 11, 51), created=datetime.datetime(2016, 5, 20, 15, 53, 34))
# Update_Status(ssn=807508539, last_updated=datetime.datetime(2017, 8, 25, 17, 2, 7), created=datetime.datetime(2016, 11, 17, 19, 43, 48))
# Update_Status(ssn=807605615, last_updated=datetime.datetime(2017, 1, 20, 8, 10, 18), created=datetime.datetime(2016, 1, 21, 10, 4))
# Update_Status(ssn=808558658, last_updated=datetime.datetime(2017, 9, 30, 9, 38, 27), created=datetime.datetime(2016, 9, 23, 12, 37, 50))
# Update_Status(ssn=808802542, last_updated=datetime.datetime(2018, 1, 3, 12, 45, 59), created=datetime.datetime(2016, 2, 2, 4, 18, 46))
# Update_Status(ssn=811652750, last_updated=datetime.datetime(2017, 6, 11, 23, 31, 14), created=datetime.datetime(2016, 2, 20, 8, 23, 25))
# Update_Status(ssn=812119403, last_updated=datetime.datetime(2017, 5, 15, 16, 9, 23), created=datetime.datetime(2016, 8, 30, 15, 39, 9))
# Update_Status(ssn=813424142, last_updated=datetime.datetime(2017, 10, 17, 13, 20, 22), created=datetime.datetime(2016, 3, 3, 4, 54, 4))
# Update_Status(ssn=813475215, last_updated=datetime.datetime(2017, 7, 17, 0, 22, 1), created=datetime.datetime(2016, 10, 2, 5, 4, 12))
# Update_Status(ssn=815830300, last_updated=datetime.datetime(2017, 9, 24, 5, 16, 56), created=datetime.datetime(2016, 5, 30, 2, 41, 36))
# Update_Status(ssn=816313858, last_updated=datetime.datetime(2017, 4, 13, 4, 17, 11), created=datetime.datetime(2016, 7, 30, 2, 46, 27))
# Update_Status(ssn=816474782, last_updated=datetime.datetime(2017, 9, 9, 12, 11, 28), created=datetime.datetime(2016, 11, 24, 12, 43, 20))
# Update_Status(ssn=816902049, last_updated=datetime.datetime(2018, 2, 16, 1, 29, 23), created=datetime.datetime(2016, 10, 25, 7, 25, 19))
# Update_Status(ssn=817041950, last_updated=datetime.datetime(2017, 5, 24, 8, 43, 21), created=datetime.datetime(2016, 7, 2, 12, 4, 51))
# Update_Status(ssn=817257437, last_updated=datetime.datetime(2017, 11, 27, 5, 44, 31), created=datetime.datetime(2016, 7, 6, 6, 49, 2))
# Update_Status(ssn=817808930, last_updated=datetime.datetime(2017, 10, 15, 5, 52, 17), created=datetime.datetime(2016, 1, 25, 15, 9, 1))
# Update_Status(ssn=818610770, last_updated=datetime.datetime(2017, 11, 24, 15, 25, 51), created=datetime.datetime(2016, 8, 12, 7, 54, 17))
# Update_Status(ssn=819525886, last_updated=datetime.datetime(2018, 2, 24, 20, 44, 53), created=datetime.datetime(2016, 3, 2, 2, 24, 48))
# Update_Status(ssn=819641414, last_updated=datetime.datetime(2017, 8, 26, 5, 23, 58), created=datetime.datetime(2016, 12, 12, 12, 4, 14))
# Update_Status(ssn=820961105, last_updated=datetime.datetime(2017, 6, 11, 20, 41, 22), created=datetime.datetime(2016, 2, 14, 2, 38, 15))
# Update_Status(ssn=822059037, last_updated=datetime.datetime(2017, 11, 14, 6, 43, 11), created=datetime.datetime(2016, 3, 28, 1, 5, 25))
# Update_Status(ssn=822304861, last_updated=datetime.datetime(2018, 3, 6, 15, 41, 52), created=datetime.datetime(2016, 11, 5, 5, 11, 25))
# Update_Status(ssn=823270762, last_updated=datetime.datetime(2017, 7, 9, 16, 33, 59), created=datetime.datetime(2016, 4, 19, 13, 46, 43))
# Update_Status(ssn=823755753, last_updated=datetime.datetime(2017, 11, 26, 1, 36, 57), created=datetime.datetime(2016, 1, 27, 23, 15, 38))
# Update_Status(ssn=824894169, last_updated=datetime.datetime(2017, 3, 30, 13, 22, 12), created=datetime.datetime(2016, 11, 16, 16, 43, 21))
# Update_Status(ssn=826978029, last_updated=datetime.datetime(2018, 2, 26, 23, 21, 58), created=datetime.datetime(2016, 5, 15, 14, 51, 21))
# Update_Status(ssn=827624599, last_updated=datetime.datetime(2017, 3, 15, 23, 54, 1), created=datetime.datetime(2016, 5, 21, 18, 17, 57))
# Update_Status(ssn=830231573, last_updated=datetime.datetime(2017, 2, 20, 23, 42), created=datetime.datetime(2016, 9, 1, 0, 6, 49))
# Update_Status(ssn=831443286, last_updated=datetime.datetime(2017, 2, 19, 2, 38, 55), created=datetime.datetime(2016, 5, 5, 3, 7, 14))
# Update_Status(ssn=833011428, last_updated=datetime.datetime(2017, 9, 22, 5, 7, 13), created=datetime.datetime(2016, 12, 14, 4, 3, 53))
# Update_Status(ssn=835543785, last_updated=datetime.datetime(2017, 6, 10, 8, 36, 26), created=datetime.datetime(2016, 10, 4, 20, 10, 40))
# Update_Status(ssn=836401837, last_updated=datetime.datetime(2017, 11, 13, 6, 7, 5), created=datetime.datetime(2016, 2, 13, 5, 4, 28))
# Update_Status(ssn=836993309, last_updated=datetime.datetime(2018, 1, 4, 11, 10, 54), created=datetime.datetime(2016, 9, 30, 11, 25, 21))
# Update_Status(ssn=837765619, last_updated=datetime.datetime(2017, 6, 28, 8, 29, 54), created=datetime.datetime(2016, 11, 3, 20, 8, 35))
# Update_Status(ssn=838691351, last_updated=datetime.datetime(2017, 12, 30, 1, 53, 27), created=datetime.datetime(2016, 4, 27, 22, 22, 15))
# Update_Status(ssn=840417929, last_updated=datetime.datetime(2017, 7, 21, 4, 56, 59), created=datetime.datetime(2016, 2, 14, 6, 25, 5))
# Update_Status(ssn=841648517, last_updated=datetime.datetime(2017, 12, 17, 5, 13, 41), created=datetime.datetime(2016, 6, 28, 23, 17, 28))
# Update_Status(ssn=842907557, last_updated=datetime.datetime(2017, 5, 13, 22, 21, 23), created=datetime.datetime(2016, 5, 30, 14, 24, 20))
# Update_Status(ssn=844154668, last_updated=datetime.datetime(2017, 7, 9, 22, 12, 16), created=datetime.datetime(2016, 3, 27, 2, 46, 16))
# Update_Status(ssn=844507305, last_updated=datetime.datetime(2018, 1, 30, 7, 49, 7), created=datetime.datetime(2016, 8, 16, 12, 42, 56))
# Update_Status(ssn=846071407, last_updated=datetime.datetime(2017, 7, 10, 17, 48, 49), created=datetime.datetime(2016, 3, 5, 11, 53, 15))
# Update_Status(ssn=846099851, last_updated=datetime.datetime(2017, 1, 25, 3, 3, 59), created=datetime.datetime(2016, 4, 26, 18, 41, 28))
# Update_Status(ssn=846599961, last_updated=datetime.datetime(2017, 2, 20, 3, 4, 34), created=datetime.datetime(2016, 12, 28, 20, 41, 47))
# Update_Status(ssn=847344817, last_updated=datetime.datetime(2017, 2, 13, 3, 31, 14), created=datetime.datetime(2016, 2, 2, 21, 15, 15))
# Update_Status(ssn=847617656, last_updated=datetime.datetime(2017, 12, 19, 9, 38, 38), created=datetime.datetime(2016, 1, 30, 9, 5, 32))
# Update_Status(ssn=848583386, last_updated=datetime.datetime(2018, 1, 21, 4, 10, 3), created=datetime.datetime(2016, 3, 18, 1, 51, 27))
# Update_Status(ssn=848742886, last_updated=datetime.datetime(2017, 4, 28, 22, 57, 18), created=datetime.datetime(2016, 3, 16, 18, 7, 48))
# Update_Status(ssn=848768808, last_updated=datetime.datetime(2017, 1, 9, 20, 35, 16), created=datetime.datetime(2016, 8, 6, 21, 44, 44))
# Update_Status(ssn=849311551, last_updated=datetime.datetime(2017, 7, 22, 6, 54, 46), created=datetime.datetime(2016, 4, 1, 21, 35, 44))
# Update_Status(ssn=849646624, last_updated=datetime.datetime(2018, 3, 23, 20, 28, 43), created=datetime.datetime(2016, 1, 10, 18, 3, 17))
# Update_Status(ssn=849982973, last_updated=datetime.datetime(2017, 8, 20, 13, 10, 57), created=datetime.datetime(2016, 2, 26, 2, 40, 54))
# Update_Status(ssn=851942162, last_updated=datetime.datetime(2017, 10, 15, 12, 43, 2), created=datetime.datetime(2016, 11, 28, 14, 34, 31))
# Update_Status(ssn=852157707, last_updated=datetime.datetime(2017, 12, 7, 23, 31, 37), created=datetime.datetime(2016, 3, 17, 17, 39, 10))
# Update_Status(ssn=853118953, last_updated=datetime.datetime(2017, 12, 30, 0, 36, 43), created=datetime.datetime(2016, 12, 24, 23, 34, 4))
# Update_Status(ssn=853473648, last_updated=datetime.datetime(2017, 11, 24, 19, 37, 50), created=datetime.datetime(2016, 4, 22, 21, 36, 41))
# Update_Status(ssn=854687635, last_updated=datetime.datetime(2017, 5, 16, 14, 22, 39), created=datetime.datetime(2016, 4, 29, 5, 3, 11))
# Update_Status(ssn=854712983, last_updated=datetime.datetime(2017, 9, 6, 20, 53, 9), created=datetime.datetime(2016, 11, 7, 5, 47, 14))
# Update_Status(ssn=854795334, last_updated=datetime.datetime(2017, 8, 29, 17, 57, 56), created=datetime.datetime(2016, 3, 27, 18, 30, 18))
# Update_Status(ssn=856183980, last_updated=datetime.datetime(2017, 1, 20, 20, 28, 10), created=datetime.datetime(2016, 12, 8, 6, 52, 33))
# Update_Status(ssn=856279112, last_updated=datetime.datetime(2017, 12, 25, 10, 25, 28), created=datetime.datetime(2016, 3, 24, 4, 1, 59))
# Update_Status(ssn=856674080, last_updated=datetime.datetime(2018, 3, 13, 21, 23, 9), created=datetime.datetime(2016, 6, 22, 3, 53, 18))
# Update_Status(ssn=857375902, last_updated=datetime.datetime(2018, 1, 20, 14, 44, 7), created=datetime.datetime(2016, 10, 23, 21, 56, 28))
# Update_Status(ssn=858037735, last_updated=datetime.datetime(2017, 4, 30, 8, 14, 24), created=datetime.datetime(2016, 9, 4, 8, 24, 3))
# Update_Status(ssn=858279190, last_updated=datetime.datetime(2017, 2, 6, 7, 12, 2), created=datetime.datetime(2016, 12, 25, 16, 52, 9))
# Update_Status(ssn=860670256, last_updated=datetime.datetime(2017, 1, 9, 22, 49, 48), created=datetime.datetime(2016, 2, 6, 4, 59, 26))
# Update_Status(ssn=860892570, last_updated=datetime.datetime(2017, 4, 15, 11, 12, 57), created=datetime.datetime(2016, 6, 22, 23, 23, 9))
# Update_Status(ssn=861506716, last_updated=datetime.datetime(2018, 3, 30, 21, 7, 8), created=datetime.datetime(2016, 9, 16, 9, 12, 34))
# Update_Status(ssn=862200653, last_updated=datetime.datetime(2017, 5, 3, 14, 37, 42), created=datetime.datetime(2016, 2, 4, 14, 11, 40))
# Update_Status(ssn=864229364, last_updated=datetime.datetime(2017, 2, 4, 13, 53, 10), created=datetime.datetime(2016, 12, 28, 0, 33, 8))
# Update_Status(ssn=864917489, last_updated=datetime.datetime(2017, 2, 3, 17, 51, 18), created=datetime.datetime(2016, 2, 14, 3, 7, 23))
# Update_Status(ssn=866181440, last_updated=datetime.datetime(2017, 5, 31, 4, 28, 19), created=datetime.datetime(2016, 2, 2, 17, 47, 22))
# Update_Status(ssn=866530625, last_updated=datetime.datetime(2018, 2, 24, 20, 22, 43), created=datetime.datetime(2016, 12, 15, 22, 59, 20))
# Update_Status(ssn=867116007, last_updated=datetime.datetime(2018, 1, 25, 4, 2, 4), created=datetime.datetime(2016, 10, 31, 14, 12, 16))
# Update_Status(ssn=867136844, last_updated=datetime.datetime(2017, 10, 31, 17, 48, 23), created=datetime.datetime(2016, 7, 17, 9, 50, 7))
# Update_Status(ssn=867882360, last_updated=datetime.datetime(2018, 3, 11, 16, 42, 31), created=datetime.datetime(2016, 11, 4, 18, 34, 52))
# Update_Status(ssn=868321805, last_updated=datetime.datetime(2017, 9, 29, 17, 46, 17), created=datetime.datetime(2016, 11, 14, 1, 26, 32))
# Update_Status(ssn=870126609, last_updated=datetime.datetime(2017, 1, 19, 3, 43, 35), created=datetime.datetime(2016, 6, 24, 16, 43, 15))
# Update_Status(ssn=870931121, last_updated=datetime.datetime(2017, 3, 3, 3, 45, 30), created=datetime.datetime(2016, 6, 21, 17, 1, 53))
# Update_Status(ssn=871993191, last_updated=datetime.datetime(2017, 5, 8, 8, 24, 12), created=datetime.datetime(2016, 2, 27, 15, 43, 26))
# Update_Status(ssn=872189267, last_updated=datetime.datetime(2018, 3, 22, 21, 11, 58), created=datetime.datetime(2016, 4, 27, 3, 27, 17))
# Update_Status(ssn=872491288, last_updated=datetime.datetime(2017, 12, 6, 2, 19, 8), created=datetime.datetime(2016, 6, 10, 10, 5, 19))
# Update_Status(ssn=873364733, last_updated=datetime.datetime(2017, 7, 23, 1, 30, 5), created=datetime.datetime(2016, 7, 8, 7, 10, 52))
# Update_Status(ssn=875189454, last_updated=datetime.datetime(2017, 3, 14, 4, 45, 19), created=datetime.datetime(2016, 8, 19, 18, 23, 57))
# Update_Status(ssn=875750495, last_updated=datetime.datetime(2017, 12, 3, 21, 27, 47), created=datetime.datetime(2016, 6, 12, 12, 36, 44))
# Update_Status(ssn=878128265, last_updated=datetime.datetime(2017, 1, 11, 18, 36, 16), created=datetime.datetime(2016, 3, 14, 14, 30, 37))
# Update_Status(ssn=880224449, last_updated=datetime.datetime(2017, 1, 13, 19, 50, 26), created=datetime.datetime(2016, 6, 11, 20, 35, 38))
# Update_Status(ssn=881195974, last_updated=datetime.datetime(2018, 2, 4, 17, 29, 28), created=datetime.datetime(2016, 10, 5, 21, 57, 12))
# Update_Status(ssn=881887308, last_updated=datetime.datetime(2017, 8, 11, 11, 40, 28), created=datetime.datetime(2016, 1, 18, 12, 51))
# Update_Status(ssn=881957180, last_updated=datetime.datetime(2018, 1, 29, 16, 6, 26), created=datetime.datetime(2016, 11, 24, 12, 12, 51))
# Update_Status(ssn=882495290, last_updated=datetime.datetime(2017, 2, 10, 19, 26, 8), created=datetime.datetime(2016, 8, 27, 5, 43, 5))
# Update_Status(ssn=884611852, last_updated=datetime.datetime(2017, 1, 9, 19, 30, 49), created=datetime.datetime(2016, 3, 18, 22, 13, 6))
# Update_Status(ssn=887417878, last_updated=datetime.datetime(2017, 3, 27, 13, 38, 47), created=datetime.datetime(2016, 9, 14, 9, 26, 53))
# Update_Status(ssn=887839002, last_updated=datetime.datetime(2017, 12, 19, 6, 24, 25), created=datetime.datetime(2016, 5, 30, 2, 40, 28))
# Update_Status(ssn=888507008, last_updated=datetime.datetime(2018, 3, 6, 16, 54, 20), created=datetime.datetime(2016, 6, 9, 11, 3, 40))
# Update_Status(ssn=888537684, last_updated=datetime.datetime(2017, 9, 5, 0, 30), created=datetime.datetime(2016, 2, 12, 1, 35, 59))
# Update_Status(ssn=888824928, last_updated=datetime.datetime(2017, 12, 8, 14, 2, 48), created=datetime.datetime(2016, 11, 9, 10, 4, 16))
# Update_Status(ssn=890289962, last_updated=datetime.datetime(2018, 1, 6, 9, 34, 59), created=datetime.datetime(2016, 2, 22, 15, 24, 59))
# Update_Status(ssn=893120901, last_updated=datetime.datetime(2018, 3, 27, 1, 24, 58), created=datetime.datetime(2016, 6, 14, 2, 41, 25))
# Update_Status(ssn=893177318, last_updated=datetime.datetime(2017, 7, 23, 7, 11, 51), created=datetime.datetime(2016, 2, 28, 8, 1, 12))
# Update_Status(ssn=894810628, last_updated=datetime.datetime(2017, 3, 7, 4, 8, 28), created=datetime.datetime(2016, 7, 9, 11, 43, 17))
# Update_Status(ssn=895261658, last_updated=datetime.datetime(2017, 4, 1, 22, 22, 5), created=datetime.datetime(2016, 11, 22, 6, 57, 45))
# Update_Status(ssn=895265515, last_updated=datetime.datetime(2017, 5, 13, 5, 52, 27), created=datetime.datetime(2016, 3, 24, 7, 34, 14))
# Update_Status(ssn=897767070, last_updated=datetime.datetime(2017, 11, 27, 19, 4, 22), created=datetime.datetime(2016, 12, 12, 7, 39, 48))
# Update_Status(ssn=898033165, last_updated=datetime.datetime(2017, 6, 1, 19, 18, 49), created=datetime.datetime(2016, 7, 20, 21, 40, 2))
# Update_Status(ssn=898868860, last_updated=datetime.datetime(2017, 7, 3, 14, 27, 26), created=datetime.datetime(2016, 11, 23, 23, 34, 17))
# Update_Status(ssn=899091766, last_updated=datetime.datetime(2017, 7, 31, 2, 26, 57), created=datetime.datetime(2016, 10, 27, 18, 41, 56))
# Update_Status(ssn=899397179, last_updated=datetime.datetime(2017, 8, 2, 13, 32, 33), created=datetime.datetime(2016, 7, 27, 12, 47, 5))
# Update_Status(ssn=899397378, last_updated=datetime.datetime(2017, 3, 27, 19, 31, 32), created=datetime.datetime(2016, 9, 4, 15, 9, 22))
# Update_Status(ssn=899476116, last_updated=datetime.datetime(2017, 6, 10, 11, 20, 41), created=datetime.datetime(2016, 4, 29, 12, 25, 23))

# %%
personal_info_iter = file_to_iter('personal_info.csv')
vehicles_iter = file_to_iter('vehicles.csv')
employment_iter = file_to_iter('employment.csv')
updated_status_iter = file_to_iter('update_status.csv')

# %%
def single_record(*files):
    file_iters = (file_to_iter(file) for file in files)
    zipped_file_iters = zip(*file_iters)
    for data in zipped_file_iters:
        yield data

# %%
r = single_record('personal_info.csv', 'vehicles.csv', 'employment.csv', 'update_status.csv')

# %%
next(r)
# Out:
# (Personal_Info(ssn=100539824, first_name='Sebastiano', last_name='Tester', gender='Male', language='Icelandic'),
#  Vehicles(ssn=100539824, vehicle_make='Oldsmobile', vehicle_model='Bravada', model_year=1993),
#  Employment(employer='Stiedemann-Bailey', department='Research and Development', employee_id=290890771, ssn=100539824),
#  Update_Status(ssn=100539824, last_updated=datetime.datetime(2017, 10, 7, 0, 14, 42), created=datetime.datetime(2016, 1, 24, 21, 19, 30)))

# %%
next(r)[0]._fields,next(r)[1]._fields,next(r)[2]._fields,next(r)[3]._fields
# Out:
# (('ssn', 'first_name', 'last_name', 'gender', 'language'),
#  ('ssn', 'vehicle_make', 'vehicle_model', 'model_year'),
#  ('employer', 'department', 'employee_id', 'ssn'),
#  ('ssn', 'last_updated', 'created'))

# %%
{*next(r)[0]._fields,*next(r)[1]._fields,*next(r)[2]._fields,*next(r)[3]._fields}
# Out:
# {'created',
#  'department',
#  'employee_id',
#  'employer',
#  'first_name',
#  'gender',
#  'language',
#  'last_name',
#  'last_updated',
#  'model_year',
#  'ssn',
#  'vehicle_make',
#  'vehicle_model'}

# %%
next(r)[0]._asdict(), next(r)[1]._asdict(), next(r)[2]._asdict(), next(r)[3]._asdict()
# Out:
# ({'ssn': 106351938,
#   'first_name': 'Mackenzie',
#   'last_name': 'Nussey',
#   'gender': 'Male',
#   'language': 'Swedish'},
#  {'ssn': 106363293,
#   'vehicle_make': 'Volkswagen',
#   'vehicle_model': 'Touareg',
#   'model_year': 2008},
#  {'employer': 'Lueilwitz LLC',
#   'department': 'Marketing',
#   'employee_id': 339146042,
#   'ssn': 110843641},
#  {'ssn': 111351034,
#   'last_updated': datetime.datetime(2017, 3, 18, 14, 51, 4),
#   'created': datetime.datetime(2016, 8, 21, 7, 36, 17)})

# %%
new = namedtuple('New', (*next(r)[0]._fields,*next(r)[1]._fields,*next(r)[2]._fields,*next(r)[3]._fields),
                 rename = True)

# %%
new
# Out:
# __main__.New

# %%
new(*next(r)[0]._asdict(), *next(r)[1]._asdict(), *next(r)[2]._asdict(), *next(r)[3]._asdict())
# Out:
# New(ssn='ssn', first_name='first_name', last_name='last_name', gender='gender', language='language', _5='ssn', vehicle_make='vehicle_make', vehicle_model='vehicle_model', model_year='model_year', employer='employer', department='department', employee_id='employee_id', _12='ssn', _13='ssn', last_updated='last_updated', created='created')

# %%
def find_fields(files):
    headers = list()
    for file in files:
        with open(file, 'r') as f:
            headers.append(next(f))
    return set(headers)

# %%
def single_record(*files):
    file_iters = (file_to_iter(file) for file in files)
    fields = find_fields(files)
    return fields
    zipped_file_iters = zip(*file_iters)
    Full_Data = namedtuple('Full_Data')
    #for data in zipped_file_iters:
        #yield data

# %%
single_record('personal_info.csv', 'vehicles.csv', 'employment.csv', 'update_status.csv')
# Out:
# {'employer,department,employee_id,ssn\n',
#  'ssn,first_name,last_name,gender,language\n',
#  'ssn,last_updated,created\n',
#  'ssn,vehicle_make,vehicle_model,model_year\n'}

# %%
{**next(r)[0]._asdict(), **next(r)[1]._asdict(), **next(r)[2]._asdict(), **next(r)[3]._asdict()}.keys()
# Out:
# dict_keys(['ssn', 'first_name', 'last_name', 'gender', 'language', 'vehicle_make', 'vehicle_model', 'model_year', 'employer', 'department', 'employee_id', 'last_updated', 'created'])

# %%
help(set)
# Out:
# Help on class set in module builtins:
#
# class set(object)
#  |  set() -> new empty set object
#  |  set(iterable) -> new set object
#  |
#  |  Build an unordered collection of unique elements.
#  |
#  |  Methods defined here:
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __contains__(...)
#  |      x.__contains__(y) <==> y in x.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iand__(self, value, /)
#  |      Return self&=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __ior__(self, value, /)
#  |      Return self|=value.
#  |
#  |  __isub__(self, value, /)
#  |      Return self-=value.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __ixor__(self, value, /)
#  |      Return self^=value.
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __or__(self, value, /)
#  |      Return self|value.
#  |
#  |  __rand__(self, value, /)
#  |      Return value&self.
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __ror__(self, value, /)
#  |      Return value|self.
#  |
#  |  __rsub__(self, value, /)
#  |      Return value-self.
#  |
#  |  __rxor__(self, value, /)
#  |      Return value^self.
#  |
#  |  __sizeof__(...)
#  |      S.__sizeof__() -> size of S in memory, in bytes
#  |
#  |  __sub__(self, value, /)
#  |      Return self-value.
#  |
#  |  __xor__(self, value, /)
#  |      Return self^value.
#  |
#  |  add(...)
#  |      Add an element to a set.
#  |
#  |      This has no effect if the element is already present.
#  |
#  |  clear(...)
#  |      Remove all elements from this set.
#  |
#  |  copy(...)
#  |      Return a shallow copy of a set.
#  |
#  |  difference(...)
#  |      Return the difference of two or more sets as a new set.
#  |
#  |      (i.e. all elements that are in this set but not the others.)
#  |
#  |  difference_update(...)
#  |      Remove all elements of another set from this set.
#  |
#  |  discard(...)
#  |      Remove an element from a set if it is a member.
#  |
#  |      If the element is not a member, do nothing.
#  |
#  |  intersection(...)
#  |      Return the intersection of two sets as a new set.
#  |
#  |      (i.e. all elements that are in both sets.)
#  |
#  |  intersection_update(...)
#  |      Update a set with the intersection of itself and another.
#  |
#  |  isdisjoint(...)
#  |      Return True if two sets have a null intersection.
#  |
#  |  issubset(...)
#  |      Report whether another set contains this set.
#  |
#  |  issuperset(...)
#  |      Report whether this set contains another set.
#  |
#  |  pop(...)
#  |      Remove and return an arbitrary set element.
#  |      Raises KeyError if the set is empty.
#  |
#  |  remove(...)
#  |      Remove an element from a set; it must be a member.
#  |
#  |      If the element is not a member, raise a KeyError.
#  |
#  |  symmetric_difference(...)
#  |      Return the symmetric difference of two sets as a new set.
#  |
#  |      (i.e. all elements that are in exactly one of the sets.)
#  |
#  |  symmetric_difference_update(...)
#  |      Update a set with the symmetric difference of itself and another.
#  |
#  |  union(...)
#  |      Return the union of sets as a new set.
#  |
#  |      (i.e. all elements that are in either set.)
#  |
#  |  update(...)
#  |      Update a set with the union of itself and others.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %% [markdown]
# # Goal 2

# %%
def single_record(*files):
    file_iters = (file_to_iter(file) for file in files)
    zipped_iters = zip(*file_iters)
    data1 = next(zipped_iters)
    data1_dict = { key : value for datum in data1 for key, value in datum._asdict().items()}
    fields =  data1_dict.keys()
    Full_Data = namedtuple('FulL_Data', fields)
    yield Full_Data(**data1_dict)
    for data in zipped_iters:
        yield Full_Data(**{ key:value for datum in data for key, value in datum._asdict().items()})

# %%
data = single_record('personal_info.csv', 'vehicles.csv', 'employment.csv', 'update_status.csv')

# %%
sum(1 for datum in data)
# Out:
# 1000

# %%
help(datetime)
# Out:
# Help on class datetime in module datetime:
#
# class datetime(date)
#  |  datetime(year, month, day[, hour[, minute[, second[, microsecond[,tzinfo]]]]])
#  |
#  |  The year, month and day arguments are required. tzinfo may be None, or an
#  |  instance of a tzinfo subclass. The remaining arguments may be ints.
#  |
#  |  Method resolution order:
#  |      datetime
#  |      date
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __radd__(self, value, /)
#  |      Return value+self.
#  |
#  |  __reduce__(...)
#  |      __reduce__() -> (cls, state)
#  |
#  |  __reduce_ex__(...)
#  |      __reduce_ex__(proto) -> (cls, state)
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __rsub__(self, value, /)
#  |      Return value-self.
#  |
#  |  __str__(self, /)
#  |      Return str(self).
#  |
#  |  __sub__(self, value, /)
#  |      Return self-value.
#  |
#  |  astimezone(...)
#  |      tz -> convert to local time in new timezone tz
#  |
#  |  ctime(...)
#  |      Return ctime() style string.
#  |
#  |  date(...)
#  |      Return date object with same year, month and day.
#  |
#  |  dst(...)
#  |      Return self.tzinfo.dst(self).
#  |
#  |  isoformat(...)
#  |      [sep] -> string in ISO 8601 format, YYYY-MM-DDT[HH[:MM[:SS[.mmm[uuu]]]]][+HH:MM].
#  |      sep is used to separate the year from the time, and defaults to 'T'.
#  |      timespec specifies what components of the time to include (allowed values are 'auto', 'hours', 'minutes', 'seconds', 'milliseconds', and 'microseconds').
#  |
#  |  replace(...)
#  |      Return datetime with new specified fields.
#  |
#  |  time(...)
#  |      Return time object with same time but with tzinfo=None.
#  |
#  |  timestamp(...)
#  |      Return POSIX timestamp as float.
#  |
#  |  timetuple(...)
#  |      Return time tuple, compatible with time.localtime().
#  |
#  |  timetz(...)
#  |      Return time object with same time and tzinfo.
#  |
#  |  tzname(...)
#  |      Return self.tzinfo.tzname(self).
#  |
#  |  utcoffset(...)
#  |      Return self.tzinfo.utcoffset(self).
#  |
#  |  utctimetuple(...)
#  |      Return UTC time tuple, compatible with time.localtime().
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  combine(...) from builtins.type
#  |      date, time -> datetime with same date and time fields
#  |
#  |  fromisoformat(...) from builtins.type
#  |      string -> datetime from datetime.isoformat() output
#  |
#  |  fromtimestamp(...) from builtins.type
#  |      timestamp[, tz] -> tz's local time from POSIX timestamp.
#  |
#  |  now(tz=None) from builtins.type
#  |      Returns new datetime object representing current time local to tz.
#  |
#  |        tz
#  |          Timezone object.
#  |
#  |      If no tz is specified, uses local timezone.
#  |
#  |  strptime(...) from builtins.type
#  |      string, format -> new datetime parsed from a string (like time.strptime()).
#  |
#  |  utcfromtimestamp(...) from builtins.type
#  |      Construct a naive UTC datetime from a POSIX timestamp.
#  |
#  |  utcnow(...) from builtins.type
#  |      Return a new datetime representing UTC day and time.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  fold
#  |
#  |  hour
#  |
#  |  microsecond
#  |
#  |  minute
#  |
#  |  second
#  |
#  |  tzinfo
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  max = datetime.datetime(9999, 12, 31, 23, 59, 59, 999999)
#  |
#  |  min = datetime.datetime(1, 1, 1, 0, 0)
#  |
#  |  resolution = datetime.timedelta(microseconds=1)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from date:
#  |
#  |  __format__(...)
#  |      Formats self with strftime.
#  |
#  |  isocalendar(...)
#  |      Return a 3-tuple containing ISO year, week number, and weekday.
#  |
#  |  isoweekday(...)
#  |      Return the day of the week represented by the date.
#  |      Monday == 1 ... Sunday == 7
#  |
#  |  strftime(...)
#  |      format -> strftime() style string.
#  |
#  |  toordinal(...)
#  |      Return proleptic Gregorian ordinal.  January 1 of year 1 is day 1.
#  |
#  |  weekday(...)
#  |      Return the day of the week represented by the date.
#  |      Monday == 0 ... Sunday == 6
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from date:
#  |
#  |  fromisocalendar(...) from builtins.type
#  |      int, int, int -> Construct a date from the ISO year, week number and weekday.
#  |
#  |      This is the inverse of the date.isocalendar() function
#  |
#  |  fromordinal(...) from builtins.type
#  |      int -> date corresponding to a proleptic Gregorian ordinal.
#  |
#  |  today(...) from builtins.type
#  |      Current date or datetime:  same as self.__class__.fromtimestamp(time.time()).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from date:
#  |
#  |  day
#  |
#  |  month
#  |
#  |  year

# %%
date1 = datetime(2000, 6, 13)

# %%
date1
# Out:
# datetime.datetime(2000, 6, 13, 0, 0)

# %%
date2 = datetime(2004, 9, 10)

# %%
date2
# Out:
# datetime.datetime(2004, 9, 10, 0, 0)

# %%
date1 < date2
# Out:
# True

# %%
date2 < date1
# Out:
# False

# %% [markdown]
# # Goal3

# %%
last_stale_date = datetime(2017, 3, 1)

# %%
data = single_record('personal_info.csv', 'vehicles.csv', 'employment.csv', 'update_status.csv')

# %%
record = filter(lambda data : data.last_updated >= last_stale_date, data)

# %%
sum(1 for _ in record)
# Out:
# 871

# %%
data = single_record('personal_info.csv', 'vehicles.csv', 'employment.csv', 'update_status.csv')

# %%
r = (datum for datum in data if datum.last_updated < last_stale_date)

# %%
for item in r:
    print(item, end='\n\n')
# Out:
# FulL_Data(ssn=101714702, first_name='Cayla', last_name='MacDonagh', gender='Female', language='Lao', vehicle_make='Ford', vehicle_model='Mustang', model_year=1997, employer='Nicolas and Sons', department='Sales', employee_id=416841359, last_updated=datetime.datetime(2017, 1, 23, 11, 23, 17), created=datetime.datetime(2016, 1, 27, 4, 32, 57))
#
# FulL_Data(ssn=117779748, first_name='Lucien', last_name='Smalman', gender='Male', language='Hebrew', vehicle_make='Audi', vehicle_model='S6', model_year=2009, employer='Schmeler and Sons', department='Research and Development', employee_id=623275199, last_updated=datetime.datetime(2017, 2, 18, 23, 9, 25), created=datetime.datetime(2016, 2, 2, 15, 41, 42))
#
# FulL_Data(ssn=123883381, first_name='Christiane', last_name='Hynes', gender='Female', language='Danish', vehicle_make='Ford', vehicle_model='Mustang', model_year=1989, employer='Mueller-Rath', department='Human Resources', employee_id=58069298, last_updated=datetime.datetime(2017, 2, 21, 16, 37, 38), created=datetime.datetime(2016, 1, 30, 23, 42, 36))
#
# FulL_Data(ssn=125079434, first_name='Florella', last_name='Mathevon', gender='Female', language='Armenian', vehicle_make='Lexus', vehicle_model='RX', model_year=2010, employer='Schumm, Schumm and Reichert', department='Engineering', employee_id=733839744, last_updated=datetime.datetime(2017, 2, 7, 14, 36, 31), created=datetime.datetime(2016, 7, 8, 17, 46, 23))
#
# FulL_Data(ssn=127528001, first_name='Wilona', last_name='Noirel', gender='Female', language='Aymara', vehicle_make='Porsche', vehicle_model='Cayenne', model_year=2008, employer='Wolf LLC', department='Engineering', employee_id=538370994, last_updated=datetime.datetime(2017, 1, 12, 9, 42, 31), created=datetime.datetime(2016, 10, 9, 1, 14, 36))
#
# FulL_Data(ssn=128424599, first_name='Neddy', last_name="O'Griffin", gender='Male', language='Croatian', vehicle_make='Chevrolet', vehicle_model='Avalanche 1500', model_year=2006, employer="Kertzmann-O'Hara", department='Sales', employee_id=448015165, last_updated=datetime.datetime(2017, 1, 29, 20, 31, 15), created=datetime.datetime(2016, 7, 13, 9, 52, 36))
#
# FulL_Data(ssn=128604388, first_name='Norton', last_name='Shailer', gender='Male', language='Czech', vehicle_make='Buick', vehicle_model='Skyhawk', model_year=1988, employer='Heidenreich, Bergnaum and Smith', department='Training', employee_id=47204163, last_updated=datetime.datetime(2017, 1, 3, 20, 33, 45), created=datetime.datetime(2016, 3, 18, 11, 18, 14))
#
# FulL_Data(ssn=129670291, first_name='Danella', last_name='Linacre', gender='Female', language='Dzongkha', vehicle_make='Lotus', vehicle_model='Esprit', model_year=1993, employer='Altenwerth-Heidenreich', department='Research and Development', employee_id=583628686, last_updated=datetime.datetime(2017, 2, 11, 10, 18, 21), created=datetime.datetime(2016, 12, 12, 5, 1, 34))
#
# FulL_Data(ssn=132263507, first_name='Shalom', last_name='Arendsen', gender='Male', language='Hindi', vehicle_make='Dodge', vehicle_model='Ramcharger', model_year=1992, employer='Rodriguez LLC', department='Legal', employee_id=657310166, last_updated=datetime.datetime(2017, 1, 19, 7, 33, 37), created=datetime.datetime(2016, 5, 20, 1, 41, 54))
#
# FulL_Data(ssn=134050120, first_name='Simone', last_name='Cruickshanks', gender='Female', language='Filipino', vehicle_make='BMW', vehicle_model='M5', model_year=2006, employer='Donnelly-Crooks', department='Human Resources', employee_id=222943669, last_updated=datetime.datetime(2017, 1, 29, 11, 53, 22), created=datetime.datetime(2016, 8, 3, 4, 54, 40))
#
# FulL_Data(ssn=138885288, first_name='Joletta', last_name='Babcock', gender='Female', language='Burmese', vehicle_make='Mercury', vehicle_model='Monterey', model_year=2004, employer='Mohr, Harvey and Mitchell', department='Legal', employee_id=647550101, last_updated=datetime.datetime(2017, 2, 24, 15, 47, 36), created=datetime.datetime(2016, 1, 4, 9, 37, 53))
#
# FulL_Data(ssn=139048189, first_name='Stirling', last_name='Creak', gender='Male', language='Italian', vehicle_make='Ford', vehicle_model='Escort', model_year=1997, employer='Keeling-Schroeder', department='Engineering', employee_id=822479019, last_updated=datetime.datetime(2017, 2, 16, 21, 23, 10), created=datetime.datetime(2016, 5, 24, 4, 10, 50))
#
# FulL_Data(ssn=145108454, first_name='Donny', last_name='Laba', gender='Male', language='Japanese', vehicle_make='GMC', vehicle_model='Savana 1500', model_year=1999, employer='Murray, Wolff and Little', department='Business Development', employee_id=293578815, last_updated=datetime.datetime(2017, 1, 18, 6, 37, 31), created=datetime.datetime(2016, 4, 25, 21, 45))
#
# FulL_Data(ssn=146813446, first_name='Korry', last_name='Billham', gender='Female', language='Hebrew', vehicle_make='Ford', vehicle_model='Thunderbird', model_year=1988, employer='Kub, Koch and Ratke', department='Marketing', employee_id=727830449, last_updated=datetime.datetime(2017, 1, 18, 8, 40, 14), created=datetime.datetime(2016, 9, 1, 8, 59, 50))
#
# FulL_Data(ssn=148607519, first_name='Jordan', last_name='Readwood', gender='Female', language='Khmer', vehicle_make='Mitsubishi', vehicle_model='RVR', model_year=1992, employer='Hudson-Gerhold', department='Human Resources', employee_id=622244500, last_updated=datetime.datetime(2017, 1, 22, 22, 15, 37), created=datetime.datetime(2016, 4, 29, 8, 42, 29))
#
# FulL_Data(ssn=151700641, first_name='Urbain', last_name='Balint', gender='Male', language='Malagasy', vehicle_make='Ford', vehicle_model='F250', model_year=1999, employer='McLaughlin-Rohan', department='Legal', employee_id=471922172, last_updated=datetime.datetime(2017, 2, 13, 21, 31, 15), created=datetime.datetime(2016, 4, 28, 8, 28, 43))
#
# FulL_Data(ssn=168810838, first_name='Toby', last_name='Pond-Jones', gender='Female', language='Aymara', vehicle_make='Mazda', vehicle_model='Mazda5', model_year=2012, employer='Zemlak LLC', department='Research and Development', employee_id=868667896, last_updated=datetime.datetime(2017, 2, 11, 14, 12, 16), created=datetime.datetime(2016, 9, 19, 20, 5, 7))
#
# FulL_Data(ssn=172897546, first_name='Trude', last_name='Gillson', gender='Female', language='Norwegian', vehicle_make='Mercury', vehicle_model='Cougar', model_year=1969, employer='Schultz, Price and Walsh', department='Business Development', employee_id=696328477, last_updated=datetime.datetime(2017, 1, 25, 2, 11, 6), created=datetime.datetime(2016, 7, 24, 12, 57, 57))
#
# FulL_Data(ssn=174132047, first_name='Rey', last_name='Dallywater', gender='Female', language='Zulu', vehicle_make='Mitsubishi', vehicle_model='L300', model_year=1988, employer='Bode-Zulauf', department='Marketing', employee_id=420021775, last_updated=datetime.datetime(2017, 1, 28, 14, 24, 40), created=datetime.datetime(2016, 1, 12, 16, 53, 59))
#
# FulL_Data(ssn=174353812, first_name='Sayer', last_name='Astling', gender='Male', language='Kyrgyz', vehicle_make='Ford', vehicle_model='Thunderbird', model_year=1972, employer='Windler Group', department='Legal', employee_id=162190623, last_updated=datetime.datetime(2017, 1, 25, 11, 34, 25), created=datetime.datetime(2016, 5, 14, 4, 55, 35))
#
# FulL_Data(ssn=176821359, first_name='Corny', last_name='Rothera', gender='Female', language='Thai', vehicle_make='Toyota', vehicle_model='Celica', model_year=1995, employer='Brown Group', department='Accounting', employee_id=910435820, last_updated=datetime.datetime(2017, 1, 14, 13, 36, 1), created=datetime.datetime(2016, 11, 29, 19, 3, 42))
#
# FulL_Data(ssn=184923560, first_name='Kore', last_name='Eastes', gender='Female', language='Fijian', vehicle_make='Scion', vehicle_model='xD', model_year=2011, employer='Johnston, Leuschke and Stracke', department='Support', employee_id=969321837, last_updated=datetime.datetime(2017, 2, 16, 4, 37, 8), created=datetime.datetime(2016, 7, 26, 19, 25, 30))
#
# FulL_Data(ssn=185500434, first_name='Alexa', last_name='Emblin', gender='Female', language='Quechua', vehicle_make='Suzuki', vehicle_model='X-90', model_year=1998, employer='Nienow-Metz', department='Legal', employee_id=885601438, last_updated=datetime.datetime(2017, 2, 19, 15, 12, 50), created=datetime.datetime(2016, 10, 24, 14, 3, 4))
#
# FulL_Data(ssn=189491458, first_name='Vernen', last_name='Ivanyushkin', gender='Male', language='Quechua', vehicle_make='Volkswagen', vehicle_model='Touareg', model_year=2008, employer='Mann-Stehr', department='Sales', employee_id=829383132, last_updated=datetime.datetime(2017, 2, 12, 16, 15, 44), created=datetime.datetime(2016, 6, 21, 4, 10, 57))
#
# FulL_Data(ssn=192673201, first_name='Edvard', last_name='Cattel', gender='Male', language='Hebrew', vehicle_make='Mitsubishi', vehicle_model='Galant', model_year=1999, employer='Nicolas Group', department='Support', employee_id=752636577, last_updated=datetime.datetime(2017, 1, 19, 20, 59, 49), created=datetime.datetime(2016, 6, 13, 1, 23, 53))
#
# FulL_Data(ssn=194765816, first_name='Jacquelynn', last_name='Shurey', gender='Female', language='Amharic', vehicle_make='Dodge', vehicle_model='Dakota', model_year=2001, employer='Sauer, Mann and Kling', department='Accounting', employee_id=893029716, last_updated=datetime.datetime(2017, 1, 16, 18, 22, 53), created=datetime.datetime(2016, 5, 26, 16, 11, 14))
#
# FulL_Data(ssn=196693796, first_name='Marijo', last_name='Tester', gender='Female', language='Oriya', vehicle_make='Subaru', vehicle_model='Legacy', model_year=2007, employer='Prosacco LLC', department='Business Development', employee_id=536059808, last_updated=datetime.datetime(2017, 1, 23, 2, 41, 20), created=datetime.datetime(2016, 8, 1, 21, 34, 6))
#
# FulL_Data(ssn=198706443, first_name='Judah', last_name='Duggan', gender='Male', language='Macedonian', vehicle_make='Infiniti', vehicle_model='QX', model_year=2005, employer='Mante, Roberts and Miller', department='Research and Development', employee_id=981318396, last_updated=datetime.datetime(2017, 2, 13, 7, 16, 31), created=datetime.datetime(2016, 1, 22, 5, 10, 14))
#
# FulL_Data(ssn=208742166, first_name='Tiebold', last_name='Gherarducci', gender='Male', language='Croatian', vehicle_make='Lexus', vehicle_model='LX', model_year=1999, employer='Feeney Group', department='Product Management', employee_id=848299490, last_updated=datetime.datetime(2017, 1, 24, 9, 46, 24), created=datetime.datetime(2016, 2, 28, 8, 58, 53))
#
# FulL_Data(ssn=212400215, first_name='Giffie', last_name='Strauss', gender='Male', language='Azeri', vehicle_make='Dodge', vehicle_model='Shadow', model_year=1993, employer='Trantow Inc', department='Services', employee_id=965222028, last_updated=datetime.datetime(2017, 2, 1, 18, 11, 47), created=datetime.datetime(2016, 1, 6, 22, 31, 22))
#
# FulL_Data(ssn=216973104, first_name='Elvira', last_name='McDougal', gender='Female', language='Bislama', vehicle_make='Bentley', vehicle_model='Continental Super', model_year=2012, employer='Skiles, Reichel and Romaguera', department='Engineering', employee_id=398820670, last_updated=datetime.datetime(2017, 2, 10, 18, 28, 9), created=datetime.datetime(2016, 9, 6, 8, 20, 10))
#
# FulL_Data(ssn=222398571, first_name='Fidelia', last_name='Domonkos', gender='Female', language='Fijian', vehicle_make='Lexus', vehicle_model='LX', model_year=2005, employer='Bernier, Ruecker and Carroll', department='Services', employee_id=690108218, last_updated=datetime.datetime(2017, 2, 3, 23, 45, 13), created=datetime.datetime(2016, 10, 4, 0, 52, 58))
#
# FulL_Data(ssn=224546919, first_name='Kelly', last_name='Shipman', gender='Male', language='Icelandic', vehicle_make='Mercedes-Benz', vehicle_model='SL-Class', model_year=1990, employer='Ziemann-Lowe', department='Sales', employee_id=730391148, last_updated=datetime.datetime(2017, 2, 11, 17, 13, 36), created=datetime.datetime(2016, 1, 30, 9, 3, 19))
#
# FulL_Data(ssn=228552042, first_name='Jaquith', last_name='Durtnel', gender='Female', language='Czech', vehicle_make='Ford', vehicle_model='Mustang', model_year=1993, employer='Batz-Bahringer', department='Research and Development', employee_id=741907423, last_updated=datetime.datetime(2017, 1, 17, 20, 5, 40), created=datetime.datetime(2016, 3, 8, 17, 42, 55))
#
# FulL_Data(ssn=236318333, first_name='Wendeline', last_name='Millins', gender='Female', language='Kashmiri', vehicle_make='Mazda', vehicle_model='B-Series', model_year=1997, employer='Zboncak and Sons', department='Product Management', employee_id=853010287, last_updated=datetime.datetime(2017, 1, 3, 13, 2, 1), created=datetime.datetime(2016, 1, 16, 12, 51, 28))
#
# FulL_Data(ssn=237486737, first_name='Eal', last_name='Ducastel', gender='Male', language='Indonesian', vehicle_make='Maserati', vehicle_model='GranSport', model_year=2006, employer='Kuhlman Group', department='Accounting', employee_id=853357304, last_updated=datetime.datetime(2017, 1, 22, 14, 20, 20), created=datetime.datetime(2016, 10, 19, 13, 28, 28))
#
# FulL_Data(ssn=240088805, first_name='Gates', last_name='McGiffin', gender='Female', language='Finnish', vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1988, employer='Mraz, Veum and Farrell', department='Product Management', employee_id=306285659, last_updated=datetime.datetime(2017, 2, 10, 12, 14, 31), created=datetime.datetime(2016, 8, 15, 20, 52, 10))
#
# FulL_Data(ssn=255810958, first_name='Darryl', last_name='Sparkes', gender='Female', language='Estonian', vehicle_make='Plymouth', vehicle_model='Colt', model_year=1992, employer='Aufderhar, Quigley and Wiza', department='Research and Development', employee_id=879571848, last_updated=datetime.datetime(2017, 1, 14, 1, 34, 12), created=datetime.datetime(2016, 9, 9, 15, 46, 19))
#
# FulL_Data(ssn=261149490, first_name='Lorry', last_name='Boshere', gender='Male', language='Oriya', vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2006, employer='Boyle, Rutherford and Parisian', department='Legal', employee_id=368081521, last_updated=datetime.datetime(2017, 1, 26, 12, 19, 19), created=datetime.datetime(2016, 4, 23, 9, 0, 56))
#
# FulL_Data(ssn=267756383, first_name='Ardath', last_name='Pitts', gender='Female', language='Romanian', vehicle_make='Ford', vehicle_model='Courier', model_year=1989, employer='Gottlieb, Gleichner and Kihn', department='Services', employee_id=421073885, last_updated=datetime.datetime(2017, 1, 18, 3, 2, 58), created=datetime.datetime(2016, 5, 12, 18, 5, 24))
#
# FulL_Data(ssn=271819938, first_name='James', last_name='Robbins', gender='Male', language='Bengali', vehicle_make='Aston Martin', vehicle_model='V8 Vantage', model_year=2008, employer='Feeney Inc', department='Sales', employee_id=949045161, last_updated=datetime.datetime(2017, 1, 29, 1, 31, 37), created=datetime.datetime(2016, 8, 16, 6, 47, 48))
#
# FulL_Data(ssn=271933051, first_name='Augustin', last_name='Agiolfinger', gender='Male', language='Latvian', vehicle_make='Lexus', vehicle_model='IS-F', model_year=2012, employer='Marks-McKenzie', department='Engineering', employee_id=62333892, last_updated=datetime.datetime(2017, 2, 18, 16, 44, 2), created=datetime.datetime(2016, 6, 8, 11, 36, 44))
#
# FulL_Data(ssn=295637693, first_name='Fonzie', last_name='Fattorini', gender='Male', language='Estonian', vehicle_make='Mazda', vehicle_model='Miata MX-5', model_year=2010, employer='Heidenreich Group', department='Accounting', employee_id=791848443, last_updated=datetime.datetime(2017, 2, 28, 11, 27, 31), created=datetime.datetime(2016, 1, 7, 4, 36, 56))
#
# FulL_Data(ssn=299036911, first_name='Janela', last_name='Ferrone', gender='Female', language='Gagauz', vehicle_make='Dodge', vehicle_model='Viper RT/10', model_year=1994, employer='Kilback Group', department='Services', employee_id=25391126, last_updated=datetime.datetime(2017, 1, 19, 3, 33, 50), created=datetime.datetime(2016, 3, 7, 15, 33, 32))
#
# FulL_Data(ssn=326649957, first_name='Jorgan', last_name='Renowden', gender='Male', language='Swati', vehicle_make='Audi', vehicle_model='RS4', model_year=2008, employer='Heathcote, Gerhold and Kuhlman', department='Services', employee_id=607003804, last_updated=datetime.datetime(2017, 1, 28, 20, 25, 31), created=datetime.datetime(2016, 5, 21, 4, 5, 26))
#
# FulL_Data(ssn=335351520, first_name='Ervin', last_name='Hugues', gender='Male', language='Armenian', vehicle_make='Lincoln', vehicle_model='Town Car', model_year=1984, employer='Berge-Schimmel', department='Business Development', employee_id=277571787, last_updated=datetime.datetime(2017, 1, 29, 15, 44, 57), created=datetime.datetime(2016, 11, 26, 7, 21, 10))
#
# FulL_Data(ssn=358847049, first_name='Emalee', last_name='McCleary', gender='Female', language='Thai', vehicle_make='Dodge', vehicle_model='Dakota Club', model_year=2007, employer='Kuhn LLC', department='Research and Development', employee_id=127386844, last_updated=datetime.datetime(2017, 2, 9, 7, 24, 45), created=datetime.datetime(2016, 2, 21, 0, 13, 44))
#
# FulL_Data(ssn=362098563, first_name='Carri', last_name='Peterffy', gender='Female', language='Icelandic', vehicle_make='Toyota', vehicle_model='Paseo', model_year=1995, employer='Kautzer and Sons', department='Research and Development', employee_id=560050837, last_updated=datetime.datetime(2017, 2, 7, 23, 59, 48), created=datetime.datetime(2016, 7, 4, 3, 26, 36))
#
# FulL_Data(ssn=370016977, first_name='Hugues', last_name='Jeffryes', gender='Male', language='Georgian', vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=2002, employer='Stark-White', department='Support', employee_id=619710930, last_updated=datetime.datetime(2017, 1, 16, 16, 48, 28), created=datetime.datetime(2016, 6, 17, 10, 50, 49))
#
# FulL_Data(ssn=378080805, first_name='Carroll', last_name='Harty', gender='Female', language='Swedish', vehicle_make='Volvo', vehicle_model='S40', model_year=2010, employer='Reynolds, Stroman and Pagac', department='Marketing', employee_id=810595624, last_updated=datetime.datetime(2017, 1, 15, 7, 10, 9), created=datetime.datetime(2016, 9, 4, 16, 17, 45))
#
# FulL_Data(ssn=380353854, first_name='Cathleen', last_name='Sizland', gender='Female', language='Bislama', vehicle_make='Honda', vehicle_model='Passport', model_year=1994, employer='Larkin, Bode and Moen', department='Services', employee_id=721163753, last_updated=datetime.datetime(2017, 2, 17, 21, 55, 47), created=datetime.datetime(2016, 7, 31, 20, 6, 38))
#
# FulL_Data(ssn=384306793, first_name='Kipp', last_name='Burnyate', gender='Male', language='English', vehicle_make='Suzuki', vehicle_model='Grand Vitara', model_year=2012, employer='Metz, Reynolds and Jerde', department='Sales', employee_id=280030219, last_updated=datetime.datetime(2017, 2, 13, 1, 25, 17), created=datetime.datetime(2016, 6, 1, 20, 11, 29))
#
# FulL_Data(ssn=385980431, first_name='Kassi', last_name='Rashleigh', gender='Female', language='Tswana', vehicle_make='Rolls-Royce', vehicle_model='Phantom', model_year=2011, employer='Upton, Boehm and Kemmer', department='Product Management', employee_id=828364397, last_updated=datetime.datetime(2017, 1, 10, 17, 0, 26), created=datetime.datetime(2016, 12, 25, 11, 6, 50))
#
# FulL_Data(ssn=390743062, first_name='Cara', last_name='Ingree', gender='Female', language='Indonesian', vehicle_make='Audi', vehicle_model='TT', model_year=2002, employer='Bechtelar-McCullough', department='Sales', employee_id=11786654, last_updated=datetime.datetime(2017, 1, 1, 12, 23, 41), created=datetime.datetime(2016, 11, 14, 16, 22, 16))
# FulL_Data(ssn=397878282, first_name='Kyrstin', last_name='Waldock', gender='Female', language='Belarusian', vehicle_make='Chevrolet', vehicle_model='Blazer', model_year=1998, employer='Jones Inc', department='Sales', employee_id=482299282, last_updated=datetime.datetime(2017, 1, 25, 21, 15, 13), created=datetime.datetime(2016, 6, 24, 8, 10, 55))
#
# FulL_Data(ssn=411434217, first_name='Cull', last_name='Noddle', gender='Male', language='Spanish', vehicle_make='Buick', vehicle_model='Century', model_year=1986, employer='Senger, Schuppe and Mueller', department='Marketing', employee_id=270379629, last_updated=datetime.datetime(2017, 2, 19, 23, 2, 59), created=datetime.datetime(2016, 9, 20, 2, 3, 16))
#
# FulL_Data(ssn=412590452, first_name='Seamus', last_name='Petrusch', gender='Male', language='Spanish', vehicle_make='Honda', vehicle_model='Prelude', model_year=1985, employer='VonRueden, Zboncak and Erdman', department='Legal', employee_id=624306075, last_updated=datetime.datetime(2017, 1, 3, 2, 43, 34), created=datetime.datetime(2016, 6, 25, 1, 41, 3))
#
# FulL_Data(ssn=420467789, first_name='Steffie', last_name='Britto', gender='Female', language='New Zealand Sign Language', vehicle_make='Chevrolet', vehicle_model='Express 2500', model_year=2005, employer='Schroeder LLC', department='Engineering', employee_id=657085477, last_updated=datetime.datetime(2017, 1, 25, 20, 25, 19), created=datetime.datetime(2016, 8, 24, 14, 54, 22))
#
# FulL_Data(ssn=422674000, first_name='Corby', last_name='Boyington', gender='Male', language='Sotho', vehicle_make='Acura', vehicle_model='MDX', model_year=2008, employer='Halvorson, Hammes and Jerde', department='Training', employee_id=946937073, last_updated=datetime.datetime(2017, 1, 17, 5, 4, 19), created=datetime.datetime(2016, 4, 22, 0, 21, 3))
#
# FulL_Data(ssn=426334523, first_name='Bibbie', last_name='Lardge', gender='Female', language='Spanish', vehicle_make='Chrysler', vehicle_model='Town & Country', model_year=2001, employer='Sporer Inc', department='Legal', employee_id=432632272, last_updated=datetime.datetime(2017, 2, 13, 11, 48, 3), created=datetime.datetime(2016, 10, 13, 14, 8, 2))
#
# FulL_Data(ssn=427124625, first_name='Ethelin', last_name='Huck', gender='Female', language='Bosnian', vehicle_make='Mercury', vehicle_model='Cougar', model_year=1989, employer='Franecki-Block', department='Marketing', employee_id=983531089, last_updated=datetime.datetime(2017, 1, 20, 11, 24, 18), created=datetime.datetime(2016, 4, 16, 3, 42, 23))
#
# FulL_Data(ssn=427966355, first_name='Fidel', last_name='Gutierrez', gender='Male', language='Yiddish', vehicle_make='Maserati', vehicle_model='Spyder', model_year=2002, employer='Casper, Ward and Gleason', department='Marketing', employee_id=75724630, last_updated=datetime.datetime(2017, 2, 5, 10, 0, 57), created=datetime.datetime(2016, 3, 26, 14, 44, 8))
#
# FulL_Data(ssn=430276236, first_name='Sergent', last_name='Tomich', gender='Male', language='Tajik', vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2008, employer='Rutherford-McCullough', department='Support', employee_id=360554843, last_updated=datetime.datetime(2017, 1, 22, 19, 48, 31), created=datetime.datetime(2016, 3, 31, 17, 41, 32))
#
# FulL_Data(ssn=438821280, first_name='Salvatore', last_name='Noirel', gender='Male', language='Somali', vehicle_make='Cadillac', vehicle_model='XLR', model_year=2009, employer='Bartell Inc', department='Support', employee_id=662492097, last_updated=datetime.datetime(2017, 1, 25, 7, 27, 19), created=datetime.datetime(2016, 3, 4, 4, 21, 54))
#
# FulL_Data(ssn=445623843, first_name='Forest', last_name='MacAughtrie', gender='Male', language='Irish Gaelic', vehicle_make='Hummer', vehicle_model='H1', model_year=1994, employer='Mohr, Hilll and Bechtelar', department='Support', employee_id=287153034, last_updated=datetime.datetime(2017, 1, 13, 18, 31, 14), created=datetime.datetime(2016, 10, 16, 16, 44, 53))
#
# FulL_Data(ssn=450567231, first_name='Xavier', last_name='Garnar', gender='Male', language='Danish', vehicle_make='Ford', vehicle_model='Freestyle', model_year=2005, employer='Frami and Sons', department='Product Management', employee_id=297672381, last_updated=datetime.datetime(2017, 2, 23, 22, 8, 8), created=datetime.datetime(2016, 10, 19, 19, 51, 48))
#
# FulL_Data(ssn=455674513, first_name='Zedekiah', last_name='Cayzer', gender='Male', language='Quechua', vehicle_make='Mercedes-Benz', vehicle_model='SLK-Class', model_year=2000, employer='Lesch-Lubowitz', department='Support', employee_id=91746419, last_updated=datetime.datetime(2017, 2, 11, 20, 36), created=datetime.datetime(2016, 10, 13, 16, 32, 4))
#
# FulL_Data(ssn=459297955, first_name='Buddy', last_name='Titmus', gender='Male', language='Gujarati', vehicle_make='Infiniti', vehicle_model='G', model_year=2007, employer='Schowalter, Zemlak and Reinger', department='Engineering', employee_id=310951657, last_updated=datetime.datetime(2017, 2, 20, 1, 40, 33), created=datetime.datetime(2016, 1, 30, 15, 41, 29))
#
# FulL_Data(ssn=460650321, first_name='Katine', last_name='Rosenstiel', gender='Female', language='Macedonian', vehicle_make='Subaru', vehicle_model='Impreza', model_year=2006, employer='Ebert-Davis', department='Human Resources', employee_id=757860653, last_updated=datetime.datetime(2017, 1, 21, 12, 2, 3), created=datetime.datetime(2016, 5, 24, 10, 31, 27))
#
# FulL_Data(ssn=468886064, first_name='Dante', last_name='Puddicombe', gender='Male', language='Nepali', vehicle_make='Suzuki', vehicle_model='Equator', model_year=2012, employer='Auer-Kiehn', department='Accounting', employee_id=83656779, last_updated=datetime.datetime(2017, 2, 15, 8, 15, 23), created=datetime.datetime(2016, 7, 17, 16, 40, 15))
#
# FulL_Data(ssn=470947669, first_name='Julio', last_name='Lune', gender='Male', language='Assamese', vehicle_make='Chevrolet', vehicle_model='Express 1500', model_year=2002, employer='Little, Olson and Towne', department='Sales', employee_id=347928148, last_updated=datetime.datetime(2017, 1, 9, 13, 30, 21), created=datetime.datetime(2016, 9, 29, 21, 11, 35))
#
# FulL_Data(ssn=476688276, first_name='Geoffrey', last_name='Whisker', gender='Male', language='Czech', vehicle_make='Porsche', vehicle_model='928', model_year=1994, employer='Mante LLC', department='Accounting', employee_id=971193479, last_updated=datetime.datetime(2017, 2, 13, 16, 0, 40), created=datetime.datetime(2016, 9, 5, 15, 34, 54))
#
# FulL_Data(ssn=477300077, first_name='Giulio', last_name='Bilsland', gender='Male', language='Macedonian', vehicle_make='Chevrolet', vehicle_model='G-Series G20', model_year=1995, employer='Goldner, Wunsch and Batz', department='Accounting', employee_id=182982615, last_updated=datetime.datetime(2017, 2, 1, 11, 36, 17), created=datetime.datetime(2016, 6, 24, 6, 45, 29))
#
# FulL_Data(ssn=479498804, first_name='Serene', last_name='Giannotti', gender='Female', language='Latvian', vehicle_make='Smart', vehicle_model='Fortwo', model_year=2008, employer='Mueller and Sons', department='Accounting', employee_id=56804255, last_updated=datetime.datetime(2017, 1, 21, 6, 1, 32), created=datetime.datetime(2016, 11, 18, 19, 32, 59))
#
# FulL_Data(ssn=480534039, first_name='Reg', last_name='Waskett', gender='Male', language='Chinese', vehicle_make='Chevrolet', vehicle_model='Express 3500', model_year=2010, employer='Morissette, Hodkiewicz and Cruickshank', department='Research and Development', employee_id=960328224, last_updated=datetime.datetime(2017, 2, 22, 18, 6, 16), created=datetime.datetime(2016, 11, 15, 19, 25, 39))
#
# FulL_Data(ssn=481873503, first_name='Delano', last_name='Mitchall', gender='Male', language='Northern Sotho', vehicle_make='Pontiac', vehicle_model='Grand Prix', model_year=1994, employer='Cole, Deckow and Schiller', department='Engineering', employee_id=64130016, last_updated=datetime.datetime(2017, 2, 10, 0, 39, 18), created=datetime.datetime(2016, 11, 8, 22, 52, 19))
#
# FulL_Data(ssn=491894895, first_name='Orv', last_name='Kelland', gender='Male', language='Belarusian', vehicle_make='Oldsmobile', vehicle_model='Cutlass Supreme', model_year=1993, employer='Lang LLC', department='Training', employee_id=881654825, last_updated=datetime.datetime(2017, 2, 23, 13, 35, 45), created=datetime.datetime(2016, 12, 30, 13, 11, 12))
#
# FulL_Data(ssn=497695399, first_name='Wanids', last_name='Bengoechea', gender='Female', language='German', vehicle_make='Toyota', vehicle_model='Prius', model_year=2009, employer='Grant Group', department='Business Development', employee_id=54747935, last_updated=datetime.datetime(2017, 2, 20, 4, 42, 30), created=datetime.datetime(2016, 1, 18, 5, 30, 53))
#
# FulL_Data(ssn=499427583, first_name='Rafaellle', last_name='Caush', gender='Male', language='Kashmiri', vehicle_make='Rolls-Royce', vehicle_model='Phantom', model_year=2009, employer='Schamberger Inc', department='Engineering', employee_id=540211778, last_updated=datetime.datetime(2017, 2, 7, 13, 22, 7), created=datetime.datetime(2016, 10, 13, 12, 17, 20))
#
# FulL_Data(ssn=499442439, first_name='Ediva', last_name='Flucks', gender='Female', language='French', vehicle_make='Ford', vehicle_model='F250', model_year=2001, employer='Bernier Inc', department='Product Management', employee_id=632531739, last_updated=datetime.datetime(2017, 1, 14, 6, 0, 18), created=datetime.datetime(2016, 8, 18, 13, 2, 28))
#
# FulL_Data(ssn=505371520, first_name='Adams', last_name='Watford', gender='Male', language='Azeri', vehicle_make='Kia', vehicle_model='Sephia', model_year=1996, employer='Sanford and Sons', department='Business Development', employee_id=594571753, last_updated=datetime.datetime(2017, 1, 7, 15, 46, 57), created=datetime.datetime(2016, 8, 8, 3, 35, 14))
#
# FulL_Data(ssn=509464927, first_name='Nickie', last_name='Dabes', gender='Female', language='Sotho', vehicle_make='Acura', vehicle_model='TL', model_year=2002, employer='Lemke, Schinner and Schaefer', department='Training', employee_id=86600485, last_updated=datetime.datetime(2017, 2, 11, 13, 16, 34), created=datetime.datetime(2016, 4, 1, 5, 21, 28))
#
# FulL_Data(ssn=523913280, first_name='Gordie', last_name='Billin', gender='Male', language='Swati', vehicle_make='Jaguar', vehicle_model='X-Type', model_year=2007, employer="Spinka, Lueilwitz and D'Amore", department='Research and Development', employee_id=760505788, last_updated=datetime.datetime(2017, 2, 27, 10, 20, 16), created=datetime.datetime(2016, 3, 26, 23, 24, 45))
#
# FulL_Data(ssn=527723566, first_name='Colin', last_name='Paddington', gender='Male', language='Pashto', vehicle_make='GMC', vehicle_model='Jimmy', model_year=1992, employer='Fritsch, Hammes and Treutel', department='Legal', employee_id=237507091, last_updated=datetime.datetime(2017, 2, 27, 21, 21, 23), created=datetime.datetime(2016, 6, 11, 17, 0, 6))
#
# FulL_Data(ssn=532364145, first_name='Dorry', last_name='Ditty', gender='Female', language='Kannada', vehicle_make='Toyota', vehicle_model='Tundra', model_year=2009, employer='Brekke, Graham and Hilll', department='Product Management', employee_id=988943921, last_updated=datetime.datetime(2017, 2, 12, 2, 37, 42), created=datetime.datetime(2016, 3, 25, 18, 33, 23))
#
# FulL_Data(ssn=534868290, first_name='Ester', last_name='Jepson', gender='Female', language='Albanian', vehicle_make='Jeep', vehicle_model='Grand Cherokee', model_year=2000, employer='Fay, Mayert and Howe', department='Services', employee_id=104744999, last_updated=datetime.datetime(2017, 2, 13, 19, 32, 45), created=datetime.datetime(2016, 7, 5, 3, 37, 45))
#
# FulL_Data(ssn=543387657, first_name='Kaja', last_name='Divisek', gender='Female', language='Estonian', vehicle_make='Lotus', vehicle_model='Esprit', model_year=2004, employer='Erdman-Kulas', department='Marketing', employee_id=393672759, last_updated=datetime.datetime(2017, 1, 10, 10, 45, 24), created=datetime.datetime(2016, 2, 2, 7, 3, 33))
#
# FulL_Data(ssn=553772419, first_name='Ray', last_name='Warrick', gender='Male', language='Amharic', vehicle_make='Chevrolet', vehicle_model='Silverado', model_year=2008, employer='Heller-Mueller', department='Legal', employee_id=263330397, last_updated=datetime.datetime(2017, 2, 1, 16, 22, 38), created=datetime.datetime(2016, 10, 28, 18, 26, 42))
#
# FulL_Data(ssn=564899688, first_name='Karoly', last_name='Collen', gender='Female', language='Albanian', vehicle_make='Mercury', vehicle_model='Grand Marquis', model_year=2009, employer='Conroy and Sons', department='Sales', employee_id=661939780, last_updated=datetime.datetime(2017, 2, 14, 23, 54, 33), created=datetime.datetime(2016, 3, 31, 2, 45, 10))
#
# FulL_Data(ssn=566620141, first_name='Tiffanie', last_name='McNamee', gender='Female', language='Polish', vehicle_make='Honda', vehicle_model='S2000', model_year=2005, employer='Rau, Jakubowski and Crona', department='Accounting', employee_id=46247743, last_updated=datetime.datetime(2017, 2, 18, 7, 17, 52), created=datetime.datetime(2016, 1, 11, 4, 58, 23))
#
# FulL_Data(ssn=570015640, first_name='Nickolas', last_name='Crosdill', gender='Male', language='Tetum', vehicle_make='Volkswagen', vehicle_model='GTI', model_year=1986, employer='Stroman Group', department='Product Management', employee_id=901208918, last_updated=datetime.datetime(2017, 1, 3, 3, 11, 19), created=datetime.datetime(2016, 5, 26, 7, 27, 46))
#
# FulL_Data(ssn=599693085, first_name='Luz', last_name='Jeffcoate', gender='Female', language='Kyrgyz', vehicle_make='Lamborghini', vehicle_model='Gallardo', model_year=2012, employer='Rau, Hegmann and Yundt', department='Product Management', employee_id=308311767, last_updated=datetime.datetime(2017, 1, 5, 11, 40, 43), created=datetime.datetime(2016, 5, 8, 7, 18, 12))
#
# FulL_Data(ssn=605267064, first_name='Howey', last_name='Acome', gender='Male', language='Finnish', vehicle_make='Cadillac', vehicle_model='Eldorado', model_year=2002, employer='Rice, Lakin and Bernier', department='Human Resources', employee_id=870668803, last_updated=datetime.datetime(2017, 1, 4, 0, 53, 36), created=datetime.datetime(2016, 3, 1, 9, 3, 8))
#
# FulL_Data(ssn=629919506, first_name='Dionysus', last_name='Twentyman', gender='Male', language='Indonesian', vehicle_make='GMC', vehicle_model='Savana 2500', model_year=2007, employer='Schumm-Cormier', department='Marketing', employee_id=179714426, last_updated=datetime.datetime(2017, 2, 7, 18, 7, 51), created=datetime.datetime(2016, 6, 19, 17, 17, 28))
#
# FulL_Data(ssn=631449168, first_name='Brooks', last_name='Edridge', gender='Male', language='Kazakh', vehicle_make='Mercury', vehicle_model='Grand Marquis', model_year=1996, employer='Ratke Group', department='Training', employee_id=240238488, last_updated=datetime.datetime(2017, 1, 29, 16, 20, 7), created=datetime.datetime(2016, 3, 6, 8, 30, 58))
#
# FulL_Data(ssn=634428798, first_name='Tomasine', last_name='Dron', gender='Female', language='English', vehicle_make='Volvo', vehicle_model='S40', model_year=2004, employer='Schowalter and Sons', department='Human Resources', employee_id=599431329, last_updated=datetime.datetime(2017, 1, 20, 7, 0, 33), created=datetime.datetime(2016, 8, 7, 10, 51, 44))
#
# FulL_Data(ssn=644708292, first_name='Glyn', last_name='Mc Giffin', gender='Female', language='Zulu', vehicle_make='Chevrolet', vehicle_model='Classic', model_year=2004, employer='Parisian, Kutch and Boyle', department='Services', employee_id=656774148, last_updated=datetime.datetime(2017, 1, 2, 0, 10, 46), created=datetime.datetime(2016, 3, 24, 13, 39, 53))
#
# FulL_Data(ssn=646696845, first_name='Joe', last_name='Mabee', gender='Male', language='Fijian', vehicle_make='Hyundai', vehicle_model='Scoupe', model_year=1993, employer='Ankunding, Hintz and Kling', department='Legal', employee_id=717182616, last_updated=datetime.datetime(2017, 2, 25, 7, 48, 17), created=datetime.datetime(2016, 2, 29, 8, 32, 23))
#
# FulL_Data(ssn=669129323, first_name='Peter', last_name='Ketteman', gender='Male', language='Hiri Motu', vehicle_make='Hyundai', vehicle_model='Sonata', model_year=2004, employer='Stark-Runte', department='Support', employee_id=626777890, last_updated=datetime.datetime(2017, 1, 2, 17, 34, 7), created=datetime.datetime(2016, 11, 19, 23, 7, 4))
#
# FulL_Data(ssn=671719470, first_name='Billie', last_name='Spittal', gender='Female', language='Catalan', vehicle_make='Porsche', vehicle_model='924 S', model_year=1987, employer='Wuckert Inc', department='Accounting', employee_id=646834709, last_updated=datetime.datetime(2017, 1, 15, 5, 30, 49), created=datetime.datetime(2016, 2, 24, 17, 39, 32))
#
# FulL_Data(ssn=687275241, first_name='Hildegarde', last_name='Crosoer', gender='Female', language='Marathi', vehicle_make='Acura', vehicle_model='TSX', model_year=2011, employer='Klocko LLC', department='Human Resources', employee_id=306205049, last_updated=datetime.datetime(2017, 2, 14, 9, 45, 31), created=datetime.datetime(2016, 10, 29, 23, 44, 20))
#
# FulL_Data(ssn=701068590, first_name='Ralf', last_name='Aliman', gender='Male', language='Aymara', vehicle_make='Toyota', vehicle_model='Tercel', model_year=1994, employer='Jones Inc', department='Engineering', employee_id=38745406, last_updated=datetime.datetime(2017, 2, 28, 13, 36, 13), created=datetime.datetime(2016, 10, 6, 8, 31, 58))
#
# FulL_Data(ssn=709736600, first_name='Stillman', last_name='Fairbrass', gender='Male', language='German', vehicle_make='Buick', vehicle_model='Rendezvous', model_year=2005, employer='Swaniawski-Goodwin', department='Training', employee_id=376864505, last_updated=datetime.datetime(2017, 2, 13, 9, 25, 57), created=datetime.datetime(2016, 6, 11, 5, 51, 57))
#
# FulL_Data(ssn=722649283, first_name='Dionisio', last_name='Peddar', gender='Male', language='Kazakh', vehicle_make='Mercedes-Benz', vehicle_model='300TE', model_year=1993, employer='Kub Group', department='Legal', employee_id=939415580, last_updated=datetime.datetime(2017, 1, 10, 3, 41, 51), created=datetime.datetime(2016, 2, 6, 23, 9, 16))
#
# FulL_Data(ssn=727486769, first_name='Ervin', last_name='Duncklee', gender='Male', language='Zulu', vehicle_make='Audi', vehicle_model='S4', model_year=2009, employer='Dickens Group', department='Training', employee_id=352878417, last_updated=datetime.datetime(2017, 1, 25, 10, 45, 49), created=datetime.datetime(2016, 1, 17, 15, 4, 5))
#
# FulL_Data(ssn=733785243, first_name='Gallard', last_name='Schapiro', gender='Male', language='Albanian', vehicle_make='Lincoln', vehicle_model='MKX', model_year=2010, employer='Hills-Pagac', department='Legal', employee_id=618685762, last_updated=datetime.datetime(2017, 2, 17, 10, 18, 1), created=datetime.datetime(2016, 11, 15, 6, 29))
#
# FulL_Data(ssn=754289729, first_name='Grata', last_name='Jiroudek', gender='Female', language='Aymara', vehicle_make='Mercedes-Benz', vehicle_model='190E', model_year=1992, employer='Auer Group', department='Human Resources', employee_id=964407720, last_updated=datetime.datetime(2017, 1, 26, 1, 29, 36), created=datetime.datetime(2016, 11, 26, 20, 1, 18))
#
# FulL_Data(ssn=755084000, first_name='Domenic', last_name='Symes', gender='Male', language='Italian', vehicle_make='Acura', vehicle_model='CL', model_year=1999, employer='Padberg, Lowe and Beer', department='Accounting', employee_id=447633504, last_updated=datetime.datetime(2017, 2, 9, 9, 44), created=datetime.datetime(2016, 4, 22, 18, 6, 55))
#
# FulL_Data(ssn=763091587, first_name='Yasmeen', last_name='Vaskin', gender='Female', language='Lithuanian', vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1995, employer='Sporer Group', department='Training', employee_id=470369978, last_updated=datetime.datetime(2017, 1, 22, 12, 35, 38), created=datetime.datetime(2016, 11, 24, 19, 46, 6))
#
# FulL_Data(ssn=778748262, first_name='Sonia', last_name='Grishakin', gender='Female', language='Bulgarian', vehicle_make='Chevrolet', vehicle_model='Sportvan G30', model_year=1993, employer='Anderson, Dickinson and Toy', department='Marketing', employee_id=468501105, last_updated=datetime.datetime(2017, 2, 5, 11, 21, 48), created=datetime.datetime(2016, 8, 7, 11, 55, 4))
#
# FulL_Data(ssn=787107877, first_name='Torrence', last_name='Tapping', gender='Male', language='Hiri Motu', vehicle_make='Buick', vehicle_model='Coachbuilder', model_year=1991, employer='Collins, Blick and Rippin', department='Marketing', employee_id=91706408, last_updated=datetime.datetime(2017, 2, 25, 0, 7, 52), created=datetime.datetime(2016, 3, 12, 16, 12, 35))
#
# FulL_Data(ssn=797652382, first_name='Marianne', last_name='Huccaby', gender='Female', language='Swedish', vehicle_make='Volkswagen', vehicle_model='Scirocco', model_year=1985, employer='Walker-Lemke', department='Research and Development', employee_id=520032929, last_updated=datetime.datetime(2017, 1, 24, 12, 7, 57), created=datetime.datetime(2016, 2, 25, 16, 22, 8))
#
# FulL_Data(ssn=807605615, first_name='Michale', last_name='Druery', gender='Male', language='Dhivehi', vehicle_make='Dodge', vehicle_model='Viper', model_year=2000, employer='Mayert, Mueller and Stamm', department='Sales', employee_id=235127432, last_updated=datetime.datetime(2017, 1, 20, 8, 10, 18), created=datetime.datetime(2016, 1, 21, 10, 4))
#
# FulL_Data(ssn=830231573, first_name='Carine', last_name='Abramin', gender='Female', language='Bislama', vehicle_make='Land Rover', vehicle_model='Defender', model_year=1994, employer='Mayer Inc', department='Legal', employee_id=686332753, last_updated=datetime.datetime(2017, 2, 20, 23, 42), created=datetime.datetime(2016, 9, 1, 0, 6, 49))
#
# FulL_Data(ssn=831443286, first_name='Leesa', last_name='Finci', gender='Female', language='Nepali', vehicle_make='Mitsubishi', vehicle_model='Mirage', model_year=2000, employer='Bashirian, Beer and Bailey', department='Engineering', employee_id=383479804, last_updated=datetime.datetime(2017, 2, 19, 2, 38, 55), created=datetime.datetime(2016, 5, 5, 3, 7, 14))
#
# FulL_Data(ssn=846099851, first_name='Shani', last_name='Penrose', gender='Female', language='New Zealand Sign Language', vehicle_make='Subaru', vehicle_model='Legacy', model_year=2002, employer='Boehm, Goldner and Wisozk', department='Sales', employee_id=299226065, last_updated=datetime.datetime(2017, 1, 25, 3, 3, 59), created=datetime.datetime(2016, 4, 26, 18, 41, 28))
#
# FulL_Data(ssn=846599961, first_name='Saleem', last_name='Osmant', gender='Male', language='Croatian', vehicle_make='Volkswagen', vehicle_model='Jetta', model_year=1999, employer='Rolfson and Sons', department='Product Management', employee_id=598318028, last_updated=datetime.datetime(2017, 2, 20, 3, 4, 34), created=datetime.datetime(2016, 12, 28, 20, 41, 47))
#
# FulL_Data(ssn=847344817, first_name='Orazio', last_name='Coners', gender='Male', language='Yiddish', vehicle_make='Nissan', vehicle_model='350Z', model_year=2003, employer='Schmidt, Schaden and Pfeffer', department='Training', employee_id=397754939, last_updated=datetime.datetime(2017, 2, 13, 3, 31, 14), created=datetime.datetime(2016, 2, 2, 21, 15, 15))
#
# FulL_Data(ssn=848768808, first_name='Durward', last_name='Nuscha', gender='Male', language='Nepali', vehicle_make='Toyota', vehicle_model='Celica', model_year=1998, employer='Robel, Luettgen and Moore', department='Legal', employee_id=857186677, last_updated=datetime.datetime(2017, 1, 9, 20, 35, 16), created=datetime.datetime(2016, 8, 6, 21, 44, 44))
#
# FulL_Data(ssn=856183980, first_name='Neale', last_name='Sesser', gender='Male', language='Maltese', vehicle_make='Toyota', vehicle_model='MR2', model_year=1992, employer='Baumbach, Jenkins and Russel', department='Product Management', employee_id=394882068, last_updated=datetime.datetime(2017, 1, 20, 20, 28, 10), created=datetime.datetime(2016, 12, 8, 6, 52, 33))
#
# FulL_Data(ssn=858279190, first_name='Yuri', last_name='Sixsmith', gender='Male', language='Norwegian', vehicle_make='Suzuki', vehicle_model='Swift', model_year=1997, employer='Goodwin Inc', department='Marketing', employee_id=732880950, last_updated=datetime.datetime(2017, 2, 6, 7, 12, 2), created=datetime.datetime(2016, 12, 25, 16, 52, 9))
#
# FulL_Data(ssn=860670256, first_name='Bendicty', last_name='Lindgren', gender='Male', language='Tajik', vehicle_make='Toyota', vehicle_model='Tacoma', model_year=2001, employer='Williamson-Lemke', department='Accounting', employee_id=809563373, last_updated=datetime.datetime(2017, 1, 9, 22, 49, 48), created=datetime.datetime(2016, 2, 6, 4, 59, 26))
#
# FulL_Data(ssn=864229364, first_name='Lyell', last_name='Petrollo', gender='Male', language='Latvian', vehicle_make='Acura', vehicle_model='ZDX', model_year=2011, employer='Thiel, Parker and Hilpert', department='Marketing', employee_id=202324966, last_updated=datetime.datetime(2017, 2, 4, 13, 53, 10), created=datetime.datetime(2016, 12, 28, 0, 33, 8))
#
# FulL_Data(ssn=864917489, first_name='Guthrie', last_name='Pilsworth', gender='Male', language='Bislama', vehicle_make='Pontiac', vehicle_model='Grand Am', model_year=2004, employer='Heidenreich, Stehr and Huel', department='Sales', employee_id=891713880, last_updated=datetime.datetime(2017, 2, 3, 17, 51, 18), created=datetime.datetime(2016, 2, 14, 3, 7, 23))
#
# FulL_Data(ssn=870126609, first_name='Jourdain', last_name='Comino', gender='Male', language='Guarana', vehicle_make='Mercedes-Benz', vehicle_model='W201', model_year=1991, employer='Thompson, Parker and Moen', department='Research and Development', employee_id=461484106, last_updated=datetime.datetime(2017, 1, 19, 3, 43, 35), created=datetime.datetime(2016, 6, 24, 16, 43, 15))
# FulL_Data(ssn=878128265, first_name='Nance', last_name='Doble', gender='Female', language='Dhivehi', vehicle_make='Chrysler', vehicle_model='Concorde', model_year=1998, employer='Witting, Schuster and Barton', department='Research and Development', employee_id=544161357, last_updated=datetime.datetime(2017, 1, 11, 18, 36, 16), created=datetime.datetime(2016, 3, 14, 14, 30, 37))
#
# FulL_Data(ssn=880224449, first_name='Zebadiah', last_name='Halliburton', gender='Male', language='Azeri', vehicle_make='Toyota', vehicle_model='Camry', model_year=2008, employer='Harber-Legros', department='Training', employee_id=599280036, last_updated=datetime.datetime(2017, 1, 13, 19, 50, 26), created=datetime.datetime(2016, 6, 11, 20, 35, 38))
#
# FulL_Data(ssn=882495290, first_name='Tamarah', last_name='Stenson', gender='Female', language='Armenian', vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2011, employer='Zulauf Inc', department='Accounting', employee_id=467067366, last_updated=datetime.datetime(2017, 2, 10, 19, 26, 8), created=datetime.datetime(2016, 8, 27, 5, 43, 5))
#
# FulL_Data(ssn=884611852, first_name='Wylie', last_name='Glennon', gender='Male', language='Romanian', vehicle_make='Plymouth', vehicle_model='Neon', model_year=1996, employer='Stanton, Price and Wehner', department='Services', employee_id=165769119, last_updated=datetime.datetime(2017, 1, 9, 19, 30, 49), created=datetime.datetime(2016, 3, 18, 22, 13, 6))

# %%
def get_filtered_data(*files, filter_key = None):
    result = single_record(*files)
    yield from filter(filter_key, result)

# %%
data = get_filtered_data('personal_info.csv', 'vehicles.csv', 'employment.csv', 'update_status.csv',
                             filter_key = lambda x : x.ssn == 101714702)

# %%
for item in data:
    print(item)
# Out:
# FulL_Data(ssn=101714702, first_name='Cayla', last_name='MacDonagh', gender='Female', language='Lao', vehicle_make='Ford', vehicle_model='Mustang', model_year=1997, employer='Nicolas and Sons', department='Sales', employee_id=416841359, last_updated=datetime.datetime(2017, 1, 23, 11, 23, 17), created=datetime.datetime(2016, 1, 27, 4, 32, 57))

# %%
data = get_filtered_data('personal_info.csv', 'vehicles.csv', 'employment.csv', 'update_status.csv',
                             filter_key = lambda x : x.language == 'Tamil')

# %%
for item in data:
    print(item)
    print()
# Out:
# FulL_Data(ssn=212411496, first_name='Agnese', last_name='Lawes', gender='Female', language='Tamil', vehicle_make='Volkswagen', vehicle_model='Eurovan', model_year=1995, employer='Hills-Luettgen', department='Engineering', employee_id=496662355, last_updated=datetime.datetime(2017, 7, 7, 20, 29, 9), created=datetime.datetime(2016, 10, 27, 12, 47, 10))
#
# FulL_Data(ssn=296904908, first_name='Holt', last_name='Angel', gender='Male', language='Tamil', vehicle_make='Jensen', vehicle_model='Interceptor', model_year=1967, employer='Mayert-Volkman', department='Research and Development', employee_id=117283397, last_updated=datetime.datetime(2017, 5, 8, 13, 53, 40), created=datetime.datetime(2016, 4, 12, 0, 23, 9))
#
# FulL_Data(ssn=412798951, first_name='Giorgi', last_name='Sisnett', gender='Male', language='Tamil', vehicle_make='Volkswagen', vehicle_model='Golf', model_year=2011, employer='Hilll, Hickle and Koelpin', department='Services', employee_id=513888263, last_updated=datetime.datetime(2017, 3, 21, 2, 17, 15), created=datetime.datetime(2016, 7, 10, 3, 10, 26))
#
# FulL_Data(ssn=435340115, first_name='Chicky', last_name='Carlos', gender='Male', language='Tamil', vehicle_make='Volkswagen', vehicle_model='Passat', model_year=2000, employer='Considine, Parker and Johnson', department='Product Management', employee_id=829119836, last_updated=datetime.datetime(2017, 7, 26, 21, 0, 27), created=datetime.datetime(2016, 10, 11, 9, 43, 33))
#
# FulL_Data(ssn=585032819, first_name='Breanne', last_name='Gorelli', gender='Female', language='Tamil', vehicle_make='Buick', vehicle_model='Regal', model_year=1997, employer='Will-Auer', department='Support', employee_id=417214465, last_updated=datetime.datetime(2017, 5, 14, 16, 27, 26), created=datetime.datetime(2016, 4, 7, 22, 6, 31))
#
# FulL_Data(ssn=612305754, first_name='Archibold', last_name='Van de Castele', gender='Male', language='Tamil', vehicle_make='Ford', vehicle_model='Falcon', model_year=1966, employer='Parker, Ritchie and Emard', department='Marketing', employee_id=798311854, last_updated=datetime.datetime(2017, 9, 18, 17, 32, 43), created=datetime.datetime(2016, 12, 18, 13, 54, 40))
#
# FulL_Data(ssn=658340029, first_name='Chrysler', last_name='Bastistini', gender='Female', language='Tamil', vehicle_make='BMW', vehicle_model='M Roadster', model_year=2008, employer='Wolf, Gerhold and Dickens', department='Marketing', employee_id=156603582, last_updated=datetime.datetime(2017, 5, 1, 12, 27, 3), created=datetime.datetime(2016, 1, 25, 17, 21, 32))
#
# FulL_Data(ssn=675310953, first_name='Mychal', last_name='Legerwood', gender='Male', language='Tamil', vehicle_make='Volvo', vehicle_model='S80', model_year=2010, employer='Fay, Becker and Purdy', department='Training', employee_id=6483056, last_updated=datetime.datetime(2017, 9, 20, 22, 55, 45), created=datetime.datetime(2016, 1, 9, 18, 15, 3))
#
# FulL_Data(ssn=887417878, first_name='Bruce', last_name='Danieli', gender='Male', language='Tamil', vehicle_make='Lexus', vehicle_model='GS', model_year=2013, employer='Ziemann, Denesik and Casper', department='Research and Development', employee_id=716097002, last_updated=datetime.datetime(2017, 3, 27, 13, 38, 47), created=datetime.datetime(2016, 9, 14, 9, 26, 53))

# %%
male_data = get_filtered_data('personal_info.csv', 'vehicles.csv', 'employment.csv', 'update_status.csv',
                             filter_key = lambda x : x.gender == 'Male')

# %%
result = sorted(male_data, key = lambda x : x.vehicle_make)

# %%
groups = itertools.groupby(result, lambda x: x.vehicle_make)

# %%
make_dict = {make:sum(1 for person in persons) for make, persons in groups}

# %%
a = sorted(make_dict.items(), key = lambda item : item[1], reverse=True)

# %%
total = 0
for key, value in a:
    total += value
print(total)
# Out:
# 507

# %%
female_data = get_filtered_data('personal_info.csv', 'vehicles.csv', 'employment.csv', 'update_status.csv',
                             filter_key = lambda x : x.gender == 'Female')
result = sorted(female_data, key = lambda x : x.vehicle_make)
groups = itertools.groupby(result, lambda x: x.vehicle_make)
make_dict = {make:sum(1 for person in persons) for make, persons in groups}

# %%
b = sorted(make_dict.items(), key = lambda item : item[1], reverse=True)

# %%
total = 0
for key, value in b:
    total += value
print(total)
# Out:
# 493

# %%
def get_filtered_grouped_data(*files, filter_key=None, group_by=None):
    data = sorted(get_filtered_data(*files, filter_key=filter_key), key=group_by)
    groups = itertools.groupby(data, group_by)
    yield from groups

# %%
data = get_filtered_grouped_data('personal_info.csv', 'vehicles.csv', 'employment.csv', 'update_status.csv',
                             filter_key = lambda x : x.gender == 'Female',
                                group_by = lambda x : x.vehicle_make)

# %%
for key, group in data:
    print(key, list(group))
    print()
# Out:
# Acura [FulL_Data(ssn=156916848, first_name='Carol', last_name='Cromar', gender='Female', language='Amharic', vehicle_make='Acura', vehicle_model='TL', model_year=2005, employer='King LLC', department='Research and Development', employee_id=394026042, last_updated=datetime.datetime(2017, 8, 30, 22, 29, 10), created=datetime.datetime(2016, 5, 7, 6, 45, 32)), FulL_Data(ssn=210914729, first_name='Tamarra', last_name='Minchella', gender='Female', language='Greek', vehicle_make='Acura', vehicle_model='Integra', model_year=1997, employer='Weber, Reynolds and Brakus', department='Training', employee_id=260100410, last_updated=datetime.datetime(2017, 7, 11, 8, 17, 40), created=datetime.datetime(2016, 12, 4, 0, 41, 8)), FulL_Data(ssn=298706018, first_name='Minny', last_name='Van der Baaren', gender='Female', language='Afrikaans', vehicle_make='Acura', vehicle_model='NSX', model_year=1997, employer='Sporer, Haley and Cartwright', department='Legal', employee_id=728129260, last_updated=datetime.datetime(2018, 2, 12, 10, 5, 39), created=datetime.datetime(2016, 3, 28, 9, 53, 54)), FulL_Data(ssn=371623727, first_name='Cymbre', last_name='Chinnock', gender='Female', language='Dutch', vehicle_make='Acura', vehicle_model='NSX', model_year=2004, employer='Gleichner Group', department='Research and Development', employee_id=527507546, last_updated=datetime.datetime(2017, 7, 26, 23, 48, 15), created=datetime.datetime(2016, 8, 16, 8, 13, 41)), FulL_Data(ssn=399638810, first_name='Bobbee', last_name='Postians', gender='Female', language='Papiamento', vehicle_make='Acura', vehicle_model='Integra', model_year=1992, employer='Mills, Barton and Lakin', department='Product Management', employee_id=741474493, last_updated=datetime.datetime(2018, 3, 5, 13, 5, 28), created=datetime.datetime(2016, 2, 29, 5, 22, 17)), FulL_Data(ssn=509464927, first_name='Nickie', last_name='Dabes', gender='Female', language='Sotho', vehicle_make='Acura', vehicle_model='TL', model_year=2002, employer='Lemke, Schinner and Schaefer', department='Training', employee_id=86600485, last_updated=datetime.datetime(2017, 2, 11, 13, 16, 34), created=datetime.datetime(2016, 4, 1, 5, 21, 28)), FulL_Data(ssn=644682955, first_name='Catrina', last_name='Gerardin', gender='Female', language='Gagauz', vehicle_make='Acura', vehicle_model='RDX', model_year=2012, employer='Stracke LLC', department='Business Development', employee_id=102258220, last_updated=datetime.datetime(2017, 10, 11, 12, 51, 58), created=datetime.datetime(2016, 6, 21, 12, 1, 17)), FulL_Data(ssn=670893434, first_name='Elvina', last_name='Scowcroft', gender='Female', language='Albanian', vehicle_make='Acura', vehicle_model='Legend', model_year=1988, employer='Mann, Trantow and Gusikowski', department='Marketing', employee_id=258521955, last_updated=datetime.datetime(2017, 3, 27, 4, 0, 1), created=datetime.datetime(2016, 11, 3, 11, 39, 45)), FulL_Data(ssn=687275241, first_name='Hildegarde', last_name='Crosoer', gender='Female', language='Marathi', vehicle_make='Acura', vehicle_model='TSX', model_year=2011, employer='Klocko LLC', department='Human Resources', employee_id=306205049, last_updated=datetime.datetime(2017, 2, 14, 9, 45, 31), created=datetime.datetime(2016, 10, 29, 23, 44, 20)), FulL_Data(ssn=822059037, first_name='Meggi', last_name='Mapes', gender='Female', language='Moldovan', vehicle_make='Acura', vehicle_model='MDX', model_year=2001, employer='Crona, Bogan and Beatty', department='Business Development', employee_id=3394171, last_updated=datetime.datetime(2017, 11, 14, 6, 43, 11), created=datetime.datetime(2016, 3, 28, 1, 5, 25)), FulL_Data(ssn=872491288, first_name='Salaidh', last_name='Barthod', gender='Female', language='Finnish', vehicle_make='Acura', vehicle_model='Integra', model_year=1997, employer='Cummings-Mertz', department='Sales', employee_id=782291834, last_updated=datetime.datetime(2017, 12, 6, 2, 19, 8), created=datetime.datetime(2016, 6, 10, 10, 5, 19))]
#
# Aston Martin [FulL_Data(ssn=240676258, first_name='Kalina', last_name='Lloyds', gender='Female', language='Hindi', vehicle_make='Aston Martin', vehicle_model='V8 Vantage', model_year=2008, employer='Donnelly-Reichel', department='Sales', employee_id=516219405, last_updated=datetime.datetime(2017, 10, 17, 17, 8, 33), created=datetime.datetime(2016, 5, 24, 9, 11, 51)), FulL_Data(ssn=386973523, first_name='Siusan', last_name='Durkin', gender='Female', language='Kurdish', vehicle_make='Aston Martin', vehicle_model='V8 Vantage S', model_year=2011, employer='Durgan LLC', department='Business Development', employee_id=758054834, last_updated=datetime.datetime(2017, 11, 13, 13, 40, 53), created=datetime.datetime(2016, 1, 9, 18, 15, 53))]
#
# Audi [FulL_Data(ssn=157179982, first_name='Ardyce', last_name='Kuhnel', gender='Female', language='Danish', vehicle_make='Audi', vehicle_model='Q7', model_year=2007, employer='Konopelski-Vandervort', department='Legal', employee_id=878332368, last_updated=datetime.datetime(2017, 4, 17, 9, 11, 49), created=datetime.datetime(2016, 3, 17, 0, 22, 29)), FulL_Data(ssn=247865288, first_name='Lilly', last_name='Holby', gender='Female', language='Bosnian', vehicle_make='Audi', vehicle_model='Q5', model_year=2010, employer='Flatley, Braun and Wiegand', department='Product Management', employee_id=838221727, last_updated=datetime.datetime(2017, 8, 7, 13, 12, 28), created=datetime.datetime(2016, 1, 13, 5, 54, 25)), FulL_Data(ssn=304484312, first_name='Edeline', last_name='Van de Vlies', gender='Female', language='Montenegrin', vehicle_make='Audi', vehicle_model='Allroad', model_year=2005, employer='Stamm-Reichert', department='Engineering', employee_id=254364794, last_updated=datetime.datetime(2017, 6, 8, 17, 56, 34), created=datetime.datetime(2016, 7, 23, 15, 40, 8)), FulL_Data(ssn=315785587, first_name='Helsa', last_name='Lumber', gender='Female', language='Tok Pisin', vehicle_make='Audi', vehicle_model='5000S', model_year=1984, employer='Wehner-Parker', department='Product Management', employee_id=35512362, last_updated=datetime.datetime(2017, 8, 20, 18, 9, 2), created=datetime.datetime(2016, 1, 17, 12, 12, 42)), FulL_Data(ssn=345742160, first_name='Camile', last_name='Pengelly', gender='Female', language='Lao', vehicle_make='Audi', vehicle_model='S8', model_year=2002, employer='Jaskolski, Batz and Rempel', department='Marketing', employee_id=829497860, last_updated=datetime.datetime(2018, 2, 4, 4, 8, 54), created=datetime.datetime(2016, 7, 13, 23, 35, 12)), FulL_Data(ssn=361835004, first_name='Wilona', last_name='Sink', gender='Female', language='Sotho', vehicle_make='Audi', vehicle_model='S4', model_year=2013, employer="D'Amore LLC", department='Services', employee_id=613591939, last_updated=datetime.datetime(2017, 8, 11, 21, 27, 23), created=datetime.datetime(2016, 12, 24, 3, 19, 11)), FulL_Data(ssn=390743062, first_name='Cara', last_name='Ingree', gender='Female', language='Indonesian', vehicle_make='Audi', vehicle_model='TT', model_year=2002, employer='Bechtelar-McCullough', department='Sales', employee_id=11786654, last_updated=datetime.datetime(2017, 1, 1, 12, 23, 41), created=datetime.datetime(2016, 11, 14, 16, 22, 16)), FulL_Data(ssn=409582034, first_name='Fiann', last_name='Corsar', gender='Female', language='Swahili', vehicle_make='Audi', vehicle_model='A4', model_year=2001, employer='Wilkinson Group', department='Accounting', employee_id=248239174, last_updated=datetime.datetime(2018, 1, 22, 3, 9, 50), created=datetime.datetime(2016, 6, 8, 17, 56, 28)), FulL_Data(ssn=427360095, first_name='Shandee', last_name='Hawthorne', gender='Female', language='Gujarati', vehicle_make='Audi', vehicle_model='S5', model_year=2010, employer='Wiza Group', department='Sales', employee_id=682794098, last_updated=datetime.datetime(2017, 3, 20, 10, 29), created=datetime.datetime(2016, 5, 4, 1, 28, 15)), FulL_Data(ssn=671768792, first_name='Melisse', last_name='Extil', gender='Female', language='Punjabi', vehicle_make='Audi', vehicle_model='Q7', model_year=2010, employer='Ruecker Inc', department='Accounting', employee_id=739942988, last_updated=datetime.datetime(2017, 10, 16, 1, 26, 58), created=datetime.datetime(2016, 3, 3, 1, 23, 14)), FulL_Data(ssn=699174497, first_name='Eolanda', last_name='Shine', gender='Female', language='Estonian', vehicle_make='Audi', vehicle_model='A6', model_year=2008, employer='Heller-Price', department='Engineering', employee_id=461230529, last_updated=datetime.datetime(2018, 1, 28, 19, 14, 50), created=datetime.datetime(2016, 7, 1, 8, 2, 58)), FulL_Data(ssn=719968751, first_name='Sallie', last_name='Gosnold', gender='Female', language='Catalan', vehicle_make='Audi', vehicle_model='4000', model_year=1987, employer= ...
#
# Austin [FulL_Data(ssn=777682978, first_name='Mignon', last_name='Skottle', gender='Female', language='Northern Sotho', vehicle_make='Austin', vehicle_model='Mini', model_year=1959, employer='Will, Crist and Jakubowski', department='Marketing', employee_id=224425487, last_updated=datetime.datetime(2018, 1, 16, 9, 16, 18), created=datetime.datetime(2016, 10, 1, 7, 34, 26))]
#
# BMW [FulL_Data(ssn=128566040, first_name='Jinny', last_name='Stebbings', gender='Female', language='Armenian', vehicle_make='BMW', vehicle_model='M', model_year=2001, employer='Harris Inc', department='Support', employee_id=537535536, last_updated=datetime.datetime(2017, 8, 13, 2, 47, 15), created=datetime.datetime(2016, 3, 21, 8, 59, 56)), FulL_Data(ssn=134050120, first_name='Simone', last_name='Cruickshanks', gender='Female', language='Filipino', vehicle_make='BMW', vehicle_model='M5', model_year=2006, employer='Donnelly-Crooks', department='Human Resources', employee_id=222943669, last_updated=datetime.datetime(2017, 1, 29, 11, 53, 22), created=datetime.datetime(2016, 8, 3, 4, 54, 40)), FulL_Data(ssn=151781397, first_name='Portia', last_name='Belshaw', gender='Female', language='Sotho', vehicle_make='BMW', vehicle_model='M5', model_year=2000, employer='Schinner, Swaniawski and Carter', department='Human Resources', employee_id=933103060, last_updated=datetime.datetime(2017, 7, 8, 4, 22, 30), created=datetime.datetime(2016, 6, 11, 0, 28, 10)), FulL_Data(ssn=157515269, first_name='Melisse', last_name='Petkov', gender='Female', language='Punjabi', vehicle_make='BMW', vehicle_model='Z3', model_year=1996, employer='Gerhold-Marquardt', department='Research and Development', employee_id=256013938, last_updated=datetime.datetime(2017, 11, 4, 20, 16, 50), created=datetime.datetime(2016, 6, 17, 10, 3, 2)), FulL_Data(ssn=288547233, first_name='Hedy', last_name='Eaklee', gender='Female', language='English', vehicle_make='BMW', vehicle_model='5 Series', model_year=2008, employer='Beatty and Sons', department='Sales', employee_id=719137028, last_updated=datetime.datetime(2017, 4, 9, 3, 49, 3), created=datetime.datetime(2016, 1, 13, 21, 17, 3)), FulL_Data(ssn=348743224, first_name='Dorthy', last_name='Abreheart', gender='Female', language='Bosnian', vehicle_make='BMW', vehicle_model='X6 M', model_year=2012, employer='Ledner and Sons', department='Engineering', employee_id=887250304, last_updated=datetime.datetime(2018, 2, 4, 18, 12, 54), created=datetime.datetime(2016, 5, 11, 22, 14, 46)), FulL_Data(ssn=405251422, first_name='Raquel', last_name='Dukelow', gender='Female', language='Gujarati', vehicle_make='BMW', vehicle_model='5 Series', model_year=2006, employer='Keebler Group', department='Product Management', employee_id=576192942, last_updated=datetime.datetime(2017, 11, 21, 0, 0, 30), created=datetime.datetime(2016, 7, 16, 10, 8, 31)), FulL_Data(ssn=484755799, first_name='Rhea', last_name='Braniff', gender='Female', language='Somali', vehicle_make='BMW', vehicle_model='M3', model_year=2005, employer='Collins-Schulist', department='Marketing', employee_id=903382110, last_updated=datetime.datetime(2018, 2, 12, 3, 45, 42), created=datetime.datetime(2016, 4, 12, 21, 29, 16)), FulL_Data(ssn=541541497, first_name='Katuscha', last_name='Jovis', gender='Female', language='Irish Gaelic', vehicle_make='BMW', vehicle_model='M5', model_year=2007, employer="O'Kon, Ortiz and Cassin", department='Engineering', employee_id=8992736, last_updated=datetime.datetime(2017, 11, 27, 22, 19, 21), created=datetime.datetime(2016, 10, 18, 14, 16, 21)), FulL_Data(ssn=654611601, first_name='Vinnie', last_name='Buzzing', gender='Female', language='Dhivehi', vehicle_make='BMW', vehicle_model='M5', model_year=2008, employer='Howe-Nitzsche', department='Engineering', employee_id=749663378, last_updated=datetime.datetime(2017, 9, 28, 18, 6, 41), created=datetime.datetime(2016, 5, 4, 2, 46, 14)), FulL_Data(ssn=658340029, first_name='Chrysler', last_name='Bastistini', gender='Female', language='Tamil', vehicle_make='BMW', vehicle_model='M Roadster', model_year=2008, employer='Wolf, Gerhold and Dickens', department='Marketing', employee_id=156603582, last_updated=datetime.datetime(2017, 5, 1, 12, 27, 3), created=datetime.datetime(2016, 1, 25, 17, 21, 32)), FulL_Data(ssn=861506716, first_name='Norina', last_name='Yerbury', gender='Female', language='Indonesian', vehicle_ ...
#
# Bentley [FulL_Data(ssn=216973104, first_name='Elvira', last_name='McDougal', gender='Female', language='Bislama', vehicle_make='Bentley', vehicle_model='Continental Super', model_year=2012, employer='Skiles, Reichel and Romaguera', department='Engineering', employee_id=398820670, last_updated=datetime.datetime(2017, 2, 10, 18, 28, 9), created=datetime.datetime(2016, 9, 6, 8, 20, 10)), FulL_Data(ssn=300768770, first_name='Danielle', last_name='Rowth', gender='Female', language='Italian', vehicle_make='Bentley', vehicle_model='Arnage', model_year=2009, employer='McClure-Gerhold', department='Business Development', employee_id=19218158, last_updated=datetime.datetime(2017, 8, 21, 0, 3, 14), created=datetime.datetime(2016, 3, 13, 15, 45, 7)), FulL_Data(ssn=599569050, first_name='Letti', last_name='Trappe', gender='Female', language='Maori', vehicle_make='Bentley', vehicle_model='Arnage', model_year=2008, employer='Koss-Windler', department='Human Resources', employee_id=65801036, last_updated=datetime.datetime(2018, 1, 12, 12, 2, 36), created=datetime.datetime(2016, 5, 21, 0, 57, 43)), FulL_Data(ssn=617714058, first_name='Lynsey', last_name='Creser', gender='Female', language='Gujarati', vehicle_make='Bentley', vehicle_model='Arnage', model_year=2005, employer='Herman, Walter and Schoen', department='Marketing', employee_id=408324882, last_updated=datetime.datetime(2017, 8, 12, 4, 22, 36), created=datetime.datetime(2016, 5, 22, 22, 29, 31)), FulL_Data(ssn=770618252, first_name='Elbertina', last_name='Colls', gender='Female', language='Chinese', vehicle_make='Bentley', vehicle_model='Arnage', model_year=2008, employer='Greenholt Inc', department='Business Development', employee_id=975181434, last_updated=datetime.datetime(2018, 2, 3, 13, 33, 14), created=datetime.datetime(2016, 4, 17, 6, 15, 58))]
#
# Bugatti [FulL_Data(ssn=116107235, first_name='Chiquita', last_name='Danbi', gender='Female', language='Dari', vehicle_make='Bugatti', vehicle_model='Veyron', model_year=2009, employer='Pfannerstill Group', department='Research and Development', employee_id=431532437, last_updated=datetime.datetime(2017, 3, 10, 0, 31, 43), created=datetime.datetime(2016, 10, 17, 2, 11, 26))]
#
# Buick [FulL_Data(ssn=262554066, first_name='Kaitlynn', last_name='Bleazard', gender='Female', language='Estonian', vehicle_make='Buick', vehicle_model='Regal', model_year=2002, employer='Schultz, West and Cummings', department='Research and Development', employee_id=818904444, last_updated=datetime.datetime(2017, 6, 3, 10, 15, 39), created=datetime.datetime(2016, 12, 20, 9, 49, 37)), FulL_Data(ssn=283046835, first_name='Tobey', last_name='Joule', gender='Female', language='Dzongkha', vehicle_make='Buick', vehicle_model='LeSabre', model_year=2001, employer='Abbott, Bahringer and Goyette', department='Marketing', employee_id=415601892, last_updated=datetime.datetime(2017, 5, 29, 2, 43, 42), created=datetime.datetime(2016, 5, 17, 15, 7, 44)), FulL_Data(ssn=315125664, first_name='Vere', last_name='Morlon', gender='Female', language='German', vehicle_make='Buick', vehicle_model='Riviera', model_year=1993, employer='Wiegand-Bernhard', department='Business Development', employee_id=575620609, last_updated=datetime.datetime(2017, 6, 11, 18, 3, 12), created=datetime.datetime(2016, 5, 19, 13, 58, 32)), FulL_Data(ssn=372447487, first_name='Jolyn', last_name='Bertome', gender='Female', language='Catalan', vehicle_make='Buick', vehicle_model='Riviera', model_year=1991, employer='Fahey, Fahey and Gleason', department='Product Management', employee_id=28347934, last_updated=datetime.datetime(2017, 10, 1, 3, 0, 17), created=datetime.datetime(2016, 5, 15, 22, 58, 12)), FulL_Data(ssn=446731646, first_name='Pattie', last_name='Ludwig', gender='Female', language='West Frisian', vehicle_make='Buick', vehicle_model='Regal', model_year=1996, employer='Fadel Group', department='Product Management', employee_id=353731698, last_updated=datetime.datetime(2017, 3, 23, 15, 31, 56), created=datetime.datetime(2016, 8, 25, 11, 40)), FulL_Data(ssn=585032819, first_name='Breanne', last_name='Gorelli', gender='Female', language='Tamil', vehicle_make='Buick', vehicle_model='Regal', model_year=1997, employer='Will-Auer', department='Support', employee_id=417214465, last_updated=datetime.datetime(2017, 5, 14, 16, 27, 26), created=datetime.datetime(2016, 4, 7, 22, 6, 31)), FulL_Data(ssn=595513047, first_name='Haley', last_name='Critchley', gender='Female', language='Ndebele', vehicle_make='Buick', vehicle_model='Skylark', model_year=1989, employer='Stehr Inc', department='Human Resources', employee_id=612533957, last_updated=datetime.datetime(2017, 3, 14, 22, 18, 40), created=datetime.datetime(2016, 2, 12, 17, 16, 20)), FulL_Data(ssn=627361126, first_name='Milzie', last_name='Steabler', gender='Female', language='Tetum', vehicle_make='Buick', vehicle_model='LeSabre', model_year=1985, employer='Kulas-Vandervort', department='Human Resources', employee_id=776897439, last_updated=datetime.datetime(2018, 3, 17, 15, 40, 40), created=datetime.datetime(2016, 2, 10, 21, 40, 20)), FulL_Data(ssn=641118353, first_name='Angel', last_name='Godthaab', gender='Female', language='Bislama', vehicle_make='Buick', vehicle_model='LeSabre', model_year=2005, employer='Rogahn, Hickle and Leuschke', department='Sales', employee_id=750981332, last_updated=datetime.datetime(2017, 5, 24, 8, 40, 40), created=datetime.datetime(2016, 7, 23, 2, 46, 34)), FulL_Data(ssn=783229258, first_name='Modestine', last_name='Cuttings', gender='Female', language='Assamese', vehicle_make='Buick', vehicle_model='Skylark', model_year=1990, employer='Funk, Boyer and Littel', department='Legal', employee_id=952744801, last_updated=datetime.datetime(2017, 9, 24, 10, 26, 26), created=datetime.datetime(2016, 8, 15, 14, 8, 12)), FulL_Data(ssn=808558658, first_name='Ursulina', last_name='Kunze', gender='Female', language='Chinese', vehicle_make='Buick', vehicle_model='Coachbuilder', model_year=1994, employer='Mosciski-Marquardt', department='Product Management', employee_id=372182084, last_updated=datetime.datetime(2017, 9, 30, 9, 38, 27), created=datetime.datetime(2016, 9, 23, 12, 37, 50))]
#
# Cadillac [FulL_Data(ssn=123622832, first_name='Kare', last_name='Barhams', gender='Female', language='Tajik', vehicle_make='Cadillac', vehicle_model='Catera', model_year=1999, employer='Cruickshank, Legros and Keebler', department='Research and Development', employee_id=571590433, last_updated=datetime.datetime(2017, 9, 11, 0, 2, 44), created=datetime.datetime(2016, 10, 22, 16, 14, 5)), FulL_Data(ssn=150646357, first_name='Helenka', last_name='Summerell', gender='Female', language='Bosnian', vehicle_make='Cadillac', vehicle_model='Escalade', model_year=2000, employer='Bosco-Kunde', department='Services', employee_id=551726090, last_updated=datetime.datetime(2018, 2, 14, 23, 35, 53), created=datetime.datetime(2016, 1, 28, 3, 19, 50)), FulL_Data(ssn=399816133, first_name='Viv', last_name='Borsay', gender='Female', language='Chinese', vehicle_make='Cadillac', vehicle_model='Allante', model_year=1992, employer='Kihn Group', department='Legal', employee_id=571893655, last_updated=datetime.datetime(2017, 12, 1, 11, 7, 24), created=datetime.datetime(2016, 4, 13, 7, 24, 21)), FulL_Data(ssn=527553736, first_name='Auguste', last_name='Hammersley', gender='Female', language='Malayalam', vehicle_make='Cadillac', vehicle_model='CTS', model_year=2005, employer='Balistreri Inc', department='Human Resources', employee_id=625455166, last_updated=datetime.datetime(2018, 2, 21, 4, 37, 24), created=datetime.datetime(2016, 4, 4, 7, 13, 28)), FulL_Data(ssn=728545322, first_name='Berti', last_name='Bertelet', gender='Female', language='German', vehicle_make='Cadillac', vehicle_model='STS', model_year=2009, employer='Hahn and Sons', department='Services', employee_id=142928154, last_updated=datetime.datetime(2017, 8, 15, 3, 53, 9), created=datetime.datetime(2016, 6, 10, 23, 47, 18)), FulL_Data(ssn=807135922, first_name='Vivi', last_name='Edinboro', gender='Female', language='Sotho', vehicle_make='Cadillac', vehicle_model='Seville', model_year=2001, employer="Kihn, D'Amore and Volkman", department='Business Development', employee_id=659491878, last_updated=datetime.datetime(2017, 3, 12, 16, 29, 50), created=datetime.datetime(2016, 6, 17, 23, 4, 5))]
#
# Chevrolet [FulL_Data(ssn=105917777, first_name='Audi', last_name='Roach', gender='Female', language='Estonian', vehicle_make='Chevrolet', vehicle_model='Silverado 3500', model_year=2004, employer='Bashirian-Lueilwitz', department='Engineering', employee_id=443328799, last_updated=datetime.datetime(2017, 5, 11, 1, 48, 32), created=datetime.datetime(2016, 5, 31, 0, 38, 13)), FulL_Data(ssn=114660984, first_name='Casandra', last_name='Juares', gender='Female', language='Lithuanian', vehicle_make='Chevrolet', vehicle_model='Camaro', model_year=1998, employer='Mayert, Rice and Schmitt', department='Product Management', employee_id=858596488, last_updated=datetime.datetime(2017, 6, 16, 17, 41, 33), created=datetime.datetime(2016, 5, 28, 20, 31, 25)), FulL_Data(ssn=119078817, first_name='Blondie', last_name='Powderham', gender='Female', language='Croatian', vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2005, employer='Terry LLC', department='Accounting', employee_id=704864087, last_updated=datetime.datetime(2017, 12, 24, 15, 31, 5), created=datetime.datetime(2016, 12, 6, 14, 16, 59)), FulL_Data(ssn=164119849, first_name='Clemence', last_name='Aujean', gender='Female', language='Albanian', vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=2001, employer='Quitzon, Rempel and Hane', department='Business Development', employee_id=34767523, last_updated=datetime.datetime(2017, 6, 24, 10, 17, 58), created=datetime.datetime(2016, 4, 20, 11, 9, 5)), FulL_Data(ssn=174519992, first_name='Drucie', last_name='Travers', gender='Female', language='Swati', vehicle_make='Chevrolet', vehicle_model='Beretta', model_year=1994, employer='Jast-Quitzon', department='Human Resources', employee_id=675707294, last_updated=datetime.datetime(2017, 3, 3, 19, 42, 18), created=datetime.datetime(2016, 5, 17, 23, 32, 25)), FulL_Data(ssn=181074434, first_name='Ferdinande', last_name='Probet', gender='Female', language='Catalan', vehicle_make='Chevrolet', vehicle_model='Impala SS', model_year=1995, employer='Little, Herzog and Mertz', department='Legal', employee_id=459164509, last_updated=datetime.datetime(2017, 10, 7, 7, 52, 10), created=datetime.datetime(2016, 11, 11, 20, 19, 19)), FulL_Data(ssn=205872423, first_name='Oralla', last_name='Kearle', gender='Female', language='Zulu', vehicle_make='Chevrolet', vehicle_model='Express 2500', model_year=1999, employer='Goodwin-Oberbrunner', department='Accounting', employee_id=70291024, last_updated=datetime.datetime(2018, 1, 1, 8, 17, 27), created=datetime.datetime(2016, 2, 16, 23, 45, 38)), FulL_Data(ssn=209508146, first_name='Kenna', last_name='Meryett', gender='Female', language='Czech', vehicle_make='Chevrolet', vehicle_model='Sportvan G20', model_year=1992, employer='Senger, Fay and Schuppe', department='Marketing', employee_id=59734435, last_updated=datetime.datetime(2018, 3, 13, 17, 52, 16), created=datetime.datetime(2016, 4, 10, 7, 14, 25)), FulL_Data(ssn=224309267, first_name='Flori', last_name='Bagnal', gender='Female', language='Swedish', vehicle_make='Chevrolet', vehicle_model='Avalanche', model_year=2009, employer='Jacobson-Kuhn', department='Human Resources', employee_id=335097675, last_updated=datetime.datetime(2017, 12, 17, 11, 57, 56), created=datetime.datetime(2016, 11, 13, 20, 27, 10)), FulL_Data(ssn=239374122, first_name='Jodee', last_name='Elsdon', gender='Female', language='Guarana', vehicle_make='Chevrolet', vehicle_model='Silverado 1500', model_year=2002, employer='Kassulke-Cruickshank', department='Support', employee_id=338042555, last_updated=datetime.datetime(2017, 9, 20, 20, 47, 44), created=datetime.datetime(2016, 3, 5, 9, 16, 37)), FulL_Data(ssn=240088805, first_name='Gates', last_name='McGiffin', gender='Female', language='Finnish', vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1988, employer='Mraz, Veum and Farrell', department='Product Management', employee_id=306285659, last_updated=datetime.datetime(2017, 2, 10, 12, 14, 31), created=datetime ...
#
# Chrysler [FulL_Data(ssn=105857486, first_name='Angelina', last_name='McAvey', gender='Female', language='Punjabi', vehicle_make='Chrysler', vehicle_model='300', model_year=2008, employer='Roberts, Torphy and Dach', department='Human Resources', employee_id=774895332, last_updated=datetime.datetime(2018, 2, 14, 11, 32, 39), created=datetime.datetime(2016, 12, 15, 5, 46, 43)), FulL_Data(ssn=211155182, first_name='Gene', last_name='Bassilashvili', gender='Female', language='Swedish', vehicle_make='Chrysler', vehicle_model='Town & Country', model_year=2010, employer='Sawayn, Marvin and Rempel', department='Research and Development', employee_id=746068283, last_updated=datetime.datetime(2017, 4, 15, 16, 17, 42), created=datetime.datetime(2016, 3, 17, 19, 14, 56)), FulL_Data(ssn=240328915, first_name='Cathee', last_name='Tarbard', gender='Female', language='Papiamento', vehicle_make='Chrysler', vehicle_model='Crossfire', model_year=2006, employer="O'Keefe-Cruickshank", department='Research and Development', employee_id=341983927, last_updated=datetime.datetime(2017, 4, 18, 14, 30, 22), created=datetime.datetime(2016, 2, 25, 19, 4, 17)), FulL_Data(ssn=253618401, first_name='Genny', last_name='Juara', gender='Female', language='Tswana', vehicle_make='Chrysler', vehicle_model='Voyager', model_year=2000, employer='Halvorson-Parisian', department='Support', employee_id=162500138, last_updated=datetime.datetime(2018, 1, 22, 4, 2, 1), created=datetime.datetime(2016, 10, 2, 2, 18, 55)), FulL_Data(ssn=280537447, first_name='Suzette', last_name='Prahl', gender='Female', language='Romanian', vehicle_make='Chrysler', vehicle_model='Concorde', model_year=1994, employer='Moen, Veum and McLaughlin', department='Accounting', employee_id=120401993, last_updated=datetime.datetime(2017, 5, 12, 7, 46, 5), created=datetime.datetime(2016, 2, 16, 0, 15, 21)), FulL_Data(ssn=426334523, first_name='Bibbie', last_name='Lardge', gender='Female', language='Spanish', vehicle_make='Chrysler', vehicle_model='Town & Country', model_year=2001, employer='Sporer Inc', department='Legal', employee_id=432632272, last_updated=datetime.datetime(2017, 2, 13, 11, 48, 3), created=datetime.datetime(2016, 10, 13, 14, 8, 2)), FulL_Data(ssn=795566486, first_name='Stevena', last_name='Vatcher', gender='Female', language='Gagauz', vehicle_make='Chrysler', vehicle_model='300', model_year=2008, employer='Rau-Schmidt', department='Legal', employee_id=398891615, last_updated=datetime.datetime(2018, 2, 1, 2, 41, 25), created=datetime.datetime(2016, 4, 27, 0, 12, 34)), FulL_Data(ssn=878128265, first_name='Nance', last_name='Doble', gender='Female', language='Dhivehi', vehicle_make='Chrysler', vehicle_model='Concorde', model_year=1998, employer='Witting, Schuster and Barton', department='Research and Development', employee_id=544161357, last_updated=datetime.datetime(2017, 1, 11, 18, 36, 16), created=datetime.datetime(2016, 3, 14, 14, 30, 37))]
#
# Dodge [FulL_Data(ssn=194765816, first_name='Jacquelynn', last_name='Shurey', gender='Female', language='Amharic', vehicle_make='Dodge', vehicle_model='Dakota', model_year=2001, employer='Sauer, Mann and Kling', department='Accounting', employee_id=893029716, last_updated=datetime.datetime(2017, 1, 16, 18, 22, 53), created=datetime.datetime(2016, 5, 26, 16, 11, 14)), FulL_Data(ssn=244810671, first_name='Viviyan', last_name='Udell', gender='Female', language='Moldovan', vehicle_make='Dodge', vehicle_model='Caravan', model_year=1997, employer='Howell-Wunsch', department='Legal', employee_id=917637157, last_updated=datetime.datetime(2017, 6, 23, 11, 56, 59), created=datetime.datetime(2016, 9, 8, 8, 33, 21)), FulL_Data(ssn=299036911, first_name='Janela', last_name='Ferrone', gender='Female', language='Gagauz', vehicle_make='Dodge', vehicle_model='Viper RT/10', model_year=1994, employer='Kilback Group', department='Services', employee_id=25391126, last_updated=datetime.datetime(2017, 1, 19, 3, 33, 50), created=datetime.datetime(2016, 3, 7, 15, 33, 32)), FulL_Data(ssn=358847049, first_name='Emalee', last_name='McCleary', gender='Female', language='Thai', vehicle_make='Dodge', vehicle_model='Dakota Club', model_year=2007, employer='Kuhn LLC', department='Research and Development', employee_id=127386844, last_updated=datetime.datetime(2017, 2, 9, 7, 24, 45), created=datetime.datetime(2016, 2, 21, 0, 13, 44)), FulL_Data(ssn=378602472, first_name='Eddie', last_name='Howieson', gender='Female', language='Albanian', vehicle_make='Dodge', vehicle_model='Ram 2500', model_year=2000, employer='Baumbach Group', department='Human Resources', employee_id=937798424, last_updated=datetime.datetime(2017, 8, 22, 22, 37, 19), created=datetime.datetime(2016, 11, 10, 10, 11, 19)), FulL_Data(ssn=391474578, first_name='Fiann', last_name='Fellman', gender='Female', language='Assamese', vehicle_make='Dodge', vehicle_model='Ram 1500', model_year=1997, employer='Rath-Hessel', department='Human Resources', employee_id=868277225, last_updated=datetime.datetime(2017, 10, 29, 15, 13, 33), created=datetime.datetime(2016, 10, 24, 19, 42, 50)), FulL_Data(ssn=406155123, first_name='Janot', last_name='Pulhoster', gender='Female', language='Dari', vehicle_make='Dodge', vehicle_model='Caravan', model_year=2000, employer='Wilkinson, Lind and Ziemann', department='Research and Development', employee_id=475274344, last_updated=datetime.datetime(2017, 3, 9, 4, 6, 27), created=datetime.datetime(2016, 10, 21, 22, 15, 43)), FulL_Data(ssn=413565613, first_name='Anjanette', last_name='Carnock', gender='Female', language='Nepali', vehicle_make='Dodge', vehicle_model='D150', model_year=1993, employer='Marks, Wilkinson and Kub', department='Services', employee_id=871098264, last_updated=datetime.datetime(2017, 7, 21, 23, 37, 57), created=datetime.datetime(2016, 11, 13, 17, 24, 37)), FulL_Data(ssn=450455021, first_name='Ailis', last_name='Allsebrook', gender='Female', language='Amharic', vehicle_make='Dodge', vehicle_model='Avenger', model_year=2011, employer='Morissette, Pfeffer and Bayer', department='Legal', employee_id=789992528, last_updated=datetime.datetime(2017, 11, 6, 2, 16, 54), created=datetime.datetime(2016, 9, 15, 7, 50, 46)), FulL_Data(ssn=476270948, first_name='Laurette', last_name='Kearney', gender='Female', language='West Frisian', vehicle_make='Dodge', vehicle_model='Intrepid', model_year=2001, employer='Jast-Gibson', department='Business Development', employee_id=200508733, last_updated=datetime.datetime(2017, 9, 14, 1, 54, 7), created=datetime.datetime(2016, 12, 18, 8, 11, 30)), FulL_Data(ssn=493097972, first_name='Agretha', last_name='Wickes', gender='Female', language='French', vehicle_make='Dodge', vehicle_model='Grand Caravan', model_year=1995, employer='Zemlak, Heathcote and Turner', department='Training', employee_id=865333401, last_updated=datetime.datetime(2017, 9, 11, 12, 20, 58), created=datetime.datetime(2016, 8, 22, 21, 53, 32)), FulL_Data(ssn=5264527 ...
#
# Eagle [FulL_Data(ssn=348734312, first_name='Elberta', last_name='Howden', gender='Female', language='Khmer', vehicle_make='Eagle', vehicle_model='Vision', model_year=1994, employer='Sanford-Rohan', department='Engineering', employee_id=892980268, last_updated=datetime.datetime(2017, 9, 13, 10, 31, 30), created=datetime.datetime(2016, 12, 14, 21, 16, 27))]
#
# Ford [FulL_Data(ssn=101714702, first_name='Cayla', last_name='MacDonagh', gender='Female', language='Lao', vehicle_make='Ford', vehicle_model='Mustang', model_year=1997, employer='Nicolas and Sons', department='Sales', employee_id=416841359, last_updated=datetime.datetime(2017, 1, 23, 11, 23, 17), created=datetime.datetime(2016, 1, 27, 4, 32, 57)), FulL_Data(ssn=110843641, first_name='Amberly', last_name='Huws', gender='Female', language='Papiamento', vehicle_make='Ford', vehicle_model='Mustang', model_year=1990, employer='Lueilwitz LLC', department='Marketing', employee_id=339146042, last_updated=datetime.datetime(2017, 9, 4, 19, 2, 3), created=datetime.datetime(2016, 9, 12, 22, 50, 5)), FulL_Data(ssn=123883381, first_name='Christiane', last_name='Hynes', gender='Female', language='Danish', vehicle_make='Ford', vehicle_model='Mustang', model_year=1989, employer='Mueller-Rath', department='Human Resources', employee_id=58069298, last_updated=datetime.datetime(2017, 2, 21, 16, 37, 38), created=datetime.datetime(2016, 1, 30, 23, 42, 36)), FulL_Data(ssn=142873416, first_name='Margaux', last_name='Wintringham', gender='Female', language='Tajik', vehicle_make='Ford', vehicle_model='Thunderbird', model_year=2005, employer='Altenwerth-Emard', department='Marketing', employee_id=305847411, last_updated=datetime.datetime(2017, 5, 3, 14, 26, 58), created=datetime.datetime(2016, 12, 26, 21, 18, 54)), FulL_Data(ssn=146813446, first_name='Korry', last_name='Billham', gender='Female', language='Hebrew', vehicle_make='Ford', vehicle_model='Thunderbird', model_year=1988, employer='Kub, Koch and Ratke', department='Marketing', employee_id=727830449, last_updated=datetime.datetime(2017, 1, 18, 8, 40, 14), created=datetime.datetime(2016, 9, 1, 8, 59, 50)), FulL_Data(ssn=147633462, first_name='Aime', last_name='Di Antonio', gender='Female', language='Tok Pisin', vehicle_make='Ford', vehicle_model='Explorer', model_year=2005, employer='Bashirian-Moen', department='Training', employee_id=519115041, last_updated=datetime.datetime(2018, 2, 2, 13, 16, 51), created=datetime.datetime(2016, 7, 17, 4, 28, 52)), FulL_Data(ssn=153671309, first_name='Annelise', last_name='Yushin', gender='Female', language='French', vehicle_make='Ford', vehicle_model='Taurus', model_year=1998, employer='Gerlach, Bahringer and Rutherford', department='Accounting', employee_id=955604381, last_updated=datetime.datetime(2017, 8, 16, 12, 3, 37), created=datetime.datetime(2016, 12, 22, 19, 37, 39)), FulL_Data(ssn=161534778, first_name='Kiri', last_name='Ciccone', gender='Female', language='Kyrgyz', vehicle_make='Ford', vehicle_model='Mustang', model_year=1995, employer='Oberbrunner, Donnelly and Gibson', department='Human Resources', employee_id=832548521, last_updated=datetime.datetime(2017, 12, 3, 11, 9, 18), created=datetime.datetime(2016, 12, 9, 18, 37, 55)), FulL_Data(ssn=171277781, first_name='Phillida', last_name='Cleeve', gender='Female', language='Lao', vehicle_make='Ford', vehicle_model='Mustang', model_year=1985, employer='Batz Inc', department='Support', employee_id=492738721, last_updated=datetime.datetime(2017, 3, 5, 9, 35, 8), created=datetime.datetime(2016, 9, 23, 3, 10, 37)), FulL_Data(ssn=184606243, first_name='Fern', last_name='Demogeot', gender='Female', language='Tok Pisin', vehicle_make='Ford', vehicle_model='Mustang', model_year=1998, employer='Quitzon-Morissette', department='Product Management', employee_id=815434446, last_updated=datetime.datetime(2018, 2, 26, 15, 42, 50), created=datetime.datetime(2016, 6, 16, 15, 17, 46)), FulL_Data(ssn=211041734, first_name='Jeana', last_name='Girardeau', gender='Female', language='Dzongkha', vehicle_make='Ford', vehicle_model='E-Series', model_year=2011, employer='Renner LLC', department='Services', employee_id=296760360, last_updated=datetime.datetime(2018, 3, 11, 20, 29, 12), created=datetime.datetime(2016, 8, 30, 15, 59, 14)), FulL_Data(ssn=211196826, first_name='Noni', last_name='Meynell', gender='Female', languag ...
#
# GMC [FulL_Data(ssn=101840356, first_name='Nomi', last_name='Lipprose', gender='Female', language='Yiddish', vehicle_make='GMC', vehicle_model='Yukon', model_year=2005, employer='Connelly Group', department='Research and Development', employee_id=987952860, last_updated=datetime.datetime(2017, 10, 4, 11, 21, 30), created=datetime.datetime(2016, 9, 21, 23, 4, 7)), FulL_Data(ssn=118210357, first_name='Laina', last_name='Bayly', gender='Female', language='Bulgarian', vehicle_make='GMC', vehicle_model='3500 Club Coupe', model_year=1992, employer='Hane-Klocko', department='Human Resources', employee_id=272946273, last_updated=datetime.datetime(2017, 12, 13, 9, 36, 48), created=datetime.datetime(2016, 10, 24, 3, 40, 22)), FulL_Data(ssn=127492473, first_name='Quinta', last_name='Rippingall', gender='Female', language='Haitian Creole', vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2004, employer='Tromp-Leffler', department='Support', employee_id=26267170, last_updated=datetime.datetime(2017, 8, 31, 10, 3, 3), created=datetime.datetime(2016, 8, 29, 18, 48, 40)), FulL_Data(ssn=152713526, first_name='Mel', last_name='Atkirk', gender='Female', language='Swedish', vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2001, employer='Little, Hagenes and McKenzie', department='Training', employee_id=759906937, last_updated=datetime.datetime(2018, 2, 25, 4, 17, 50), created=datetime.datetime(2016, 10, 8, 19, 49, 4)), FulL_Data(ssn=167392377, first_name='Reyna', last_name='Ullyatt', gender='Female', language='Portuguese', vehicle_make='GMC', vehicle_model='3500', model_year=1998, employer='Howell LLC', department='Business Development', employee_id=702399476, last_updated=datetime.datetime(2017, 10, 31, 22, 27, 7), created=datetime.datetime(2016, 2, 3, 10, 32, 1)), FulL_Data(ssn=181288337, first_name='Fan', last_name='Hillyatt', gender='Female', language='Moldovan', vehicle_make='GMC', vehicle_model='Canyon', model_year=2004, employer='Kertzmann-Reichel', department='Research and Development', employee_id=670581933, last_updated=datetime.datetime(2017, 11, 30, 23, 28), created=datetime.datetime(2016, 4, 27, 20, 53, 49)), FulL_Data(ssn=231669264, first_name='Gisele', last_name='Castelow', gender='Female', language='Hiri Motu', vehicle_make='GMC', vehicle_model='Sonoma Club Coupe', model_year=1994, employer='Dare, Kuhn and Pfannerstill', department='Marketing', employee_id=683132488, last_updated=datetime.datetime(2017, 4, 7, 22, 50, 50), created=datetime.datetime(2016, 6, 1, 8, 10, 38)), FulL_Data(ssn=236372567, first_name='Ariel', last_name='Murrigan', gender='Female', language='West Frisian', vehicle_make='GMC', vehicle_model='3500', model_year=1992, employer='Tremblay LLC', department='Research and Development', employee_id=456122996, last_updated=datetime.datetime(2017, 9, 1, 17, 59, 5), created=datetime.datetime(2016, 3, 1, 16, 19, 30)), FulL_Data(ssn=296327910, first_name='Harlene', last_name='Morrill', gender='Female', language='Swati', vehicle_make='GMC', vehicle_model='Yukon XL 2500', model_year=2009, employer='Collier-Wisozk', department='Legal', employee_id=403440604, last_updated=datetime.datetime(2017, 5, 8, 14, 27, 35), created=datetime.datetime(2016, 11, 18, 18, 55, 41)), FulL_Data(ssn=306862930, first_name='Kassie', last_name='Neaverson', gender='Female', language='Luxembourgish', vehicle_make='GMC', vehicle_model='Sierra Denali', model_year=2006, employer='Considine-Schaefer', department='Human Resources', employee_id=588894681, last_updated=datetime.datetime(2017, 5, 10, 18, 3, 52), created=datetime.datetime(2016, 9, 15, 15, 20, 35)), FulL_Data(ssn=342550538, first_name='Hilliary', last_name='Suddards', gender='Female', language='Dzongkha', vehicle_make='GMC', vehicle_model='Sierra', model_year=2012, employer='Pouros-Kohler', department='Legal', employee_id=760199175, last_updated=datetime.datetime(2017, 8, 30, 11, 9, 11), created=datetime.datetime(2016, 1, 1, 10, 27, 44)), FulL_Data(ssn=461842780, first_nam ...
#
# Geo [FulL_Data(ssn=408983291, first_name='Karia', last_name='Riquet', gender='Female', language='Italian', vehicle_make='Geo', vehicle_model='Metro', model_year=1992, employer='Gibson LLC', department='Training', employee_id=758998272, last_updated=datetime.datetime(2017, 5, 14, 10, 52, 18), created=datetime.datetime(2016, 4, 17, 22, 36, 47))]
#
# Honda [FulL_Data(ssn=163981022, first_name='Babbette', last_name='Crystal', gender='Female', language='Lithuanian', vehicle_make='Honda', vehicle_model='Civic', model_year=2012, employer='Olson-Lynch', department='Business Development', employee_id=507113609, last_updated=datetime.datetime(2017, 3, 26, 4, 2, 28), created=datetime.datetime(2016, 3, 22, 11, 24, 33)), FulL_Data(ssn=324395230, first_name='Alexandrina', last_name='Dahlbom', gender='Female', language='Moldovan', vehicle_make='Honda', vehicle_model='Prelude', model_year=1997, employer='Kovacek, Effertz and Rodriguez', department='Accounting', employee_id=543498156, last_updated=datetime.datetime(2017, 12, 12, 18, 34, 16), created=datetime.datetime(2016, 8, 10, 15, 8, 1)), FulL_Data(ssn=379078748, first_name='Dyanna', last_name='Noto', gender='Female', language='Polish', vehicle_make='Honda', vehicle_model='Accord', model_year=2011, employer='Dach-Torp', department='Product Management', employee_id=591247068, last_updated=datetime.datetime(2018, 1, 12, 10, 47, 39), created=datetime.datetime(2016, 1, 16, 3, 56, 28)), FulL_Data(ssn=380353854, first_name='Cathleen', last_name='Sizland', gender='Female', language='Bislama', vehicle_make='Honda', vehicle_model='Passport', model_year=1994, employer='Larkin, Bode and Moen', department='Services', employee_id=721163753, last_updated=datetime.datetime(2017, 2, 17, 21, 55, 47), created=datetime.datetime(2016, 7, 31, 20, 6, 38)), FulL_Data(ssn=389848254, first_name='Chiquita', last_name='Jolliman', gender='Female', language='Marathi', vehicle_make='Honda', vehicle_model='S2000', model_year=2006, employer='Little, Johns and Kuphal', department='Human Resources', employee_id=585489644, last_updated=datetime.datetime(2017, 8, 14, 20, 14, 13), created=datetime.datetime(2016, 5, 2, 7, 4, 51)), FulL_Data(ssn=440604889, first_name='Evanne', last_name='Loosely', gender='Female', language='Ndebele', vehicle_make='Honda', vehicle_model='Ridgeline', model_year=2011, employer='Schaefer, McDermott and Bradtke', department='Training', employee_id=908995592, last_updated=datetime.datetime(2017, 5, 30, 16, 28, 38), created=datetime.datetime(2016, 11, 5, 0, 32, 24)), FulL_Data(ssn=499074759, first_name='Kizzee', last_name='MacTrustam', gender='Female', language='Norwegian', vehicle_make='Honda', vehicle_model='Civic Si', model_year=2006, employer='Beer-Nitzsche', department='Product Management', employee_id=908245850, last_updated=datetime.datetime(2017, 6, 28, 19, 29, 35), created=datetime.datetime(2016, 8, 7, 22, 19, 21)), FulL_Data(ssn=528107051, first_name='Leonie', last_name='Sondon', gender='Female', language='Romanian', vehicle_make='Honda', vehicle_model='Element', model_year=2009, employer='Gerlach, Haag and Marvin', department='Research and Development', employee_id=787465299, last_updated=datetime.datetime(2017, 4, 14, 11, 4, 37), created=datetime.datetime(2016, 8, 19, 5, 19, 6)), FulL_Data(ssn=566620141, first_name='Tiffanie', last_name='McNamee', gender='Female', language='Polish', vehicle_make='Honda', vehicle_model='S2000', model_year=2005, employer='Rau, Jakubowski and Crona', department='Accounting', employee_id=46247743, last_updated=datetime.datetime(2017, 2, 18, 7, 17, 52), created=datetime.datetime(2016, 1, 11, 4, 58, 23)), FulL_Data(ssn=822304861, first_name='Phyllis', last_name='Cronk', gender='Female', language='Fijian', vehicle_make='Honda', vehicle_model='Element', model_year=2010, employer='Halvorson, Hirthe and Quitzon', department='Marketing', employee_id=678224406, last_updated=datetime.datetime(2018, 3, 6, 15, 41, 52), created=datetime.datetime(2016, 11, 5, 5, 11, 25))]
#
# Hyundai [FulL_Data(ssn=391149280, first_name='Faun', last_name='Chillistone', gender='Female', language='Montenegrin', vehicle_make='Hyundai', vehicle_model='Genesis', model_year=2010, employer='Friesen, Goyette and Satterfield', department='Research and Development', employee_id=161384768, last_updated=datetime.datetime(2018, 2, 16, 3, 12, 49), created=datetime.datetime(2016, 3, 16, 11, 53, 37)), FulL_Data(ssn=397298349, first_name='Madelle', last_name='Mapledorum', gender='Female', language='Tok Pisin', vehicle_make='Hyundai', vehicle_model='Elantra', model_year=1995, employer='Okuneva-Lehner', department='Sales', employee_id=464308357, last_updated=datetime.datetime(2018, 3, 22, 14, 14, 2), created=datetime.datetime(2016, 5, 29, 20, 18, 22)), FulL_Data(ssn=807246202, first_name='Lanette', last_name='Elvins', gender='Female', language='Hiri Motu', vehicle_make='Hyundai', vehicle_model='Accent', model_year=2000, employer='King Inc', department='Marketing', employee_id=284538440, last_updated=datetime.datetime(2017, 12, 22, 4, 19, 35), created=datetime.datetime(2016, 2, 20, 3, 53, 16)), FulL_Data(ssn=848742886, first_name='Helyn', last_name='Witheford', gender='Female', language='Bislama', vehicle_make='Hyundai', vehicle_model='Accent', model_year=2011, employer='Macejkovic and Sons', department='Support', employee_id=520638791, last_updated=datetime.datetime(2017, 4, 28, 22, 57, 18), created=datetime.datetime(2016, 3, 16, 18, 7, 48))]
#
# ...
#
# Toyota [FulL_Data(ssn=135869625, first_name='Tilly', last_name='Meir', gender='Female', language='Gagauz', vehicle_make='Toyota', vehicle_model='Tundra', model_year=2004, employer='Hyatt LLC', department='Training', employee_id=969647102, last_updated=datetime.datetime(2017, 12, 22, 4, 4, 28), created=datetime.datetime(2016, 2, 28, 23, 53, 17)), FulL_Data(ssn=141150543, first_name='Candy', last_name='Murtagh', gender='Female', language='Montenegrin', vehicle_make='Toyota', vehicle_model='Corolla', model_year=2000, employer='Greenholt LLC', department='Sales', employee_id=845391800, last_updated=datetime.datetime(2017, 9, 27, 10, 29, 9), created=datetime.datetime(2016, 7, 17, 22, 40, 37)), FulL_Data(ssn=176821359, first_name='Corny', last_name='Rothera', gender='Female', language='Thai', vehicle_make='Toyota', vehicle_model='Celica', model_year=1995, employer='Brown Group', department='Accounting', employee_id=910435820, last_updated=datetime.datetime(2017, 1, 14, 13, 36, 1), created=datetime.datetime(2016, 11, 29, 19, 3, 42)), FulL_Data(ssn=262667030, first_name='Gray', last_name='Bissatt', gender='Female', language='Khmer', vehicle_make='Toyota', vehicle_model='T100 Xtra', model_year=1998, employer='Jacobson LLC', department='Research and Development', employee_id=834988535, last_updated=datetime.datetime(2018, 1, 23, 23, 44, 35), created=datetime.datetime(2016, 3, 22, 3, 8, 3)), FulL_Data(ssn=278555842, first_name='Korie', last_name='Di Pietro', gender='Female', language='German', vehicle_make='Toyota', vehicle_model='Highlander', model_year=2002, employer='Pfannerstill-Rowe', department='Sales', employee_id=50913038, last_updated=datetime.datetime(2018, 1, 2, 5, 17, 17), created=datetime.datetime(2016, 5, 1, 8, 36, 52)), FulL_Data(ssn=297631154, first_name='Maribelle', last_name='Gowanson', gender='Female', language='Montenegrin', vehicle_make='Toyota', vehicle_model='Camry', model_year=2001, employer='Stark-Wolff', department='Product Management', employee_id=656789812, last_updated=datetime.datetime(2018, 1, 18, 23, 20, 37), created=datetime.datetime(2016, 3, 3, 14, 10, 1)), FulL_Data(ssn=327887554, first_name='Malynda', last_name='Kingerby', gender='Female', language='Swahili', vehicle_make='Toyota', vehicle_model='Corolla', model_year=1994, employer='Lowe, Tromp and Orn', department='Product Management', employee_id=955467981, last_updated=datetime.datetime(2017, 11, 24, 22, 24, 17), created=datetime.datetime(2016, 10, 12, 9, 25, 25)), FulL_Data(ssn=362098563, first_name='Carri', last_name='Peterffy', gender='Female', language='Icelandic', vehicle_make='Toyota', vehicle_model='Paseo', model_year=1995, employer='Kautzer and Sons', department='Research and Development', employee_id=560050837, last_updated=datetime.datetime(2017, 2, 7, 23, 59, 48), created=datetime.datetime(2016, 7, 4, 3, 26, 36)), FulL_Data(ssn=406490634, first_name='Lolita', last_name='Dailey', gender='Female', language='Czech', vehicle_make='Toyota', vehicle_model='Corolla', model_year=2003, employer='Bashirian Group', department='Legal', employee_id=674961160, last_updated=datetime.datetime(2017, 5, 10, 9, 45, 50), created=datetime.datetime(2016, 9, 6, 20, 39, 43)), FulL_Data(ssn=409908946, first_name='Doralia', last_name='Proughten', gender='Female', language='Estonian', vehicle_make='Toyota', vehicle_model='Paseo', model_year=1994, employer='Yost and Sons', department='Sales', employee_id=77718175, last_updated=datetime.datetime(2017, 8, 14, 2, 56, 14), created=datetime.datetime(2016, 7, 13, 17, 13, 48)), FulL_Data(ssn=411794655, first_name='Caterina', last_name='Coey', gender='Female', language='French', vehicle_make='Toyota', vehicle_model='Sienna', model_year=2003, employer='Gleason LLC', department='Product Management', employee_id=79043060, last_updated=datetime.datetime(2017, 8, 9, 14, 41, 54), created=datetime.datetime(2016, 7, 14, 9, 28, 46)), FulL_Data(ssn=421887316, first_name='Cherie', last_name='Yeudall', gender='Female', language='Dutch' ...
#
# Volkswagen [FulL_Data(ssn=212411496, first_name='Agnese', last_name='Lawes', gender='Female', language='Tamil', vehicle_make='Volkswagen', vehicle_model='Eurovan', model_year=1995, employer='Hills-Luettgen', department='Engineering', employee_id=496662355, last_updated=datetime.datetime(2017, 7, 7, 20, 29, 9), created=datetime.datetime(2016, 10, 27, 12, 47, 10)), FulL_Data(ssn=351732802, first_name='Cybill', last_name='Parnham', gender='Female', language='Latvian', vehicle_make='Volkswagen', vehicle_model='Jetta', model_year=2001, employer='Goodwin, Luettgen and Harvey', department='Human Resources', employee_id=914775280, last_updated=datetime.datetime(2017, 8, 11, 7, 49, 34), created=datetime.datetime(2016, 9, 3, 2, 20, 26)), FulL_Data(ssn=451345996, first_name='Dolly', last_name='Pennyman', gender='Female', language='Spanish', vehicle_make='Volkswagen', vehicle_model='Routan', model_year=2011, employer='Gutmann, Gibson and Hilpert', department='Research and Development', employee_id=323330955, last_updated=datetime.datetime(2017, 6, 22, 16, 58, 53), created=datetime.datetime(2016, 11, 18, 23, 32, 30)), FulL_Data(ssn=495642134, first_name='Noami', last_name='Schuck', gender='Female', language='Nepali', vehicle_make='Volkswagen', vehicle_model='Jetta', model_year=1999, employer='Heller-Connelly', department='Sales', employee_id=593433099, last_updated=datetime.datetime(2018, 3, 2, 1, 16, 24), created=datetime.datetime(2016, 4, 8, 1, 38, 27)), FulL_Data(ssn=497732347, first_name='Rana', last_name='Duhig', gender='Female', language='Indonesian', vehicle_make='Volkswagen', vehicle_model='New Beetle', model_year=2010, employer='Bartell, Friesen and Lakin', department='Sales', employee_id=807946674, last_updated=datetime.datetime(2017, 9, 26, 9, 31), created=datetime.datetime(2016, 8, 27, 16, 39, 43)), FulL_Data(ssn=515471848, first_name='Darla', last_name='Leftridge', gender='Female', language='Finnish', vehicle_make='Volkswagen', vehicle_model='Passat', model_year=1987, employer='Batz-Effertz', department='Marketing', employee_id=476735310, last_updated=datetime.datetime(2018, 2, 9, 16, 48, 47), created=datetime.datetime(2016, 10, 5, 9, 32, 19)), FulL_Data(ssn=551574018, first_name='Magdalena', last_name='Morland', gender='Female', language='Gagauz', vehicle_make='Volkswagen', vehicle_model='Passat', model_year=2010, employer='Skiles-Botsford', department='Research and Development', employee_id=909959175, last_updated=datetime.datetime(2018, 3, 20, 20, 28, 18), created=datetime.datetime(2016, 6, 18, 20, 47, 47)), FulL_Data(ssn=556134040, first_name='Mignonne', last_name='Beckett', gender='Female', language='Catalan', vehicle_make='Volkswagen', vehicle_model='GTI', model_year=2002, employer='Gutmann-Rau', department='Accounting', employee_id=832806591, last_updated=datetime.datetime(2017, 4, 30, 7, 12, 18), created=datetime.datetime(2016, 11, 27, 10, 43, 54)), FulL_Data(ssn=797652382, first_name='Marianne', last_name='Huccaby', gender='Female', language='Swedish', vehicle_make='Volkswagen', vehicle_model='Scirocco', model_year=1985, employer='Walker-Lemke', department='Research and Development', employee_id=520032929, last_updated=datetime.datetime(2017, 1, 24, 12, 7, 57), created=datetime.datetime(2016, 2, 25, 16, 22, 8)), FulL_Data(ssn=797877992, first_name='Lonna', last_name='Plumridge', gender='Female', language='Armenian', vehicle_make='Volkswagen', vehicle_model='Scirocco', model_year=1985, employer='Becker, Ferry and Kulas', department='Human Resources', employee_id=830034047, last_updated=datetime.datetime(2018, 2, 24, 14, 55, 36), created=datetime.datetime(2016, 10, 19, 9, 48, 40)), FulL_Data(ssn=899476116, first_name='Tiphanie', last_name='Kevlin', gender='Female', language='Tetum', vehicle_make='Volkswagen', vehicle_model='Phaeton', model_year=2005, employer='Bednar LLC', department='Support', employee_id=166342889, last_updated=datetime.datetime(2017, 6, 10, 11, 20, 41), created=datetime.datetime(2016, 4, 29, 12, 25,  ...
#
# Volvo [FulL_Data(ssn=139996417, first_name='Susanetta', last_name='Nazaret', gender='Female', language='Punjabi', vehicle_make='Volvo', vehicle_model='V70', model_year=2002, employer='Pollich-Heathcote', department='Product Management', employee_id=122844710, last_updated=datetime.datetime(2018, 1, 17, 17, 51, 12), created=datetime.datetime(2016, 12, 21, 14, 14, 20)), FulL_Data(ssn=140588263, first_name='Tim', last_name='Bergin', gender='Female', language='Maori', vehicle_make='Volvo', vehicle_model='XC90', model_year=2009, employer='Gutkowski Inc', department='Engineering', employee_id=834836768, last_updated=datetime.datetime(2017, 11, 12, 21, 41, 50), created=datetime.datetime(2016, 12, 14, 20, 27, 22)), FulL_Data(ssn=206838848, first_name='Ardyth', last_name='Arger', gender='Female', language='Gagauz', vehicle_make='Volvo', vehicle_model='S60', model_year=2011, employer='Hickle, Beatty and McCullough', department='Business Development', employee_id=957755368, last_updated=datetime.datetime(2017, 11, 8, 14, 57, 17), created=datetime.datetime(2016, 4, 11, 17, 40, 42)), FulL_Data(ssn=287662660, first_name='Larissa', last_name='Airy', gender='Female', language='Bislama', vehicle_make='Volvo', vehicle_model='V50', model_year=2010, employer='Collier Inc', department='Research and Development', employee_id=815101189, last_updated=datetime.datetime(2018, 1, 8, 5, 9, 53), created=datetime.datetime(2016, 1, 3, 15, 12, 3)), FulL_Data(ssn=294531911, first_name='Ginelle', last_name='Jaquet', gender='Female', language='Persian', vehicle_make='Volvo', vehicle_model='XC60', model_year=2012, employer='Little, Veum and Sauer', department='Legal', employee_id=457118863, last_updated=datetime.datetime(2018, 3, 8, 15, 24, 15), created=datetime.datetime(2016, 7, 22, 21, 42, 17)), FulL_Data(ssn=378080805, first_name='Carroll', last_name='Harty', gender='Female', language='Swedish', vehicle_make='Volvo', vehicle_model='S40', model_year=2010, employer='Reynolds, Stroman and Pagac', department='Marketing', employee_id=810595624, last_updated=datetime.datetime(2017, 1, 15, 7, 10, 9), created=datetime.datetime(2016, 9, 4, 16, 17, 45)), FulL_Data(ssn=385301777, first_name='Aubrey', last_name='Wetherill', gender='Female', language='Tswana', vehicle_make='Volvo', vehicle_model='S80', model_year=2009, employer='Monahan, Weber and Reynolds', department='Sales', employee_id=593207276, last_updated=datetime.datetime(2017, 8, 5, 3, 34, 46), created=datetime.datetime(2016, 7, 30, 16, 51, 41)), FulL_Data(ssn=485390911, first_name='Rea', last_name='Buzek', gender='Female', language='Croatian', vehicle_make='Volvo', vehicle_model='S40', model_year=2003, employer='Schamberger-Hirthe', department='Services', employee_id=487268338, last_updated=datetime.datetime(2017, 6, 22, 9, 16, 31), created=datetime.datetime(2016, 2, 5, 20, 25, 20)), FulL_Data(ssn=595671091, first_name='Odette', last_name='Delue', gender='Female', language='Filipino', vehicle_make='Volvo', vehicle_model='C70', model_year=2002, employer='Hegmann, Treutel and Hudson', department='Business Development', employee_id=438081335, last_updated=datetime.datetime(2017, 7, 1, 9, 48, 41), created=datetime.datetime(2016, 9, 4, 4, 32, 10)), FulL_Data(ssn=634428798, first_name='Tomasine', last_name='Dron', gender='Female', language='English', vehicle_make='Volvo', vehicle_model='S40', model_year=2004, employer='Schowalter and Sons', department='Human Resources', employee_id=599431329, last_updated=datetime.datetime(2017, 1, 20, 7, 0, 33), created=datetime.datetime(2016, 8, 7, 10, 51, 44)), FulL_Data(ssn=692310697, first_name='Blondell', last_name='Wrigley', gender='Female', language='Persian', vehicle_make='Volvo', vehicle_model='850', model_year=1997, employer='Smith-Boehm', department='Training', employee_id=580730098, last_updated=datetime.datetime(2018, 1, 28, 18, 18, 17), created=datetime.datetime(2016, 5, 22, 21, 42, 24)), FulL_Data(ssn=729951691, first_name='Marion', last_name='Danson', gender='Female' ...

# %%
def get_largest_group(groups):
    return sorted(groups, key=lambda group : sum(1 for _ in group[1]), reverse = True)

# %%
groups = get_filtered_grouped_data('personal_info.csv', 'vehicles.csv', 'employment.csv', 'update_status.csv',
                             filter_key = lambda x : x.gender == 'Female',
                                group_by = lambda x : x.vehicle_make)

# %%
for make, group in groups:
    print(f'\t\t\t\t\t\t------------------{make}-------------------')
    for person in group:
        print(person)
    print()
# Out:
# 						------------------Acura-------------------
# FulL_Data(ssn=156916848, first_name='Carol', last_name='Cromar', gender='Female', language='Amharic', vehicle_make='Acura', vehicle_model='TL', model_year=2005, employer='King LLC', department='Research and Development', employee_id=394026042, last_updated=datetime.datetime(2017, 8, 30, 22, 29, 10), created=datetime.datetime(2016, 5, 7, 6, 45, 32))
# FulL_Data(ssn=210914729, first_name='Tamarra', last_name='Minchella', gender='Female', language='Greek', vehicle_make='Acura', vehicle_model='Integra', model_year=1997, employer='Weber, Reynolds and Brakus', department='Training', employee_id=260100410, last_updated=datetime.datetime(2017, 7, 11, 8, 17, 40), created=datetime.datetime(2016, 12, 4, 0, 41, 8))
# FulL_Data(ssn=298706018, first_name='Minny', last_name='Van der Baaren', gender='Female', language='Afrikaans', vehicle_make='Acura', vehicle_model='NSX', model_year=1997, employer='Sporer, Haley and Cartwright', department='Legal', employee_id=728129260, last_updated=datetime.datetime(2018, 2, 12, 10, 5, 39), created=datetime.datetime(2016, 3, 28, 9, 53, 54))
# FulL_Data(ssn=371623727, first_name='Cymbre', last_name='Chinnock', gender='Female', language='Dutch', vehicle_make='Acura', vehicle_model='NSX', model_year=2004, employer='Gleichner Group', department='Research and Development', employee_id=527507546, last_updated=datetime.datetime(2017, 7, 26, 23, 48, 15), created=datetime.datetime(2016, 8, 16, 8, 13, 41))
# FulL_Data(ssn=399638810, first_name='Bobbee', last_name='Postians', gender='Female', language='Papiamento', vehicle_make='Acura', vehicle_model='Integra', model_year=1992, employer='Mills, Barton and Lakin', department='Product Management', employee_id=741474493, last_updated=datetime.datetime(2018, 3, 5, 13, 5, 28), created=datetime.datetime(2016, 2, 29, 5, 22, 17))
# FulL_Data(ssn=509464927, first_name='Nickie', last_name='Dabes', gender='Female', language='Sotho', vehicle_make='Acura', vehicle_model='TL', model_year=2002, employer='Lemke, Schinner and Schaefer', department='Training', employee_id=86600485, last_updated=datetime.datetime(2017, 2, 11, 13, 16, 34), created=datetime.datetime(2016, 4, 1, 5, 21, 28))
# FulL_Data(ssn=644682955, first_name='Catrina', last_name='Gerardin', gender='Female', language='Gagauz', vehicle_make='Acura', vehicle_model='RDX', model_year=2012, employer='Stracke LLC', department='Business Development', employee_id=102258220, last_updated=datetime.datetime(2017, 10, 11, 12, 51, 58), created=datetime.datetime(2016, 6, 21, 12, 1, 17))
# FulL_Data(ssn=670893434, first_name='Elvina', last_name='Scowcroft', gender='Female', language='Albanian', vehicle_make='Acura', vehicle_model='Legend', model_year=1988, employer='Mann, Trantow and Gusikowski', department='Marketing', employee_id=258521955, last_updated=datetime.datetime(2017, 3, 27, 4, 0, 1), created=datetime.datetime(2016, 11, 3, 11, 39, 45))
# FulL_Data(ssn=687275241, first_name='Hildegarde', last_name='Crosoer', gender='Female', language='Marathi', vehicle_make='Acura', vehicle_model='TSX', model_year=2011, employer='Klocko LLC', department='Human Resources', employee_id=306205049, last_updated=datetime.datetime(2017, 2, 14, 9, 45, 31), created=datetime.datetime(2016, 10, 29, 23, 44, 20))
# FulL_Data(ssn=822059037, first_name='Meggi', last_name='Mapes', gender='Female', language='Moldovan', vehicle_make='Acura', vehicle_model='MDX', model_year=2001, employer='Crona, Bogan and Beatty', department='Business Development', employee_id=3394171, last_updated=datetime.datetime(2017, 11, 14, 6, 43, 11), created=datetime.datetime(2016, 3, 28, 1, 5, 25))
# FulL_Data(ssn=872491288, first_name='Salaidh', last_name='Barthod', gender='Female', language='Finnish', vehicle_make='Acura', vehicle_model='Integra', model_year=1997, employer='Cummings-Mertz', department='Sales', employee_id=782291834, last_updated=datetime.datetime(2017, 12, 6, 2, 19, 8), created=datetime.datetime(2016, 6, 10, 10, 5, 19))
#
# 						------------------Aston Martin-------------------
# FulL_Data(ssn=240676258, first_name='Kalina', last_name='Lloyds', gender='Female', language='Hindi', vehicle_make='Aston Martin', vehicle_model='V8 Vantage', model_year=2008, employer='Donnelly-Reichel', department='Sales', employee_id=516219405, last_updated=datetime.datetime(2017, 10, 17, 17, 8, 33), created=datetime.datetime(2016, 5, 24, 9, 11, 51))
# FulL_Data(ssn=386973523, first_name='Siusan', last_name='Durkin', gender='Female', language='Kurdish', vehicle_make='Aston Martin', vehicle_model='V8 Vantage S', model_year=2011, employer='Durgan LLC', department='Business Development', employee_id=758054834, last_updated=datetime.datetime(2017, 11, 13, 13, 40, 53), created=datetime.datetime(2016, 1, 9, 18, 15, 53))
#
# 						------------------Audi-------------------
# FulL_Data(ssn=157179982, first_name='Ardyce', last_name='Kuhnel', gender='Female', language='Danish', vehicle_make='Audi', vehicle_model='Q7', model_year=2007, employer='Konopelski-Vandervort', department='Legal', employee_id=878332368, last_updated=datetime.datetime(2017, 4, 17, 9, 11, 49), created=datetime.datetime(2016, 3, 17, 0, 22, 29))
# FulL_Data(ssn=247865288, first_name='Lilly', last_name='Holby', gender='Female', language='Bosnian', vehicle_make='Audi', vehicle_model='Q5', model_year=2010, employer='Flatley, Braun and Wiegand', department='Product Management', employee_id=838221727, last_updated=datetime.datetime(2017, 8, 7, 13, 12, 28), created=datetime.datetime(2016, 1, 13, 5, 54, 25))
# FulL_Data(ssn=304484312, first_name='Edeline', last_name='Van de Vlies', gender='Female', language='Montenegrin', vehicle_make='Audi', vehicle_model='Allroad', model_year=2005, employer='Stamm-Reichert', department='Engineering', employee_id=254364794, last_updated=datetime.datetime(2017, 6, 8, 17, 56, 34), created=datetime.datetime(2016, 7, 23, 15, 40, 8))
# FulL_Data(ssn=315785587, first_name='Helsa', last_name='Lumber', gender='Female', language='Tok Pisin', vehicle_make='Audi', vehicle_model='5000S', model_year=1984, employer='Wehner-Parker', department='Product Management', employee_id=35512362, last_updated=datetime.datetime(2017, 8, 20, 18, 9, 2), created=datetime.datetime(2016, 1, 17, 12, 12, 42))
# FulL_Data(ssn=345742160, first_name='Camile', last_name='Pengelly', gender='Female', language='Lao', vehicle_make='Audi', vehicle_model='S8', model_year=2002, employer='Jaskolski, Batz and Rempel', department='Marketing', employee_id=829497860, last_updated=datetime.datetime(2018, 2, 4, 4, 8, 54), created=datetime.datetime(2016, 7, 13, 23, 35, 12))
# FulL_Data(ssn=361835004, first_name='Wilona', last_name='Sink', gender='Female', language='Sotho', vehicle_make='Audi', vehicle_model='S4', model_year=2013, employer="D'Amore LLC", department='Services', employee_id=613591939, last_updated=datetime.datetime(2017, 8, 11, 21, 27, 23), created=datetime.datetime(2016, 12, 24, 3, 19, 11))
# FulL_Data(ssn=390743062, first_name='Cara', last_name='Ingree', gender='Female', language='Indonesian', vehicle_make='Audi', vehicle_model='TT', model_year=2002, employer='Bechtelar-McCullough', department='Sales', employee_id=11786654, last_updated=datetime.datetime(2017, 1, 1, 12, 23, 41), created=datetime.datetime(2016, 11, 14, 16, 22, 16))
# FulL_Data(ssn=409582034, first_name='Fiann', last_name='Corsar', gender='Female', language='Swahili', vehicle_make='Audi', vehicle_model='A4', model_year=2001, employer='Wilkinson Group', department='Accounting', employee_id=248239174, last_updated=datetime.datetime(2018, 1, 22, 3, 9, 50), created=datetime.datetime(2016, 6, 8, 17, 56, 28))
# FulL_Data(ssn=427360095, first_name='Shandee', last_name='Hawthorne', gender='Female', language='Gujarati', vehicle_make='Audi', vehicle_model='S5', model_year=2010, employer='Wiza Group', department='Sales', employee_id=682794098, last_updated=datetime.datetime(2017, 3, 20, 10, 29), created=datetime.datetime(2016, 5, 4, 1, 28, 15))
# FulL_Data(ssn=671768792, first_name='Melisse', last_name='Extil', gender='Female', language='Punjabi', vehicle_make='Audi', vehicle_model='Q7', model_year=2010, employer='Ruecker Inc', department='Accounting', employee_id=739942988, last_updated=datetime.datetime(2017, 10, 16, 1, 26, 58), created=datetime.datetime(2016, 3, 3, 1, 23, 14))
# FulL_Data(ssn=699174497, first_name='Eolanda', last_name='Shine', gender='Female', language='Estonian', vehicle_make='Audi', vehicle_model='A6', model_year=2008, employer='Heller-Price', department='Engineering', employee_id=461230529, last_updated=datetime.datetime(2018, 1, 28, 19, 14, 50), created=datetime.datetime(2016, 7, 1, 8, 2, 58))
# FulL_Data(ssn=719968751, first_name='Sallie', last_name='Gosnold', gender='Female', language='Catalan', vehicle_make='Audi', vehicle_model='4000', model_year=1987, employer='Koepp LLC', department='Human Resources', employee_id=346229266, last_updated=datetime.datetime(2017, 6, 9, 4, 59, 8), created=datetime.datetime(2016, 12, 7, 1, 36, 10))
# FulL_Data(ssn=765879144, first_name='Pandora', last_name='Paull', gender='Female', language='Tswana', vehicle_make='Audi', vehicle_model='A4', model_year=2001, employer='Hahn-Conn', department='Business Development', employee_id=894056804, last_updated=datetime.datetime(2017, 7, 10, 16, 23, 32), created=datetime.datetime(2016, 11, 4, 17, 25, 8))
# FulL_Data(ssn=887839002, first_name='Mab', last_name='Bozworth', gender='Female', language='Tok Pisin', vehicle_make='Audi', vehicle_model='S6', model_year=2011, employer='Terry and Sons', department='Research and Development', employee_id=69390159, last_updated=datetime.datetime(2017, 12, 19, 6, 24, 25), created=datetime.datetime(2016, 5, 30, 2, 40, 28))
#
# 						------------------Austin-------------------
# FulL_Data(ssn=777682978, first_name='Mignon', last_name='Skottle', gender='Female', language='Northern Sotho', vehicle_make='Austin', vehicle_model='Mini', model_year=1959, employer='Will, Crist and Jakubowski', department='Marketing', employee_id=224425487, last_updated=datetime.datetime(2018, 1, 16, 9, 16, 18), created=datetime.datetime(2016, 10, 1, 7, 34, 26))
#
# 						------------------BMW-------------------
# FulL_Data(ssn=128566040, first_name='Jinny', last_name='Stebbings', gender='Female', language='Armenian', vehicle_make='BMW', vehicle_model='M', model_year=2001, employer='Harris Inc', department='Support', employee_id=537535536, last_updated=datetime.datetime(2017, 8, 13, 2, 47, 15), created=datetime.datetime(2016, 3, 21, 8, 59, 56))
# FulL_Data(ssn=134050120, first_name='Simone', last_name='Cruickshanks', gender='Female', language='Filipino', vehicle_make='BMW', vehicle_model='M5', model_year=2006, employer='Donnelly-Crooks', department='Human Resources', employee_id=222943669, last_updated=datetime.datetime(2017, 1, 29, 11, 53, 22), created=datetime.datetime(2016, 8, 3, 4, 54, 40))
# FulL_Data(ssn=151781397, first_name='Portia', last_name='Belshaw', gender='Female', language='Sotho', vehicle_make='BMW', vehicle_model='M5', model_year=2000, employer='Schinner, Swaniawski and Carter', department='Human Resources', employee_id=933103060, last_updated=datetime.datetime(2017, 7, 8, 4, 22, 30), created=datetime.datetime(2016, 6, 11, 0, 28, 10))
# FulL_Data(ssn=157515269, first_name='Melisse', last_name='Petkov', gender='Female', language='Punjabi', vehicle_make='BMW', vehicle_model='Z3', model_year=1996, employer='Gerhold-Marquardt', department='Research and Development', employee_id=256013938, last_updated=datetime.datetime(2017, 11, 4, 20, 16, 50), created=datetime.datetime(2016, 6, 17, 10, 3, 2))
# FulL_Data(ssn=288547233, first_name='Hedy', last_name='Eaklee', gender='Female', language='English', vehicle_make='BMW', vehicle_model='5 Series', model_year=2008, employer='Beatty and Sons', department='Sales', employee_id=719137028, last_updated=datetime.datetime(2017, 4, 9, 3, 49, 3), created=datetime.datetime(2016, 1, 13, 21, 17, 3))
# FulL_Data(ssn=348743224, first_name='Dorthy', last_name='Abreheart', gender='Female', language='Bosnian', vehicle_make='BMW', vehicle_model='X6 M', model_year=2012, employer='Ledner and Sons', department='Engineering', employee_id=887250304, last_updated=datetime.datetime(2018, 2, 4, 18, 12, 54), created=datetime.datetime(2016, 5, 11, 22, 14, 46))
# FulL_Data(ssn=405251422, first_name='Raquel', last_name='Dukelow', gender='Female', language='Gujarati', vehicle_make='BMW', vehicle_model='5 Series', model_year=2006, employer='Keebler Group', department='Product Management', employee_id=576192942, last_updated=datetime.datetime(2017, 11, 21, 0, 0, 30), created=datetime.datetime(2016, 7, 16, 10, 8, 31))
# FulL_Data(ssn=484755799, first_name='Rhea', last_name='Braniff', gender='Female', language='Somali', vehicle_make='BMW', vehicle_model='M3', model_year=2005, employer='Collins-Schulist', department='Marketing', employee_id=903382110, last_updated=datetime.datetime(2018, 2, 12, 3, 45, 42), created=datetime.datetime(2016, 4, 12, 21, 29, 16))
# FulL_Data(ssn=541541497, first_name='Katuscha', last_name='Jovis', gender='Female', language='Irish Gaelic', vehicle_make='BMW', vehicle_model='M5', model_year=2007, employer="O'Kon, Ortiz and Cassin", department='Engineering', employee_id=8992736, last_updated=datetime.datetime(2017, 11, 27, 22, 19, 21), created=datetime.datetime(2016, 10, 18, 14, 16, 21))
# FulL_Data(ssn=654611601, first_name='Vinnie', last_name='Buzzing', gender='Female', language='Dhivehi', vehicle_make='BMW', vehicle_model='M5', model_year=2008, employer='Howe-Nitzsche', department='Engineering', employee_id=749663378, last_updated=datetime.datetime(2017, 9, 28, 18, 6, 41), created=datetime.datetime(2016, 5, 4, 2, 46, 14))
# FulL_Data(ssn=658340029, first_name='Chrysler', last_name='Bastistini', gender='Female', language='Tamil', vehicle_make='BMW', vehicle_model='M Roadster', model_year=2008, employer='Wolf, Gerhold and Dickens', department='Marketing', employee_id=156603582, last_updated=datetime.datetime(2017, 5, 1, 12, 27, 3), created=datetime.datetime(2016, 1, 25, 17, 21, 32))
# FulL_Data(ssn=861506716, first_name='Norina', last_name='Yerbury', gender='Female', language='Indonesian', vehicle_make='BMW', vehicle_model='M5', model_year=2007, employer='Stokes Inc', department='Training', employee_id=126635955, last_updated=datetime.datetime(2018, 3, 30, 21, 7, 8), created=datetime.datetime(2016, 9, 16, 9, 12, 34))
# FulL_Data(ssn=897767070, first_name='Glynnis', last_name='Tillerton', gender='Female', language='Nepali', vehicle_make='BMW', vehicle_model='X3', model_year=2011, employer='Reilly-Jakubowski', department='Marketing', employee_id=776363112, last_updated=datetime.datetime(2017, 11, 27, 19, 4, 22), created=datetime.datetime(2016, 12, 12, 7, 39, 48))
#
# 						------------------Bentley-------------------
# FulL_Data(ssn=216973104, first_name='Elvira', last_name='McDougal', gender='Female', language='Bislama', vehicle_make='Bentley', vehicle_model='Continental Super', model_year=2012, employer='Skiles, Reichel and Romaguera', department='Engineering', employee_id=398820670, last_updated=datetime.datetime(2017, 2, 10, 18, 28, 9), created=datetime.datetime(2016, 9, 6, 8, 20, 10))
# FulL_Data(ssn=300768770, first_name='Danielle', last_name='Rowth', gender='Female', language='Italian', vehicle_make='Bentley', vehicle_model='Arnage', model_year=2009, employer='McClure-Gerhold', department='Business Development', employee_id=19218158, last_updated=datetime.datetime(2017, 8, 21, 0, 3, 14), created=datetime.datetime(2016, 3, 13, 15, 45, 7))
# FulL_Data(ssn=599569050, first_name='Letti', last_name='Trappe', gender='Female', language='Maori', vehicle_make='Bentley', vehicle_model='Arnage', model_year=2008, employer='Koss-Windler', department='Human Resources', employee_id=65801036, last_updated=datetime.datetime(2018, 1, 12, 12, 2, 36), created=datetime.datetime(2016, 5, 21, 0, 57, 43))
# FulL_Data(ssn=617714058, first_name='Lynsey', last_name='Creser', gender='Female', language='Gujarati', vehicle_make='Bentley', vehicle_model='Arnage', model_year=2005, employer='Herman, Walter and Schoen', department='Marketing', employee_id=408324882, last_updated=datetime.datetime(2017, 8, 12, 4, 22, 36), created=datetime.datetime(2016, 5, 22, 22, 29, 31))
# FulL_Data(ssn=770618252, first_name='Elbertina', last_name='Colls', gender='Female', language='Chinese', vehicle_make='Bentley', vehicle_model='Arnage', model_year=2008, employer='Greenholt Inc', department='Business Development', employee_id=975181434, last_updated=datetime.datetime(2018, 2, 3, 13, 33, 14), created=datetime.datetime(2016, 4, 17, 6, 15, 58))
#
# 						------------------Bugatti-------------------
# FulL_Data(ssn=116107235, first_name='Chiquita', last_name='Danbi', gender='Female', language='Dari', vehicle_make='Bugatti', vehicle_model='Veyron', model_year=2009, employer='Pfannerstill Group', department='Research and Development', employee_id=431532437, last_updated=datetime.datetime(2017, 3, 10, 0, 31, 43), created=datetime.datetime(2016, 10, 17, 2, 11, 26))
#
# 						------------------Buick-------------------
# FulL_Data(ssn=262554066, first_name='Kaitlynn', last_name='Bleazard', gender='Female', language='Estonian', vehicle_make='Buick', vehicle_model='Regal', model_year=2002, employer='Schultz, West and Cummings', department='Research and Development', employee_id=818904444, last_updated=datetime.datetime(2017, 6, 3, 10, 15, 39), created=datetime.datetime(2016, 12, 20, 9, 49, 37))
# FulL_Data(ssn=283046835, first_name='Tobey', last_name='Joule', gender='Female', language='Dzongkha', vehicle_make='Buick', vehicle_model='LeSabre', model_year=2001, employer='Abbott, Bahringer and Goyette', department='Marketing', employee_id=415601892, last_updated=datetime.datetime(2017, 5, 29, 2, 43, 42), created=datetime.datetime(2016, 5, 17, 15, 7, 44))
# FulL_Data(ssn=315125664, first_name='Vere', last_name='Morlon', gender='Female', language='German', vehicle_make='Buick', vehicle_model='Riviera', model_year=1993, employer='Wiegand-Bernhard', department='Business Development', employee_id=575620609, last_updated=datetime.datetime(2017, 6, 11, 18, 3, 12), created=datetime.datetime(2016, 5, 19, 13, 58, 32))
# FulL_Data(ssn=372447487, first_name='Jolyn', last_name='Bertome', gender='Female', language='Catalan', vehicle_make='Buick', vehicle_model='Riviera', model_year=1991, employer='Fahey, Fahey and Gleason', department='Product Management', employee_id=28347934, last_updated=datetime.datetime(2017, 10, 1, 3, 0, 17), created=datetime.datetime(2016, 5, 15, 22, 58, 12))
# FulL_Data(ssn=446731646, first_name='Pattie', last_name='Ludwig', gender='Female', language='West Frisian', vehicle_make='Buick', vehicle_model='Regal', model_year=1996, employer='Fadel Group', department='Product Management', employee_id=353731698, last_updated=datetime.datetime(2017, 3, 23, 15, 31, 56), created=datetime.datetime(2016, 8, 25, 11, 40))
# FulL_Data(ssn=585032819, first_name='Breanne', last_name='Gorelli', gender='Female', language='Tamil', vehicle_make='Buick', vehicle_model='Regal', model_year=1997, employer='Will-Auer', department='Support', employee_id=417214465, last_updated=datetime.datetime(2017, 5, 14, 16, 27, 26), created=datetime.datetime(2016, 4, 7, 22, 6, 31))
# FulL_Data(ssn=595513047, first_name='Haley', last_name='Critchley', gender='Female', language='Ndebele', vehicle_make='Buick', vehicle_model='Skylark', model_year=1989, employer='Stehr Inc', department='Human Resources', employee_id=612533957, last_updated=datetime.datetime(2017, 3, 14, 22, 18, 40), created=datetime.datetime(2016, 2, 12, 17, 16, 20))
# FulL_Data(ssn=627361126, first_name='Milzie', last_name='Steabler', gender='Female', language='Tetum', vehicle_make='Buick', vehicle_model='LeSabre', model_year=1985, employer='Kulas-Vandervort', department='Human Resources', employee_id=776897439, last_updated=datetime.datetime(2018, 3, 17, 15, 40, 40), created=datetime.datetime(2016, 2, 10, 21, 40, 20))
# FulL_Data(ssn=641118353, first_name='Angel', last_name='Godthaab', gender='Female', language='Bislama', vehicle_make='Buick', vehicle_model='LeSabre', model_year=2005, employer='Rogahn, Hickle and Leuschke', department='Sales', employee_id=750981332, last_updated=datetime.datetime(2017, 5, 24, 8, 40, 40), created=datetime.datetime(2016, 7, 23, 2, 46, 34))
# FulL_Data(ssn=783229258, first_name='Modestine', last_name='Cuttings', gender='Female', language='Assamese', vehicle_make='Buick', vehicle_model='Skylark', model_year=1990, employer='Funk, Boyer and Littel', department='Legal', employee_id=952744801, last_updated=datetime.datetime(2017, 9, 24, 10, 26, 26), created=datetime.datetime(2016, 8, 15, 14, 8, 12))
# FulL_Data(ssn=808558658, first_name='Ursulina', last_name='Kunze', gender='Female', language='Chinese', vehicle_make='Buick', vehicle_model='Coachbuilder', model_year=1994, employer='Mosciski-Marquardt', department='Product Management', employee_id=372182084, last_updated=datetime.datetime(2017, 9, 30, 9, 38, 27), created=datetime.datetime(2016, 9, 23, 12, 37, 50))
#
# 						------------------Cadillac-------------------
# FulL_Data(ssn=123622832, first_name='Kare', last_name='Barhams', gender='Female', language='Tajik', vehicle_make='Cadillac', vehicle_model='Catera', model_year=1999, employer='Cruickshank, Legros and Keebler', department='Research and Development', employee_id=571590433, last_updated=datetime.datetime(2017, 9, 11, 0, 2, 44), created=datetime.datetime(2016, 10, 22, 16, 14, 5))
# FulL_Data(ssn=150646357, first_name='Helenka', last_name='Summerell', gender='Female', language='Bosnian', vehicle_make='Cadillac', vehicle_model='Escalade', model_year=2000, employer='Bosco-Kunde', department='Services', employee_id=551726090, last_updated=datetime.datetime(2018, 2, 14, 23, 35, 53), created=datetime.datetime(2016, 1, 28, 3, 19, 50))
# FulL_Data(ssn=399816133, first_name='Viv', last_name='Borsay', gender='Female', language='Chinese', vehicle_make='Cadillac', vehicle_model='Allante', model_year=1992, employer='Kihn Group', department='Legal', employee_id=571893655, last_updated=datetime.datetime(2017, 12, 1, 11, 7, 24), created=datetime.datetime(2016, 4, 13, 7, 24, 21))
# FulL_Data(ssn=527553736, first_name='Auguste', last_name='Hammersley', gender='Female', language='Malayalam', vehicle_make='Cadillac', vehicle_model='CTS', model_year=2005, employer='Balistreri Inc', department='Human Resources', employee_id=625455166, last_updated=datetime.datetime(2018, 2, 21, 4, 37, 24), created=datetime.datetime(2016, 4, 4, 7, 13, 28))
# FulL_Data(ssn=728545322, first_name='Berti', last_name='Bertelet', gender='Female', language='German', vehicle_make='Cadillac', vehicle_model='STS', model_year=2009, employer='Hahn and Sons', department='Services', employee_id=142928154, last_updated=datetime.datetime(2017, 8, 15, 3, 53, 9), created=datetime.datetime(2016, 6, 10, 23, 47, 18))
# FulL_Data(ssn=807135922, first_name='Vivi', last_name='Edinboro', gender='Female', language='Sotho', vehicle_make='Cadillac', vehicle_model='Seville', model_year=2001, employer="Kihn, D'Amore and Volkman", department='Business Development', employee_id=659491878, last_updated=datetime.datetime(2017, 3, 12, 16, 29, 50), created=datetime.datetime(2016, 6, 17, 23, 4, 5))
#
# 						------------------Chevrolet-------------------
# FulL_Data(ssn=105917777, first_name='Audi', last_name='Roach', gender='Female', language='Estonian', vehicle_make='Chevrolet', vehicle_model='Silverado 3500', model_year=2004, employer='Bashirian-Lueilwitz', department='Engineering', employee_id=443328799, last_updated=datetime.datetime(2017, 5, 11, 1, 48, 32), created=datetime.datetime(2016, 5, 31, 0, 38, 13))
# FulL_Data(ssn=114660984, first_name='Casandra', last_name='Juares', gender='Female', language='Lithuanian', vehicle_make='Chevrolet', vehicle_model='Camaro', model_year=1998, employer='Mayert, Rice and Schmitt', department='Product Management', employee_id=858596488, last_updated=datetime.datetime(2017, 6, 16, 17, 41, 33), created=datetime.datetime(2016, 5, 28, 20, 31, 25))
# FulL_Data(ssn=119078817, first_name='Blondie', last_name='Powderham', gender='Female', language='Croatian', vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2005, employer='Terry LLC', department='Accounting', employee_id=704864087, last_updated=datetime.datetime(2017, 12, 24, 15, 31, 5), created=datetime.datetime(2016, 12, 6, 14, 16, 59))
# FulL_Data(ssn=164119849, first_name='Clemence', last_name='Aujean', gender='Female', language='Albanian', vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=2001, employer='Quitzon, Rempel and Hane', department='Business Development', employee_id=34767523, last_updated=datetime.datetime(2017, 6, 24, 10, 17, 58), created=datetime.datetime(2016, 4, 20, 11, 9, 5))
# FulL_Data(ssn=174519992, first_name='Drucie', last_name='Travers', gender='Female', language='Swati', vehicle_make='Chevrolet', vehicle_model='Beretta', model_year=1994, employer='Jast-Quitzon', department='Human Resources', employee_id=675707294, last_updated=datetime.datetime(2017, 3, 3, 19, 42, 18), created=datetime.datetime(2016, 5, 17, 23, 32, 25))
# FulL_Data(ssn=181074434, first_name='Ferdinande', last_name='Probet', gender='Female', language='Catalan', vehicle_make='Chevrolet', vehicle_model='Impala SS', model_year=1995, employer='Little, Herzog and Mertz', department='Legal', employee_id=459164509, last_updated=datetime.datetime(2017, 10, 7, 7, 52, 10), created=datetime.datetime(2016, 11, 11, 20, 19, 19))
# FulL_Data(ssn=205872423, first_name='Oralla', last_name='Kearle', gender='Female', language='Zulu', vehicle_make='Chevrolet', vehicle_model='Express 2500', model_year=1999, employer='Goodwin-Oberbrunner', department='Accounting', employee_id=70291024, last_updated=datetime.datetime(2018, 1, 1, 8, 17, 27), created=datetime.datetime(2016, 2, 16, 23, 45, 38))
# FulL_Data(ssn=209508146, first_name='Kenna', last_name='Meryett', gender='Female', language='Czech', vehicle_make='Chevrolet', vehicle_model='Sportvan G20', model_year=1992, employer='Senger, Fay and Schuppe', department='Marketing', employee_id=59734435, last_updated=datetime.datetime(2018, 3, 13, 17, 52, 16), created=datetime.datetime(2016, 4, 10, 7, 14, 25))
# FulL_Data(ssn=224309267, first_name='Flori', last_name='Bagnal', gender='Female', language='Swedish', vehicle_make='Chevrolet', vehicle_model='Avalanche', model_year=2009, employer='Jacobson-Kuhn', department='Human Resources', employee_id=335097675, last_updated=datetime.datetime(2017, 12, 17, 11, 57, 56), created=datetime.datetime(2016, 11, 13, 20, 27, 10))
# FulL_Data(ssn=239374122, first_name='Jodee', last_name='Elsdon', gender='Female', language='Guarana', vehicle_make='Chevrolet', vehicle_model='Silverado 1500', model_year=2002, employer='Kassulke-Cruickshank', department='Support', employee_id=338042555, last_updated=datetime.datetime(2017, 9, 20, 20, 47, 44), created=datetime.datetime(2016, 3, 5, 9, 16, 37))
# FulL_Data(ssn=240088805, first_name='Gates', last_name='McGiffin', gender='Female', language='Finnish', vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1988, employer='Mraz, Veum and Farrell', department='Product Management', employee_id=306285659, last_updated=datetime.datetime(2017, 2, 10, 12, 14, 31), created=datetime.datetime(2016, 8, 15, 20, 52, 10))
# FulL_Data(ssn=274769883, first_name='Fawn', last_name='MacNamara', gender='Female', language='Bengali', vehicle_make='Chevrolet', vehicle_model='Impala', model_year=1995, employer='Kassulke Group', department='Human Resources', employee_id=864085293, last_updated=datetime.datetime(2017, 10, 9, 4, 11, 3), created=datetime.datetime(2016, 12, 22, 11, 44, 48))
# FulL_Data(ssn=315262241, first_name='Cammy', last_name='Harland', gender='Female', language='Bulgarian', vehicle_make='Chevrolet', vehicle_model='Silverado 2500', model_year=1999, employer='Predovic, Renner and Hansen', department='Research and Development', employee_id=161755710, last_updated=datetime.datetime(2017, 11, 27, 8, 16, 19), created=datetime.datetime(2016, 5, 27, 6, 53, 31))
# FulL_Data(ssn=333955025, first_name='Rebeca', last_name='Walesa', gender='Female', language='Zulu', vehicle_make='Chevrolet', vehicle_model='Monte Carlo', model_year=2002, employer='Beahan-Little', department='Sales', employee_id=701386102, last_updated=datetime.datetime(2017, 8, 28, 15, 13, 59), created=datetime.datetime(2016, 5, 25, 23, 33, 3))
# FulL_Data(ssn=339278046, first_name='Julita', last_name='Jouhan', gender='Female', language='Bosnian', vehicle_make='Chevrolet', vehicle_model='Camaro', model_year=1998, employer='Kessler-Simonis', department='Research and Development', employee_id=156371973, last_updated=datetime.datetime(2017, 12, 12, 18, 26, 28), created=datetime.datetime(2016, 4, 9, 3, 13, 49))
# FulL_Data(ssn=347648652, first_name='Dusty', last_name='Morat', gender='Female', language='Japanese', vehicle_make='Chevrolet', vehicle_model='Metro', model_year=2001, employer='Prosacco-Herzog', department='Sales', employee_id=386538811, last_updated=datetime.datetime(2017, 5, 23, 11, 28, 5), created=datetime.datetime(2016, 12, 30, 3, 51, 10))
# FulL_Data(ssn=367228998, first_name='Blake', last_name='Mustin', gender='Female', language='Kyrgyz', vehicle_make='Chevrolet', vehicle_model='Express 2500', model_year=1997, employer='Dickinson-Wiegand', department='Accounting', employee_id=439661529, last_updated=datetime.datetime(2017, 12, 11, 17, 58, 1), created=datetime.datetime(2016, 5, 13, 12, 0, 26))
# FulL_Data(ssn=371285892, first_name='Malia', last_name='Hanse', gender='Female', language='Tsonga', vehicle_make='Chevrolet', vehicle_model='Corvair', model_year=1960, employer='Adams-Ledner', department='Services', employee_id=405208891, last_updated=datetime.datetime(2017, 10, 23, 5, 51, 2), created=datetime.datetime(2016, 11, 1, 11, 0, 34))
# FulL_Data(ssn=397878282, first_name='Kyrstin', last_name='Waldock', gender='Female', language='Belarusian', vehicle_make='Chevrolet', vehicle_model='Blazer', model_year=1998, employer='Jones Inc', department='Sales', employee_id=482299282, last_updated=datetime.datetime(2017, 1, 25, 21, 15, 13), created=datetime.datetime(2016, 6, 24, 8, 10, 55))
# FulL_Data(ssn=420467789, first_name='Steffie', last_name='Britto', gender='Female', language='New Zealand Sign Language', vehicle_make='Chevrolet', vehicle_model='Express 2500', model_year=2005, employer='Schroeder LLC', department='Engineering', employee_id=657085477, last_updated=datetime.datetime(2017, 1, 25, 20, 25, 19), created=datetime.datetime(2016, 8, 24, 14, 54, 22))
# FulL_Data(ssn=469961488, first_name='Euphemia', last_name='Neggrini', gender='Female', language='Guarana', vehicle_make='Chevrolet', vehicle_model='Silverado 1500', model_year=2008, employer='Reichert-Hagenes', department='Human Resources', employee_id=844676473, last_updated=datetime.datetime(2017, 8, 14, 12, 32, 41), created=datetime.datetime(2016, 8, 9, 16, 15, 51))
# FulL_Data(ssn=485798123, first_name='Tish', last_name='Kemston', gender='Female', language='Khmer', vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1995, employer='Fadel-Gleichner', department='Legal', employee_id=964640239, last_updated=datetime.datetime(2017, 12, 14, 14, 16, 43), created=datetime.datetime(2016, 4, 10, 23, 54, 6))
# FulL_Data(ssn=486871145, first_name='Elyn', last_name='Djokovic', gender='Female', language='French', vehicle_make='Chevrolet', vehicle_model='Beretta', model_year=1993, employer='Treutel-Lubowitz', department='Services', employee_id=335310332, last_updated=datetime.datetime(2017, 8, 25, 5, 12, 39), created=datetime.datetime(2016, 11, 13, 3, 27, 50))
# FulL_Data(ssn=495626374, first_name='Nevsa', last_name='Boarder', gender='Female', language='Czech', vehicle_make='Chevrolet', vehicle_model='Lumina', model_year=2000, employer='Gerlach LLC', department='Services', employee_id=115891434, last_updated=datetime.datetime(2017, 5, 21, 12, 26, 52), created=datetime.datetime(2016, 1, 16, 18, 49, 45))
# FulL_Data(ssn=506023957, first_name='Tilly', last_name='Joubert', gender='Female', language='Danish', vehicle_make='Chevrolet', vehicle_model='Silverado', model_year=2002, employer='Boyer, Hermann and Bayer', department='Legal', employee_id=452093562, last_updated=datetime.datetime(2018, 3, 26, 10, 53, 26), created=datetime.datetime(2016, 8, 19, 22, 34, 54))
# FulL_Data(ssn=508543168, first_name='Helaine', last_name='Accombe', gender='Female', language='Dutch', vehicle_make='Chevrolet', vehicle_model='Express 1500', model_year=1997, employer='Wunsch-Ruecker', department='Accounting', employee_id=308759158, last_updated=datetime.datetime(2017, 11, 29, 20, 18, 24), created=datetime.datetime(2016, 9, 29, 5, 12, 25))
# FulL_Data(ssn=509391128, first_name='Carie', last_name='Leneham', gender='Female', language='Telugu', vehicle_make='Chevrolet', vehicle_model='Silverado 1500', model_year=2000, employer='Cartwright-Emmerich', department='Marketing', employee_id=331047074, last_updated=datetime.datetime(2017, 4, 30, 21, 28, 1), created=datetime.datetime(2016, 7, 20, 14, 12, 38))
# FulL_Data(ssn=520810974, first_name='Ofella', last_name='Navarro', gender='Female', language='Kurdish', vehicle_make='Chevrolet', vehicle_model='Metro', model_year=1998, employer='Breitenberg-Wiza', department='Accounting', employee_id=556401615, last_updated=datetime.datetime(2017, 3, 21, 6, 39, 8), created=datetime.datetime(2016, 7, 31, 23, 47, 30))
# FulL_Data(ssn=526989361, first_name='Cathe', last_name='Allsupp', gender='Female', language='Marathi', vehicle_make='Chevrolet', vehicle_model='Camaro', model_year=2001, employer='Mitchell-Kovacek', department='Product Management', employee_id=983030999, last_updated=datetime.datetime(2017, 4, 3, 2, 58, 51), created=datetime.datetime(2016, 1, 16, 10, 59, 40))
# FulL_Data(ssn=534506091, first_name='Florencia', last_name='Abramof', gender='Female', language='Arabic', vehicle_make='Chevrolet', vehicle_model='Silverado', model_year=2007, employer='Mills, Schmidt and Orn', department='Training', employee_id=994129786, last_updated=datetime.datetime(2017, 3, 27, 6, 4, 16), created=datetime.datetime(2016, 11, 19, 11, 20, 44))
# FulL_Data(ssn=567828701, first_name='Bathsheba', last_name='Ainge', gender='Female', language='Montenegrin', vehicle_make='Chevrolet', vehicle_model='Aveo', model_year=2008, employer='Satterfield, Ankunding and Robel', department='Product Management', employee_id=378628284, last_updated=datetime.datetime(2017, 10, 25, 2, 27, 51), created=datetime.datetime(2016, 8, 14, 14, 48, 11))
# FulL_Data(ssn=586854199, first_name='Gisela', last_name='Foulser', gender='Female', language='Albanian', vehicle_make='Chevrolet', vehicle_model='SSR', model_year=2005, employer='Hodkiewicz and Sons', department='Training', employee_id=151367840, last_updated=datetime.datetime(2017, 11, 29, 6, 11, 57), created=datetime.datetime(2016, 4, 3, 4, 1, 59))
# FulL_Data(ssn=599695584, first_name='Concordia', last_name='Grassot', gender='Female', language='Czech', vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1953, employer='Bartell, Brakus and Considine', department='Marketing', employee_id=763802991, last_updated=datetime.datetime(2017, 10, 11, 17, 31, 15), created=datetime.datetime(2016, 12, 26, 10, 45, 34))
# FulL_Data(ssn=603313174, first_name='Adelind', last_name='Pautard', gender='Female', language='English', vehicle_make='Chevrolet', vehicle_model='G-Series 2500', model_year=1998, employer='Hansen-Bayer', department='Training', employee_id=65805930, last_updated=datetime.datetime(2018, 3, 5, 13, 44, 43), created=datetime.datetime(2016, 4, 26, 19, 38, 9))
# FulL_Data(ssn=644708292, first_name='Glyn', last_name='Mc Giffin', gender='Female', language='Zulu', vehicle_make='Chevrolet', vehicle_model='Classic', model_year=2004, employer='Parisian, Kutch and Boyle', department='Services', employee_id=656774148, last_updated=datetime.datetime(2017, 1, 2, 0, 10, 46), created=datetime.datetime(2016, 3, 24, 13, 39, 53))
# FulL_Data(ssn=650639841, first_name='Evanne', last_name='Ibeson', gender='Female', language='Korean', vehicle_make='Chevrolet', vehicle_model='Lumina', model_year=2000, employer='Windler Inc', department='Sales', employee_id=536449997, last_updated=datetime.datetime(2017, 12, 12, 8, 39, 46), created=datetime.datetime(2016, 10, 4, 6, 20, 18))
# FulL_Data(ssn=680112707, first_name='Letta', last_name='Wishart', gender='Female', language='Chinese', vehicle_make='Chevrolet', vehicle_model='Beretta', model_year=1992, employer='Satterfield, Wolf and Thiel', department='Research and Development', employee_id=634901321, last_updated=datetime.datetime(2017, 12, 29, 10, 10, 26), created=datetime.datetime(2016, 7, 13, 12, 11, 36))
# FulL_Data(ssn=681722644, first_name='Rosie', last_name='Aartsen', gender='Female', language='Luxembourgish', vehicle_make='Chevrolet', vehicle_model='Malibu', model_year=2001, employer='Wolff, Metz and Gorczany', department='Accounting', employee_id=116978970, last_updated=datetime.datetime(2017, 12, 14, 23, 56, 34), created=datetime.datetime(2016, 3, 1, 22, 1, 49))
# FulL_Data(ssn=719056621, first_name='Susanne', last_name='Dilger', gender='Female', language='Punjabi', vehicle_make='Chevrolet', vehicle_model='Silverado 2500', model_year=2003, employer='Wintheiser-Dach', department='Research and Development', employee_id=237767142, last_updated=datetime.datetime(2017, 9, 17, 14, 33, 45), created=datetime.datetime(2016, 5, 9, 18, 56, 22))
# FulL_Data(ssn=743752371, first_name='Jodee', last_name='Lintin', gender='Female', language='Dzongkha', vehicle_make='Chevrolet', vehicle_model='Tahoe', model_year=2011, employer='Hand Group', department='Business Development', employee_id=693955011, last_updated=datetime.datetime(2017, 12, 27, 9, 33, 42), created=datetime.datetime(2016, 5, 6, 13, 55, 20))
# FulL_Data(ssn=763091587, first_name='Yasmeen', last_name='Vaskin', gender='Female', language='Lithuanian', vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1995, employer='Sporer Group', department='Training', employee_id=470369978, last_updated=datetime.datetime(2017, 1, 22, 12, 35, 38), created=datetime.datetime(2016, 11, 24, 19, 46, 6))
# FulL_Data(ssn=764932248, first_name='Maure', last_name='Verrillo', gender='Female', language='Spanish', vehicle_make='Chevrolet', vehicle_model='Monte Carlo', model_year=2004, employer='Olson, McClure and Schiller', department='Marketing', employee_id=382550412, last_updated=datetime.datetime(2017, 11, 26, 1, 41, 24), created=datetime.datetime(2016, 9, 28, 17, 49, 11))
# FulL_Data(ssn=778748262, first_name='Sonia', last_name='Grishakin', gender='Female', language='Bulgarian', vehicle_make='Chevrolet', vehicle_model='Sportvan G30', model_year=1993, employer='Anderson, Dickinson and Toy', department='Marketing', employee_id=468501105, last_updated=datetime.datetime(2017, 2, 5, 11, 21, 48), created=datetime.datetime(2016, 8, 7, 11, 55, 4))
# FulL_Data(ssn=816313858, first_name='Elvera', last_name='Walmsley', gender='Female', language='Montenegrin', vehicle_make='Chevrolet', vehicle_model='Silverado 3500', model_year=2004, employer='Hilll Inc', department='Product Management', employee_id=133299629, last_updated=datetime.datetime(2017, 4, 13, 4, 17, 11), created=datetime.datetime(2016, 7, 30, 2, 46, 27))
# FulL_Data(ssn=851942162, first_name='Rodi', last_name='Mulrenan', gender='Female', language='Catalan', vehicle_make='Chevrolet', vehicle_model='Cobalt', model_year=2010, employer='Collier, Botsford and Ruecker', department='Engineering', employee_id=185849664, last_updated=datetime.datetime(2017, 10, 15, 12, 43, 2), created=datetime.datetime(2016, 11, 28, 14, 34, 31))
# FulL_Data(ssn=866530625, first_name='Francene', last_name='Ehlerding', gender='Female', language='Latvian', vehicle_make='Chevrolet', vehicle_model='Blazer', model_year=1997, employer='Douglas-Breitenberg', department='Business Development', employee_id=636285198, last_updated=datetime.datetime(2018, 2, 24, 20, 22, 43), created=datetime.datetime(2016, 12, 15, 22, 59, 20))
# FulL_Data(ssn=868321805, first_name='Joanna', last_name='Raycroft', gender='Female', language='Bosnian', vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2007, employer='Abshire Inc', department='Research and Development', employee_id=558987515, last_updated=datetime.datetime(2017, 9, 29, 17, 46, 17), created=datetime.datetime(2016, 11, 14, 1, 26, 32))
# FulL_Data(ssn=893177318, first_name='Nani', last_name='Bonelle', gender='Female', language='Kyrgyz', vehicle_make='Chevrolet', vehicle_model='Lumina', model_year=1995, employer='Orn Inc', department='Human Resources', employee_id=384356300, last_updated=datetime.datetime(2017, 7, 23, 7, 11, 51), created=datetime.datetime(2016, 2, 28, 8, 1, 12))
#
# 						------------------Chrysler-------------------
# FulL_Data(ssn=105857486, first_name='Angelina', last_name='McAvey', gender='Female', language='Punjabi', vehicle_make='Chrysler', vehicle_model='300', model_year=2008, employer='Roberts, Torphy and Dach', department='Human Resources', employee_id=774895332, last_updated=datetime.datetime(2018, 2, 14, 11, 32, 39), created=datetime.datetime(2016, 12, 15, 5, 46, 43))
# FulL_Data(ssn=211155182, first_name='Gene', last_name='Bassilashvili', gender='Female', language='Swedish', vehicle_make='Chrysler', vehicle_model='Town & Country', model_year=2010, employer='Sawayn, Marvin and Rempel', department='Research and Development', employee_id=746068283, last_updated=datetime.datetime(2017, 4, 15, 16, 17, 42), created=datetime.datetime(2016, 3, 17, 19, 14, 56))
# FulL_Data(ssn=240328915, first_name='Cathee', last_name='Tarbard', gender='Female', language='Papiamento', vehicle_make='Chrysler', vehicle_model='Crossfire', model_year=2006, employer="O'Keefe-Cruickshank", department='Research and Development', employee_id=341983927, last_updated=datetime.datetime(2017, 4, 18, 14, 30, 22), created=datetime.datetime(2016, 2, 25, 19, 4, 17))
# FulL_Data(ssn=253618401, first_name='Genny', last_name='Juara', gender='Female', language='Tswana', vehicle_make='Chrysler', vehicle_model='Voyager', model_year=2000, employer='Halvorson-Parisian', department='Support', employee_id=162500138, last_updated=datetime.datetime(2018, 1, 22, 4, 2, 1), created=datetime.datetime(2016, 10, 2, 2, 18, 55))
# FulL_Data(ssn=280537447, first_name='Suzette', last_name='Prahl', gender='Female', language='Romanian', vehicle_make='Chrysler', vehicle_model='Concorde', model_year=1994, employer='Moen, Veum and McLaughlin', department='Accounting', employee_id=120401993, last_updated=datetime.datetime(2017, 5, 12, 7, 46, 5), created=datetime.datetime(2016, 2, 16, 0, 15, 21))
# FulL_Data(ssn=426334523, first_name='Bibbie', last_name='Lardge', gender='Female', language='Spanish', vehicle_make='Chrysler', vehicle_model='Town & Country', model_year=2001, employer='Sporer Inc', department='Legal', employee_id=432632272, last_updated=datetime.datetime(2017, 2, 13, 11, 48, 3), created=datetime.datetime(2016, 10, 13, 14, 8, 2))
# FulL_Data(ssn=795566486, first_name='Stevena', last_name='Vatcher', gender='Female', language='Gagauz', vehicle_make='Chrysler', vehicle_model='300', model_year=2008, employer='Rau-Schmidt', department='Legal', employee_id=398891615, last_updated=datetime.datetime(2018, 2, 1, 2, 41, 25), created=datetime.datetime(2016, 4, 27, 0, 12, 34))
# FulL_Data(ssn=878128265, first_name='Nance', last_name='Doble', gender='Female', language='Dhivehi', vehicle_make='Chrysler', vehicle_model='Concorde', model_year=1998, employer='Witting, Schuster and Barton', department='Research and Development', employee_id=544161357, last_updated=datetime.datetime(2017, 1, 11, 18, 36, 16), created=datetime.datetime(2016, 3, 14, 14, 30, 37))
#
# 						------------------Dodge-------------------
# FulL_Data(ssn=194765816, first_name='Jacquelynn', last_name='Shurey', gender='Female', language='Amharic', vehicle_make='Dodge', vehicle_model='Dakota', model_year=2001, employer='Sauer, Mann and Kling', department='Accounting', employee_id=893029716, last_updated=datetime.datetime(2017, 1, 16, 18, 22, 53), created=datetime.datetime(2016, 5, 26, 16, 11, 14))
# FulL_Data(ssn=244810671, first_name='Viviyan', last_name='Udell', gender='Female', language='Moldovan', vehicle_make='Dodge', vehicle_model='Caravan', model_year=1997, employer='Howell-Wunsch', department='Legal', employee_id=917637157, last_updated=datetime.datetime(2017, 6, 23, 11, 56, 59), created=datetime.datetime(2016, 9, 8, 8, 33, 21))
# FulL_Data(ssn=299036911, first_name='Janela', last_name='Ferrone', gender='Female', language='Gagauz', vehicle_make='Dodge', vehicle_model='Viper RT/10', model_year=1994, employer='Kilback Group', department='Services', employee_id=25391126, last_updated=datetime.datetime(2017, 1, 19, 3, 33, 50), created=datetime.datetime(2016, 3, 7, 15, 33, 32))
# FulL_Data(ssn=358847049, first_name='Emalee', last_name='McCleary', gender='Female', language='Thai', vehicle_make='Dodge', vehicle_model='Dakota Club', model_year=2007, employer='Kuhn LLC', department='Research and Development', employee_id=127386844, last_updated=datetime.datetime(2017, 2, 9, 7, 24, 45), created=datetime.datetime(2016, 2, 21, 0, 13, 44))
# FulL_Data(ssn=378602472, first_name='Eddie', last_name='Howieson', gender='Female', language='Albanian', vehicle_make='Dodge', vehicle_model='Ram 2500', model_year=2000, employer='Baumbach Group', department='Human Resources', employee_id=937798424, last_updated=datetime.datetime(2017, 8, 22, 22, 37, 19), created=datetime.datetime(2016, 11, 10, 10, 11, 19))
# FulL_Data(ssn=391474578, first_name='Fiann', last_name='Fellman', gender='Female', language='Assamese', vehicle_make='Dodge', vehicle_model='Ram 1500', model_year=1997, employer='Rath-Hessel', department='Human Resources', employee_id=868277225, last_updated=datetime.datetime(2017, 10, 29, 15, 13, 33), created=datetime.datetime(2016, 10, 24, 19, 42, 50))
# FulL_Data(ssn=406155123, first_name='Janot', last_name='Pulhoster', gender='Female', language='Dari', vehicle_make='Dodge', vehicle_model='Caravan', model_year=2000, employer='Wilkinson, Lind and Ziemann', department='Research and Development', employee_id=475274344, last_updated=datetime.datetime(2017, 3, 9, 4, 6, 27), created=datetime.datetime(2016, 10, 21, 22, 15, 43))
# FulL_Data(ssn=413565613, first_name='Anjanette', last_name='Carnock', gender='Female', language='Nepali', vehicle_make='Dodge', vehicle_model='D150', model_year=1993, employer='Marks, Wilkinson and Kub', department='Services', employee_id=871098264, last_updated=datetime.datetime(2017, 7, 21, 23, 37, 57), created=datetime.datetime(2016, 11, 13, 17, 24, 37))
# FulL_Data(ssn=450455021, first_name='Ailis', last_name='Allsebrook', gender='Female', language='Amharic', vehicle_make='Dodge', vehicle_model='Avenger', model_year=2011, employer='Morissette, Pfeffer and Bayer', department='Legal', employee_id=789992528, last_updated=datetime.datetime(2017, 11, 6, 2, 16, 54), created=datetime.datetime(2016, 9, 15, 7, 50, 46))
# FulL_Data(ssn=476270948, first_name='Laurette', last_name='Kearney', gender='Female', language='West Frisian', vehicle_make='Dodge', vehicle_model='Intrepid', model_year=2001, employer='Jast-Gibson', department='Business Development', employee_id=200508733, last_updated=datetime.datetime(2017, 9, 14, 1, 54, 7), created=datetime.datetime(2016, 12, 18, 8, 11, 30))
# FulL_Data(ssn=493097972, first_name='Agretha', last_name='Wickes', gender='Female', language='French', vehicle_make='Dodge', vehicle_model='Grand Caravan', model_year=1995, employer='Zemlak, Heathcote and Turner', department='Training', employee_id=865333401, last_updated=datetime.datetime(2017, 9, 11, 12, 20, 58), created=datetime.datetime(2016, 8, 22, 21, 53, 32))
# ...
# FulL_Data(ssn=327887554, first_name='Malynda', last_name='Kingerby', gender='Female', language='Swahili', vehicle_make='Toyota', vehicle_model='Corolla', model_year=1994, employer='Lowe, Tromp and Orn', department='Product Management', employee_id=955467981, last_updated=datetime.datetime(2017, 11, 24, 22, 24, 17), created=datetime.datetime(2016, 10, 12, 9, 25, 25))
# FulL_Data(ssn=362098563, first_name='Carri', last_name='Peterffy', gender='Female', language='Icelandic', vehicle_make='Toyota', vehicle_model='Paseo', model_year=1995, employer='Kautzer and Sons', department='Research and Development', employee_id=560050837, last_updated=datetime.datetime(2017, 2, 7, 23, 59, 48), created=datetime.datetime(2016, 7, 4, 3, 26, 36))
# FulL_Data(ssn=406490634, first_name='Lolita', last_name='Dailey', gender='Female', language='Czech', vehicle_make='Toyota', vehicle_model='Corolla', model_year=2003, employer='Bashirian Group', department='Legal', employee_id=674961160, last_updated=datetime.datetime(2017, 5, 10, 9, 45, 50), created=datetime.datetime(2016, 9, 6, 20, 39, 43))
# FulL_Data(ssn=409908946, first_name='Doralia', last_name='Proughten', gender='Female', language='Estonian', vehicle_make='Toyota', vehicle_model='Paseo', model_year=1994, employer='Yost and Sons', department='Sales', employee_id=77718175, last_updated=datetime.datetime(2017, 8, 14, 2, 56, 14), created=datetime.datetime(2016, 7, 13, 17, 13, 48))
# FulL_Data(ssn=411794655, first_name='Caterina', last_name='Coey', gender='Female', language='French', vehicle_make='Toyota', vehicle_model='Sienna', model_year=2003, employer='Gleason LLC', department='Product Management', employee_id=79043060, last_updated=datetime.datetime(2017, 8, 9, 14, 41, 54), created=datetime.datetime(2016, 7, 14, 9, 28, 46))
# FulL_Data(ssn=421887316, first_name='Cherie', last_name='Yeudall', gender='Female', language='Dutch', vehicle_make='Toyota', vehicle_model='Xtra', model_year=1993, employer='Sanford, Becker and Nienow', department='Product Management', employee_id=239748703, last_updated=datetime.datetime(2017, 9, 23, 23, 50, 31), created=datetime.datetime(2016, 10, 17, 16, 59, 29))
# FulL_Data(ssn=426523410, first_name='Deeyn', last_name='Feldberg', gender='Female', language='Lithuanian', vehicle_make='Toyota', vehicle_model='FJ Cruiser', model_year=2009, employer='Harris-Rau', department='Marketing', employee_id=957119223, last_updated=datetime.datetime(2017, 11, 23, 10, 8, 43), created=datetime.datetime(2016, 6, 29, 12, 35, 4))
# FulL_Data(ssn=497695399, first_name='Wanids', last_name='Bengoechea', gender='Female', language='German', vehicle_make='Toyota', vehicle_model='Prius', model_year=2009, employer='Grant Group', department='Business Development', employee_id=54747935, last_updated=datetime.datetime(2017, 2, 20, 4, 42, 30), created=datetime.datetime(2016, 1, 18, 5, 30, 53))
# FulL_Data(ssn=532364145, first_name='Dorry', last_name='Ditty', gender='Female', language='Kannada', vehicle_make='Toyota', vehicle_model='Tundra', model_year=2009, employer='Brekke, Graham and Hilll', department='Product Management', employee_id=988943921, last_updated=datetime.datetime(2017, 2, 12, 2, 37, 42), created=datetime.datetime(2016, 3, 25, 18, 33, 23))
# FulL_Data(ssn=603349733, first_name='Joellen', last_name='Doddrell', gender='Female', language='Lithuanian', vehicle_make='Toyota', vehicle_model='Highlander', model_year=2010, employer='Romaguera, Torp and Bode', department='Human Resources', employee_id=77590960, last_updated=datetime.datetime(2017, 10, 5, 18, 16), created=datetime.datetime(2016, 11, 4, 4, 36, 19))
# FulL_Data(ssn=659434520, first_name='Alessandra', last_name='Rouf', gender='Female', language='Fijian', vehicle_make='Toyota', vehicle_model='Tacoma', model_year=2003, employer='Quitzon Group', department='Sales', employee_id=524061438, last_updated=datetime.datetime(2017, 10, 10, 1, 12), created=datetime.datetime(2016, 4, 4, 18, 49, 20))
# FulL_Data(ssn=705156989, first_name='Minta', last_name='Beecroft', gender='Female', language='Maltese', vehicle_make='Toyota', vehicle_model='Land Cruiser', model_year=2005, employer="O'Connell-Lehner", department='Legal', employee_id=983357063, last_updated=datetime.datetime(2017, 11, 1, 15, 6, 19), created=datetime.datetime(2016, 7, 15, 21, 23, 23))
# FulL_Data(ssn=781882076, first_name='Gelya', last_name='Stell', gender='Female', language='Czech', vehicle_make='Toyota', vehicle_model='Yaris', model_year=2009, employer='Gulgowski, Carroll and Sauer', department='Training', employee_id=276046833, last_updated=datetime.datetime(2017, 4, 19, 7, 31, 17), created=datetime.datetime(2016, 4, 11, 20, 43, 18))
# FulL_Data(ssn=848583386, first_name='Julianne', last_name='Lygo', gender='Female', language='Japanese', vehicle_make='Toyota', vehicle_model='RAV4', model_year=2007, employer='Jerde-Batz', department='Product Management', employee_id=140272415, last_updated=datetime.datetime(2018, 1, 21, 4, 10, 3), created=datetime.datetime(2016, 3, 18, 1, 51, 27))
# FulL_Data(ssn=871993191, first_name='Susann', last_name='Walrond', gender='Female', language='Amharic', vehicle_make='Toyota', vehicle_model='Sienna', model_year=2000, employer='Lueilwitz, Stokes and Kassulke', department='Marketing', employee_id=161937114, last_updated=datetime.datetime(2017, 5, 8, 8, 24, 12), created=datetime.datetime(2016, 2, 27, 15, 43, 26))
# FulL_Data(ssn=895261658, first_name='Nance', last_name='Danzelman', gender='Female', language='Icelandic', vehicle_make='Toyota', vehicle_model='Land Cruiser', model_year=2003, employer='Hilll, Kunze and Beer', department='Human Resources', employee_id=904168298, last_updated=datetime.datetime(2017, 4, 1, 22, 22, 5), created=datetime.datetime(2016, 11, 22, 6, 57, 45))
# FulL_Data(ssn=898033165, first_name='Sela', last_name='Vaillant', gender='Female', language='Arabic', vehicle_make='Toyota', vehicle_model='Xtra', model_year=1994, employer='Bins-Gerhold', department='Sales', employee_id=899965641, last_updated=datetime.datetime(2017, 6, 1, 19, 18, 49), created=datetime.datetime(2016, 7, 20, 21, 40, 2))
# FulL_Data(ssn=899397378, first_name='Lindsay', last_name='Colledge', gender='Female', language='Croatian', vehicle_make='Toyota', vehicle_model='Land Cruiser', model_year=1999, employer="Christiansen, Ondricka and O'Connell", department='Marketing', employee_id=327034344, last_updated=datetime.datetime(2017, 3, 27, 19, 31, 32), created=datetime.datetime(2016, 9, 4, 15, 9, 22))
#
# 						------------------Volkswagen-------------------
# FulL_Data(ssn=212411496, first_name='Agnese', last_name='Lawes', gender='Female', language='Tamil', vehicle_make='Volkswagen', vehicle_model='Eurovan', model_year=1995, employer='Hills-Luettgen', department='Engineering', employee_id=496662355, last_updated=datetime.datetime(2017, 7, 7, 20, 29, 9), created=datetime.datetime(2016, 10, 27, 12, 47, 10))
# FulL_Data(ssn=351732802, first_name='Cybill', last_name='Parnham', gender='Female', language='Latvian', vehicle_make='Volkswagen', vehicle_model='Jetta', model_year=2001, employer='Goodwin, Luettgen and Harvey', department='Human Resources', employee_id=914775280, last_updated=datetime.datetime(2017, 8, 11, 7, 49, 34), created=datetime.datetime(2016, 9, 3, 2, 20, 26))
# FulL_Data(ssn=451345996, first_name='Dolly', last_name='Pennyman', gender='Female', language='Spanish', vehicle_make='Volkswagen', vehicle_model='Routan', model_year=2011, employer='Gutmann, Gibson and Hilpert', department='Research and Development', employee_id=323330955, last_updated=datetime.datetime(2017, 6, 22, 16, 58, 53), created=datetime.datetime(2016, 11, 18, 23, 32, 30))
# FulL_Data(ssn=495642134, first_name='Noami', last_name='Schuck', gender='Female', language='Nepali', vehicle_make='Volkswagen', vehicle_model='Jetta', model_year=1999, employer='Heller-Connelly', department='Sales', employee_id=593433099, last_updated=datetime.datetime(2018, 3, 2, 1, 16, 24), created=datetime.datetime(2016, 4, 8, 1, 38, 27))
# FulL_Data(ssn=497732347, first_name='Rana', last_name='Duhig', gender='Female', language='Indonesian', vehicle_make='Volkswagen', vehicle_model='New Beetle', model_year=2010, employer='Bartell, Friesen and Lakin', department='Sales', employee_id=807946674, last_updated=datetime.datetime(2017, 9, 26, 9, 31), created=datetime.datetime(2016, 8, 27, 16, 39, 43))
# FulL_Data(ssn=515471848, first_name='Darla', last_name='Leftridge', gender='Female', language='Finnish', vehicle_make='Volkswagen', vehicle_model='Passat', model_year=1987, employer='Batz-Effertz', department='Marketing', employee_id=476735310, last_updated=datetime.datetime(2018, 2, 9, 16, 48, 47), created=datetime.datetime(2016, 10, 5, 9, 32, 19))
# FulL_Data(ssn=551574018, first_name='Magdalena', last_name='Morland', gender='Female', language='Gagauz', vehicle_make='Volkswagen', vehicle_model='Passat', model_year=2010, employer='Skiles-Botsford', department='Research and Development', employee_id=909959175, last_updated=datetime.datetime(2018, 3, 20, 20, 28, 18), created=datetime.datetime(2016, 6, 18, 20, 47, 47))
# FulL_Data(ssn=556134040, first_name='Mignonne', last_name='Beckett', gender='Female', language='Catalan', vehicle_make='Volkswagen', vehicle_model='GTI', model_year=2002, employer='Gutmann-Rau', department='Accounting', employee_id=832806591, last_updated=datetime.datetime(2017, 4, 30, 7, 12, 18), created=datetime.datetime(2016, 11, 27, 10, 43, 54))
# FulL_Data(ssn=797652382, first_name='Marianne', last_name='Huccaby', gender='Female', language='Swedish', vehicle_make='Volkswagen', vehicle_model='Scirocco', model_year=1985, employer='Walker-Lemke', department='Research and Development', employee_id=520032929, last_updated=datetime.datetime(2017, 1, 24, 12, 7, 57), created=datetime.datetime(2016, 2, 25, 16, 22, 8))
# FulL_Data(ssn=797877992, first_name='Lonna', last_name='Plumridge', gender='Female', language='Armenian', vehicle_make='Volkswagen', vehicle_model='Scirocco', model_year=1985, employer='Becker, Ferry and Kulas', department='Human Resources', employee_id=830034047, last_updated=datetime.datetime(2018, 2, 24, 14, 55, 36), created=datetime.datetime(2016, 10, 19, 9, 48, 40))
# FulL_Data(ssn=899476116, first_name='Tiphanie', last_name='Kevlin', gender='Female', language='Tetum', vehicle_make='Volkswagen', vehicle_model='Phaeton', model_year=2005, employer='Bednar LLC', department='Support', employee_id=166342889, last_updated=datetime.datetime(2017, 6, 10, 11, 20, 41), created=datetime.datetime(2016, 4, 29, 12, 25, 23))
#
# 						------------------Volvo-------------------
# FulL_Data(ssn=139996417, first_name='Susanetta', last_name='Nazaret', gender='Female', language='Punjabi', vehicle_make='Volvo', vehicle_model='V70', model_year=2002, employer='Pollich-Heathcote', department='Product Management', employee_id=122844710, last_updated=datetime.datetime(2018, 1, 17, 17, 51, 12), created=datetime.datetime(2016, 12, 21, 14, 14, 20))
# FulL_Data(ssn=140588263, first_name='Tim', last_name='Bergin', gender='Female', language='Maori', vehicle_make='Volvo', vehicle_model='XC90', model_year=2009, employer='Gutkowski Inc', department='Engineering', employee_id=834836768, last_updated=datetime.datetime(2017, 11, 12, 21, 41, 50), created=datetime.datetime(2016, 12, 14, 20, 27, 22))
# FulL_Data(ssn=206838848, first_name='Ardyth', last_name='Arger', gender='Female', language='Gagauz', vehicle_make='Volvo', vehicle_model='S60', model_year=2011, employer='Hickle, Beatty and McCullough', department='Business Development', employee_id=957755368, last_updated=datetime.datetime(2017, 11, 8, 14, 57, 17), created=datetime.datetime(2016, 4, 11, 17, 40, 42))
# FulL_Data(ssn=287662660, first_name='Larissa', last_name='Airy', gender='Female', language='Bislama', vehicle_make='Volvo', vehicle_model='V50', model_year=2010, employer='Collier Inc', department='Research and Development', employee_id=815101189, last_updated=datetime.datetime(2018, 1, 8, 5, 9, 53), created=datetime.datetime(2016, 1, 3, 15, 12, 3))
# FulL_Data(ssn=294531911, first_name='Ginelle', last_name='Jaquet', gender='Female', language='Persian', vehicle_make='Volvo', vehicle_model='XC60', model_year=2012, employer='Little, Veum and Sauer', department='Legal', employee_id=457118863, last_updated=datetime.datetime(2018, 3, 8, 15, 24, 15), created=datetime.datetime(2016, 7, 22, 21, 42, 17))
# FulL_Data(ssn=378080805, first_name='Carroll', last_name='Harty', gender='Female', language='Swedish', vehicle_make='Volvo', vehicle_model='S40', model_year=2010, employer='Reynolds, Stroman and Pagac', department='Marketing', employee_id=810595624, last_updated=datetime.datetime(2017, 1, 15, 7, 10, 9), created=datetime.datetime(2016, 9, 4, 16, 17, 45))
# FulL_Data(ssn=385301777, first_name='Aubrey', last_name='Wetherill', gender='Female', language='Tswana', vehicle_make='Volvo', vehicle_model='S80', model_year=2009, employer='Monahan, Weber and Reynolds', department='Sales', employee_id=593207276, last_updated=datetime.datetime(2017, 8, 5, 3, 34, 46), created=datetime.datetime(2016, 7, 30, 16, 51, 41))
# FulL_Data(ssn=485390911, first_name='Rea', last_name='Buzek', gender='Female', language='Croatian', vehicle_make='Volvo', vehicle_model='S40', model_year=2003, employer='Schamberger-Hirthe', department='Services', employee_id=487268338, last_updated=datetime.datetime(2017, 6, 22, 9, 16, 31), created=datetime.datetime(2016, 2, 5, 20, 25, 20))
# FulL_Data(ssn=595671091, first_name='Odette', last_name='Delue', gender='Female', language='Filipino', vehicle_make='Volvo', vehicle_model='C70', model_year=2002, employer='Hegmann, Treutel and Hudson', department='Business Development', employee_id=438081335, last_updated=datetime.datetime(2017, 7, 1, 9, 48, 41), created=datetime.datetime(2016, 9, 4, 4, 32, 10))
# FulL_Data(ssn=634428798, first_name='Tomasine', last_name='Dron', gender='Female', language='English', vehicle_make='Volvo', vehicle_model='S40', model_year=2004, employer='Schowalter and Sons', department='Human Resources', employee_id=599431329, last_updated=datetime.datetime(2017, 1, 20, 7, 0, 33), created=datetime.datetime(2016, 8, 7, 10, 51, 44))
# FulL_Data(ssn=692310697, first_name='Blondell', last_name='Wrigley', gender='Female', language='Persian', vehicle_make='Volvo', vehicle_model='850', model_year=1997, employer='Smith-Boehm', department='Training', employee_id=580730098, last_updated=datetime.datetime(2018, 1, 28, 18, 18, 17), created=datetime.datetime(2016, 5, 22, 21, 42, 24))
# FulL_Data(ssn=729951691, first_name='Marion', last_name='Danson', gender='Female', language='Zulu', vehicle_make='Volvo', vehicle_model='S60', model_year=2001, employer="Kris, O'Kon and Legros", department='Support', employee_id=296891285, last_updated=datetime.datetime(2017, 3, 15, 7, 34, 31), created=datetime.datetime(2016, 3, 29, 21, 15, 40))
# FulL_Data(ssn=753985796, first_name='Charlena', last_name='Cleve', gender='Female', language='New Zealand Sign Language', vehicle_make='Volvo', vehicle_model='S40', model_year=2011, employer='Lowe, Johnston and Zemlak', department='Legal', employee_id=346530835, last_updated=datetime.datetime(2017, 4, 12, 3, 50, 4), created=datetime.datetime(2016, 7, 31, 18, 20, 35))
# FulL_Data(ssn=773537438, first_name='Flo', last_name='Sirmond', gender='Female', language='Khmer', vehicle_make='Volvo', vehicle_model='V40', model_year=2001, employer='Boyer, Mueller and Boyer', department='Engineering', employee_id=199999045, last_updated=datetime.datetime(2017, 12, 19, 1, 55, 17), created=datetime.datetime(2016, 11, 9, 2, 56, 26))
# FulL_Data(ssn=888824928, first_name='Billye', last_name='Legat', gender='Female', language='Icelandic', vehicle_make='Volvo', vehicle_model='S60', model_year=2005, employer='Reynolds, Nicolas and Morar', department='Engineering', employee_id=483998718, last_updated=datetime.datetime(2017, 12, 8, 14, 2, 48), created=datetime.datetime(2016, 11, 9, 10, 4, 16))

# %%
groups = get_filtered_grouped_data('personal_info.csv', 'vehicles.csv', 'employment.csv', 'update_status.csv',
                             filter_key = lambda x : x.gender == 'Female',
                                group_by = lambda x : x.vehicle_make)

# %%
{make:sum(1 for _ in group) for make, group in groups}
# Out:
# {'Acura': 11,
#  'Aston Martin': 2,
#  'Audi': 14,
#  'Austin': 1,
#  'BMW': 13,
#  'Bentley': 5,
#  'Bugatti': 1,
#  'Buick': 11,
#  'Cadillac': 6,
#  'Chevrolet': 48,
#  'Chrysler': 8,
#  'Dodge': 20,
#  'Eagle': 1,
#  'Ford': 48,
#  'GMC': 23,
#  'Geo': 1,
#  'Honda': 10,
#  'Hyundai': 4,
#  'Infiniti': 9,
#  'Isuzu': 3,
#  'Jaguar': 3,
#  'Jeep': 6,
#  'Kia': 9,
#  'Lamborghini': 3,
#  'Land Rover': 9,
#  'Lexus': 17,
#  'Lincoln': 4,
#  'Lotus': 7,
#  'Mazda': 15,
#  'Mercedes-Benz': 18,
#  'Mercury': 9,
#  'Mitsubishi': 25,
#  'Morgan': 1,
#  'Nissan': 12,
#  'Oldsmobile': 8,
#  'Panoz': 1,
#  'Plymouth': 4,
#  'Pontiac': 14,
#  'Porsche': 5,
#  'Rolls-Royce': 2,
#  'Saab': 3,
#  'Saturn': 3,
#  'Scion': 3,
#  'Smart': 1,
#  'Subaru': 9,
#  'Suzuki': 13,
#  'Toyota': 24,
#  'Volkswagen': 11,
#  'Volvo': 15}

# %%
groups = get_filtered_grouped_data('personal_info.csv', 'vehicles.csv', 'employment.csv', 'update_status.csv',
                             filter_key = lambda x : x.gender == 'Female',
                                group_by = lambda x : x.vehicle_make)

# %%
sorted(groups, key = lambda group : len(list(x[1])))
# Out:
# [('Acura', <itertools._grouper at 0x4524988>),
#  ('Aston Martin', <itertools._grouper at 0x7032868>),
#  ('Audi', <itertools._grouper at 0x70327c0>),
#  ('Austin', <itertools._grouper at 0x70326a0>),
#  ('BMW', <itertools._grouper at 0x7032aa8>),
#  ('Bentley', <itertools._grouper at 0x7032550>),
#  ('Bugatti', <itertools._grouper at 0x7032640>),
#  ('Buick', <itertools._grouper at 0x7032e80>),
#  ('Cadillac', <itertools._grouper at 0x7032538>),
#  ('Chevrolet', <itertools._grouper at 0x7032820>),
#  ('Chrysler', <itertools._grouper at 0x6cc7f10>),
#  ('Dodge', <itertools._grouper at 0x6cc7be0>),
#  ('Eagle', <itertools._grouper at 0x6cc7e08>),
#  ('Ford', <itertools._grouper at 0x6cc7d78>),
#  ('GMC', <itertools._grouper at 0x6cc7e50>),
#  ('Geo', <itertools._grouper at 0x6d17c28>),
#  ('Honda', <itertools._grouper at 0x69db190>),
#  ('Hyundai', <itertools._grouper at 0x69db178>),
#  ('Infiniti', <itertools._grouper at 0x6f9df10>),
#  ('Isuzu', <itertools._grouper at 0x6f9de80>),
#  ('Jaguar', <itertools._grouper at 0x6f9dfb8>),
#  ('Jeep', <itertools._grouper at 0x6f9df40>),
#  ('Kia', <itertools._grouper at 0x6f9df28>),
#  ('Lamborghini', <itertools._grouper at 0x6f9deb0>),
#  ('Land Rover', <itertools._grouper at 0x6f9dec8>),
#  ('Lexus', <itertools._grouper at 0x6f9def8>),
#  ('Lincoln', <itertools._grouper at 0x6f9dfa0>),
#  ('Lotus', <itertools._grouper at 0x6f9dfe8>),
#  ('Mazda', <itertools._grouper at 0x6f9df58>),
#  ('Mercedes-Benz', <itertools._grouper at 0x6f9d9b8>),
#  ('Mercury', <itertools._grouper at 0x6f9da18>),
#  ('Mitsubishi', <itertools._grouper at 0x6f9da30>),
#  ('Morgan', <itertools._grouper at 0x6f9d940>),
#  ('Nissan', <itertools._grouper at 0x6f9d970>),
#  ('Oldsmobile', <itertools._grouper at 0x6f9dbf8>),
#  ('Panoz', <itertools._grouper at 0x6f9dc10>),
#  ('Plymouth', <itertools._grouper at 0x4561ef8>),
#  ('Pontiac', <itertools._grouper at 0x4545fe8>),
#  ('Porsche', <itertools._grouper at 0x54a8e50>),
#  ('Rolls-Royce', <itertools._grouper at 0x54a8400>),
#  ('Saab', <itertools._grouper at 0x54a86e8>),
#  ('Saturn', <itertools._grouper at 0x54a8d78>),
#  ('Scion', <itertools._grouper at 0x54a8070>),
#  ('Smart', <itertools._grouper at 0x54a8100>),
#  ('Subaru', <itertools._grouper at 0x54a84c0>),
#  ('Suzuki', <itertools._grouper at 0x54a8118>),
#  ('Toyota', <itertools._grouper at 0x54a8508>),
#  ('Volkswagen', <itertools._grouper at 0x54a8238>),
#  ('Volvo', <itertools._grouper at 0x54a80b8>)]

# %%
def get_largest_group(groups):
    group_dict = {make : list(group) for make, group in groups}
    return sorted(group_dict.items(),key = lambda g : len(g[1]) , reverse=True)

# %%
groups = get_filtered_grouped_data('personal_info.csv', 'vehicles.csv', 'employment.csv', 'update_status.csv',
                             filter_key = lambda x : x.gender == 'Female',
                                group_by = lambda x : x.vehicle_make)

# %%
get_largest_group(groups)
# Out:
# [('Chevrolet',
#   [FulL_Data(ssn=105917777, first_name='Audi', last_name='Roach', gender='Female', language='Estonian', vehicle_make='Chevrolet', vehicle_model='Silverado 3500', model_year=2004, employer='Bashirian-Lueilwitz', department='Engineering', employee_id=443328799, last_updated=datetime.datetime(2017, 5, 11, 1, 48, 32), created=datetime.datetime(2016, 5, 31, 0, 38, 13)),
#    FulL_Data(ssn=114660984, first_name='Casandra', last_name='Juares', gender='Female', language='Lithuanian', vehicle_make='Chevrolet', vehicle_model='Camaro', model_year=1998, employer='Mayert, Rice and Schmitt', department='Product Management', employee_id=858596488, last_updated=datetime.datetime(2017, 6, 16, 17, 41, 33), created=datetime.datetime(2016, 5, 28, 20, 31, 25)),
#    FulL_Data(ssn=119078817, first_name='Blondie', last_name='Powderham', gender='Female', language='Croatian', vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2005, employer='Terry LLC', department='Accounting', employee_id=704864087, last_updated=datetime.datetime(2017, 12, 24, 15, 31, 5), created=datetime.datetime(2016, 12, 6, 14, 16, 59)),
#    FulL_Data(ssn=164119849, first_name='Clemence', last_name='Aujean', gender='Female', language='Albanian', vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=2001, employer='Quitzon, Rempel and Hane', department='Business Development', employee_id=34767523, last_updated=datetime.datetime(2017, 6, 24, 10, 17, 58), created=datetime.datetime(2016, 4, 20, 11, 9, 5)),
#    FulL_Data(ssn=174519992, first_name='Drucie', last_name='Travers', gender='Female', language='Swati', vehicle_make='Chevrolet', vehicle_model='Beretta', model_year=1994, employer='Jast-Quitzon', department='Human Resources', employee_id=675707294, last_updated=datetime.datetime(2017, 3, 3, 19, 42, 18), created=datetime.datetime(2016, 5, 17, 23, 32, 25)),
#    FulL_Data(ssn=181074434, first_name='Ferdinande', last_name='Probet', gender='Female', language='Catalan', vehicle_make='Chevrolet', vehicle_model='Impala SS', model_year=1995, employer='Little, Herzog and Mertz', department='Legal', employee_id=459164509, last_updated=datetime.datetime(2017, 10, 7, 7, 52, 10), created=datetime.datetime(2016, 11, 11, 20, 19, 19)),
#    FulL_Data(ssn=205872423, first_name='Oralla', last_name='Kearle', gender='Female', language='Zulu', vehicle_make='Chevrolet', vehicle_model='Express 2500', model_year=1999, employer='Goodwin-Oberbrunner', department='Accounting', employee_id=70291024, last_updated=datetime.datetime(2018, 1, 1, 8, 17, 27), created=datetime.datetime(2016, 2, 16, 23, 45, 38)),
#    FulL_Data(ssn=209508146, first_name='Kenna', last_name='Meryett', gender='Female', language='Czech', vehicle_make='Chevrolet', vehicle_model='Sportvan G20', model_year=1992, employer='Senger, Fay and Schuppe', department='Marketing', employee_id=59734435, last_updated=datetime.datetime(2018, 3, 13, 17, 52, 16), created=datetime.datetime(2016, 4, 10, 7, 14, 25)),
#    FulL_Data(ssn=224309267, first_name='Flori', last_name='Bagnal', gender='Female', language='Swedish', vehicle_make='Chevrolet', vehicle_model='Avalanche', model_year=2009, employer='Jacobson-Kuhn', department='Human Resources', employee_id=335097675, last_updated=datetime.datetime(2017, 12, 17, 11, 57, 56), created=datetime.datetime(2016, 11, 13, 20, 27, 10)),
#    FulL_Data(ssn=239374122, first_name='Jodee', last_name='Elsdon', gender='Female', language='Guarana', vehicle_make='Chevrolet', vehicle_model='Silverado 1500', model_year=2002, employer='Kassulke-Cruickshank', department='Support', employee_id=338042555, last_updated=datetime.datetime(2017, 9, 20, 20, 47, 44), created=datetime.datetime(2016, 3, 5, 9, 16, 37)),
#    FulL_Data(ssn=240088805, first_name='Gates', last_name='McGiffin', gender='Female', language='Finnish', vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1988, employer='Mraz, Veum and Farrell', department='Product Management', employee_id=306285659, last_updated=datetime.datetime(2017, 2, 10, 12, 14, 31), created=datetime.datetime(2016, 8, 15, 20, 52, 10)),
#    FulL_Data(ssn=274769883, first_name='Fawn', last_name='MacNamara', gender='Female', language='Bengali', vehicle_make='Chevrolet', vehicle_model='Impala', model_year=1995, employer='Kassulke Group', department='Human Resources', employee_id=864085293, last_updated=datetime.datetime(2017, 10, 9, 4, 11, 3), created=datetime.datetime(2016, 12, 22, 11, 44, 48)),
#    FulL_Data(ssn=315262241, first_name='Cammy', last_name='Harland', gender='Female', language='Bulgarian', vehicle_make='Chevrolet', vehicle_model='Silverado 2500', model_year=1999, employer='Predovic, Renner and Hansen', department='Research and Development', employee_id=161755710, last_updated=datetime.datetime(2017, 11, 27, 8, 16, 19), created=datetime.datetime(2016, 5, 27, 6, 53, 31)),
#    FulL_Data(ssn=333955025, first_name='Rebeca', last_name='Walesa', gender='Female', language='Zulu', vehicle_make='Chevrolet', vehicle_model='Monte Carlo', model_year=2002, employer='Beahan-Little', department='Sales', employee_id=701386102, last_updated=datetime.datetime(2017, 8, 28, 15, 13, 59), created=datetime.datetime(2016, 5, 25, 23, 33, 3)),
#    FulL_Data(ssn=339278046, first_name='Julita', last_name='Jouhan', gender='Female', language='Bosnian', vehicle_make='Chevrolet', vehicle_model='Camaro', model_year=1998, employer='Kessler-Simonis', department='Research and Development', employee_id=156371973, last_updated=datetime.datetime(2017, 12, 12, 18, 26, 28), created=datetime.datetime(2016, 4, 9, 3, 13, 49)),
#    FulL_Data(ssn=347648652, first_name='Dusty', last_name='Morat', gender='Female', language='Japanese', vehicle_make='Chevrolet', vehicle_model='Metro', model_year=2001, employer='Prosacco-Herzog', department='Sales', employee_id=386538811, last_updated=datetime.datetime(2017, 5, 23, 11, 28, 5), created=datetime.datetime(2016, 12, 30, 3, 51, 10)),
#    FulL_Data(ssn=367228998, first_name='Blake', last_name='Mustin', gender='Female', language='Kyrgyz', vehicle_make='Chevrolet', vehicle_model='Express 2500', model_year=1997, employer='Dickinson-Wiegand', department='Accounting', employee_id=439661529, last_updated=datetime.datetime(2017, 12, 11, 17, 58, 1), created=datetime.datetime(2016, 5, 13, 12, 0, 26)),
#    FulL_Data(ssn=371285892, first_name='Malia', last_name='Hanse', gender='Female', language='Tsonga', vehicle_make='Chevrolet', vehicle_model='Corvair', model_year=1960, employer='Adams-Ledner', department='Services', employee_id=405208891, last_updated=datetime.datetime(2017, 10, 23, 5, 51, 2), created=datetime.datetime(2016, 11, 1, 11, 0, 34)),
#    FulL_Data(ssn=397878282, first_name='Kyrstin', last_name='Waldock', gender='Female', language='Belarusian', vehicle_make='Chevrolet', vehicle_model='Blazer', model_year=1998, employer='Jones Inc', department='Sales', employee_id=482299282, last_updated=datetime.datetime(2017, 1, 25, 21, 15, 13), created=datetime.datetime(2016, 6, 24, 8, 10, 55)),
#    FulL_Data(ssn=420467789, first_name='Steffie', last_name='Britto', gender='Female', language='New Zealand Sign Language', vehicle_make='Chevrolet', vehicle_model='Express 2500', model_year=2005, employer='Schroeder LLC', department='Engineering', employee_id=657085477, last_updated=datetime.datetime(2017, 1, 25, 20, 25, 19), created=datetime.datetime(2016, 8, 24, 14, 54, 22)),
#    FulL_Data(ssn=469961488, first_name='Euphemia', last_name='Neggrini', gender='Female', language='Guarana', vehicle_make='Chevrolet', vehicle_model='Silverado 1500', model_year=2008, employer='Reichert-Hagenes', department='Human Resources', employee_id=844676473, last_updated=datetime.datetime(2017, 8, 14, 12, 32, 41), created=datetime.datetime(2016, 8, 9, 16, 15, 51)),
#    FulL_Data(ssn=485798123, first_name='Tish', last_name='Kemston', gender='Female', language='Khmer', vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1995, employer='Fadel-Gleichner', department='Legal', employee_id=964640239, last_updated=datetime.datetime(2017, 12, 14, 14, 16, 43), created=datetime.datetime(2016, 4, 10, 23, 54, 6)),
#    FulL_Data(ssn=486871145, first_name='Elyn', last_name='Djokovic', gender='Female', language='French', vehicle_make='Chevrolet', vehicle_model='Beretta', model_year=1993, employer='Treutel-Lubowitz', department='Services', employee_id=335310332, last_updated=datetime.datetime(2017, 8, 25, 5, 12, 39), created=datetime.datetime(2016, 11, 13, 3, 27, 50)),
#    FulL_Data(ssn=495626374, first_name='Nevsa', last_name='Boarder', gender='Female', language='Czech', vehicle_make='Chevrolet', vehicle_model='Lumina', model_year=2000, employer='Gerlach LLC', department='Services', employee_id=115891434, last_updated=datetime.datetime(2017, 5, 21, 12, 26, 52), created=datetime.datetime(2016, 1, 16, 18, 49, 45)),
#    FulL_Data(ssn=506023957, first_name='Tilly', last_name='Joubert', gender='Female', language='Danish', vehicle_make='Chevrolet', vehicle_model='Silverado', model_year=2002, employer='Boyer, Hermann and Bayer', department='Legal', employee_id=452093562, last_updated=datetime.datetime(2018, 3, 26, 10, 53, 26), created=datetime.datetime(2016, 8, 19, 22, 34, 54)),
#    FulL_Data(ssn=508543168, first_name='Helaine', last_name='Accombe', gender='Female', language='Dutch', vehicle_make='Chevrolet', vehicle_model='Express 1500', model_year=1997, employer='Wunsch-Ruecker', department='Accounting', employee_id=308759158, last_updated=datetime.datetime(2017, 11, 29, 20, 18, 24), created=datetime.datetime(2016, 9, 29, 5, 12, 25)),
#    FulL_Data(ssn=509391128, first_name='Carie', last_name='Leneham', gender='Female', language='Telugu', vehicle_make='Chevrolet', vehicle_model='Silverado 1500', model_year=2000, employer='Cartwright-Emmerich', department='Marketing', employee_id=331047074, last_updated=datetime.datetime(2017, 4, 30, 21, 28, 1), created=datetime.datetime(2016, 7, 20, 14, 12, 38)),
#    FulL_Data(ssn=520810974, first_name='Ofella', last_name='Navarro', gender='Female', language='Kurdish', vehicle_make='Chevrolet', vehicle_model='Metro', model_year=1998, employer='Breitenberg-Wiza', department='Accounting', employee_id=556401615, last_updated=datetime.datetime(2017, 3, 21, 6, 39, 8), created=datetime.datetime(2016, 7, 31, 23, 47, 30)),
#    FulL_Data(ssn=526989361, first_name='Cathe', last_name='Allsupp', gender='Female', language='Marathi', vehicle_make='Chevrolet', vehicle_model='Camaro', model_year=2001, employer='Mitchell-Kovacek', department='Product Management', employee_id=983030999, last_updated=datetime.datetime(2017, 4, 3, 2, 58, 51), created=datetime.datetime(2016, 1, 16, 10, 59, 40)),
#    FulL_Data(ssn=534506091, first_name='Florencia', last_name='Abramof', gender='Female', language='Arabic', vehicle_make='Chevrolet', vehicle_model='Silverado', model_year=2007, employer='Mills, Schmidt and Orn', department='Training', employee_id=994129786, last_updated=datetime.datetime(2017, 3, 27, 6, 4, 16), created=datetime.datetime(2016, 11, 19, 11, 20, 44)),
#    FulL_Data(ssn=567828701, first_name='Bathsheba', last_name='Ainge', gender='Female', language='Montenegrin', vehicle_make='Chevrolet', vehicle_model='Aveo', model_year=2008, employer='Satterfield, Ankunding and Robel', department='Product Management', employee_id=378628284, last_updated=datetime.datetime(2017, 10, 25, 2, 27, 51), created=datetime.datetime(2016, 8, 14, 14, 48, 11)),
#    FulL_Data(ssn=586854199, first_name='Gisela', last_name='Foulser', gender='Female', language='Albanian', vehicle_make='Chevrolet', vehicle_model='SSR', model_year=2005, employer='Hodkiewicz and Sons', department='Training', employee_id=151367840, last_updated=datetime.datetime(2017, 11, 29, 6, 11, 57), created=datetime.datetime(2016, 4, 3, 4, 1, 59)),
#    FulL_Data(ssn=599695584, first_name='Concordia', last_name='Grassot', gender='Female', language='Czech', vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1953, employer='Bartell, Brakus and Considine', department='Marketing', employee_id=763802991, last_updated=datetime.datetime(2017, 10, 11, 17, 31, 15), created=datetime.datetime(2016, 12, 26, 10, 45, 34)),
#    FulL_Data(ssn=603313174, first_name='Adelind', last_name='Pautard', gender='Female', language='English', vehicle_make='Chevrolet', vehicle_model='G-Series 2500', model_year=1998, employer='Hansen-Bayer', department='Training', employee_id=65805930, last_updated=datetime.datetime(2018, 3, 5, 13, 44, 43), created=datetime.datetime(2016, 4, 26, 19, 38, 9)),
#    FulL_Data(ssn=644708292, first_name='Glyn', last_name='Mc Giffin', gender='Female', language='Zulu', vehicle_make='Chevrolet', vehicle_model='Classic', model_year=2004, employer='Parisian, Kutch and Boyle', department='Services', employee_id=656774148, last_updated=datetime.datetime(2017, 1, 2, 0, 10, 46), created=datetime.datetime(2016, 3, 24, 13, 39, 53)),
#    FulL_Data(ssn=650639841, first_name='Evanne', last_name='Ibeson', gender='Female', language='Korean', vehicle_make='Chevrolet', vehicle_model='Lumina', model_year=2000, employer='Windler Inc', department='Sales', employee_id=536449997, last_updated=datetime.datetime(2017, 12, 12, 8, 39, 46), created=datetime.datetime(2016, 10, 4, 6, 20, 18)),
#    FulL_Data(ssn=680112707, first_name='Letta', last_name='Wishart', gender='Female', language='Chinese', vehicle_make='Chevrolet', vehicle_model='Beretta', model_year=1992, employer='Satterfield, Wolf and Thiel', department='Research and Development', employee_id=634901321, last_updated=datetime.datetime(2017, 12, 29, 10, 10, 26), created=datetime.datetime(2016, 7, 13, 12, 11, 36)),
#    FulL_Data(ssn=681722644, first_name='Rosie', last_name='Aartsen', gender='Female', language='Luxembourgish', vehicle_make='Chevrolet', vehicle_model='Malibu', model_year=2001, employer='Wolff, Metz and Gorczany', department='Accounting', employee_id=116978970, last_updated=datetime.datetime(2017, 12, 14, 23, 56, 34), created=datetime.datetime(2016, 3, 1, 22, 1, 49)),
#    FulL_Data(ssn=719056621, first_name='Susanne', last_name='Dilger', gender='Female', language='Punjabi', vehicle_make='Chevrolet', vehicle_model='Silverado 2500', model_year=2003, employer='Wintheiser-Dach', department='Research and Development', employee_id=237767142, last_updated=datetime.datetime(2017, 9, 17, 14, 33, 45), created=datetime.datetime(2016, 5, 9, 18, 56, 22)),
#    FulL_Data(ssn=743752371, first_name='Jodee', last_name='Lintin', gender='Female', language='Dzongkha', vehicle_make='Chevrolet', vehicle_model='Tahoe', model_year=2011, employer='Hand Group', department='Business Development', employee_id=693955011, last_updated=datetime.datetime(2017, 12, 27, 9, 33, 42), created=datetime.datetime(2016, 5, 6, 13, 55, 20)),
#    FulL_Data(ssn=763091587, first_name='Yasmeen', last_name='Vaskin', gender='Female', language='Lithuanian', vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1995, employer='Sporer Group', department='Training', employee_id=470369978, last_updated=datetime.datetime(2017, 1, 22, 12, 35, 38), created=datetime.datetime(2016, 11, 24, 19, 46, 6)),
#    FulL_Data(ssn=764932248, first_name='Maure', last_name='Verrillo', gender='Female', language='Spanish', vehicle_make='Chevrolet', vehicle_model='Monte Carlo', model_year=2004, employer='Olson, McClure and Schiller', department='Marketing', employee_id=382550412, last_updated=datetime.datetime(2017, 11, 26, 1, 41, 24), created=datetime.datetime(2016, 9, 28, 17, 49, 11)),
#    FulL_Data(ssn=778748262, first_name='Sonia', last_name='Grishakin', gender='Female', language='Bulgarian', vehicle_make='Chevrolet', vehicle_model='Sportvan G30', model_year=1993, employer='Anderson, Dickinson and Toy', department='Marketing', employee_id=468501105, last_updated=datetime.datetime(2017, 2, 5, 11, 21, 48), created=datetime.datetime(2016, 8, 7, 11, 55, 4)),
#    FulL_Data(ssn=816313858, first_name='Elvera', last_name='Walmsley', gender='Female', language='Montenegrin', vehicle_make='Chevrolet', vehicle_model='Silverado 3500', model_year=2004, employer='Hilll Inc', department='Product Management', employee_id=133299629, last_updated=datetime.datetime(2017, 4, 13, 4, 17, 11), created=datetime.datetime(2016, 7, 30, 2, 46, 27)),
#    FulL_Data(ssn=851942162, first_name='Rodi', last_name='Mulrenan', gender='Female', language='Catalan', vehicle_make='Chevrolet', vehicle_model='Cobalt', model_year=2010, employer='Collier, Botsford and Ruecker', department='Engineering', employee_id=185849664, last_updated=datetime.datetime(2017, 10, 15, 12, 43, 2), created=datetime.datetime(2016, 11, 28, 14, 34, 31)),
#    FulL_Data(ssn=866530625, first_name='Francene', last_name='Ehlerding', gender='Female', language='Latvian', vehicle_make='Chevrolet', vehicle_model='Blazer', model_year=1997, employer='Douglas-Breitenberg', department='Business Development', employee_id=636285198, last_updated=datetime.datetime(2018, 2, 24, 20, 22, 43), created=datetime.datetime(2016, 12, 15, 22, 59, 20)),
#    FulL_Data(ssn=868321805, first_name='Joanna', last_name='Raycroft', gender='Female', language='Bosnian', vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2007, employer='Abshire Inc', department='Research and Development', employee_id=558987515, last_updated=datetime.datetime(2017, 9, 29, 17, 46, 17), created=datetime.datetime(2016, 11, 14, 1, 26, 32)),
#    FulL_Data(ssn=893177318, first_name='Nani', last_name='Bonelle', gender='Female', language='Kyrgyz', vehicle_make='Chevrolet', vehicle_model='Lumina', model_year=1995, employer='Orn Inc', department='Human Resources', employee_id=384356300, last_updated=datetime.datetime(2017, 7, 23, 7, 11, 51), created=datetime.datetime(2016, 2, 28, 8, 1, 12))]),
#  ('Ford',
#   [FulL_Data(ssn=101714702, first_name='Cayla', last_name='MacDonagh', gender='Female', language='Lao', vehicle_make='Ford', vehicle_model='Mustang', model_year=1997, employer='Nicolas and Sons', department='Sales', employee_id=416841359, last_updated=datetime.datetime(2017, 1, 23, 11, 23, 17), created=datetime.datetime(2016, 1, 27, 4, 32, 57)),
#    FulL_Data(ssn=110843641, first_name='Amberly', last_name='Huws', gender='Female', language='Papiamento', vehicle_make='Ford', vehicle_model='Mustang', model_year=1990, employer='Lueilwitz LLC', department='Marketing', employee_id=339146042, last_updated=datetime.datetime(2017, 9, 4, 19, 2, 3), created=datetime.datetime(2016, 9, 12, 22, 50, 5)),
#    FulL_Data(ssn=123883381, first_name='Christiane', last_name='Hynes', gender='Female', language='Danish', vehicle_make='Ford', vehicle_model='Mustang', model_year=1989, employer='Mueller-Rath', department='Human Resources', employee_id=58069298, last_updated=datetime.datetime(2017, 2, 21, 16, 37, 38), created=datetime.datetime(2016, 1, 30, 23, 42, 36)),
#    FulL_Data(ssn=142873416, first_name='Margaux', last_name='Wintringham', gender='Female', language='Tajik', vehicle_make='Ford', vehicle_model='Thunderbird', model_year=2005, employer='Altenwerth-Emard', department='Marketing', employee_id=305847411, last_updated=datetime.datetime(2017, 5, 3, 14, 26, 58), created=datetime.datetime(2016, 12, 26, 21, 18, 54)),
#    FulL_Data(ssn=146813446, first_name='Korry', last_name='Billham', gender='Female', language='Hebrew', vehicle_make='Ford', vehicle_model='Thunderbird', model_year=1988, employer='Kub, Koch and Ratke', department='Marketing', employee_id=727830449, last_updated=datetime.datetime(2017, 1, 18, 8, 40, 14), created=datetime.datetime(2016, 9, 1, 8, 59, 50)),
#    FulL_Data(ssn=147633462, first_name='Aime', last_name='Di Antonio', gender='Female', language='Tok Pisin', vehicle_make='Ford', vehicle_model='Explorer', model_year=2005, employer='Bashirian-Moen', department='Training', employee_id=519115041, last_updated=datetime.datetime(2018, 2, 2, 13, 16, 51), created=datetime.datetime(2016, 7, 17, 4, 28, 52)),
#    FulL_Data(ssn=153671309, first_name='Annelise', last_name='Yushin', gender='Female', language='French', vehicle_make='Ford', vehicle_model='Taurus', model_year=1998, employer='Gerlach, Bahringer and Rutherford', department='Accounting', employee_id=955604381, last_updated=datetime.datetime(2017, 8, 16, 12, 3, 37), created=datetime.datetime(2016, 12, 22, 19, 37, 39)),
#    FulL_Data(ssn=161534778, first_name='Kiri', last_name='Ciccone', gender='Female', language='Kyrgyz', vehicle_make='Ford', vehicle_model='Mustang', model_year=1995, employer='Oberbrunner, Donnelly and Gibson', department='Human Resources', employee_id=832548521, last_updated=datetime.datetime(2017, 12, 3, 11, 9, 18), created=datetime.datetime(2016, 12, 9, 18, 37, 55)),
#    FulL_Data(ssn=171277781, first_name='Phillida', last_name='Cleeve', gender='Female', language='Lao', vehicle_make='Ford', vehicle_model='Mustang', model_year=1985, employer='Batz Inc', department='Support', employee_id=492738721, last_updated=datetime.datetime(2017, 3, 5, 9, 35, 8), created=datetime.datetime(2016, 9, 23, 3, 10, 37)),
#    FulL_Data(ssn=184606243, first_name='Fern', last_name='Demogeot', gender='Female', language='Tok Pisin', vehicle_make='Ford', vehicle_model='Mustang', model_year=1998, employer='Quitzon-Morissette', department='Product Management', employee_id=815434446, last_updated=datetime.datetime(2018, 2, 26, 15, 42, 50), created=datetime.datetime(2016, 6, 16, 15, 17, 46)),
#    FulL_Data(ssn=211041734, first_name='Jeana', last_name='Girardeau', gender='Female', language='Dzongkha', vehicle_make='Ford', vehicle_model='E-Series', model_year=2011, employer='Renner LLC', department='Services', employee_id=296760360, last_updated=datetime.datetime(2018, 3, 11, 20, 29, 12), created=datetime.datetime(2016, 8, 30, 15, 59, 14)),
#    FulL_Data(ssn=211196826, first_name='Noni', last_name='Meynell', gender='Female', language='Portuguese', vehicle_make='Ford', vehicle_model='Econoline E150', model_year=1996, employer='Feil, Wunsch and Cassin', department='Human Resources', employee_id=453457627, last_updated=datetime.datetime(2018, 2, 12, 4, 33, 14), created=datetime.datetime(2016, 8, 25, 22, 0, 15)),
#    FulL_Data(ssn=213281395, first_name='Catlaina', last_name='Patullo', gender='Female', language='Bengali', vehicle_make='Ford', vehicle_model='Mustang', model_year=2002, employer='Larson and Sons', department='Sales', employee_id=183961077, last_updated=datetime.datetime(2017, 6, 4, 4, 51, 16), created=datetime.datetime(2016, 6, 11, 0, 6, 58)),
#    FulL_Data(ssn=217815416, first_name='Gusta', last_name='Cruise', gender='Female', language='Tsonga', vehicle_make='Ford', vehicle_model='Mustang', model_year=2005, employer='Gislason-Padberg', department='Sales', employee_id=208472919, last_updated=datetime.datetime(2017, 12, 27, 18, 15, 59), created=datetime.datetime(2016, 11, 20, 2, 39, 48)),
#    FulL_Data(ssn=220380208, first_name='Jess', last_name='Fulun', gender='Female', language='Gagauz', vehicle_make='Ford', vehicle_model='Lightning', model_year=1994, employer='Brekke, Grady and Ruecker', department='Human Resources', employee_id=662984352, last_updated=datetime.datetime(2017, 11, 10, 15, 6, 25), created=datetime.datetime(2016, 10, 28, 19, 34, 21)),
#    FulL_Data(ssn=228552042, first_name='Jaquith', last_name='Durtnel', gender='Female', language='Czech', vehicle_make='Ford', vehicle_model='Mustang', model_year=1993, employer='Batz-Bahringer', department='Research and Development', employee_id=741907423, last_updated=datetime.datetime(2017, 1, 17, 20, 5, 40), created=datetime.datetime(2016, 3, 8, 17, 42, 55)),
#    FulL_Data(ssn=247089326, first_name='Minni', last_name='Scurman', gender='Female', language='Kannada', vehicle_make='Ford', vehicle_model='E250', model_year=2008, employer='McClure and Sons', department='Human Resources', employee_id=801737009, last_updated=datetime.datetime(2017, 10, 20, 3, 18, 53), created=datetime.datetime(2016, 9, 15, 4, 25, 48)),
#    FulL_Data(ssn=267756383, first_name='Ardath', last_name='Pitts', gender='Female', language='Romanian', vehicle_make='Ford', vehicle_model='Courier', model_year=1989, employer='Gottlieb, Gleichner and Kihn', department='Services', employee_id=421073885, last_updated=datetime.datetime(2017, 1, 18, 3, 2, 58), created=datetime.datetime(2016, 5, 12, 18, 5, 24)),
#    FulL_Data(ssn=271040134, first_name='Eadith', last_name='Jerg', gender='Female', language='Gagauz', vehicle_make='Ford', vehicle_model='Bronco', model_year=1995, employer='Wilderman-Larkin', department='Business Development', employee_id=86806443, last_updated=datetime.datetime(2017, 5, 14, 7, 18, 59), created=datetime.datetime(2016, 8, 2, 17, 22, 46)),
#    FulL_Data(ssn=313527312, first_name='Farrand', last_name='MacKenzie', gender='Female', language='French', vehicle_make='Ford', vehicle_model='Taurus', model_year=2013, employer='Torp LLC', department='Training', employee_id=194509043, last_updated=datetime.datetime(2017, 11, 27, 22, 37, 28), created=datetime.datetime(2016, 6, 9, 16, 42, 48)),
#    FulL_Data(ssn=320979147, first_name='Roch', last_name='Wahlberg', gender='Female', language='Thai', vehicle_make='Ford', vehicle_model='F-Series Super Duty', model_year=2007, employer='Deckow, Hudson and Koch', department='Research and Development', employee_id=458944543, last_updated=datetime.datetime(2017, 11, 27, 2, 56, 43), created=datetime.datetime(2016, 12, 30, 2, 58, 10)),
#    FulL_Data(ssn=349538864, first_name='Muffin', last_name='Lord', gender='Female', language='Georgian', vehicle_make='Ford', vehicle_model='Focus', model_year=2000, employer='Labadie, Lockman and Kozey', department='Support', employee_id=732905417, last_updated=datetime.datetime(2017, 12, 27, 21, 15, 3), created=datetime.datetime(2016, 1, 28, 10, 14, 46)),
#    FulL_Data(ssn=355219711, first_name='Daryn', last_name='Battin', gender='Female', language='Georgian', vehicle_make='Ford', vehicle_model='Festiva', model_year=1992, employer='Jacobson and Sons', department='Legal', employee_id=527624074, last_updated=datetime.datetime(2017, 11, 1, 23, 0, 15), created=datetime.datetime(2016, 4, 22, 13, 52, 40)),
#    FulL_Data(ssn=361427068, first_name='Ashia', last_name='Ferran', gender='Female', language='West Frisian', vehicle_make='Ford', vehicle_model='Club Wagon', model_year=1996, employer="Altenwerth, Jacobson and O'Keefe", department='Training', employee_id=768687759, last_updated=datetime.datetime(2018, 2, 4, 13, 38, 12), created=datetime.datetime(2016, 9, 7, 15, 20, 13)),
#    FulL_Data(ssn=366610607, first_name='Bethena', last_name='Joicey', gender='Female', language='Haitian Creole', vehicle_make='Ford', vehicle_model='F350', model_year=2007, employer="Brakus-D'Amore", department='Human Resources', employee_id=670234629, last_updated=datetime.datetime(2017, 12, 27, 23, 53, 19), created=datetime.datetime(2016, 3, 28, 15, 11, 41)),
#    FulL_Data(ssn=378886805, first_name='Vittoria', last_name='Oldroyd', gender='Female', language='Moldovan', vehicle_make='Ford', vehicle_model='Festiva', model_year=1992, employer='Franecki-Wisozk', department='Marketing', employee_id=404637900, last_updated=datetime.datetime(2017, 7, 4, 17, 16, 15), created=datetime.datetime(2016, 9, 25, 8, 10, 22)),
#    FulL_Data(ssn=421012511, first_name='Mikaela', last_name='Andrivot', gender='Female', language='English', vehicle_make='Ford', vehicle_model='F350', model_year=2012, employer='Wyman and Sons', department='Support', employee_id=274093007, last_updated=datetime.datetime(2018, 3, 19, 13, 36, 26), created=datetime.datetime(2016, 7, 31, 17, 41, 15)),
#    FulL_Data(ssn=421203448, first_name='Alie', last_name='Gerauld', gender='Female', language='Khmer', vehicle_make='Ford', vehicle_model='Crown Victoria', model_year=1998, employer='Orn, Willms and Torp', department='Support', employee_id=252477756, last_updated=datetime.datetime(2017, 7, 8, 17, 17, 10), created=datetime.datetime(2016, 10, 8, 3, 4, 54)),
#    FulL_Data(ssn=424910692, first_name='Jeanie', last_name='Titchard', gender='Female', language='Swati', vehicle_make='Ford', vehicle_model='Escape', model_year=2008, employer='Harvey-Schumm', department='Services', employee_id=687788538, last_updated=datetime.datetime(2018, 1, 6, 3, 9, 36), created=datetime.datetime(2016, 2, 2, 7, 49, 10)),
#    FulL_Data(ssn=428192946, first_name='Dionne', last_name='Bibb', gender='Female', language='Moldovan', vehicle_make='Ford', vehicle_model='Taurus', model_year=2012, employer='Hegmann-Gerlach', department='Business Development', employee_id=501450543, last_updated=datetime.datetime(2017, 11, 14, 5, 58, 52), created=datetime.datetime(2016, 6, 25, 0, 25, 32)),
#    FulL_Data(ssn=428790781, first_name='Mame', last_name='Criag', gender='Female', language='Catalan', vehicle_make='Ford', vehicle_model='Taurus', model_year=1993, employer='Heller, Conroy and Ankunding', department='Accounting', employee_id=800769995, last_updated=datetime.datetime(2018, 1, 30, 1, 53, 32), created=datetime.datetime(2016, 1, 7, 17, 54, 14)),
#    FulL_Data(ssn=438800430, first_name='Gunilla', last_name='Navan', gender='Female', language='Moldovan', vehicle_make='Ford', vehicle_model='Explorer', model_year=2009, employer='Armstrong, Koelpin and Moen', department='Business Development', employee_id=472658940, last_updated=datetime.datetime(2017, 4, 12, 15, 23, 42), created=datetime.datetime(2016, 4, 7, 13, 46, 40)),
#    FulL_Data(ssn=450363771, first_name='Anette', last_name='Reast', gender='Female', language='Guarana', vehicle_make='Ford', vehicle_model='Mustang', model_year=1997, employer="O'Conner-Breitenberg", department='Research and Development', employee_id=203523742, last_updated=datetime.datetime(2017, 5, 24, 19, 44, 3), created=datetime.datetime(2016, 3, 14, 0, 49, 29)),
#    FulL_Data(ssn=451528000, first_name='Donia', last_name='Daville', gender='Female', language='Burmese', vehicle_make='Ford', vehicle_model='Club Wagon', model_year=1997, employer='Hilpert, Douglas and Kunde', department='Human Resources', employee_id=502072742, last_updated=datetime.datetime(2018, 2, 24, 11, 3, 12), created=datetime.datetime(2016, 10, 1, 17, 6, 58)),
#    FulL_Data(ssn=455743521, first_name='Nesta', last_name='Gascone', gender='Female', language='Croatian', vehicle_make='Ford', vehicle_model='Mustang', model_year=2001, employer='Berge-Davis', department='Services', employee_id=365486054, last_updated=datetime.datetime(2018, 1, 2, 16, 4, 54), created=datetime.datetime(2016, 11, 20, 22, 55, 38)),
#    FulL_Data(ssn=474951775, first_name='Ivette', last_name='Whitewood', gender='Female', language='Korean', vehicle_make='Ford', vehicle_model='Explorer Sport', model_year=2003, employer='Schneider-Bins', department='Human Resources', employee_id=572599249, last_updated=datetime.datetime(2017, 4, 26, 11, 28, 52), created=datetime.datetime(2016, 2, 29, 11, 15, 51)),
#    FulL_Data(ssn=499442439, first_name='Ediva', last_name='Flucks', gender='Female', language='French', vehicle_make='Ford', vehicle_model='F250', model_year=2001, employer='Bernier Inc', department='Product Management', employee_id=632531739, last_updated=datetime.datetime(2017, 1, 14, 6, 0, 18), created=datetime.datetime(2016, 8, 18, 13, 2, 28)),
#    FulL_Data(ssn=517050600, first_name='Lindy', last_name='Losz', gender='Female', language='Kurdish', vehicle_make='Ford', vehicle_model='Expedition', model_year=2000, employer='Feeney Group', department='Sales', employee_id=413035896, last_updated=datetime.datetime(2017, 7, 12, 19, 7, 36), created=datetime.datetime(2016, 9, 21, 3, 51, 44)),
#    FulL_Data(ssn=521825436, first_name='Barb', last_name='Riolfi', gender='Female', language='Swedish', vehicle_make='Ford', vehicle_model='Tempo', model_year=1994, employer='Hartmann Inc', department='Support', employee_id=920051110, last_updated=datetime.datetime(2017, 4, 2, 21, 7, 7), created=datetime.datetime(2016, 9, 9, 10, 55, 6)),
#    FulL_Data(ssn=545668802, first_name='Cassey', last_name='Gammage', gender='Female', language='English', vehicle_make='Ford', vehicle_model='Mustang', model_year=2009, employer='Kuhn and Sons', department='Training', employee_id=683122262, last_updated=datetime.datetime(2017, 8, 31, 13, 48, 46), created=datetime.datetime(2016, 6, 17, 14, 30, 31)),
#    FulL_Data(ssn=589150686, first_name='Corabelle', last_name='Northin', gender='Female', language='Sotho', vehicle_make='Ford', vehicle_model='F250', model_year=1994, employer='Schmidt and Sons', department='Training', employee_id=72545492, last_updated=datetime.datetime(2017, 11, 5, 12, 2, 34), created=datetime.datetime(2016, 6, 21, 9, 34, 58)),
#    FulL_Data(ssn=592234343, first_name='Iona', last_name='Garron', gender='Female', language='Catalan', vehicle_make='Ford', vehicle_model='F150', model_year=2000, employer='Torphy, Doyle and Padberg', department='Sales', employee_id=703159834, last_updated=datetime.datetime(2017, 12, 7, 16, 5, 21), created=datetime.datetime(2016, 5, 23, 22, 5, 4)),
#    FulL_Data(ssn=654753300, first_name='Korney', last_name='Chiplin', gender='Female', language='Chinese', vehicle_make='Ford', vehicle_model='Expedition', model_year=2004, employer='Weimann, Howell and Mills', department='Research and Development', employee_id=841375663, last_updated=datetime.datetime(2017, 10, 8, 21, 3, 38), created=datetime.datetime(2016, 10, 16, 7, 41, 3)),
#    FulL_Data(ssn=658213014, first_name='Star', last_name='Crummey', gender='Female', language='Norwegian', vehicle_make='Ford', vehicle_model='Bronco', model_year=1995, employer='Bauch Group', department='Legal', employee_id=147760557, last_updated=datetime.datetime(2017, 4, 14, 18, 38, 7), created=datetime.datetime(2016, 9, 7, 14, 58, 13)),
#    FulL_Data(ssn=686225917, first_name='Aleta', last_name='Abad', gender='Female', language='Latvian', vehicle_make='Ford', vehicle_model='Crown Victoria', model_year=1992, employer='Zieme LLC', department='Product Management', employee_id=656531918, last_updated=datetime.datetime(2017, 4, 16, 16, 32, 39), created=datetime.datetime(2016, 5, 21, 9, 26, 22)),
#    FulL_Data(ssn=758205576, first_name='Kathrine', last_name='Amar', gender='Female', language='Croatian', vehicle_make='Ford', vehicle_model='Escape', model_year=2008, employer='Walker, Hayes and Jenkins', department='Support', employee_id=714104023, last_updated=datetime.datetime(2017, 5, 31, 12, 9, 25), created=datetime.datetime(2016, 4, 23, 0, 47, 19)),
#    FulL_Data(ssn=771710505, first_name='Romona', last_name='Meikle', gender='Female', language='New Zealand Sign Language', vehicle_make='Ford', vehicle_model='Festiva', model_year=1989, employer='Crooks LLC', department='Human Resources', employee_id=711703061, last_updated=datetime.datetime(2017, 7, 13, 12, 42, 39), created=datetime.datetime(2016, 3, 7, 13, 28, 27)),
#    FulL_Data(ssn=849311551, first_name='Lisabeth', last_name='Mattessen', gender='Female', language='German', vehicle_make='Ford', vehicle_model='Crown Victoria', model_year=2011, employer='Yundt, Wehner and Brown', department='Legal', employee_id=550777439, last_updated=datetime.datetime(2017, 7, 22, 6, 54, 46), created=datetime.datetime(2016, 4, 1, 21, 35, 44))]),
#  ('Mitsubishi',
#   [FulL_Data(ssn=147478577, first_name='Janessa', last_name='Growy', gender='Female', language='Gujarati', vehicle_make='Mitsubishi', vehicle_model='GTO', model_year=1996, employer='Tremblay, Jacobs and Swift', department='Training', employee_id=461648855, last_updated=datetime.datetime(2017, 4, 2, 18, 37, 59), created=datetime.datetime(2016, 12, 11, 3, 5, 36)),
#    FulL_Data(ssn=148607519, first_name='Jordan', last_name='Readwood', gender='Female', language='Khmer', vehicle_make='Mitsubishi', vehicle_model='RVR', model_year=1992, employer='Hudson-Gerhold', department='Human Resources', employee_id=622244500, last_updated=datetime.datetime(2017, 1, 22, 22, 15, 37), created=datetime.datetime(2016, 4, 29, 8, 42, 29)),
#    FulL_Data(ssn=174132047, first_name='Rey', last_name='Dallywater', gender='Female', language='Zulu', vehicle_make='Mitsubishi', vehicle_model='L300', model_year=1988, employer='Bode-Zulauf', department='Marketing', employee_id=420021775, last_updated=datetime.datetime(2017, 1, 28, 14, 24, 40), created=datetime.datetime(2016, 1, 12, 16, 53, 59)),
#    FulL_Data(ssn=200817151, first_name='Merilyn', last_name='Tink', gender='Female', language='Bengali', vehicle_make='Mitsubishi', vehicle_model='Tredia', model_year=1985, employer='Hilpert, Kassulke and Gutkowski', department='Research and Development', employee_id=26484055, last_updated=datetime.datetime(2017, 11, 19, 13, 58, 42), created=datetime.datetime(2016, 7, 31, 19, 2, 12)),
#    FulL_Data(ssn=225085789, first_name='Tamra', last_name='Becken', gender='Female', language='Telugu', vehicle_make='Mitsubishi', vehicle_model='Expo', model_year=1995, employer='Greenholt, Sawayn and Gusikowski', department='Business Development', employee_id=980311958, last_updated=datetime.datetime(2017, 8, 5, 11, 29, 59), created=datetime.datetime(2016, 4, 1, 16, 56, 12)),
#    FulL_Data(ssn=243379496, first_name='Verine', last_name='Etchells', gender='Female', language='Burmese', vehicle_make='Mitsubishi', vehicle_model='Lancer', model_year=2003, employer='Ferry, Schaden and Lowe', department='Product Management', employee_id=949140863, last_updated=datetime.datetime(2017, 5, 5, 6, 46, 9), created=datetime.datetime(2016, 9, 27, 0, 48, 56)),
#    FulL_Data(ssn=309388085, first_name='Nell', last_name='Scrigmour', gender='Female', language='Persian', vehicle_make='Mitsubishi', vehicle_model='3000GT', model_year=1999, employer='Aufderhar, Metz and Bashirian', department='Business Development', employee_id=682399289, last_updated=datetime.datetime(2017, 10, 15, 2, 43, 14), created=datetime.datetime(2016, 5, 12, 11, 34, 16)),
#    FulL_Data(ssn=317432055, first_name='Jocelyn', last_name='Gildroy', gender='Female', language='Punjabi', vehicle_make='Mitsubishi', vehicle_model='Mirage', model_year=1984, employer='Dickens LLC', department='Product Management', employee_id=109248587, last_updated=datetime.datetime(2017, 12, 26, 16, 31, 21), created=datetime.datetime(2016, 9, 18, 19, 55, 52)),
#    FulL_Data(ssn=330993055, first_name='Marinna', last_name='Dally', gender='Female', language='Azeri', vehicle_make='Mitsubishi', vehicle_model='Montero', model_year=2001, employer='Schimmel and Sons', department='Sales', employee_id=756111866, last_updated=datetime.datetime(2017, 3, 15, 2, 8, 35), created=datetime.datetime(2016, 6, 13, 6, 58, 21)),
#    FulL_Data(ssn=339712687, first_name='Marlie', last_name='Corpe', gender='Female', language='Persian', vehicle_make='Mitsubishi', vehicle_model='Raider', model_year=2007, employer='Homenick, Mitchell and Mills', department='Engineering', employee_id=442643547, last_updated=datetime.datetime(2017, 10, 22, 21, 42, 38), created=datetime.datetime(2016, 12, 18, 12, 54, 8)),
#    FulL_Data(ssn=403651535, first_name='Cathy', last_name='Gabe', gender='Female', language='Hiri Motu', vehicle_make='Mitsubishi', vehicle_model='Eclipse', model_year=1992, employer='Kirlin, Welch and Braun', department='Accounting', employee_id=810591716, last_updated=datetime.datetime(2017, 12, 17, 5, 20, 26), created=datetime.datetime(2016, 1, 9, 8, 11, 36)),
#    FulL_Data(ssn=421139794, first_name='Minne', last_name='Measey', gender='Female', language='Danish', vehicle_make='Mitsubishi', vehicle_model='Eclipse', model_year=1996, employer='Kunde Group', department='Engineering', employee_id=804320276, last_updated=datetime.datetime(2018, 2, 4, 11, 45, 24), created=datetime.datetime(2016, 6, 12, 16, 21, 5)),
#    FulL_Data(ssn=457553869, first_name='Lotta', last_name='Maclean', gender='Female', language='Swati', vehicle_make='Mitsubishi', vehicle_model='Pajero', model_year=2003, employer='Wisozk, Ward and Hodkiewicz', department='Human Resources', employee_id=34271568, last_updated=datetime.datetime(2017, 9, 5, 17, 48, 10), created=datetime.datetime(2016, 11, 21, 7, 59, 43)),
#    FulL_Data(ssn=458970499, first_name='Ginny', last_name="O'Keenan", gender='Female', language='Maltese', vehicle_make='Mitsubishi', vehicle_model='Endeavor', model_year=2011, employer='Ortiz and Sons', department='Marketing', employee_id=635978335, last_updated=datetime.datetime(2018, 1, 9, 9, 39, 25), created=datetime.datetime(2016, 11, 24, 23, 17, 7)),
#    FulL_Data(ssn=558377838, first_name='Drucie', last_name='Andrick', gender='Female', language='New Zealand Sign Language', vehicle_make='Mitsubishi', vehicle_model='Galant', model_year=1997, employer='Sipes Group', department='Product Management', employee_id=228032150, last_updated=datetime.datetime(2017, 6, 17, 0, 30), created=datetime.datetime(2016, 7, 20, 11, 41, 19)),
#    FulL_Data(ssn=639087138, first_name='Betsey', last_name='Wimbridge', gender='Female', language='Telugu', vehicle_make='Mitsubishi', vehicle_model='L300', model_year=1990, employer='Mayert and Sons', department='Research and Development', employee_id=771523110, last_updated=datetime.datetime(2018, 1, 6, 2, 57, 15), created=datetime.datetime(2016, 9, 6, 18, 30, 40)),
#    FulL_Data(ssn=670666403, first_name='Marje', last_name='Durdle', gender='Female', language='Japanese', vehicle_make='Mitsubishi', vehicle_model='Endeavor', model_year=2008, employer='Ernser-Crooks', department='Sales', employee_id=214570883, last_updated=datetime.datetime(2017, 3, 30, 16, 44, 59), created=datetime.datetime(2016, 6, 30, 15, 45, 29)),
#    FulL_Data(ssn=684955429, first_name='Ajay', last_name='Layne', gender='Female', language='Hungarian', vehicle_make='Mitsubishi', vehicle_model='Challenger', model_year=1998, employer='Ankunding and Sons', department='Engineering', employee_id=500020034, last_updated=datetime.datetime(2018, 2, 20, 13, 57, 55), created=datetime.datetime(2016, 9, 6, 18, 26, 18)),
#    FulL_Data(ssn=696104037, first_name='Marcela', last_name='Stoade', gender='Female', language='Lithuanian', vehicle_make='Mitsubishi', vehicle_model='Chariot', model_year=1987, employer='Hoppe Inc', department='Sales', employee_id=146526397, last_updated=datetime.datetime(2017, 4, 12, 6, 13, 59), created=datetime.datetime(2016, 5, 14, 0, 18, 27)),
#    FulL_Data(ssn=731228474, first_name='Hatti', last_name='Dzeniskevich', gender='Female', language='Punjabi', vehicle_make='Mitsubishi', vehicle_model='Starion', model_year=1985, employer='Becker-Bogisich', department='Research and Development', employee_id=23341550, last_updated=datetime.datetime(2017, 12, 23, 2, 30), created=datetime.datetime(2016, 2, 4, 14, 11, 45)),
#    FulL_Data(ssn=737898983, first_name='Katherine', last_name='Kuschke', gender='Female', language='Tajik', vehicle_make='Mitsubishi', vehicle_model='GTO', model_year=1995, employer='Bauch Inc', department='Business Development', employee_id=840420516, last_updated=datetime.datetime(2017, 5, 21, 16, 7, 36), created=datetime.datetime(2016, 7, 15, 14, 34, 42)),
#    FulL_Data(ssn=773219639, first_name='Brittney', last_name='Byart', gender='Female', language='Tok Pisin', vehicle_make='Mitsubishi', vehicle_model='Starion', model_year=1984, employer='Bednar-Senger', department='Legal', employee_id=431692930, last_updated=datetime.datetime(2018, 3, 2, 8, 43, 41), created=datetime.datetime(2016, 2, 7, 11, 6, 8)),
#    FulL_Data(ssn=779591449, first_name='Gertrude', last_name='Ledamun', gender='Female', language='Hungarian', vehicle_make='Mitsubishi', vehicle_model='Mighty Max', model_year=1992, employer='Emmerich, Auer and Howe', department='Accounting', employee_id=411699228, last_updated=datetime.datetime(2017, 12, 11, 23, 10, 58), created=datetime.datetime(2016, 7, 28, 1, 52, 2)),
#    FulL_Data(ssn=831443286, first_name='Leesa', last_name='Finci', gender='Female', language='Nepali', vehicle_make='Mitsubishi', vehicle_model='Mirage', model_year=2000, employer='Bashirian, Beer and Bailey', department='Engineering', employee_id=383479804, last_updated=datetime.datetime(2017, 2, 19, 2, 38, 55), created=datetime.datetime(2016, 5, 5, 3, 7, 14)),
#    FulL_Data(ssn=844507305, first_name='Merralee', last_name='Orae', gender='Female', language='Macedonian', vehicle_make='Mitsubishi', vehicle_model='Montero', model_year=2001, employer='Beer-Kihn', department='Support', employee_id=515485483, last_updated=datetime.datetime(2018, 1, 30, 7, 49, 7), created=datetime.datetime(2016, 8, 16, 12, 42, 56))]),
#  ('Toyota',
#   [FulL_Data(ssn=135869625, first_name='Tilly', last_name='Meir', gender='Female', language='Gagauz', vehicle_make='Toyota', vehicle_model='Tundra', model_year=2004, employer='Hyatt LLC', department='Training', employee_id=969647102, last_updated=datetime.datetime(2017, 12, 22, 4, 4, 28), created=datetime.datetime(2016, 2, 28, 23, 53, 17)),
#    FulL_Data(ssn=141150543, first_name='Candy', last_name='Murtagh', gender='Female', language='Montenegrin', vehicle_make='Toyota', vehicle_model='Corolla', model_year=2000, employer='Greenholt LLC', department='Sales', employee_id=845391800, last_updated=datetime.datetime(2017, 9, 27, 10, 29, 9), created=datetime.datetime(2016, 7, 17, 22, 40, 37)),
#    FulL_Data(ssn=176821359, first_name='Corny', last_name='Rothera', gender='Female', language='Thai', vehicle_make='Toyota', vehicle_model='Celica', model_year=1995, employer='Brown Group', department='Accounting', employee_id=910435820, last_updated=datetime.datetime(2017, 1, 14, 13, 36, 1), created=datetime.datetime(2016, 11, 29, 19, 3, 42)),
#    FulL_Data(ssn=262667030, first_name='Gray', last_name='Bissatt', gender='Female', language='Khmer', vehicle_make='Toyota', vehicle_model='T100 Xtra', model_year=1998, employer='Jacobson LLC', department='Research and Development', employee_id=834988535, last_updated=datetime.datetime(2018, 1, 23, 23, 44, 35), created=datetime.datetime(2016, 3, 22, 3, 8, 3)),
#    FulL_Data(ssn=278555842, first_name='Korie', last_name='Di Pietro', gender='Female', language='German', vehicle_make='Toyota', vehicle_model='Highlander', model_year=2002, employer='Pfannerstill-Rowe', department='Sales', employee_id=50913038, last_updated=datetime.datetime(2018, 1, 2, 5, 17, 17), created=datetime.datetime(2016, 5, 1, 8, 36, 52)),
#    FulL_Data(ssn=297631154, first_name='Maribelle', last_name='Gowanson', gender='Female', language='Montenegrin', vehicle_make='Toyota', vehicle_model='Camry', model_year=2001, employer='Stark-Wolff', department='Product Management', employee_id=656789812, last_updated=datetime.datetime(2018, 1, 18, 23, 20, 37), created=datetime.datetime(2016, 3, 3, 14, 10, 1)),
#    FulL_Data(ssn=327887554, first_name='Malynda', last_name='Kingerby', gender='Female', language='Swahili', vehicle_make='Toyota', vehicle_model='Corolla', model_year=1994, employer='Lowe, Tromp and Orn', department='Product Management', employee_id=955467981, last_updated=datetime.datetime(2017, 11, 24, 22, 24, 17), created=datetime.datetime(2016, 10, 12, 9, 25, 25)),
#    FulL_Data(ssn=362098563, first_name='Carri', last_name='Peterffy', gender='Female', language='Icelandic', vehicle_make='Toyota', vehicle_model='Paseo', model_year=1995, employer='Kautzer and Sons', department='Research and Development', employee_id=560050837, last_updated=datetime.datetime(2017, 2, 7, 23, 59, 48), created=datetime.datetime(2016, 7, 4, 3, 26, 36)),
#    FulL_Data(ssn=406490634, first_name='Lolita', last_name='Dailey', gender='Female', language='Czech', vehicle_make='Toyota', vehicle_model='Corolla', model_year=2003, employer='Bashirian Group', department='Legal', employee_id=674961160, last_updated=datetime.datetime(2017, 5, 10, 9, 45, 50), created=datetime.datetime(2016, 9, 6, 20, 39, 43)),
#    FulL_Data(ssn=409908946, first_name='Doralia', last_name='Proughten', gender='Female', language='Estonian', vehicle_make='Toyota', vehicle_model='Paseo', model_year=1994, employer='Yost and Sons', department='Sales', employee_id=77718175, last_updated=datetime.datetime(2017, 8, 14, 2, 56, 14), created=datetime.datetime(2016, 7, 13, 17, 13, 48)),
# ...
#    FulL_Data(ssn=671719470, first_name='Billie', last_name='Spittal', gender='Female', language='Catalan', vehicle_make='Porsche', vehicle_model='924 S', model_year=1987, employer='Wuckert Inc', department='Accounting', employee_id=646834709, last_updated=datetime.datetime(2017, 1, 15, 5, 30, 49), created=datetime.datetime(2016, 2, 24, 17, 39, 32)),
#    FulL_Data(ssn=773821734, first_name='Maris', last_name='Currin', gender='Female', language='Armenian', vehicle_make='Porsche', vehicle_model='Boxster', model_year=1999, employer='Hickle-Herman', department='Accounting', employee_id=915888473, last_updated=datetime.datetime(2018, 3, 18, 2, 18, 27), created=datetime.datetime(2016, 2, 25, 17, 48, 36))]),
#  ('Hyundai',
#   [FulL_Data(ssn=391149280, first_name='Faun', last_name='Chillistone', gender='Female', language='Montenegrin', vehicle_make='Hyundai', vehicle_model='Genesis', model_year=2010, employer='Friesen, Goyette and Satterfield', department='Research and Development', employee_id=161384768, last_updated=datetime.datetime(2018, 2, 16, 3, 12, 49), created=datetime.datetime(2016, 3, 16, 11, 53, 37)),
#    FulL_Data(ssn=397298349, first_name='Madelle', last_name='Mapledorum', gender='Female', language='Tok Pisin', vehicle_make='Hyundai', vehicle_model='Elantra', model_year=1995, employer='Okuneva-Lehner', department='Sales', employee_id=464308357, last_updated=datetime.datetime(2018, 3, 22, 14, 14, 2), created=datetime.datetime(2016, 5, 29, 20, 18, 22)),
#    FulL_Data(ssn=807246202, first_name='Lanette', last_name='Elvins', gender='Female', language='Hiri Motu', vehicle_make='Hyundai', vehicle_model='Accent', model_year=2000, employer='King Inc', department='Marketing', employee_id=284538440, last_updated=datetime.datetime(2017, 12, 22, 4, 19, 35), created=datetime.datetime(2016, 2, 20, 3, 53, 16)),
#    FulL_Data(ssn=848742886, first_name='Helyn', last_name='Witheford', gender='Female', language='Bislama', vehicle_make='Hyundai', vehicle_model='Accent', model_year=2011, employer='Macejkovic and Sons', department='Support', employee_id=520638791, last_updated=datetime.datetime(2017, 4, 28, 22, 57, 18), created=datetime.datetime(2016, 3, 16, 18, 7, 48))]),
#  ('Lincoln',
#   [FulL_Data(ssn=432258923, first_name='Violetta', last_name='Remmer', gender='Female', language='Swati', vehicle_make='Lincoln', vehicle_model='MKX', model_year=2008, employer='Stracke Group', department='Research and Development', employee_id=785974454, last_updated=datetime.datetime(2017, 4, 19, 6, 56, 28), created=datetime.datetime(2016, 12, 12, 14, 10, 18)),
#    FulL_Data(ssn=617383504, first_name='Toby', last_name='Hugnot', gender='Female', language='Maori', vehicle_make='Lincoln', vehicle_model='Town Car', model_year=1984, employer='Schuppe-Lynch', department='Training', employee_id=550503985, last_updated=datetime.datetime(2017, 5, 22, 11, 45, 40), created=datetime.datetime(2016, 1, 8, 20, 37, 3)),
#    FulL_Data(ssn=762438029, first_name='Gill', last_name='Wilford', gender='Female', language='Malay', vehicle_make='Lincoln', vehicle_model='Navigator', model_year=2001, employer='Sipes, Kovacek and McDermott', department='Legal', employee_id=764780191, last_updated=datetime.datetime(2017, 9, 27, 8, 58, 46), created=datetime.datetime(2016, 4, 25, 19, 17, 14)),
#    FulL_Data(ssn=819641414, first_name='Malynda', last_name='Hundall', gender='Female', language='Filipino', vehicle_make='Lincoln', vehicle_model='Aviator', model_year=2004, employer='Reichel and Sons', department='Human Resources', employee_id=151566614, last_updated=datetime.datetime(2017, 8, 26, 5, 23, 58), created=datetime.datetime(2016, 12, 12, 12, 4, 14))]),
#  ('Plymouth',
#   [FulL_Data(ssn=118957100, first_name='Alexi', last_name='Leglise', gender='Female', language='Lithuanian', vehicle_make='Plymouth', vehicle_model='Laser', model_year=1993, employer='Ernser LLC', department='Services', employee_id=76466085, last_updated=datetime.datetime(2017, 4, 25, 7, 54, 46), created=datetime.datetime(2016, 1, 29, 12, 5, 28)),
#    FulL_Data(ssn=218497300, first_name='Justinn', last_name='Sherebrooke', gender='Female', language='English', vehicle_make='Plymouth', vehicle_model='Neon', model_year=1995, employer='Johns, Corkery and Feeney', department='Services', employee_id=227439070, last_updated=datetime.datetime(2017, 12, 22, 19, 46, 19), created=datetime.datetime(2016, 9, 17, 5, 14, 16)),
#    FulL_Data(ssn=255810958, first_name='Darryl', last_name='Sparkes', gender='Female', language='Estonian', vehicle_make='Plymouth', vehicle_model='Colt', model_year=1992, employer='Aufderhar, Quigley and Wiza', department='Research and Development', employee_id=879571848, last_updated=datetime.datetime(2017, 1, 14, 1, 34, 12), created=datetime.datetime(2016, 9, 9, 15, 46, 19)),
#    FulL_Data(ssn=474567332, first_name='Maurine', last_name='Stopps', gender='Female', language='Tswana', vehicle_make='Plymouth', vehicle_model='Voyager', model_year=1995, employer='Ebert, McClure and Heidenreich', department='Legal', employee_id=598005391, last_updated=datetime.datetime(2017, 5, 14, 2, 24, 24), created=datetime.datetime(2016, 10, 11, 17, 27, 22))]),
#  ('Isuzu',
#   [FulL_Data(ssn=105915022, first_name='Moselle', last_name='Apfel', gender='Female', language='Latvian', vehicle_make='Isuzu', vehicle_model='Hombre Space', model_year=2000, employer='Lind-Jast', department='Marketing', employee_id=796418731, last_updated=datetime.datetime(2018, 3, 24, 14, 29, 33), created=datetime.datetime(2016, 3, 24, 3, 43, 3)),
#    FulL_Data(ssn=373672734, first_name='Ileana', last_name='Luty', gender='Female', language='Italian', vehicle_make='Isuzu', vehicle_model='Hombre Space', model_year=1997, employer='Brekke-Rippin', department='Services', employee_id=16025412, last_updated=datetime.datetime(2017, 9, 12, 1, 34, 15), created=datetime.datetime(2016, 7, 1, 8, 51, 19)),
#    FulL_Data(ssn=820961105, first_name='Andy', last_name='Sayce', gender='Female', language='Pashto', vehicle_make='Isuzu', vehicle_model='Hombre', model_year=1998, employer='Watsica-Ziemann', department='Research and Development', employee_id=877414041, last_updated=datetime.datetime(2017, 6, 11, 20, 41, 22), created=datetime.datetime(2016, 2, 14, 2, 38, 15))]),
#  ('Jaguar',
#   [FulL_Data(ssn=380339730, first_name='Katinka', last_name='Piet', gender='Female', language='Malay', vehicle_make='Jaguar', vehicle_model='X-Type', model_year=2003, employer='McDermott Inc', department='Research and Development', employee_id=907715733, last_updated=datetime.datetime(2017, 4, 3, 2, 41, 45), created=datetime.datetime(2016, 2, 23, 0, 21, 9)),
#    FulL_Data(ssn=446161946, first_name='Jacinthe', last_name='Hackworth', gender='Female', language='Albanian', vehicle_make='Jaguar', vehicle_model='XJ Series', model_year=2002, employer='Vandervort-Gutmann', department='Research and Development', employee_id=48895735, last_updated=datetime.datetime(2017, 8, 30, 3, 24, 42), created=datetime.datetime(2016, 5, 17, 15, 29, 10)),
#    FulL_Data(ssn=488127780, first_name='Cynthea', last_name='Ioannou', gender='Female', language='Yiddish', vehicle_make='Jaguar', vehicle_model='XJ', model_year=2010, employer='Turcotte Inc', department='Product Management', employee_id=210489175, last_updated=datetime.datetime(2018, 1, 3, 0, 42, 57), created=datetime.datetime(2016, 2, 12, 15, 0, 37))]),
#  ('Lamborghini',
#   [FulL_Data(ssn=342059057, first_name='Beatrix', last_name='Relton', gender='Female', language='Latvian', vehicle_make='Lamborghini', vehicle_model='Gallardo', model_year=2003, employer='Lind, Auer and Waelchi', department='Research and Development', employee_id=594510364, last_updated=datetime.datetime(2017, 3, 23, 6, 34, 5), created=datetime.datetime(2016, 7, 19, 5, 33, 42)),
#    FulL_Data(ssn=412509133, first_name='Dianemarie', last_name='Withey', gender='Female', language='Czech', vehicle_make='Lamborghini', vehicle_model='Gallardo', model_year=2003, employer="O'Connell-Stiedemann", department='Engineering', employee_id=44499468, last_updated=datetime.datetime(2017, 10, 11, 22, 13, 28), created=datetime.datetime(2016, 7, 21, 9, 43, 50)),
#    FulL_Data(ssn=599693085, first_name='Luz', last_name='Jeffcoate', gender='Female', language='Kyrgyz', vehicle_make='Lamborghini', vehicle_model='Gallardo', model_year=2012, employer='Rau, Hegmann and Yundt', department='Product Management', employee_id=308311767, last_updated=datetime.datetime(2017, 1, 5, 11, 40, 43), created=datetime.datetime(2016, 5, 8, 7, 18, 12))]),
#  ('Saab',
#   [FulL_Data(ssn=370726509, first_name='Wrennie', last_name='McCrorie', gender='Female', language='Papiamento', vehicle_make='Saab', vehicle_model='900', model_year=1991, employer='Padberg, Walter and Barton', department='Product Management', employee_id=221713376, last_updated=datetime.datetime(2017, 4, 26, 2, 36, 25), created=datetime.datetime(2016, 10, 28, 4, 26, 21)),
#    FulL_Data(ssn=499315371, first_name='Valenka', last_name='Triplett', gender='Female', language='Somali', vehicle_make='Saab', vehicle_model='5-Sep', model_year=2003, employer='Hickle and Sons', department='Research and Development', employee_id=255073339, last_updated=datetime.datetime(2017, 8, 3, 14, 53, 32), created=datetime.datetime(2016, 3, 3, 9, 43, 37)),
#    FulL_Data(ssn=789701821, first_name='Denni', last_name='De Biasio', gender='Female', language='Azeri', vehicle_make='Saab', vehicle_model='5-Sep', model_year=2004, employer='Hayes-Rutherford', department='Product Management', employee_id=947076951, last_updated=datetime.datetime(2017, 11, 3, 11, 8, 28), created=datetime.datetime(2016, 2, 3, 5, 46, 32))]),
#  ('Saturn',
#   [FulL_Data(ssn=195235731, first_name='Talyah', last_name='Canny', gender='Female', language='Portuguese', vehicle_make='Saturn', vehicle_model='Outlook', model_year=2007, employer='Hodkiewicz, Rau and Ryan', department='Marketing', employee_id=292776451, last_updated=datetime.datetime(2017, 5, 22, 16, 24, 23), created=datetime.datetime(2016, 10, 23, 11, 15, 3)),
#    FulL_Data(ssn=531381945, first_name='Eveleen', last_name='Mignot', gender='Female', language='Japanese', vehicle_make='Saturn', vehicle_model='S-Series', model_year=1995, employer='Fisher Inc', department='Research and Development', employee_id=750604341, last_updated=datetime.datetime(2017, 9, 12, 13, 13, 39), created=datetime.datetime(2016, 6, 13, 23, 32, 48)),
#    FulL_Data(ssn=573974729, first_name='Torey', last_name='Forcade', gender='Female', language='Indonesian', vehicle_make='Saturn', vehicle_model='Relay', model_year=2007, employer='Boehm-Schaefer', department='Human Resources', employee_id=603540943, last_updated=datetime.datetime(2017, 5, 8, 0, 22, 1), created=datetime.datetime(2016, 4, 29, 23, 31, 18))]),
#  ('Scion',
#   [FulL_Data(ssn=117396617, first_name='Auroora', last_name='Yong', gender='Female', language='Swahili', vehicle_make='Scion', vehicle_model='tC', model_year=2008, employer='Ritchie-Pagac', department='Business Development', employee_id=380095184, last_updated=datetime.datetime(2017, 9, 1, 11, 58, 21), created=datetime.datetime(2016, 12, 1, 10, 11, 17)),
#    FulL_Data(ssn=127684232, first_name='Tresa', last_name='Verheyden', gender='Female', language='Icelandic', vehicle_make='Scion', vehicle_model='xB', model_year=2004, employer='Kulas-Corwin', department='Sales', employee_id=780632027, last_updated=datetime.datetime(2017, 3, 20, 6, 5, 42), created=datetime.datetime(2016, 8, 19, 16, 32, 21)),
#    FulL_Data(ssn=184923560, first_name='Kore', last_name='Eastes', gender='Female', language='Fijian', vehicle_make='Scion', vehicle_model='xD', model_year=2011, employer='Johnston, Leuschke and Stracke', department='Support', employee_id=969321837, last_updated=datetime.datetime(2017, 2, 16, 4, 37, 8), created=datetime.datetime(2016, 7, 26, 19, 25, 30))]),
#  ('Aston Martin',
#   [FulL_Data(ssn=240676258, first_name='Kalina', last_name='Lloyds', gender='Female', language='Hindi', vehicle_make='Aston Martin', vehicle_model='V8 Vantage', model_year=2008, employer='Donnelly-Reichel', department='Sales', employee_id=516219405, last_updated=datetime.datetime(2017, 10, 17, 17, 8, 33), created=datetime.datetime(2016, 5, 24, 9, 11, 51)),
#    FulL_Data(ssn=386973523, first_name='Siusan', last_name='Durkin', gender='Female', language='Kurdish', vehicle_make='Aston Martin', vehicle_model='V8 Vantage S', model_year=2011, employer='Durgan LLC', department='Business Development', employee_id=758054834, last_updated=datetime.datetime(2017, 11, 13, 13, 40, 53), created=datetime.datetime(2016, 1, 9, 18, 15, 53))]),
#  ('Rolls-Royce',
#   [FulL_Data(ssn=117786202, first_name='Dareen', last_name='Jiggins', gender='Female', language='Polish', vehicle_make='Rolls-Royce', vehicle_model='Phantom', model_year=2007, employer='Kerluke-Dibbert', department='Services', employee_id=905121197, last_updated=datetime.datetime(2017, 11, 2, 2, 26, 10), created=datetime.datetime(2016, 4, 18, 0, 25, 1)),
#    FulL_Data(ssn=385980431, first_name='Kassi', last_name='Rashleigh', gender='Female', language='Tswana', vehicle_make='Rolls-Royce', vehicle_model='Phantom', model_year=2011, employer='Upton, Boehm and Kemmer', department='Product Management', employee_id=828364397, last_updated=datetime.datetime(2017, 1, 10, 17, 0, 26), created=datetime.datetime(2016, 12, 25, 11, 6, 50))]),
#  ('Austin',
#   [FulL_Data(ssn=777682978, first_name='Mignon', last_name='Skottle', gender='Female', language='Northern Sotho', vehicle_make='Austin', vehicle_model='Mini', model_year=1959, employer='Will, Crist and Jakubowski', department='Marketing', employee_id=224425487, last_updated=datetime.datetime(2018, 1, 16, 9, 16, 18), created=datetime.datetime(2016, 10, 1, 7, 34, 26))]),
#  ('Bugatti',
#   [FulL_Data(ssn=116107235, first_name='Chiquita', last_name='Danbi', gender='Female', language='Dari', vehicle_make='Bugatti', vehicle_model='Veyron', model_year=2009, employer='Pfannerstill Group', department='Research and Development', employee_id=431532437, last_updated=datetime.datetime(2017, 3, 10, 0, 31, 43), created=datetime.datetime(2016, 10, 17, 2, 11, 26))]),
#  ('Eagle',
#   [FulL_Data(ssn=348734312, first_name='Elberta', last_name='Howden', gender='Female', language='Khmer', vehicle_make='Eagle', vehicle_model='Vision', model_year=1994, employer='Sanford-Rohan', department='Engineering', employee_id=892980268, last_updated=datetime.datetime(2017, 9, 13, 10, 31, 30), created=datetime.datetime(2016, 12, 14, 21, 16, 27))]),
#  ('Geo',
#   [FulL_Data(ssn=408983291, first_name='Karia', last_name='Riquet', gender='Female', language='Italian', vehicle_make='Geo', vehicle_model='Metro', model_year=1992, employer='Gibson LLC', department='Training', employee_id=758998272, last_updated=datetime.datetime(2017, 5, 14, 10, 52, 18), created=datetime.datetime(2016, 4, 17, 22, 36, 47))]),
#  ('Morgan',
#   [FulL_Data(ssn=702675109, first_name='Gabi', last_name='Swallow', gender='Female', language='Sotho', vehicle_make='Morgan', vehicle_model='Aero 8', model_year=2009, employer='Wunsch, Johnson and Kiehn', department='Marketing', employee_id=476501802, last_updated=datetime.datetime(2017, 9, 19, 22, 31, 18), created=datetime.datetime(2016, 11, 2, 14, 50, 30))]),
#  ('Panoz',
#   [FulL_Data(ssn=849646624, first_name='Hallie', last_name='Proschke', gender='Female', language='Fijian', vehicle_make='Panoz', vehicle_model='Esperante', model_year=2006, employer='Blanda, Marks and Metz', department='Training', employee_id=810398914, last_updated=datetime.datetime(2018, 3, 23, 20, 28, 43), created=datetime.datetime(2016, 1, 10, 18, 3, 17))]),
#  ('Smart',
#   [FulL_Data(ssn=479498804, first_name='Serene', last_name='Giannotti', gender='Female', language='Latvian', vehicle_make='Smart', vehicle_model='Fortwo', model_year=2008, employer='Mueller and Sons', department='Accounting', employee_id=56804255, last_updated=datetime.datetime(2017, 1, 21, 6, 1, 32), created=datetime.datetime(2016, 11, 18, 19, 32, 59))])]

# %%
groups = get_filtered_grouped_data('personal_info.csv', 'vehicles.csv', 'employment.csv', 'update_status.csv',
                             filter_key = lambda x : x.gender == 'Female',
                                group_by = lambda x : x.vehicle_make)

# %%
length = lambda group : sum(1 for _ in group[1])
for group in groups:
    print(group[0])
    print(length(group))
    print()
# Out:
# Acura
# 11
#
# Aston Martin
# 2
#
# Audi
# 14
#
# Austin
# 1
#
# BMW
# 13
#
# Bentley
# 5
#
# Bugatti
# 1
#
# Buick
# 11
#
# Cadillac
# 6
#
# Chevrolet
# 48
#
# Chrysler
# 8
#
# Dodge
# 20
#
# Eagle
# 1
#
# Ford
# 48
#
# GMC
# 23
#
# Geo
# 1
#
# Honda
# 10
#
# Hyundai
# 4
#
# Infiniti
# 9
#
# Isuzu
# 3
#
# Jaguar
# 3
#
# Jeep
# 6
#
# Kia
# 9
#
# Lamborghini
# 3
#
# Land Rover
# 9
#
# Lexus
# 17
#
# Lincoln
# 4
#
# Lotus
# 7
#
# Mazda
# 15
#
# Mercedes-Benz
# 18
#
# Mercury
# 9
#
# Mitsubishi
# 25
#
# Morgan
# 1
#
# Nissan
# 12
#
# Oldsmobile
# 8
#
# Panoz
# 1
#
# Plymouth
# 4
#
# Pontiac
# 14
#
# Porsche
# 5
#
# Rolls-Royce
# 2
#
# Saab
# 3
#
# Saturn
# 3
#
# Scion
# 3
#
# Smart
# 1
#
# Subaru
# 9
#
# Suzuki
# 13
#
# Toyota
# 24
#
# Volkswagen
# 11
#
# Volvo
# 15
